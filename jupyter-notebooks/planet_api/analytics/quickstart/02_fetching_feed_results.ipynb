# %% [markdown]
# ###  Planet Analytics API Tutorial Part 2
#
# # Getting Analytic Feed Results
# This notebook shows how to paginate through Planet Analytic Feed Results for an existing analytics [Subscription](https://developers.planet.com/docs/analytics/#subscriptions) to construct a combined [GeoJSON](https://geojson.org/) feature collection that can be imported into geospatial analysis tools.

# %% [markdown]
# You can open this notebook in Colab below:

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/planetlabs/notebooks/blob/master/jupyter-notebooks/analytics/quickstart/02_fetching_feed_results.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Setup

# %% [markdown]
# #### Import Packages

# %%
import os
import requests
import pandas as pd
import json

from dateutil.parser import parse
from datetime import timedelta
from IPython.display import FileLink, FileLinks
import geopandas as gpd

# %% [markdown]
# To use this notebook, you need an [API key](https://developers.planet.com/quickstart/apis/) for a Planet account with access to the [Analytics API](https://developers.planet.com/docs/analytics/).
# #### API Key and Test Connection
# Set `API_KEY` below if it is not already in your notebook as an environment variable.
# See the [Analytics API Docs](https://developers.planet.com/docs/analytics/) for more details on authentication.

# %%
# If your Planet API Key is not set as an environment variable, you can paste it below
API_KEY = os.environ.get('PL_API_KEY', 'PASTE_YOUR_KEY_HERE')

# Alternatively, you can just set your API key directly as a string variable:
# API_KEY = "YOUR_PLANET_API_KEY_HERE"

# Construct auth tuple for use in the requests library
BASIC_AUTH = (API_KEY, '')
BASE_URL = "https://api.planet.com/analytics/"

subscriptions_list_url = BASE_URL + 'subscriptions' + '?limit=1000'
resp = requests.get(subscriptions_list_url, auth=BASIC_AUTH)
if resp.status_code == 200:
    print('Yay, you can access the Analytics API')
    subscriptions = resp.json()['data']
    print('Available subscriptions:', len(subscriptions))
else:
    print('Something is wrong:', resp.content)
# Out:
# Yay, you can access the Analytics API
# Available subscriptions: 562

# %% [markdown]
# #### Specify Analytics Subscription of Interest
# Below we will list your available subscription ids and some metadata in a dataframe and then select a subscription of interest. Note: this dataframe is only displaying a few of the rows. Change the code below to have max_rows set to the number of rows in the dataframe to see all of them.

# %%
pd.options.display.max_rows = 25
df = pd.DataFrame(subscriptions)
df['start'] = pd.to_datetime(df['startTime']).dt.date
df['end'] = pd.to_datetime(df['endTime']).dt.date
df[['id', 'title', 'description', 'start', 'end']]
# Out:
#                                        id  \
# 0    74e7c01e-f25c-4712-9c72-f5b58afb6f53
# 1    d113c5ac-6d64-4f7b-b501-16fa45a49293
# 2    ea0b8c2b-7504-4018-bed3-2ce089dd77c5
# 3    a7011f4c-20ec-4344-95fa-24708bee57e1
# 4    7dd2c0af-d88e-471d-bc76-9ffdb931ed6a
# ..                                    ...
# 557  3f598862-07e7-4d6e-a2ab-5a3d0889fb7d
# 558  360a743c-6021-40c3-a84a-d0a866239492
# 559  9db92275-1d89-4d3b-a0b6-68abd2e94142
# 560  6eff6c9e-c86a-4b89-b1e7-4f54d20075b2
# 561  63b8c2a8-1bf6-4280-9c45-29431fdb550f
#
#                                              title  \
# 0                                  Eastern Canada
# 1              Weekly road detections over Nairobi
# 2          Weekly building detections over Nairobi
# 3        Weekly road change detection over Nairobi
# 4    Weekly building change detection over Nairobi
# ..                                             ...
# 557                            Cartagena, Colombia
# 558                         Santa Rosa, California
# 559                           Port of Oakland, USA
# 560                                   Cairo, Egypt
# 561                           Silo Bags, Argentina
#
#                                       description       start         end
# 0                             Ship Detection 50m+  2023-06-01  2023-06-30
# 1    https://hello.planet.com/jira/browse/AN-6006  2022-01-01  2023-06-15
# 2    https://hello.planet.com/jira/browse/AN-6006  2022-01-01  2023-06-15
# 3    https://hello.planet.com/jira/browse/AN-6006  2022-01-01  2023-06-15
# 4    https://hello.planet.com/jira/browse/AN-6006  2022-01-01  2023-06-15
# ..                                            ...         ...         ...
# 557                        Daily Vessel Detection  2019-04-01  2020-04-01
# 558                    Monthly Building Detection  2018-01-01  2019-07-01
# 559                        Daily Vessel Detection  2019-01-01  2019-07-01
# 560                    Monthly Building Detection  2018-01-01  2020-03-01
# 561      Monthly silo bag detections in Argentina  2016-12-31  2018-08-01
#
# [562 rows x 5 columns]

# %% [markdown]
# Pick a subscription from which to pull results, and replace the ID below.

# %%
# This example ID is for a subscription of ship detections in the Port of Oakland
# You can replace this ID with your own subscription ID
SUBSCRIPTION_ID = '9db92275-1d89-4d3b-a0b6-68abd2e94142'

# %% [markdown]
# ## Getting subscription results
# In this section, we will make sure that we can get data from the subscription of interest by fetching the latest page of results.

# %%
# Construct the url for the subscription's results collection
subscription_results_url = BASE_URL + 'collections/' + SUBSCRIPTION_ID + '/items'
print("Request URL: {}".format(subscription_results_url))

# Get subscription results collection
resp = requests.get(subscription_results_url, auth=BASIC_AUTH)
if resp.status_code == 200:
    print('Yay, you can access analytic feed results!')
    subscription_results = resp.json()
    print(json.dumps(subscription_results, sort_keys=True, indent=4))
else:
    print('Something is wrong:', resp.content)
# Out:
# Request URL: https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items
# Yay, you can access analytic feed results!
# {
#     "features": [
#         {
#             "created": "2022-10-27T22:53:29.202Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.321902511231,
#                             37.7985556136176
#                         ],
#                         [
#                             -122.321911880908,
#                             37.797530647137
#                         ],
#                         [
#                             -122.324780667438,
#                             37.797547124339
#                         ],
#                         [
#                             -122.324771337394,
#                             37.7985720914244
#                         ],
#                         [
#                             -122.321902511231,
#                             37.7985556136176
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "3f758abf-a88e-452a-93bf-b989df5e2fb0",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/3f758abf-a88e-452a-93bf-b989df5e2fb0",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/3f758abf-a88e-452a-93bf-b989df5e2fb0/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 28725.010136945457,
#                 "object_diagonal_m": 277.00267308124154,
#                 "object_length_m": 252.58033275604248,
#                 "object_width_m": 113.72623443603516,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9999632835388184,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 3769,
#                 "xmin_px": 3685,
#                 "ymax_px": 2806,
#                 "ymin_px": 2768
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:29.180Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.317745920739,
#                             37.7976499863161
#                         ],
#                         [
#                             -122.317756885241,
#                             37.7964578230423
#                         ],
#                         [
#                             -122.321005906905,
#                             37.7964765933459
#                         ],
#                         [
#                             -122.320994994608,
#                             37.7976687574211
#                         ],
#                         [
#                             -122.317745920739,
#                             37.7976499863161
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "6f896217-3e72-47b9-b65f-dda00551897a",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/6f896217-3e72-47b9-b65f-dda00551897a",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/6f896217-3e72-47b9-b65f-dda00551897a/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 37839.69028454521,
#                 "object_diagonal_m": 315.16508026955614,
#                 "object_length_m": 286.06224060058594,
#                 "object_width_m": 132.27782249450684,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9999384880065918,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 3892,
#                 "xmin_px": 3796,
#                 "ymax_px": 2845,
#                 "ymin_px": 2801
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:29.107Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.337702269752,
#                             37.808791202799
#                         ],
#                         [
#                             -122.337720290319,
#                             37.8067735645397
#                         ],
#                         [
#                             -122.341159797492,
#                             37.8067928514107
#                         ],
#                         [
#                             -122.341141870497,
#                             37.8088104910636
#                         ],
#                         [
#                             -122.337702269752,
#                             37.808791202799
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "41486086-8f60-4242-ae8a-715a1c7dd2c5",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/41486086-8f60-4242-ae8a-715a1c7dd2c5",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/41486086-8f60-4242-ae8a-715a1c7dd2c5/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 67785.30854868407,
#                 "object_diagonal_m": 376.56236793235536,
#                 "object_length_m": 302.79030203819275,
#                 "object_width_m": 223.86882305145264,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9998646974563599,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 3303,
#                 "xmin_px": 3202,
#                 "ymax_px": 2467,
#                 "ymin_px": 2393
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:29.034Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.309536280453,
#                             37.8195378339453
#                         ],
#                         [
#                             -122.309542451641,
#                             37.8188753565485
#                         ],
#                         [
#                             -122.312786711391,
#                             37.8188943293961
#                         ],
#                         [
#                             -122.312780569194,
#                             37.819556807243
#                         ],
#                         [
#                             -122.309536280453,
#                             37.8195378339453
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "a5e7c66d-ab93-46a8-a5d9-4ae80c174707",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/a5e7c66d-ab93-46a8-a5d9-4ae80c174707",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/a5e7c66d-ab93-46a8-a5d9-4ae80c174707/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 20990.25682331671,
#                 "object_diagonal_m": 294.86616208407247,
#                 "object_length_m": 285.55712699890137,
#                 "object_width_m": 73.50633144378662,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9997599720954895,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 4127,
#                 "xmin_px": 4031,
#                 "ymax_px": 2014,
#                 "ymin_px": 1989
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.985Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.336624173715,
#                             37.7617381252532
#                         ],
#                         [
#                             -122.336639062114,
#                             37.760071064247
#                         ],
#                         [
#                             -122.337733136521,
#                             37.760077217602
#                         ],
#                         [
#                             -122.337718272673,
#                             37.7617442789756
#                         ],
#                         [
#                             -122.336624173715,
#                             37.7617381252532
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "0ba91a62-3174-4926-a693-78a5d7b0b6dc",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/0ba91a62-3174-4926-a693-78a5d7b0b6dc",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/0ba91a62-3174-4926-a693-78a5d7b0b6dc/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 17826.436962482432,
#                 "object_diagonal_m": 208.57052611600227,
#                 "object_length_m": 184.96878147125244,
#                 "object_width_m": 96.37538194656372,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9994613528251648,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 3347,
#                 "xmin_px": 3315,
#                 "ymax_px": 4194,
#                 "ymin_px": 4133
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.866Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.353905185539,
#                             37.7532650530998
#                         ],
#                         [
#                             -122.353926368906,
#                             37.7508289017967
#                         ],
#                         [
#                             -122.355411792288,
#                             37.7508370351469
#                         ],
#                         [
#                             -122.355390657617,
#                             37.7532731871599
#                         ],
#                         [
#                             -122.353905185539,
#                             37.7532650530998
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "9bf6d045-7c64-4bf9-bd3b-a4f7931e8340",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/9bf6d045-7c64-4bf9-bd3b-a4f7931e8340",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/9bf6d045-7c64-4bf9-bd3b-a4f7931e8340/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 35372.93177184551,
#                 "object_diagonal_m": 300.3142173663986,
#                 "object_length_m": 270.30186653137207,
#                 "object_width_m": 130.8645486831665,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9992130994796753,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 2842,
#                 "xmin_px": 2798,
#                 "ymax_px": 4540,
#                 "ymin_px": 4450
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.846Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.339408238694,
#                             37.7709226393746
#                         ],
#                         [
#                             -122.33942239954,
#                             37.7693308914788
#                         ],
#                         [
#                             -122.340812426844,
#                             37.769338675412
#                         ],
#                         [
#                             -122.340798295791,
#                             37.7709304237517
#                         ],
#                         [
#                             -122.339408238694,
#                             37.7709226393746
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "dc9c0b51-2903-42de-ba3c-6689b57b7ba0",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/dc9c0b51-2903-42de-ba3c-6689b57b7ba0",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/dc9c0b51-2903-42de-ba3c-6689b57b7ba0/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 21622.695872524248,
#                 "object_diagonal_m": 214.89796419012646,
#                 "object_length_m": 176.61259174346924,
#                 "object_width_m": 122.43009209632874,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9991957545280457,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 3263,
#                 "xmin_px": 3222,
#                 "ymax_px": 3853,
#                 "ymin_px": 3794
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.824Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.302170595011,
#                             37.7720997873654
#                         ],
#                         [
#                             -122.302174808813,
#                             37.7716514446495
#                         ],
#                         [
#                             -122.304667897189,
#                             37.7716661822955
#                         ],
#                         [
#                             -122.304663698438,
#                             37.772114525248
#                         ],
#                         [
#                             -122.302170595011,
#                             37.7720997873654
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "c03c9ad1-c75e-43df-8dc7-c2cfd8d57c19",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/c03c9ad1-c75e-43df-8dc7-c2cfd8d57c19",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/c03c9ad1-c75e-43df-8dc7-c2cfd8d57c19/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 10923.283619258655,
#                 "object_diagonal_m": 225.14428766679612,
#                 "object_length_m": 219.57972049713135,
#                 "object_width_m": 49.74632263183594,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9991936087608337,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 4356,
#                 "xmin_px": 4283,
#                 "ymax_px": 3759,
#                 "ymin_px": 3742
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.782Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.303812442421,
#                             37.7741787629601
#                         ],
#                         [
#                             -122.303815999374,
#                             37.7737994446457
#                         ],
#                         [
#                             -122.306250380485,
#                             37.7738138022212
#                         ],
#                         [
#                             -122.306246835967,
#                             37.7741931207307
#                         ],
#                         [
#                             -122.303812442421,
#                             37.7741787629601
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "ff916050-7469-4e00-ac40-b98002e7aa06",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/ff916050-7469-4e00-ac40-b98002e7aa06",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/ff916050-7469-4e00-ac40-b98002e7aa06/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 9023.709225128585,
#                 "object_diagonal_m": 218.49467351018149,
#                 "object_length_m": 214.40277993679047,
#                 "object_width_m": 42.087650299072266,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9991641044616699,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 4307,
#                 "xmin_px": 4236,
#                 "ymax_px": 3680,
#                 "ymin_px": 3666
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.629Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.321151378794,
#                             37.7955823621382
#                         ],
#                         [
#                             -122.321152844603,
#                             37.7954221782053
#                         ],
#                         [
#                             -122.321418686333,
#                             37.7954237097189
#                         ],
#                         [
#                             -122.321417221098,
#                             37.7955838936606
#                         ],
#                         [
#                             -122.321151378794,
#                             37.7955823621382
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "1e4784d8-65c7-4790-8323-ec5e8b73cc68",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/1e4784d8-65c7-4790-8323-ec5e8b73cc68",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/1e4784d8-65c7-4790-8323-ec5e8b73cc68/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 416.0129532034773,
#                 "object_diagonal_m": 29.389766411679247,
#                 "object_length_m": 23.406529426574707,
#                 "object_width_m": 17.773371934890747,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9951919317245483,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 3792,
#                 "xmin_px": 3785,
#                 "ymax_px": 2884,
#                 "ymin_px": 2878
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.564Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.320370107304,
#                             37.8167493182344
#                         ],
#                         [
#                             -122.320375462561,
#                             37.8161652083297
#                         ],
#                         [
#                             -122.321019600474,
#                             37.8161689231044
#                         ],
#                         [
#                             -122.321014250291,
#                             37.8167530330869
#                         ],
#                         [
#                             -122.320370107304,
#                             37.8167493182344
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "27e899f4-d240-43dd-aa82-b18e46263041",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/27e899f4-d240-43dd-aa82-b18e46263041",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/27e899f4-d240-43dd-aa82-b18e46263041/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 3674.6702256550634,
#                 "object_diagonal_m": 86.11126325945624,
#                 "object_length_m": 64.81075286865234,
#                 "object_width_m": 56.69846534729004,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.992913544178009,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 3810,
#                 "xmin_px": 3791,
#                 "ymax_px": 2116,
#                 "ymin_px": 2095
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.542Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.351231284014,
#                             37.7909927185961
#                         ],
#                         [
#                             -122.351233206482,
#                             37.7907728525038
#                         ],
#                         [
#                             -122.351497784244,
#                             37.7907743091177
#                         ],
#                         [
#                             -122.35149586256,
#                             37.7909941752216
#                         ],
#                         [
#                             -122.351231284014,
#                             37.7909927185961
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "9caf5f19-aa89-464d-bf15-604f653778bf",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/9caf5f19-aa89-464d-bf15-604f653778bf",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/9caf5f19-aa89-464d-bf15-604f653778bf/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 568.3265180041985,
#                 "object_diagonal_m": 33.73218442107828,
#                 "object_length_m": 24.395298957824707,
#                 "object_width_m": 23.29655885696411,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9925131797790527,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 2911,
#                 "xmin_px": 2903,
#                 "ymax_px": 3062,
#                 "ymin_px": 3054
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.522Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.355224789167,
#                             37.804491074178
#                         ],
#                         [
#                             -122.355226800578,
#                             37.8042597239505
#                         ],
#                         [
#                             -122.355558940088,
#                             37.8042615413832
#                         ],
#                         [
#                             -122.355556929713,
#                             37.8044928916258
#                         ],
#                         [
#                             -122.355224789167,
#                             37.804491074178
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "862e8536-7ad9-47f7-97b2-9df8410ddb08",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/862e8536-7ad9-47f7-97b2-9df8410ddb08",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/862e8536-7ad9-47f7-97b2-9df8410ddb08/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 750.5820011883202,
#                 "object_diagonal_m": 38.9090366430209,
#                 "object_length_m": 29.24015522003174,
#                 "object_width_m": 25.669562816619873,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9917938113212585,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 2790,
#                 "xmin_px": 2780,
#                 "ymax_px": 2564,
#                 "ymin_px": 2555
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.434Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.339611051894,
#                             37.7576914897686
#                         ],
#                         [
#                             -122.339615234897,
#                             37.7572209434447
#                         ],
#                         [
#                             -122.340071338518,
#                             37.7572234983386
#                         ],
#                         [
#                             -122.340067158403,
#                             37.7576940447057
#                         ],
#                         [
#                             -122.339611051894,
#                             37.7576914897686
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "c3e742c7-7a60-4bb7-9fd2-4dba19210ce0",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/c3e742c7-7a60-4bb7-9fd2-4dba19210ce0",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/c3e742c7-7a60-4bb7-9fd2-4dba19210ce0/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 2097.722437491498,
#                 "object_diagonal_m": 65.8800084607047,
#                 "object_length_m": 52.209413051605225,
#                 "object_width_m": 40.17900824546814,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9868725538253784,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 3260,
#                 "xmin_px": 3247,
#                 "ymax_px": 4300,
#                 "ymin_px": 4283
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.412Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.350805141521,
#                             37.8313603992745
#                         ],
#                         [
#                             -122.350812257398,
#                             37.8305482890107
#                         ],
#                         [
#                             -122.351155230508,
#                             37.8305501790001
#                         ],
#                         [
#                             -122.351148118389,
#                             37.8313622893189
#                         ],
#                         [
#                             -122.350805141521,
#                             37.8313603992745
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "9ddb92f1-97ca-402e-a8ff-6974c506b6a5",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/9ddb92f1-97ca-402e-a8ff-6974c506b6a5",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/9ddb92f1-97ca-402e-a8ff-6974c506b6a5/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 2719.7654485394196,
#                 "object_diagonal_m": 95.02932798614472,
#                 "object_length_m": 90.10852575302124,
#                 "object_width_m": 30.18321990966797,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9858047366142273,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 2913,
#                 "xmin_px": 2903,
#                 "ymax_px": 1591,
#                 "ymin_px": 1561
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.369Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.353732435549,
#                             37.8304912537751
#                         ],
#                         [
#                             -122.353739192918,
#                             37.8297165418005
#                         ],
#                         [
#                             -122.354324171759,
#                             37.8297197502244
#                         ],
#                         [
#                             -122.354317420506,
#                             37.830494462288
#                         ],
#                         [
#                             -122.353732435549,
#                             37.8304912537751
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "90498785-dbb5-4692-9908-fb91bdb41d36",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/90498785-dbb5-4692-9908-fb91bdb41d36",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/90498785-dbb5-4692-9908-fb91bdb41d36/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDSYKARNMSENEHY2B4W04H2",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 4425.283555329429,
#                 "object_diagonal_m": 100.19613601952774,
#                 "object_length_m": 85.95889806747437,
#                 "object_width_m": 51.48138999938965,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9849955439567566,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 2827,
#                 "xmin_px": 2810,
#                 "ymax_px": 1622,
#                 "ymin_px": 1594
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:53:28.348Z",
# ...
#                 "source_item": "20190310_183151_1011",
#                 "source_item_id": "20190310_183151_1011",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 7075,
#                 "xmin_px": 7057,
#                 "ymax_px": 3244,
#                 "ymin_px": 3236
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:02:51.901Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.248596288713,
#                             37.7561512910541
#                         ],
#                         [
#                             -122.248601306493,
#                             37.7556551890158
#                         ],
#                         [
#                             -122.249301981756,
#                             37.7556596542748
#                         ],
#                         [
#                             -122.249296968654,
#                             37.7561557563925
#                         ],
#                         [
#                             -122.248596288713,
#                             37.7561512910541
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "d0a76e0c-7980-4b19-a2e9-5c01d569a801",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/d0a76e0c-7980-4b19-a2e9-5c01d569a801",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/d0a76e0c-7980-4b19-a2e9-5c01d569a801/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190306_174823_1020/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDQ6V8P5WHSA2HD4RPMN1MK",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 3397.7856488922953,
#                 "object_diagonal_m": 82.70548566225413,
#                 "object_length_m": 61.72628402709961,
#                 "object_width_m": 55.04601001739502,
#                 "observed": "2019-03-06T17:48:23.711623Z",
#                 "score": 0.2576855719089508,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0.95,
#                 "source_item": "20190306_174823_1020",
#                 "source_item_id": "20190306_174823_1020",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 7223,
#                 "xmin_px": 7203,
#                 "ymax_px": 569,
#                 "ymin_px": 551
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2022-10-27T22:01:26.094Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.296835300226,
#                             37.7797134940192
#                         ],
#                         [
#                             -122.296837602377,
#                             37.7794704752446
#                         ],
#                         [
#                             -122.297757496194,
#                             37.7794759612973
#                         ],
#                         [
#                             -122.297755197054,
#                             37.7797189801196
#                         ],
#                         [
#                             -122.296835300226,
#                             37.7797134940192
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "3fcffeb2-0f53-40ac-8ed4-245834add24a",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/3fcffeb2-0f53-40ac-8ed4-245834add24a",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/3fcffeb2-0f53-40ac-8ed4-245834add24a/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene/20190306_174824_1020/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01GGDQ25WXKZEVQHTHG4QT01JN",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 2184.433692859784,
#                 "object_diagonal_m": 85.38125394173964,
#                 "object_length_m": 81.01158142089844,
#                 "object_width_m": 26.96446180343628,
#                 "observed": "2019-03-06T17:48:24.679458Z",
#                 "score": 0.9371533989906311,
#                 "source_asset_type": "ortho_visual",
#                 "source_cloud_cover": 0.96,
#                 "source_item": "20190306_174824_1020",
#                 "source_item_id": "20190306_174824_1020",
#                 "source_item_type": "PSScene",
#                 "xmax_px": 6276,
#                 "xmin_px": 6249,
#                 "ymax_px": 1942,
#                 "ymin_px": 1933
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.759Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.317713873257,
#                             37.7976192704836
#                         ],
#                         [
#                             -122.317723790946,
#                             37.7965409790567
#                         ],
#                         [
#                             -122.321105937749,
#                             37.7965605175067
#                         ],
#                         [
#                             -122.321096069214,
#                             37.7976388096881
#                         ],
#                         [
#                             -122.317713873257,
#                             37.7976192704836
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "cd15b571-7be7-402e-b22e-53fff14b3e46",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/cd15b571-7be7-402e-b22e-53fff14b3e46",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/cd15b571-7be7-402e-b22e-53fff14b3e46/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 35627.66391231207,
#                 "object_diagonal_m": 320.9192565102493,
#                 "object_length_m": 297.7829933166504,
#                 "object_width_m": 119.64304447174072,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9999659061431885,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8757,
#                 "xmin_px": 8657,
#                 "ymax_px": 4782,
#                 "ymin_px": 4742
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.708Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.343476877205,
#                             37.7586051994162
#                         ],
#                         [
#                             -122.343491849288,
#                             37.7569110752871
#                         ],
#                         [
#                             -122.344261218932,
#                             37.7569153586168
#                         ],
#                         [
#                             -122.344246264392,
#                             37.7586094830059
#                         ],
#                         [
#                             -122.343476877205,
#                             37.7586051994162
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "ec342c11-16ab-4fc9-a647-5736cce07b71",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/ec342c11-16ab-4fc9-a647-5736cce07b71",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/ec342c11-16ab-4fc9-a647-5736cce07b71/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 12739.827056627746,
#                 "object_diagonal_m": 199.81662351745013,
#                 "object_length_m": 187.97121047973633,
#                 "object_width_m": 67.77541637420654,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9997726082801819,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8011,
#                 "xmin_px": 7988,
#                 "ymax_px": 6253,
#                 "ymin_px": 6190
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.661Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.352774419657,
#                             37.7810046282309
#                         ],
#                         [
#                             -122.352791033632,
#                             37.7790992467131
#                         ],
#                         [
#                             -122.353339749612,
#                             37.7791022594001
#                         ],
#                         [
#                             -122.35332314972,
#                             37.7810076411235
#                         ],
#                         [
#                             -122.352774419657,
#                             37.7810046282309
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "06c7f0f0-7d24-4ac2-880d-b2bb3ec70693",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/06c7f0f0-7d24-4ac2-880d-b2bb3ec70693",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/06c7f0f0-7d24-4ac2-880d-b2bb3ec70693/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 10216.052276237519,
#                 "object_diagonal_m": 216.8640093301126,
#                 "object_length_m": 211.41164302825928,
#                 "object_width_m": 48.32303524017334,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9996918439865112,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 7732,
#                 "xmin_px": 7716,
#                 "ymax_px": 5434,
#                 "ymin_px": 5364
#             },
#             "type": "Feature"
#         }
#     ],
#     "links": [
#         {
#             "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items",
#             "rel": "self",
#             "type": "application/geo+json"
#         },
#         {
#             "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142",
#             "rel": "collection",
#             "type": "application/json"
#         },
#         {
#             "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items?before=06c7f0f0-7d24-4ac2-880d-b2bb3ec70693",
#             "rel": "next",
#             "type": "application/json"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %% [markdown]
# ## Pagination

# %% [markdown]
# The response JSON above will only include the most recent 250 detections by default. For subscriptions with many results, you can page through

# %%
print(len(subscription_results['features']))
# Out:
# 250

# %% [markdown]
# More results can be fetched by following the `next` link. Let's look at the links section of the response:

# %%
subscription_results['links']
# Out:
# [{'href': 'https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items',
#   'rel': 'self',
#   'type': 'application/geo+json'},
#  {'href': 'https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142',
#   'rel': 'collection',
#   'type': 'application/json'},
#  {'href': 'https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items?before=06c7f0f0-7d24-4ac2-880d-b2bb3ec70693',
#   'rel': 'next',
#   'type': 'application/json'}]

# %% [markdown]
# To get more results, we will want the link with a `rel` of `next`

# %%
def get_next_link(results_json):
    """Given a response json from one page of subscription results, 
    get the url for the next page of results.
    
    Args:
        results_json (dict): The response JSON containing the subscription results.

    Returns:
        str or None: The URL for the next page of results if available, None otherwise.
    """
    for link in results_json['links']:
        if link['rel'] == 'next':
            return link['href']
    return None

# %%
next_link = get_next_link(subscription_results)
print('next page url: ' + next_link)
# Out:
# next page url: https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items?before=06c7f0f0-7d24-4ac2-880d-b2bb3ec70693

# %% [markdown]
# Using this url, we can fetch the next page of results

# %%
next_results = requests.get(next_link, auth=BASIC_AUTH).json()
print(json.dumps(next_results, sort_keys=True, indent=4))
# Out:
# {
#     "features": [
#         {
#             "created": "2021-03-11T11:54:55.587Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.339000091352,
#                             37.7676941976696
#                         ],
#                         [
#                             -122.339016420564,
#                             37.7658596232049
#                         ],
#                         [
#                             -122.339984096549,
#                             37.7658650469385
#                         ],
#                         [
#                             -122.339967791239,
#                             37.7676996217596
#                         ],
#                         [
#                             -122.339000091352,
#                             37.7676941976696
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "361a4e3d-913f-442c-a566-4c6e45ef2291",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/361a4e3d-913f-442c-a566-4c6e45ef2291",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/361a4e3d-913f-442c-a566-4c6e45ef2291/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 17349.92818464889,
#                 "object_diagonal_m": 220.68006340257944,
#                 "object_length_m": 203.55534553527832,
#                 "object_width_m": 85.23445129394531,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9995751976966858,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8140,
#                 "xmin_px": 8111,
#                 "ymax_px": 5921,
#                 "ymin_px": 5853
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.563Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.320547005317,
#                             37.8126018925402
#                         ],
#                         [
#                             -122.32056216554,
#                             37.8109476105829
#                         ],
#                         [
#                             -122.322710566533,
#                             37.8109599828214
#                         ],
#                         [
#                             -122.322695454238,
#                             37.8126142655116
#                         ],
#                         [
#                             -122.320547005317,
#                             37.8126018925402
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "18a5bb97-7060-4deb-a2a7-385605c23a8b",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/18a5bb97-7060-4deb-a2a7-385605c23a8b",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/18a5bb97-7060-4deb-a2a7-385605c23a8b/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 34713.62016527337,
#                 "object_diagonal_m": 263.5493023424518,
#                 "object_length_m": 189.12034034729004,
#                 "object_width_m": 183.55307579040527,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9993937015533447,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8669,
#                 "xmin_px": 8606,
#                 "ymax_px": 4250,
#                 "ymin_px": 4188
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.539Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.335659318336,
#                             37.7575659097866
#                         ],
#                         [
#                             -122.335674207888,
#                             37.7559008901309
#                         ],
#                         [
#                             -122.336160449326,
#                             37.7559036300111
#                         ],
#                         [
#                             -122.33614557067,
#                             37.7575686498301
#                         ],
#                         [
#                             -122.335659318336,
#                             37.7575659097866
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "49137b5e-1d37-4e99-b371-86301ebb9708",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/49137b5e-1d37-4e99-b371-86301ebb9708",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/49137b5e-1d37-4e99-b371-86301ebb9708/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 7913.376063446265,
#                 "object_diagonal_m": 189.64305325072692,
#                 "object_length_m": 184.74218845367432,
#                 "object_width_m": 42.83469915390015,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9992891550064087,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8241,
#                 "xmin_px": 8226,
#                 "ymax_px": 6288,
#                 "ymin_px": 6227
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.514Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.309594954954,
#                             37.8195932713129
#                         ],
#                         [
#                             -122.309601508227,
#                             37.8188897180348
#                         ],
#                         [
#                             -122.312710839389,
#                             37.8189079020269
#                         ],
#                         [
#                             -122.312704315624,
#                             37.819611455763
#                         ],
#                         [
#                             -122.309594954954,
#                             37.8195932713129
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "f9767b9d-e723-4ba6-9191-07a7a7024559",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/f9767b9d-e723-4ba6-9191-07a7a7024559",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/f9767b9d-e723-4ba6-9191-07a7a7024559/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 21364.609301225384,
#                 "object_diagonal_m": 284.5964661648379,
#                 "object_length_m": 273.6807703971863,
#                 "object_width_m": 78.06397676467896,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9985138773918152,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8989,
#                 "xmin_px": 8898,
#                 "ymax_px": 3953,
#                 "ymin_px": 3927
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.477Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.349385568053,
#                             37.7892067345552
#                         ],
#                         [
#                             -122.349396860038,
#                             37.7879188555906
#                         ],
#                         [
#                             -122.349879968374,
#                             37.7879215223241
#                         ],
#                         [
#                             -122.349868684772,
#                             37.7892094014117
#                         ],
#                         [
#                             -122.349385568053,
#                             37.7892067345552
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "153b4b25-27e9-42e8-be78-25a38282619c",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/153b4b25-27e9-42e8-be78-25a38282619c",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/153b4b25-27e9-42e8-be78-25a38282619c/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 6078.868389225818,
#                 "object_diagonal_m": 149.09462100246844,
#                 "object_length_m": 142.8969383239746,
#                 "object_width_m": 42.54022836685181,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9981566071510315,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 7829,
#                 "xmin_px": 7815,
#                 "ymax_px": 5107,
#                 "ymin_px": 5060
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.246Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.351996889599,
#                             37.8265843993318
#                         ],
#                         [
#                             -122.35200378254,
#                             37.8257961495419
#                         ],
#                         [
#                             -122.352281135353,
#                             37.8257976751309
#                         ],
#                         [
#                             -122.352274245362,
#                             37.8265859249639
#                         ],
#                         [
#                             -122.351996889599,
#                             37.8265843993318
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "03af42b8-1ddf-4f3b-a07c-5ba26ebe589e",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/03af42b8-1ddf-4f3b-a07c-5ba26ebe589e",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/03af42b8-1ddf-4f3b-a07c-5ba26ebe589e/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 2134.9126937337815,
#                 "object_diagonal_m": 90.80343696896341,
#                 "object_length_m": 87.46097087860107,
#                 "object_width_m": 24.409890174865723,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.972985029220581,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 7743,
#                 "xmin_px": 7735,
#                 "ymax_px": 3707,
#                 "ymin_px": 3678
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.222Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.320354102277,
#                             37.8167411457625
#                         ],
#                         [
#                             -122.320358881889,
#                             37.8162198357986
#                         ],
#                         [
#                             -122.32094803015,
#                             37.8162232336675
#                         ],
#                         [
#                             -122.320943254681,
#                             37.8167445436948
#                         ],
#                         [
#                             -122.320354102277,
#                             37.8167411457625
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "80c8f7a6-d91d-470a-b0d5-74aa6a6ae1e0",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/80c8f7a6-d91d-470a-b0d5-74aa6a6ae1e0",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/80c8f7a6-d91d-470a-b0d5-74aa6a6ae1e0/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 2999.61317754736,
#                 "object_diagonal_m": 77.68552992068062,
#                 "object_length_m": 57.84269571304321,
#                 "object_width_m": 51.85811519622803,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9687620997428894,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8674,
#                 "xmin_px": 8657,
#                 "ymax_px": 4054,
#                 "ymin_px": 4035
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.197Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.352224388895,
#                             37.8326381838189
#                         ],
#                         [
#                             -122.352231033945,
#                             37.8318781818481
#                         ],
#                         [
#                             -122.352509680698,
#                             37.8318797140975
#                         ],
#                         [
#                             -122.352503038506,
#                             37.8326397161099
#                         ],
#                         [
#                             -122.352224388895,
#                             37.8326381838189
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "e6078467-371a-470d-bfb6-b47beb221e60",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/e6078467-371a-470d-bfb6-b47beb221e60",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/e6078467-371a-470d-bfb6-b47beb221e60/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 2067.841026401993,
#                 "object_diagonal_m": 87.8198402119918,
#                 "object_length_m": 84.32679176330566,
#                 "object_width_m": 24.521756172180176,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9661811590194702,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 7735,
#                 "xmin_px": 7727,
#                 "ymax_px": 3482,
#                 "ymin_px": 3454
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:55.053Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.350349666167,
#                             37.8298619602961
#                         ],
#                         [
#                             -122.350356421256,
#                             37.8290915252331
#                         ],
#                         [
#                             -122.350609586409,
#                             37.8290929213849
#                         ],
#                         [
#                             -122.350602833952,
#                             37.8298633564864
#                         ],
#                         [
#                             -122.350349666167,
#                             37.8298619602961
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "eacdfcd6-5a1b-404c-993c-23253ac3fa49",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/eacdfcd6-5a1b-404c-993c-23253ac3fa49",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/eacdfcd6-5a1b-404c-993c-23253ac3fa49/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 1904.60474318769,
#                 "object_diagonal_m": 88.34017799537044,
#                 "object_length_m": 85.48439741134644,
#                 "object_width_m": 22.280144691467285,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.9010502099990845,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 7791,
#                 "xmin_px": 7783,
#                 "ymax_px": 3585,
#                 "ymin_px": 3556
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:54.992Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.321472378819,
#                             37.798566407811
#                         ],
#                         [
#                             -122.321482838087,
#                             37.7974229713648
#                         ],
#                         [
#                             -122.325188256583,
#                             37.7974442541754
#                         ],
#                         [
#                             -122.325177854423,
#                             37.798587691493
#                         ],
#                         [
#                             -122.321472378819,
#                             37.798566407811
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "9ffab0fd-ad63-4ef1-8a61-0631c306cb19",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/9ffab0fd-ad63-4ef1-8a61-0631c306cb19",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/9ffab0fd-ad63-4ef1-8a61-0631c306cb19/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 41390.649650542175,
#                 "object_diagonal_m": 350.04257830071333,
#                 "object_length_m": 326.2414813041687,
#                 "object_width_m": 126.8712043762207,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.8576847314834595,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8646,
#                 "xmin_px": 8537,
#                 "ymax_px": 4750,
#                 "ymin_px": 4708
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:54.941Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.304246937672,
#                             37.8216452143384
#                         ],
#                         [
#                             -122.304258763853,
#                             37.8203854029174
#                         ],
#                         [
#                             -122.305664185167,
#                             37.8203936961337
#                         ],
#                         [
#                             -122.305652382871,
#                             37.8216535079287
#                         ],
#                         [
#                             -122.304246937672,
#                             37.8216452143384
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "75f38a96-2deb-4177-8ee4-4af236cc84bc",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/75f38a96-2deb-4177-8ee4-4af236cc84bc",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/75f38a96-2deb-4177-8ee4-4af236cc84bc/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 17291.61344557903,
#                 "object_diagonal_m": 186.65982924699557,
#                 "object_length_m": 139.78476617485285,
#                 "object_width_m": 123.70170168578625,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.8043216466903687,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 9145,
#                 "xmin_px": 9104,
#                 "ymax_px": 3897,
#                 "ymin_px": 3850
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:54.847Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.316380917373,
#                             37.8164296581306
#                         ],
#                         [
#                             -122.316388914282,
#                             37.8155624916365
#                         ],
#                         [
#                             -122.317355970468,
#                             37.8155681000738
#                         ],
#                         [
#                             -122.31734798487,
#                             37.8164352667421
#                         ],
#                         [
#                             -122.316380917373,
#                             37.8164296581306
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "0f009702-54e2-4584-9507-cf7ffc7bb524",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/0f009702-54e2-4584-9507-cf7ffc7bb524",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/0f009702-54e2-4584-9507-cf7ffc7bb524/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 8190.366436747283,
#                 "object_diagonal_m": 128.4672025424276,
#                 "object_length_m": 96.21777534484863,
#                 "object_width_m": 85.12321561574936,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.7406523823738098,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8791,
#                 "xmin_px": 8762,
#                 "ymax_px": 4078,
#                 "ymin_px": 4046
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:54.733Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.336093641802,
#                             37.8095212357031
#                         ],
#                         [
#                             -122.336101106264,
#                             37.8086875632165
#                         ],
#                         [
#                             -122.337101075975,
#                             37.8086931946946
#                         ],
#                         [
#                             -122.337093622754,
#                             37.8095268673493
#                         ],
#                         [
#                             -122.336093641802,
#                             37.8095212357031
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "d61e2987-45f3-4649-9164-48fd81b63fe5",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/d61e2987-45f3-4649-9164-48fd81b63fe5",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/d61e2987-45f3-4649-9164-48fd81b63fe5/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 8142.685985061178,
#                 "object_diagonal_m": 127.69251118671924,
#                 "object_length_m": 92.50091314315796,
#                 "object_width_m": 88.02816867828369,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.6821142435073853,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8214,
#                 "xmin_px": 8185,
#                 "ymax_px": 4336,
#                 "ymin_px": 4306
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:54.619Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.30852281663,
#                             37.8209046601334
#                         ],
#                         [
#                             -122.308531977667,
#                             37.8199227046799
#                         ],
#                         [
#                             -122.308971067045,
#                             37.8199252815509
#                         ],
#                         [
#                             -122.308961911825,
#                             37.820907237095
#                         ],
#                         [
#                             -122.30852281663,
#                             37.8209046601334
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "bd801db3-ded3-46e3-ad25-6f9ae96d9b5d",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/bd801db3-ded3-46e3-ad25-6f9ae96d9b5d",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/bd801db3-ded3-46e3-ad25-6f9ae96d9b5d/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 4210.853204222076,
#                 "object_diagonal_m": 115.60605300849029,
#                 "object_length_m": 108.95462036132812,
#                 "object_width_m": 38.64777088165283,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.50907963514328,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 9020,
#                 "xmin_px": 9007,
#                 "ymax_px": 3915,
#                 "ymin_px": 3879
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2021-03-11T11:54:54.368Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.331932411211,
#                             37.811459018645
#                         ],
#                         [
#                             -122.331936432948,
#                             37.811012682236
#                         ],
#                         [
#                             -122.332245352216,
#                             37.8110144338255
#                         ],
#                         [
#                             -122.332241332337,
#                             37.8114607702626
#                         ],
#                         [
#                             -122.331932411211,
#                             37.811459018645
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "886f149e-3aa4-4ac7-a47e-7d453379e917",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/886f149e-3aa4-4ac7-a47e-7d453379e917",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/886f149e-3aa4-4ac7-a47e-7d453379e917/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190321_184225_76_105a/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01F0GHQ13R38DBT4S60XNBA5YH",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 1346.7283431691612,
#                 "object_diagonal_m": 56.49860074756711,
#                 "object_length_m": 49.52373504638672,
#                 "object_width_m": 27.193593978881836,
#                 "observed": "2019-03-21T18:42:25.761709Z",
#                 "score": 0.2980149984359741,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190321_184225_76_105a",
#                 "source_item_id": "20190321_184225_76_105a",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 8336,
#                 "xmin_px": 8327,
#                 "ymax_px": 4249,
#                 "ymin_px": 4233
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2020-01-08T23:17:33.705Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.321840759081,
#                             37.7985758487169
#                         ],
#                         [
#                             -122.321850352724,
#                             37.7975264778576
#                         ],
#                         [
#                             -122.324821925668,
#                             37.7975435456801
#                         ],
#                         [
#                             -122.324812374055,
#                             37.7985929171809
#                         ],
#                         [
#                             -122.321840759081,
#                             37.7985758487169
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "f7b67a48-9703-467f-abaf-9e85a1da604e",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/f7b67a48-9703-467f-abaf-9e85a1da604e",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/f7b67a48-9703-467f-abaf-9e85a1da604e/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190317_184156_63_105d/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01DY3PAXQ2XNYB1760P67TCY1R",
#                 "_object_class_idx": 1,
#                 "intersects": false,
#                 "model_id": "01DPSEHT77T7HHJZHAHCKFDPEK",
#                 "model_version": "2019-10-16T00:58:07Z",
#                 "object_area_m2": 30462.652737285225,
#                 "object_diagonal_m": 286.3689931867615,
#                 "object_length_m": 261.63010597229004,
#                 "object_width_m": 116.43404960632324,
#                 "observed": "2019-03-17T18:41:56.6367Z",
#                 "score": 0.9999649524688721,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0,
#                 "source_item": "20190317_184156_63_105d",
#                 "source_item_id": "20190317_184156_63_105d",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 3771,
#                 "xmin_px": 3684,
#                 "ymax_px": 2806,
#                 "ymin_px": 2767
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2020-01-08T23:17:33.599Z",
#             "geometry": {
#                 "coordinates": [
# ...
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0.01,
#                 "source_item": "20190420_190506_46_106e",
#                 "source_item_id": "20190420_190506_46_106e",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 7003,
#                 "xmin_px": 6944,
#                 "ymax_px": 5172,
#                 "ymin_px": 5158
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2019-09-10T09:08:32.778Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.33927096793,
#                             37.8338859937042
#                         ],
#                         [
#                             -122.339273437621,
#                             37.8336090862757
#                         ],
#                         [
#                             -122.339641830787,
#                             37.8336111524566
#                         ],
#                         [
#                             -122.339639362473,
#                             37.8338880599056
#                         ],
#                         [
#                             -122.33927096793,
#                             37.8338859937042
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "e1216693-df38-4619-87b7-3379d16e9bf5",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/e1216693-df38-4619-87b7-3379d16e9bf5",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/e1216693-df38-4619-87b7-3379d16e9bf5/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190420_190506_46_106e/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01DMD6KWX5VGVF7KD2HK0J640S",
#                 "_object_class_idx": 1,
#                 "model_id": "01DC28ADKRSTRBFV9RRMXMCGCD",
#                 "model_version": "2019-06-11T17:49:59Z",
#                 "object_area_m2": 996.0630307708129,
#                 "object_diagonal_m": 44.66539007008656,
#                 "object_length_m": 32.41903781890869,
#                 "object_width_m": 30.724632740020752,
#                 "observed": "2019-04-20T19:05:06.46994Z",
#                 "score": 0.5504727959632874,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0.01,
#                 "source_item": "20190420_190506_46_106e",
#                 "source_item_id": "20190420_190506_46_106e",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 6288,
#                 "xmin_px": 6277,
#                 "ymax_px": 3269,
#                 "ymin_px": 3259
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2019-09-10T09:08:32.771Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.313145786449,
#                             37.8192067931807
#                         ],
#                         [
#                             -122.313157111308,
#                             37.8179846480517
#                         ],
#                         [
#                             -122.314530245441,
#                             37.8179926470179
#                         ],
#                         [
#                             -122.314518943219,
#                             37.8192147924969
#                         ],
#                         [
#                             -122.313145786449,
#                             37.8192067931807
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "f2563b47-1b06-47b8-9e0e-e0daca92386b",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/f2563b47-1b06-47b8-9e0e-e0daca92386b",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/f2563b47-1b06-47b8-9e0e-e0daca92386b/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190420_190506_46_106e/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01DMD6KWX5VGVF7KD2HK0J640S",
#                 "_object_class_idx": 1,
#                 "model_id": "01DC28ADKRSTRBFV9RRMXMCGCD",
#                 "model_version": "2019-06-11T17:49:59Z",
#                 "object_area_m2": 16389.7166053135,
#                 "object_diagonal_m": 181.6500675629046,
#                 "object_length_m": 135.6051206588745,
#                 "object_width_m": 120.86355239152908,
#                 "observed": "2019-04-20T19:05:06.46994Z",
#                 "score": 0.5253764986991882,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0.01,
#                 "source_item": "20190420_190506_46_106e",
#                 "source_item_id": "20190420_190506_46_106e",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 7058,
#                 "xmin_px": 7018,
#                 "ymax_px": 3842,
#                 "ymin_px": 3796
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2019-09-10T09:08:32.757Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.31952463309,
#                             37.8133094703489
#                         ],
#                         [
#                             -122.319528934085,
#                             37.8128408771892
#                         ],
#                         [
#                             -122.320169135455,
#                             37.8128445737653
#                         ],
#                         [
#                             -122.320164838506,
#                             37.813313166987
#                         ],
#                         [
#                             -122.31952463309,
#                             37.8133094703489
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "95ec3c02-cecd-44f6-8b6f-417c72680e89",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/95ec3c02-cecd-44f6-8b6f-417c72680e89",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/95ec3c02-cecd-44f6-8b6f-417c72680e89/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190420_190506_46_106e/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01DMD6KWX5VGVF7KD2HK0J640S",
#                 "_object_class_idx": 1,
#                 "model_id": "01DC28ADKRSTRBFV9RRMXMCGCD",
#                 "model_version": "2019-06-11T17:49:59Z",
#                 "object_area_m2": 2930.062329118357,
#                 "object_diagonal_m": 76.6755749295536,
#                 "object_length_m": 56.354498863220215,
#                 "object_width_m": 51.99340581893921,
#                 "observed": "2019-04-20T19:05:06.46994Z",
#                 "score": 0.5015562772750854,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0.01,
#                 "source_item": "20190420_190506_46_106e",
#                 "source_item_id": "20190420_190506_46_106e",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 6872,
#                 "xmin_px": 6854,
#                 "ymax_px": 4033,
#                 "ymin_px": 4016
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2019-09-10T09:08:32.749Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.322445137544,
#                             37.8109457250545
#                         ],
#                         [
#                             -122.322448232253,
#                             37.8106070753061
#                         ],
#                         [
#                             -122.322876951518,
#                             37.8106095404771
#                         ],
#                         [
#                             -122.322873858766,
#                             37.8109481902555
#                         ],
#                         [
#                             -122.322445137544,
#                             37.8109457250545
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "4d989f54-f275-46dc-88cf-c7ba7faab9be",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/4d989f54-f275-46dc-88cf-c7ba7faab9be",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/4d989f54-f275-46dc-88cf-c7ba7faab9be/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190420_190506_46_106e/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01DMD6KWX5VGVF7KD2HK0J640S",
#                 "_object_class_idx": 1,
#                 "model_id": "01DC28ADKRSTRBFV9RRMXMCGCD",
#                 "model_version": "2019-06-11T17:49:59Z",
#                 "object_area_m2": 1418.079156710803,
#                 "object_diagonal_m": 53.25584773311154,
#                 "object_length_m": 37.739646434783936,
#                 "object_width_m": 37.575316429138184,
#                 "observed": "2019-04-20T19:05:06.46994Z",
#                 "score": 0.48599621653556824,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0.01,
#                 "source_item": "20190420_190506_46_106e",
#                 "source_item_id": "20190420_190506_46_106e",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 6787,
#                 "xmin_px": 6775,
#                 "ymax_px": 4116,
#                 "ymin_px": 4104
#             },
#             "type": "Feature"
#         },
#         {
#             "created": "2019-09-10T09:08:32.744Z",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             -122.342290353196,
#                             37.8063607295564
#                         ],
#                         [
#                             -122.342293968641,
#                             37.8059530895413
#                         ],
#                         [
#                             -122.342640321852,
#                             37.8059550227851
#                         ],
#                         [
#                             -122.34263670831,
#                             37.8063626628285
#                         ],
#                         [
#                             -122.342290353196,
#                             37.8063607295564
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "0307bbd3-4540-48ee-87d2-6908af802d6d",
#             "links": [
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/0307bbd3-4540-48ee-87d2-6908af802d6d",
#                     "rel": "self",
#                     "type": "application/geo+json"
#                 },
#                 {
#                     "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items/0307bbd3-4540-48ee-87d2-6908af802d6d/resources/source-image-info",
#                     "rel": "source-image-info",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://tiles.planet.com/data/v1/PSScene3Band/20190420_190506_46_106e/{z}/{x}/{y}.png?api_key=PLAKc5a71489528f4bfe8fa087bfd60befc7",
#                     "rel": "source-tiles",
#                     "type": "image/png"
#                 }
#             ],
#             "properties": {
#                 "_g4_task_instance_id": "taski_01DMD6KWX5VGVF7KD2HK0J640S",
#                 "_object_class_idx": 1,
#                 "model_id": "01DC28ADKRSTRBFV9RRMXMCGCD",
#                 "model_version": "2019-06-11T17:49:59Z",
#                 "object_area_m2": 1379.1012458547414,
#                 "object_diagonal_m": 54.5476399929291,
#                 "object_length_m": 45.23000121116638,
#                 "object_width_m": 30.490851402282715,
#                 "observed": "2019-04-20T19:05:06.46994Z",
#                 "score": 0.4816700518131256,
#                 "source_asset_type": "visual",
#                 "source_cloud_cover": 0.01,
#                 "source_item": "20190420_190506_46_106e",
#                 "source_item_id": "20190420_190506_46_106e",
#                 "source_item_type": "PSScene3Band",
#                 "xmax_px": 6206,
#                 "xmin_px": 6196,
#                 "ymax_px": 4293,
#                 "ymin_px": 4278
#             },
#             "type": "Feature"
#         }
#     ],
#     "links": [
#         {
#             "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items?before=06c7f0f0-7d24-4ac2-880d-b2bb3ec70693",
#             "rel": "self",
#             "type": "application/geo+json"
#         },
#         {
#             "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142",
#             "rel": "collection",
#             "type": "application/json"
#         },
#         {
#             "href": "https://api.planet.com/analytics/collections/9db92275-1d89-4d3b-a0b6-68abd2e94142/items?before=0307bbd3-4540-48ee-87d2-6908af802d6d",
#             "rel": "next",
#             "type": "application/json"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %% [markdown]
# ## Aggregating results

# %% [markdown]
# Each page of results comes as one feature collection. We can combine the features from different pages of results into one big feature collection. Below we will page through all results in the subscription from the past 3 months and make a combined feature collection.
#
# Results in the API are ordered by a `created` timestamp. This corresponds the time that the feature was published to a Feed and does not necessarily match the `observed` timestamp in the feature's properties, which corresponds to when the source imagery for a feature was collected.

# %%
latest_feature = subscription_results['features'][0]
creation_datestring = latest_feature['created']
print('latest feature creation date:', creation_datestring)
# Out:
# latest feature creation date: 2022-10-27T22:53:29.202Z

# %%
# This date string can be parsed as a datetime and converted to a date
latest_date = parse(creation_datestring).date()
latest_date
# Out:
# datetime.date(2022, 10, 27)

# %%
min_date = latest_date - timedelta(days=90)
print('Aggregate all detections from after this date:', min_date)
# Out:
# Aggregate all detections from after this date: 2022-07-29

# %%
feature_collection = {'type': 'FeatureCollection', 'features': []}
next_link = subscription_results_url

# Fetch features iteratively until there are no more next links
while next_link:
    results = requests.get(next_link, auth=BASIC_AUTH).json()
    next_features = results['features']

    # Check if there are next features available
    if next_features:
        latest_feature_creation = parse(next_features[0]['created']).date()
        earliest_feature_creation = parse(next_features[-1]['created']).date()
        print('Fetched {} features fetched ({}, {})'.format(
            len(next_features), earliest_feature_creation, latest_feature_creation))
        feature_collection['features'].extend(next_features)
        next_link = get_next_link(results)

    # No next features available
    else:
        next_link = None

print('Total features: {}'.format(len(feature_collection['features'])))
# Out:
# Fetched 250 features fetched (2021-03-11, 2022-10-27)
# Fetched 250 features fetched (2019-09-10, 2021-03-11)
# Fetched 250 features fetched (2019-07-27, 2019-09-10)
# Fetched 250 features fetched (2019-07-27, 2019-07-27)
# Fetched 250 features fetched (2019-07-27, 2019-07-27)
# Fetched 250 features fetched (2019-06-13, 2019-07-27)
# Fetched 250 features fetched (2019-05-10, 2019-06-13)
# Fetched 250 features fetched (2019-04-27, 2019-05-10)
# Fetched 250 features fetched (2019-04-17, 2019-04-27)
# Fetched 250 features fetched (2019-04-17, 2019-04-17)
# Fetched 250 features fetched (2019-04-17, 2019-04-17)
# Fetched 231 features fetched (2019-04-16, 2019-04-17)
# Total features: 2981

# %% [markdown]
# ## Saving Results
# We can now save the combined geojson feature collection to a file.

# %%
os.makedirs('data', exist_ok=True)
filename = 'data/collection_{}.geojson'.format(SUBSCRIPTION_ID)
with open(filename, 'w') as file:
    json.dump(feature_collection, file)

FileLink(filename)
# Out:
# /Users/em.steuer/repos/notebooks/jupyter-notebooks/analytics/quickstart/data/collection_9db92275-1d89-4d3b-a0b6-68abd2e94142.geojson

# %% [markdown]
# After downloading the aggregated geojson file with the file link above, try importing the data into a geojson-compatible tool for visualization and exploration:
# - [geojson.io](http://geojson.io/)
# - [kepler gl](https://kepler.gl/demo)

# %% [markdown]
# The saved geojson file can also be used to make a geopandas dataframe.

# %%
gpd.read_file(filename)
# Out:
#                                         id              _g4_task_instance_id  \
# 0     3f758abf-a88e-452a-93bf-b989df5e2fb0  taski_01GGDSYKARNMSENEHY2B4W04H2
# 1     6f896217-3e72-47b9-b65f-dda00551897a  taski_01GGDSYKARNMSENEHY2B4W04H2
# 2     41486086-8f60-4242-ae8a-715a1c7dd2c5  taski_01GGDSYKARNMSENEHY2B4W04H2
# 3     a5e7c66d-ab93-46a8-a5d9-4ae80c174707  taski_01GGDSYKARNMSENEHY2B4W04H2
# 4     0ba91a62-3174-4926-a693-78a5d7b0b6dc  taski_01GGDSYKARNMSENEHY2B4W04H2
# ...                                    ...                               ...
# 2976  86a84bc9-61a9-430a-8ec8-51cda2867309  taski_01D8M83TAF00T4216FMNSEY244
# 2977  15374c67-7264-4e4d-b9ae-1918cfda6191  taski_01D8M83TAF00T4216FMNSEY244
# 2978  a7924c83-80ee-4f66-9b8a-927bde558280  taski_01D8M83TAF00T4216FMNSEY244
# 2979  9c058105-a0da-4740-ab10-100802d4ea81  taski_01D8M83TAF00T4216FMNSEY244
# 2980  80ef6dd2-b58b-4e4f-9597-e766d65532c3  taski_01D8M83TAF00T4216FMNSEY244
#
#       _object_class_idx intersects                    model_id  \
# 0                     1      False  01DPSEHT77T7HHJZHAHCKFDPEK
# 1                     1      False  01DPSEHT77T7HHJZHAHCKFDPEK
# 2                     1      False  01DPSEHT77T7HHJZHAHCKFDPEK
# 3                     1      False  01DPSEHT77T7HHJZHAHCKFDPEK
# 4                     1      False  01DPSEHT77T7HHJZHAHCKFDPEK
# ...                 ...        ...                         ...
# 2976                  1       None  01D3FJCDHEZ1JS56150B7YR8VT
# 2977                  1       None  01D3FJCDHEZ1JS56150B7YR8VT
# 2978                  1       None  01D3FJCDHEZ1JS56150B7YR8VT
# 2979                  1       None  01D3FJCDHEZ1JS56150B7YR8VT
# 2980                  1       None  01D3FJCDHEZ1JS56150B7YR8VT
#
#                   model_version  object_area_m2  object_diagonal_m  \
# 0     2019-10-16T00:58:07+00:00    28725.010137         277.002673
# 1     2019-10-16T00:58:07+00:00    37839.690285         315.165080
# 2     2019-10-16T00:58:07+00:00    67785.308549         376.562368
# 3     2019-10-16T00:58:07+00:00    20990.256823         294.866162
# 4     2019-10-16T00:58:07+00:00    17826.436962         208.570526
# ...                         ...             ...                ...
# 2976  2019-03-29T21:01:06+00:00    16964.645640         292.182788
# 2977  2019-03-29T21:01:06+00:00     3788.069094         128.292116
# 2978  2019-03-29T21:01:06+00:00     2820.959943         104.516177
# 2979  2019-03-29T21:01:06+00:00     3311.149335         133.751098
# 2980  2019-03-29T21:01:06+00:00     1551.966873          56.647755
#
#       object_length_m  object_width_m  ... source_asset_type  \
# 0          252.580333      113.726234  ...      ortho_visual
# 1          286.062241      132.277822  ...      ortho_visual
# 2          302.790302      223.868823  ...      ortho_visual
# 3          285.557127       73.506331  ...      ortho_visual
# 4          184.968781       96.375382  ...      ortho_visual
# ...               ...             ...  ...               ...
# 2976       286.102796       59.295630  ...            visual
# 2977       124.640250       30.392021  ...            visual
# 2978       100.691307       28.015924  ...            visual
# 2979       131.354190       25.207794  ...            visual
# 2980        44.851202       34.602571  ...            visual
#
#       source_cloud_cover              source_item           source_item_id  \
# 0                    0.0  20190317_184156_63_105d  20190317_184156_63_105d
# 1                    0.0  20190317_184156_63_105d  20190317_184156_63_105d
# 2                    0.0  20190317_184156_63_105d  20190317_184156_63_105d
# 3                    0.0  20190317_184156_63_105d  20190317_184156_63_105d
# 4                    0.0  20190317_184156_63_105d  20190317_184156_63_105d
# ...                  ...                      ...                      ...
# 2976                 0.7     20190408_183125_1027     20190408_183125_1027
# 2977                 0.7     20190408_183125_1027     20190408_183125_1027
# 2978                 0.7     20190408_183125_1027     20190408_183125_1027
# 2979                 0.7     20190408_183125_1027     20190408_183125_1027
# 2980                 0.7     20190408_183125_1027     20190408_183125_1027
#
#      source_item_type xmax_px xmin_px  ymax_px  ymin_px  \
# 0             PSScene    3769    3685     2806     2768
# 1             PSScene    3892    3796     2845     2801
# 2             PSScene    3303    3202     2467     2393
# 3             PSScene    4127    4031     2014     1989
# 4             PSScene    3347    3315     4194     4133
# ...               ...     ...     ...      ...      ...
# 2976     PSScene3Band    6651    6555     2072     2052
# 2977     PSScene3Band    6974    6932     3860     3850
# 2978     PSScene3Band    6909    6900     3023     2989
# 2979     PSScene3Band    7415    7406     3911     3867
# 2980     PSScene3Band    7109    7094     3101     3089
#
#                                                geometry
# 0     POLYGON ((-122.32190 37.79856, -122.32191 37.7...
# 1     POLYGON ((-122.31775 37.79765, -122.31776 37.7...
# 2     POLYGON ((-122.33770 37.80879, -122.33772 37.8...
# 3     POLYGON ((-122.30954 37.81954, -122.30954 37.8...
# 4     POLYGON ((-122.33662 37.76174, -122.33664 37.7...
# ...                                                 ...
# 2976  POLYGON ((-122.30958 37.81943, -122.30958 37.8...
# 2977  POLYGON ((-122.29903 37.77078, -122.29903 37.7...
# 2978  POLYGON ((-122.30100 37.79405, -122.30101 37.7...
# 2979  POLYGON ((-122.28400 37.77021, -122.28401 37.7...
# 2980  POLYGON ((-122.29421 37.79131, -122.29422 37.7...
#
# [2981 rows x 22 columns]
