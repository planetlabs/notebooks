# %% [markdown]
# # Deriving a vegetation index from PlanetScope SR data

# %% [markdown]
# Researchers often use a vegetation index called NDVI to measure the "greenness" or density of vegetation across a landscape. In addition to monitoring vegetation health, NDVI _(Normalized Difference Vegetation Index)_ can be used to track climate change, agricultural production, desertification, and land cover change. Developed by NASA scientist Compton Tucker in 1977, NDVI is derived from satellite imagery and compares reflected near-infrared light to reflected visible red light. It can be expressed as following equation:

# %% [markdown]
# ![ndvi-equation.png](images/ndvi-equation.png)

# %% [markdown]
# In general, healthy and/or dense vegetation reflects a lot of near-infrared light and not as much red visible light. Conversely, when vegetation is sparse or not-so-healthy, its near-infrared reflectance decreases and its red light reflectance increases. You can read more about how NDVI is used to study cyclical, seasonal, and long-term changes to the Earth's physical characteristics from [NASA](https://earthobservatory.nasa.gov/Features/MeasuringVegetation/measuring_vegetation_1.php) and [USGS](https://phenology.cr.usgs.gov/ndvi_foundation.php) researchers.

# %% [markdown]
# To create this vegetation index, we're going to use PlanetScope's SR _(Surface Reflectance)_ data product. This data has been algorithmically corrected to remove atmospheric interference, and contains normalized Surface Reflectance values.

# %% [markdown]
# **In this guide, you'll perform a basic NDVI calculation on PlanetScope Surface Reflectance data using just a few lines of Python. Here are the steps:**
#
# 1. Download a PlanetScope SR product
# 2. Extract data from the red and near-infrared bands
# 3. Perform the NDVI calculation
# 4. Save the NDVI image
# 5. Apply a color scheme and visualize NDVI on a map
# 6. Generate a histogram to view NDVI values

# %% [markdown]
# ### Requirements
# - Python 2.7 or 3+
# - [Planet's Python Client](https://www.planet.com/docs/api-quickstart-examples/cli/)
# - [rasterio](https://github.com/mapbox/rasterio)
# - [numpy](http://www.numpy.org/)
# - [matplotlib](https://matplotlib.org/)
# - [Planet API Key](https://www.planet.com/account/#/), stored as environment variable `$PL_API_KEY`.
# - [Planet 4-Band Imagery](https://www.planet.com/docs/imagery-quickstart/) with the following specifications: `item-type`: `PSScene4Band`; `asset-type`: `analytic_sr`

# %% [markdown]
# ## Step 1. Download a PlanetScope SR Product

# %% [markdown]
# First, you're going to download a [4-band PlanetScope Surface Reflectance product](https://www.planet.com/docs/spec-sheets/sat-imagery/#ps-imagery-product) of agricultural land in California's Central Valley, captured in late August 2016 (`item-id`: `20160831_180302_0e26`). You can do this using [Planet's Python client](https://www.planet.com/docs/api-quickstart-examples/cli/) to interact with our Data API, or by browsing [Planet Explorer](https://www.planet.com/products/explorer/), filtering for 4 Band PlanetScope scene (`PSScene4Band`), and downloading an `analytic_sr` asset.
#
# Before you download the full image, you can [preview a thumbnail](https://www.planet.com/docs/reference/data-api/previews/) of the image via Planet's Data API. (The thumbnails are 256x256 by default, and can be scaled up to 512x512 by passing in a `width` parameter.)

# %%
from IPython.display import Image
Image(url="https://api.planet.com/data/v1/item-types/PSScene4Band/items/20160831_180302_0e26/thumb?width=512")
# Out:
# <img src="https://api.planet.com/data/v1/item-types/PSScene4Band/items/20160831_180302_0e26/thumb?width=512"/>

# %% [markdown]
# Next, you'll use [Planet's Python client](https://planetlabs.github.io/planet-client-python/index.html) to download the image. *Note: when you run this command, you'll get a stream of messages in your Jupyter notebook as the Python client polls the Data API to determine if the image is [activated and ready to download](https://www.planet.com/docs/api-quickstart-examples/step-2-download/#activate).*

# %%
# !planet data download --item-type PSScene4Band --asset-type analytic_sr --dest data --string-in id 20160831_180302_0e26
# Out:
# activating: 0            complete: 0              elapsed: 0
# paging: False            pending: 0
#
# activating: 1            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 1               paging: True
# pending: 0
#
# activating: 0            complete: 0              downloaded: 0.00MB
# downloading: 0           elapsed: 2               paging: False
# pending: 1
#
# activating: 0            complete: 0              downloaded: 0.00MB
# downloading: 1           elapsed: 3               paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 0.00MB
# downloading: 1           elapsed: 4               paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 0.29MB
# downloading: 1           elapsed: 5               paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 0.75MB
# downloading: 1           elapsed: 6               paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 1.15MB
# downloading: 1           elapsed: 7               paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 1.57MB
# downloading: 1           elapsed: 8               paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 1.97MB
# downloading: 1           elapsed: 9               paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 2.42MB
# downloading: 1           elapsed: 10              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 2.59MB
# downloading: 1           elapsed: 11              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 3.15MB
# downloading: 1           elapsed: 12              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 3.44MB
# downloading: 1           elapsed: 13              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 3.96MB
# downloading: 1           elapsed: 14              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 4.33MB
# downloading: 1           elapsed: 15              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 4.69MB
# downloading: 1           elapsed: 16              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 5.11MB
# downloading: 1           elapsed: 17              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 5.57MB
# downloading: 1           elapsed: 18              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 5.90MB
# downloading: 1           elapsed: 19              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 6.32MB
# downloading: 1           elapsed: 20              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 6.75MB
# downloading: 1           elapsed: 21              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 7.21MB
# downloading: 1           elapsed: 22              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 7.54MB
# downloading: 1           elapsed: 23              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 7.86MB
# downloading: 1           elapsed: 24              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 8.19MB
# downloading: 1           elapsed: 25              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 8.59MB
# downloading: 1           elapsed: 26              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 8.91MB
# downloading: 1           elapsed: 27              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 9.24MB
# downloading: 1           elapsed: 28              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 9.57MB
# downloading: 1           elapsed: 29              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 9.86MB
# downloading: 1           elapsed: 30              paging: False
# pending: 0
# activating: 0            complete: 0              downloaded: 10.19MB
# downloading: 1           elapsed: 31              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 10.52MB
# downloading: 1           elapsed: 32              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 10.85MB
# downloading: 1           elapsed: 33              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 11.14MB
# downloading: 1           elapsed: 34              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 11.40MB
# downloading: 1           elapsed: 35              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 11.60MB
# downloading: 1           elapsed: 36              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 11.76MB
# downloading: 1           elapsed: 37              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 11.99MB
# downloading: 1           elapsed: 38              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 12.16MB
# downloading: 1           elapsed: 39              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 12.29MB
# downloading: 1           elapsed: 40              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 12.45MB
# downloading: 1           elapsed: 41              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 12.75MB
# downloading: 1           elapsed: 42              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 13.04MB
# downloading: 1           elapsed: 43              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 13.30MB
# downloading: 1           elapsed: 44              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 13.57MB
# downloading: 1           elapsed: 45              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 13.86MB
# downloading: 1           elapsed: 46              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 14.09MB
# downloading: 1           elapsed: 47              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 14.32MB
# downloading: 1           elapsed: 48              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 14.48MB
# downloading: 1           elapsed: 49              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 14.75MB
# downloading: 1           elapsed: 50              paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded:
paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 156.66MB
# downloading: 1           elapsed: 597             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 156.89MB
# downloading: 1           elapsed: 598             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 157.12MB
# downloading: 1           elapsed: 599             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 157.35MB
# downloading: 1           elapsed: 600             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 157.58MB
# downloading: 1           elapsed: 601             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 157.78MB
# downloading: 1           elapsed: 602             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 157.94MB
# downloading: 1           elapsed: 603             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 157.94MB
# downloading: 1           elapsed: 604             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 158.01MB
# downloading: 1           elapsed: 605             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 158.17MB
# downloading: 1           elapsed: 606             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 158.27MB
# downloading: 1           elapsed: 607             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 158.37MB
# downloading: 1           elapsed: 608             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 158.47MB
# downloading: 1           elapsed: 609             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 158.60MB
# downloading: 1           elapsed: 610             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 158.76MB
# downloading: 1           elapsed: 611             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 158.92MB
# downloading: 1           elapsed: 612             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 159.15MB
# downloading: 1           elapsed: 613             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 159.38MB
# downloading: 1           elapsed: 614             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 159.71MB
# downloading: 1           elapsed: 615             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 159.97MB
# downloading: 1           elapsed: 616             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 160.30MB
# downloading: 1           elapsed: 617             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 160.53MB
# downloading: 1           elapsed: 618             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 160.83MB
# downloading: 1           elapsed: 619             paging: False
# pending: 0
# activating: 0            complete: 0              downloaded: 161.05MB
# downloading: 1           elapsed: 620             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 161.32MB
# downloading: 1           elapsed: 621             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 161.61MB
# downloading: 1           elapsed: 622             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 161.97MB
# downloading: 1           elapsed: 623             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 162.37MB
# downloading: 1           elapsed: 624             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 162.73MB
# downloading: 1           elapsed: 625             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 163.12MB
# downloading: 1           elapsed: 626             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 163.41MB
# downloading: 1           elapsed: 627             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 163.74MB
# downloading: 1           elapsed: 628             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 164.07MB
# downloading: 1           elapsed: 629             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 164.07MB
# downloading: 1           elapsed: 630             paging: False
# pending: 0
#
# activating: 0            complete: 0              downloaded: 164.07MB
# downloading: 1           elapsed: 630             paging: False
# pending: 0

# %% [markdown]
# **Congratulations!** You now have a new file in your `data` directory: `20160831_180302_0e26_3B_AnalyticMS_SR.tif`. This file is a GeoTIFF, the image you requested with spatial reference data embedded.

# %% [markdown]
# ## Step 2. Extract the data from the red and near-infrared bands

# %% [markdown]
# In this step, you'll use [Rasterio](https://github.com/mapbox/rasterio), a Python library for reading and writing geospatial raster datasets, to open the raster image you downloaded (the .tif file). Then you'll extract the data from the red and near-infrared bands and load the band data into arrays that you can manipulate using Python's [NumPy](http://www.numpy.org/) libary.
#
# *Note: in PlanetScope 4-band images, the band order is BGRN: (1) Blue, (2) Green, (3) Red, (4) Near-infrared.*

# %%
import rasterio
import numpy as np

filename = "data/20160831_180302_0e26_3B_AnalyticMS_SR.tif"

# Load red and NIR bands - note all PlanetScope 4-band images have band order BGRN
with rasterio.open(filename) as src:
    band_red = src.read(3)

with rasterio.open(filename) as src:
    band_nir = src.read(4)

# %% [markdown]
# ## Step 3. Perform the NDVI calculation

# %% [markdown]
# Next, you're going to calculate NDVI through subtraction and division of the values stored in the NumPy arrays. This calculation will give you NDVI values that range from -1 to 1. Values closer to 1 indicate a greater density of vegetation or higher level of "greenness."

# %%
# Allow division by zero
np.seterr(divide='ignore', invalid='ignore')

# Calculate NDVI. This is the equation at the top of this guide expressed in code
ndvi = (band_nir.astype(float) - band_red.astype(float)) / (band_nir + band_red)

# %%
# check range NDVI values, excluding NaN
np.nanmin(ndvi), np.nanmax(ndvi)
# Out:
# (-0.4971605575632421, 0.8841409691629956)

# %% [markdown]
# ## Step 5. Save the NDVI image

# %% [markdown]
# Next, you're going to save the calculated NDVI values to a new image file, making sure the new image file has the same geospatial metadata as the original GeoTIFF we downloaded.

# %%
# Set spatial characteristics of the output object to mirror the input
kwargs = src.meta
kwargs.update(
    dtype=rasterio.float32,
    count = 1)

# Write band calculations to a new raster file
with rasterio.open('output/ndvi.tif', 'w', **kwargs) as dst:
        dst.write_band(1, ndvi.astype(rasterio.float32))

# %% [markdown]
# ## Step 6. Apply a color scheme to visualize the NDVI values on the image

# %% [markdown]
# In the last two steps, you'll use [Matplotlib](https://matplotlib.org/) to visualize the NDVI values you calculated for the PlanetScope scene. First you'll view a map of the NDVI values; then you'll generate a histogram of NDVI values.

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

"""
The NDVI values will range from -1 to 1. You want to use a diverging color scheme to visualize the data,
and you want to center the colorbar at a defined midpoint. The class below allows you to normalize the colorbar.
"""

class MidpointNormalize(colors.Normalize):
    """
    Normalise the colorbar so that diverging bars work there way either side from a prescribed midpoint value)
    e.g. im=ax1.imshow(array, norm=MidpointNormalize(midpoint=0.,vmin=-100, vmax=100))
    Credit: Joe Kington, http://chris35wills.github.io/matplotlib_diverging_colorbar/
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y), np.isnan(value))


# Set min/max values from NDVI range for image (excluding NAN)
# set midpoint according to how NDVI is interpreted: https://earthobservatory.nasa.gov/Features/MeasuringVegetation/
min=np.nanmin(ndvi)
max=np.nanmax(ndvi)
mid=0.1

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

# diverging color scheme chosen from https://matplotlib.org/users/colormaps.html
cmap = plt.cm.RdYlGn 

cax = ax.imshow(ndvi, cmap=cmap, clim=(min, max), norm=MidpointNormalize(midpoint=mid,vmin=min, vmax=max))

ax.axis('off')
ax.set_title('Normalized Difference Vegetation Index', fontsize=18, fontweight='bold')

cbar = fig.colorbar(cax, orientation='horizontal', shrink=0.65)

fig.savefig("output/ndvi-fig.png", dpi=200, bbox_inches='tight', pad_inches=0.7)

plt.show()

# %% [markdown]
# ## 7. Generate a histogram of NDVI values

# %%
fig2 = plt.figure(figsize=(10,10))
ax = fig2.add_subplot(111)

plt.title("NDVI Histogram", fontsize=18, fontweight='bold')
plt.xlabel("NDVI values", fontsize=14)
plt.ylabel("# pixels", fontsize=14)


x = ndvi[~np.isnan(ndvi)]
numBins = 20
ax.hist(x,numBins,color='green',alpha=0.8)

fig2.savefig("output/ndvi-histogram.png", dpi=200, bbox_inches='tight', pad_inches=0.7)

plt.show()
