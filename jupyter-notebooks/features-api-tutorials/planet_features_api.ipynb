# %% [markdown]
# # Planet Features API Introduction using Python
#
# ---

# %% [markdown]
# ## Introduction
#
# ---
#
# This tutorial is an introduction to [Planet](https://www.planet.com)'s [Features API.](https://api.planet.com/features/v0/ogc/my)
#
# The focus of this tutorial will be the creating and using AOI references within other Planet APIs. We will create a `FeatureCollection` and then create two `Features` and use them in a few other Planet APIs. After completing this tutorial, you should feel comfortable interacting with the Features API, and have a good foundation for leveraging them across the Planet API ecosystem.

# %% [markdown]
# ## Table of Contents
#
# ---
#
# * **Introduction**
#     * Requirements
#        * Software & Modules
#        * Planet API Key
#     * Useful Links
#
#
# * **Overview**
#      * [The Basic Setup](#Basic-Setup)
#      * [First Feature Collection](#Let's-Create-Our-First-Feature-Collection)
#      * [Adding Features](#Adding-Features-to-our-Collection)
#      * [Validating Features](#Validating-Features-before-Create)
#      * [Getting Alternate Features](#Get-an-alternative)
#      * [Using References](#Using-the-references)
#        * [Data API](#Data-API)
#        * [Orders API](#Orders-API)
#        * [Subscriptions API](#Subscriptions-API)

# %% [markdown]
# ### Requirements
#
# ---
#
# #### Software & Modules
#
# This tutorial assumes familiarity with the [Python](https://python.org) programming language throughout. Familiarity with basic REST API concepts and usage is also assumed.
#
# We'll be using a **"Jupyter Notebook"** (aka Python Notebook) to run through the examples.
# To learn more about and get started with using Jupyter, visit: [Jupyter](https://jupyter.org/) and [IPython](https://ipython.org/).
#
# For the best experience, download this notebook and run it on your system, and make sure to install the modules listed below first. You can also copy the examples' code to a separate Python files an run them directly with Python on your system if you prefer.
#
#
# #### Planet API Key
#
# You should have an account on the Planet Platform to access the Data API. You may retrieve your API key from your [account page](https://www.planet.com/account/), or from the "API Tab" in [Planet Explorer](https://www.planet.com/explorer).

# %% [markdown]
# ### Useful links
#
# ---
#
# * [Planet Features API Reference & Documentation](https://developers.planet.com/docs/apis/features)
# * [Planet Explorer](https://www.planet.com/explorer)

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Basic Setup
#
# ---
#
# Before interacting with the Planet Features API using Python, we will set up our environment with some useful modules and helper functions.
#
# * We'll configure *authentication* to the Planet Features API
# * We'll use the `requests` Python module to make HTTP communication easier.
# * We'll use the `json` Python module to help us work with JSON responses from the API.
# * We'll create a function called `p` that will print Python dictionaries nicely.
#
#
# pip install -q requests pandas geopandas
#
#
# Let's start by importing needed packages configuring authentication:

# %% [markdown]
# ### Import Packages & Define Helper Functions

# %%
import os
import json
import requests
import time


# Helper function to printformatted JSON using the json module
def p(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# ### Authentication
#
# Authentication with the Planet Features API be achieved using a valid Planet **API key**.

# %% [markdown]
# You can *export* your API Key as an environment variable on your system:
#
# `export PL_API_KEY="YOUR API KEY HERE"`
#
# Or add the variable to your path, etc. If you are using our Docker environement, it will already be set.
#
# To start our Python code, we'll setup an API Key variable from an environment variable to use with our requests:

# %%
# if your Planet API Key is not set as an environment variable, you can paste it below
if os.environ.get('PL_API_KEY', ''):
    API_KEY = os.environ.get('PL_API_KEY', '')
else:
    API_KEY = 'PASTE_YOUR_API_KEY_HERE'

    # construct auth tuple for use in the requests library
BASIC_AUTH = (API_KEY, '')

# %% [markdown]
# ### Our First Request

# %%
# Setup Planet Features API base URL
URL = "https://api.planet.com/features/v0/ogc/my/collections"

# Setup the session
session = requests.Session()
# Authenticate
session.auth = (API_KEY, "")

# %%
# Make a GET request to the Planet Features API
res = session.get(URL)
# Now we should get a response, hopefully it's a `200` code, saying everything is OK!
res.status_code
# Out:
# 200

# %% [markdown]
# ## Let's Create Our First Feature Collection
#
# ---
#
# To upload an AOI Feature you must first create a Feature Collection. To create a Feature Collection make a POST request to the `/collections` endpoint providing a title and optionally a description.
#
# The title will be used to create a "slug" that will be part of the collection's id.
#
# A Collection identifier is a combination of optional user-supplied title and a hashid. For example, if a user creates a Collection with the title set to "My Great Places", the URL path identifier used to reference the Collection will be my-great-places-HASHID (where HASHID might be 4wr3wrz, for example). The Collection may also be referenced using only the HASHID - this way the user may change the title of their Collection if needed.

# %%
request = {
    "title" : "My Title",
    "description" : "A description of this collection"
}

# Send the POST request to the API stats endpoint
res = session.post(URL, json=request)

# Print response
p(res.json())

# let's save the collection-id to use later
collection_id = res.json()["id"]
# Out:
# {
#   "id": "my-title-DZ1KBq1",
#   "title": "My Title",
#   "description": "A description of this collection",
#   "item_type": "feature",
#   "links": [
#     {
#       "href": "https://api.planet.com/features/v0/ogc/my/collections/my-title-DZ1KBq1",
#       "rel": "self",
#       "title": "This collection",
#       "type": "application/json"
#     },
#     {
#       "href": "https://api.planet.com/features/v0/ogc/my/collections/my-title-DZ1KBq1/items",
#       "rel": "features",
#       "title": "Features",
#       "type": "application/json"
#     }
#   ],
#   "permissions": {
#     "can_write": true,
#     "shared_with_my_org": false
#   }
# }

# %% [markdown]
# ***Good Job!*** You've created your first Feature Collection

# %% [markdown]
# ## Adding Features to our Collection
# The features API guarantees that your geojson will work in Planet's Platform.
#
# *Note* there is a 1500 vertex limit

# %%
# Put your own Polygon here!
geo1 = {
    "type": "Polygon",
    "coordinates": [
      [
        [
          -125.29632568359376,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          48.37084770238366
        ]
      ]
    ]
  }


request = {
    "geometry": geo1,
    "id": "1231", #optional, if you want to give your feature it's own id, use that here. this needs to be unique
    "properties" : {
        "title": "some-title",
        "description": "some-description"
    }

}

res = session.post(URL +"/"+ collection_id + "/items", json=request)


# Let's save the response as the short ref for later!
short_ref = res.json()[0]

print(short_ref)
# Out:
# pl:features/my/my-title-DZ1KBq1/1231-zo1pQam

# %%
# add a second feature
geo2 = {
        "type": "Polygon",
        "coordinates": [
          [
            [
              -124.87509770059592,
              48.42395972830914
            ],
            [
              -124.58981375958084,
              47.620415719416116
            ],
            [
              -124.36822528967289,
              47.28340570291758
            ],
            [
              -124.20764093293805,
              47.048428715791005
            ],
            [
              -122.64306485391211,
              47.097307284357186
            ],
            [
              -122.7148343988215,
              48.16372351943102
            ],
            [
              -123.31052162156989,
              48.14326012054822
            ],
            [
              -123.9995092527008,
              48.23068727937715
            ],
            [
              -124.87509770059592,
              48.42395972830914
            ]
          ]
        ]
      }


request = {
    "geometry": geo2,
    "id": "1235", #optional, if you want to give your feature it's own id, use that here. this needs to be unique
    "properties" : {
        "title": "some-title",
        "description": "some-description"
    }

}

res = session.post(URL +"/"+ collection_id + "/items", json=request)


# Let's save the response as the short ref for later!
short_ref_2 = res.json()[0]

print(short_ref_2)
# Out:
# pl:features/my/my-title-DZ1KBq1/1235-jgyM61g

# %% [markdown]
# ## Validating Features before Create
#
# ---
#
# The Features API enables you to check if your Feature geometry is valid for use in Planet's Platform before uploading it to your Feature Collection. The `/validate` endpoint provides more details as to why a geometry is invalid, such as not meeting the vertex limit. The validation endpoint only supports validating Features.
# *i.e., you cannot validate a Feature Collection.*

# %%
validate_url =  'https://api.planet.com/features/v0/ogc/my/collections/validate'

# A request with no issues
request = {
    "type": "Feature", 
    "properties": {},
    "geometry": geo1,
    }


res = session.post(validate_url, json=request)
p(res.json())
# Out:
# {
#   "status": "okay",
#   "detail": "No errors."
# }

# %% [markdown]
# ### Let's try a bow tie, this request will return an error

# %%
# A request with problems

bow_tie = {
        "coordinates": [
            [
              [
                -110.19612631421622,
                35.143918734708365
              ],
              [
                -106.04640407969373,
                36.00744957163177
              ],
              [
                -106.28152102495591,
                33.78198439977524
              ],
              [
                -110.06298522792459,
                36.426344365077654
              ],
              [
                 -110.19612631421622,
                35.143918734708365
              ]
            ]
        ],
        "type": "Polygon"
      }

request = {
    "type": "Feature", 
    "properties": {},
    "geometry": bow_tie,
    }


res = session.post(validate_url, json=request)
p(res.json())
# Out:
# {
#   "errors": [
#     {
#       "code": "invalid-geometry",
#       "description": "Geometry is invalid: Self-intersection[-108.680204575141 35.4593724190932]"
#     }
#   ],
#   "description": "To see valid version of the geometry, post to the alternates_url",
#   "alternates_url": "https://api.planet.com/features/v0/ogc/my/collections/alternates"
# }

# %% [markdown]
# **Note:** When you get an invalid geojson, we will try to offer alternate solutions, checkout the `/alternates` endpoint.

# %% [markdown]
# ### Let's try getting alternates for a feature with more than 1500 vertices

# %%
# read this from a file
complex_geom_file = os.path.join('warren-county.geojson')

def load_geojson(filename):
    with open(filename, 'r') as f:
        return json.load(f)

complex_geom = load_geojson(complex_geom_file)

# %%
request = complex_geom


res = session.post(validate_url, json=request)
p(res.json())
# Out:
# {
#   "errors": [
#     {
#       "code": "too-many-coordinates",
#       "description": "Geometry has more than 1500 points."
#     }
#   ],
#   "description": "To see valid version of the geometry, post to the alternates_url",
#   "alternates_url": "https://api.planet.com/features/v0/ogc/my/collections/alternates"
# }

# %% [markdown]
# ### Get an alternative

# %%
alternate_url = 'https://api.planet.com/features/v0/ogc/my/collections/alternates'
request = complex_geom


res = session.post(alternate_url, json=request)
p(res.json())
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "properties": {
#         "technique": "Bounding box"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -91.174577,
#               32.078327
#             ],
#             [
#               -91.174577,
#               32.618885
#             ],
#             [
#               -90.553821,
#               32.618885
#             ],
#             [
#               -90.553821,
#               32.078327
#             ],
#             [
#               -91.174577,
#               32.078327
#             ]
#           ]
#         ]
#       }
#     },
#     {
#       "properties": {
#         "technique": "Convex hull"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -90.943286,
#               32.078327
#             ],
#             [
#               -90.943913,
#               32.078343
#             ],
#             [
#               -90.944029,
#               32.078359
#             ],
#             [
#               -91.162822,
#               32.132694
#             ],
#             [
#               -91.16445,
#               32.133505
#             ],
#             [
#               -91.165267,
#               32.134145
#             ],
#             [
#               -91.165452,
#               32.13429
#             ],
#             [
#               -91.167269,
#               32.136893
#             ],
#             [
#               -91.168141,
#               32.138179
#             ],
#             [
#               -91.1685,
#               32.138709
#             ],
#             [
#               -91.169771,
#               32.140678
#             ],
#             [
#               -91.171702,
#               32.14425
#             ],
#             [
#               -91.17273,
#               32.146479
#             ],
#             [
#               -91.173495,
#               32.149009
#             ],
#             [
#               -91.17427,
#               32.152451
#             ],
#             [
#               -91.174552,
#               32.154978
#             ],
#             [
#               -91.174577,
#               32.157311
#             ],
#             [
#               -91.174348,
#               32.159832
#             ],
#             [
#               -91.173702,
#               32.163988
#             ],
#             [
#               -91.173664,
#               32.164231
#             ],
#             [
#               -91.117008,
#               32.498739
#             ],
#             [
#               -91.116708,
#               32.500138
#             ],
#             [
#               -91.097878,
#               32.544751
#             ],
#             [
#               -91.093742,
#               32.549127
#             ],
#             [
#               -91.072317,
#               32.561369
#             ],
#             [
#               -91.069354,
#               32.563052
#             ],
#             [
#               -91.049312,
#               32.573624
#             ],
#             [
#               -91.045337,
#               32.575626
#             ],
#             [
#               -91.043552,
#               32.576271
#             ],
#             [
#               -90.720102,
#               32.618858
#             ],
#             [
#               -90.719492,
#               32.618885
#             ],
#             [
#               -90.70458,
#               32.618781
#             ],
#             [
#               -90.691681,
#               32.618691
#             ],
#             [
#               -90.689946,
#               32.618658
#             ],
#             [
#               -90.553904,
#               32.531907
#             ],
#             [
#               -90.5539,
#               32.530817
#             ],
#             [
#               -90.553864,
#               32.520448
#             ],
#             [
#               -90.553821,
#               32.507574
#             ],
#             [
#               -90.627978,
#               32.339483
#             ],
#             [
#               -90.769689,
#               32.155318
#             ],
#             [
#               -90.770653,
#               32.154648
#             ],
#             [
#               -90.916233,
#               32.081363
#             ],
#             [
#               -90.916336,
#               32.081322
#             ],
#             [
#               -90.917952,
#               32.080684
#             ],
#             [
#               -90.942925,
#               32.078337
#             ],
#             [
#               -90.943286,
#               32.078327
#             ]
#           ]
#         ]
#       }
#     },
#     {
#       "properties": {
#         "technique": "Simplified to ~10m"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -90.885771,
#               32.3508
#             ],
#             [
#               -90.883578,
#               32.354739
#             ],
#             [
#               -90.877289,
#               32.366945
#             ],
#             [
#               -90.875638,
#               32.371729
#             ],
#             [
#               -90.875621,
#               32.373526
#             ],
#             [
#               -90.876644,
#               32.37409
#             ],
#             [
#               -90.878604,
#               32.374636
#             ],
#             [
#               -90.884606,
#               32.374083
#             ],
#             [
#               -90.88823,
#               32.373499
#             ],
#             [
#               -90.88983,
#               32.372933
#             ],
#             [
#               -90.891598,
#               32.371451
#             ],
#             [
#               -90.892428,
#               32.36966
#             ],
#             [
#               -90.893331,
#               32.365343
#             ],
#             [
#               -90.89481,
#               32.360019
#             ],
#             [
#               -90.897179,
#               32.355178
#             ],
#             [
#               -90.900957,
#               32.349876
#             ],
#             [
#               -90.912363,
#               32.339454
#             ],
#             [
#               -90.92117,
#               32.342073
#             ],
#             [
#               -90.93076,
#               32.344254
#             ],
#             [
#               -90.934897,
#               32.344966
#             ],
#             [
#               -90.938986,
#               32.345605
#             ],
#             [
#               -90.942981,
#               32.345956
#             ],
#             [
#               -90.951895,
#               32.345605
#             ],
#             [
#               -90.954583,
#               32.345858
#             ],
#             [
#               -90.986672,
#               32.35176
#             ],
#             [
#               -90.993625,
#               32.354047
#             ],
#             [
#               -90.997567,
#               32.356144
#             ],
#             [
#               -91.000106,
#               32.357695
#             ],
#             [
#               -91.002406,
#               32.360445
#             ],
#             [
#               -91.003806,
#               32.362744
#             ],
#             [
#               -91.004506,
#               32.364744
#             ],
#             [
#               -91.004706,
#               32.365944
#             ],
#             [
#               -91.004706,
#               32.367244
#             ],
#             [
#               -91.003606,
#               32.371344
#             ],
#             [
#               -91.003006,
#               32.372844
#             ],
#             [
#               -91.002406,
#               32.375044
#             ],
#             [
#               -91.002206,
#               32.375144
#             ],
#             [
#               -91.002006,
#               32.376944
#             ],
#             [
#               -91.001406,
#               32.379444
#             ],
#             [
#               -91.000606,
#               32.381844
#             ],
#             [
#               -91.000206,
#               32.382143
#             ],
#             [
#               -90.998049,
#               32.385174
#             ],
#             [
#               -90.996237,
#               32.388061
#             ],
#             [
#               -90.994686,
#               32.392277
#             ],
#             [
#               -90.99378,
#               32.396777
#             ],
#             [
#               -90.99408,
#               32.403861
#             ],
#             [
#               -90.980723,
#               32.408243
#             ],
#             [
#               -90.975342,
#               32.410951
#             ],
#             [
#               -90.971365,
#               32.414094
#             ],
#             [
#               -90.968497,
#               32.416965
#             ],
#             [
#               -90.965987,
#               32.420654
#             ],
#             [
#               -90.965739,
#               32.423643
#             ],
#             [
#               -90.966269,
#               32.427693
#             ],
#             [
#               -90.966441,
#               32.433874
#             ],
#             [
#               -90.966857,
#               32.435505
#             ],
#             [
#               -90.969587,
#               32.439492
#             ],
#             [
#               -90.972412,
#               32.441376
#             ],
#             [
#               -90.974873,
#               32.443889
#             ],
#             [
#               -90.977212,
#               32.446005
#             ],
#             [
#               -90.978547,
#               32.447032
#             ],
#             [
#               -90.980007,
#               32.447842
#             ],
#             [
#               -90.983423,
#               32.449077
#             ],
#             [
#               -90.984124,
#               32.449063
#             ],
#             [
#               -90.99054,
#               32.450402
#             ],
#             [
#               -90.993863,
#               32.450851
#             ],
#             [
#               -90.995487,
#               32.450885
#             ],
#             [
#               -90.997092,
#               32.450718
#             ],
#             [
#               -90.99753,
#               32.450404
#             ],
#             [
#               -90.998974,
#               32.450165
#             ],
#             [
#               -91.000106,
#               32.44934
#             ],
#             [
#               -91.001606,
#               32.44784
#             ],
#             [
#               -91.003706,
#               32.44634
#             ],
#             [
#               -91.010406,
#               32.44294
#             ],
#             [
#               -91.016506,
#               32.440342
#             ],
#             [
#               -91.017906,
#               32.439542
#             ],
#             [
#               -91.018506,
#               32.438941
#             ],
#             [
#               -91.021106,
#               32.437742
#             ],
#             [
#               -91.024606,
#               32.435342
#             ],
#             [
#               -91.026306,
#               32.434441
#             ],
#             [
#               -91.027406,
#               32.433942
#             ],
#             [
#               -91.029606,
#               32.433542
#             ],
#             [
#               -91.031906,
#               32.433742
#             ],
#             [
#               -91.034907,
#               32.434742
#             ],
#             [
#               -91.043707,
#               32.436642
#             ],
#             [
#               -91.049307,
#               32.437342
#             ],
#             [
#               -91.051407,
#               32.437842
#             ],
#             [
#               -91.052607,
#               32.438242
#             ],
#             [
#               -91.052907,
#               32.438542
#             ],
#             [
#               -91.067807,
#               32.444141
#             ],
#             [
#               -91.075507,
#               32.44744
#             ],
#             [
#               -91.081807,
#               32.45044
#             ],
#             [
#               -91.087108,
#               32.45344
#             ],
#             [
#               -91.093423,
#               32.457386
#             ],
#             [
#               -91.095308,
#               32.458741
#             ],
#             [
#               -91.102208,
#               32.465141
#             ],
#             [
#               -91.107508,
#               32.47084
#             ],
#             [
#               -91.108808,
#               32.47204
#             ],
#             [
#               -91.111508,
#               32.47534
#             ],
#             [
#               -91.113108,
#               32.477739
#             ],
#             [
#               -91.115708,
#               32.48234
#             ],
#             [
#               -91.116008,
#               32.48314
#             ],
#             [
#               -91.116608,
#               32.48594
#             ],
#             [
#               -91.117008,
#               32.492739
#             ],
#             [
#               -91.117308,
#               32.495039
#             ],
#             [
#               -91.117008,
#               32.498739
#             ],
#             [
#               -91.116708,
#               32.500138
#             ],
#             [
#               -91.113564,
#               32.505235
#             ],
#             [
#               -91.106985,
#               32.514933
#             ],
#             [
#               -91.104896,
#               32.51845
#             ],
#             [
#               -91.101304,
#               32.525599
#             ],
#             [
#               -91.099841,
#               32.529217
#             ],
#             [
#               -91.098756,
#               32.532967
#             ],
#             [
#               -91.097949,
#               32.537214
#             ],
#             [
#               -91.097598,
#               32.542931
#             ],
#             [
#               -91.097878,
#               32.544751
#             ],
#             [
#               -91.093742,
#               32.549127
#             ],
#             [
#               -91.076151,
#               32.534699
#             ],
#             [
#               -91.074844,
#               32.533489
#             ],
#             [
#               -91.070485,
#               32.528185
#             ],
#             [
#               -91.063771,
#               32.516983
#             ],
#             [
#               -91.057753,
#               32.508622
#             ],
#             [
#               -91.053904,
#               32.503669
#             ],
#             [
#               -91.050907,
#               32.500138
#             ],
#             [
#               -91.049307,
#               32.498539
#             ],
#             [
#               -91.045807,
#               32.495539
#             ],
#             [
#               -91.044207,
#               32.49434
#             ],
#             [
#               -91.040907,
#               32.49244
#             ],
#             [
#               -91.038106,
#               32.49044
#             ],
#             [
#               -91.033906,
#               32.48854
#             ],
#             [
#               -91.028906,
#               32.48704
#             ],
#             [
#               -91.024106,
#               32.485239
#             ],
#             [
#               -91.020906,
#               32.48454
#             ],
#             [
#               -91.017106,
#               32.483739
#             ],
#             [
#               -91.007106,
#               32.48234
#             ],
#             [
#               -91.004206,
#               32.48214
#             ],
#             [
#               -91.000106,
#               32.48229
#             ],
#             [
#               -90.996126,
#               32.484201
#             ],
#             [
#               -90.993087,
#               32.486211
#             ],
#             [
#               -90.990089,
#               32.488561
#             ],
#             [
#               -90.988505,
#               32.490559
#             ],
#             [
#               -90.987579,
#               32.492387
#             ],
#             [
#               -90.987202,
#               32.495663
#             ],
#             [
#               -90.987669,
#               32.498481
#             ],
#             [
#               -90.988784,
#               32.500841
#             ],
#             [
#               -90.989585,
#               32.502052
#             ],
#             [
#               -90.994867,
#               32.508611
#             ],
#             [
#               -91.001129,
#               32.512945
#             ],
#             [
#               -91.007075,
#               32.516371
#             ],
#             [
#               -91.013484,
#               32.519153
#             ],
#             [
#               -91.018469,
#               32.521019
#             ],
#             [
#               -91.045539,
#               32.529169
#             ],
#             [
#               -91.053861,
#               32.53204
#             ],
#             [
#               -91.057706,
#               32.533777
#             ],
#             [
#               -91.063344,
#               32.537339
#             ],
#             [
#               -91.0754,
#               32.546743
#             ],
#             [
#               -91.080411,
#               32.556468
#             ],
#             [
#               -91.069354,
#               32.563052
#             ],
#             [
#               -91.06223,
#               32.566591
#             ],
#             [
#               -91.049312,
#               32.573624
#             ],
#             [
#               -91.045337,
#               32.575626
#             ],
#             [
#               -91.043552,
#               32.576271
#             ],
#             [
#               -90.964043,
#               32.575605
#             ],
#             [
#               -90.964802,
#               32.503664
#             ],
#             [
#               -90.964398,
#               32.500137
#             ],
#             [
#               -90.963502,
#               32.420583
#             ],
#             [
#               -90.963612,
#               32.420212
#             ],
#             [
#               -90.963381,
#               32.411185
#             ],
#             [
#               -90.958946,
#               32.420937
#             ],
#             [
#               -90.957933,
#               32.428027
#             ],
#             [
#               -90.954626,
#               32.437585
#             ],
#             [
#               -90.95305,
#               32.440288
#             ],
#             [
#               -90.953224,
#               32.440542
#             ],
#             [
#               -90.953208,
#               32.441058
#             ],
#             [
#               -90.952427,
#               32.4419
#             ],
#             [
#               -90.95124,
#               32.444389
#             ],
#             [
#               -90.949678,
#               32.446089
#             ],
#             [
#               -90.947309,
#               32.448307
#             ],
#             [
#               -90.944658,
#               32.450107
#             ],
#             [
#               -90.939828,
#               32.452068
#             ],
#             [
#               -90.935386,
#               32.452414
#             ],
#             [
#               -90.932169,
#               32.451975
#             ],
#             [
#               -90.926476,
#               32.450579
#             ],
#             [
#               -90.925033,
#               32.449696
#             ],
#             [
#               -90.922884,
#               32.447984
#             ],
#             [
#               -90.920441,
#               32.444693
#             ],
#             [
#               -90.919402,
#               32.444254
#             ],
#             [
#               -90.917688,
#               32.443952
#             ],
#             [
#               -90.915712,
#               32.444141
#             ],
#             [
#               -90.910292,
#               32.445863
#             ],
#             [
#               -90.905441,
#               32.447764
#             ],
#             [
#               -90.902313,
#               32.448684
#             ],
#             [
#               -90.899007,
#               32.448951
#             ],
#             [
#               -90.894745,
#               32.448602
#             ],
#             [
#               -90.891418,
#               32.447037
#             ],
#             [
#               -90.884416,
#               32.441566
#             ],
#             [
#               -90.882652,
#               32.4409
#             ],
#             [
#               -90.881466,
#               32.440768
#             ],
#             [
#               -90.879308,
#               32.441311
#             ],
#             [
#               -90.877034,
#               32.442418
#             ],
#             [
#               -90.875104,
#               32.444253
#             ],
#             [
#               -90.874008,
#               32.448051
#             ],
#             [
#               -90.873527,
#               32.449411
#             ],
#             [
#               -90.87288,
#               32.450557
#             ],
#             [
#               -90.871546,
#               32.451518
#             ],
#             [
#               -90.870873,
#               32.451608
#             ],
#             [
#               -90.869784,
#               32.451315
#             ],
#             [
#               -90.868649,
#               32.45058
#             ],
#             [
#               -90.867888,
#               32.449452
#             ],
#             [
#               -90.867133,
#               32.44705
#             ],
#             [
#               -90.866106,
#               32.44532
#             ],
#             [
#               -90.864259,
#               32.443553
#             ],
#             [
#               -90.862451,
#               32.442366
#             ],
#             [
#               -90.861364,
#               32.442115
#             ],
#             [
#               -90.860777,
#               32.50014
#             ],
#             [
#               -90.860566,
#               32.575173
#             ],
#             [
#               -90.829297,
#               32.57526
#             ],
#             [
#               -90.828981,
#               32.575453
#             ],
#             [
#               -90.824894,
#               32.575411
#             ],
#             [
#               -90.82288,
#               32.575144
#             ],
#             [
#               -90.781667,
#               32.574738
#             ],
#             [
#               -90.768081,
#               32.574751
#             ],
#             [
#               -90.766582,
#               32.5764
#             ],
#             [
#               -90.765237,
#               32.577008
#             ],
#             [
#               -90.762783,
#               32.577419
#             ],
#             [
#               -90.760485,
#               32.577157
#             ],
#             [
#               -90.75874,
#               32.576425
#             ],
#             [
#               -90.756075,
#               32.573081
#             ],
#             [
#               -90.753654,
#               32.571412
#             ],
#             [
#               -90.7501,
#               32.570552
#             ],
#             [
#               -90.748141,
#               32.570435
#             ],
#             [
#               -90.745964,
#               32.570917
#             ],
#             [
#               -90.742561,
#               32.571975
#             ],
#             [
#               -90.740937,
#               32.572086
#             ],
#             [
#               -90.73952,
#               32.571773
#             ],
#             [
#               -90.733457,
#               32.566403
#             ],
#             [
#               -90.732027,
#               32.565807
#             ],
#             [
#               -90.729847,
#               32.565686
#             ],
#             [
#               -90.728344,
#               32.566265
#             ],
#             [
#               -90.727044,
#               32.567813
#             ],
#             [
#               -90.726262,
#               32.569893
#             ],
#             [
#               -90.725577,
#               32.575792
#             ],
#             [
#               -90.725864,
#               32.577666
#             ],
#             [
#               -90.727418,
#               32.579265
#             ],
#             [
#               -90.729727,
#               32.581159
#             ],
#             [
#               -90.730804,
#               32.582527
#             ],
#             [
#               -90.731731,
#               32.585669
#             ],
#             [
#               -90.731699,
#               32.587276
#             ],
#             [
#               -90.73107,
#               32.588318
#             ],
#             [
#               -90.729924,
#               32.58896
#             ],
#             [
#               -90.725965,
#               32.589821
#             ],
#             [
#               -90.724303,
#               32.590501
#             ],
#             [
#               -90.723197,
#               32.59131
#             ],
#             [
#               -90.722726,
#               32.592118
#             ],
#             [
#               -90.72258,
#               32.59463
#             ],
#             [
#               -90.722042,
#               32.598115
#             ],
#             [
#               -90.719924,
#               32.602649
#             ],
#             [
#               -90.716399,
#               32.611578
#             ],
#             [
#               -90.716326,
#               32.612751
#             ],
#             [
#               -90.716848,
#               32.614154
#             ],
#             [
#               -90.720102,
#               32.618858
#             ],
#             [
#               -90.689946,
#               32.618658
#             ],
#             [
#               -90.690249,
#               32.589388
#             ],
#             [
#               -90.655527,
#               32.589771
#             ],
#             [
#               -90.655265,
#               32.574739
#             ],
#             [
#               -90.654591,
#               32.574743
#             ],
#             [
#               -90.654589,
#               32.546044
#             ],
#             [
#               -90.588019,
#               32.546067
#             ],
#             [
#               -90.587925,
#               32.531756
#             ],
#             [
#               -90.553904,
#               32.531907
#             ],
#             [
#               -90.553821,
#               32.507574
#             ],
#             [
#               -90.555481,
#               32.505021
#             ],
#             [
#               -90.556235,
#               32.504616
#             ],
#             [
#               -90.55969,
#               32.504337
#             ],
#             [
#               -90.565605,
#               32.502944
#             ],
#             [
#               -90.56595,
#               32.503256
#             ],
#             [
#               -90.566031,
#               32.503877
#             ],
#             [
#               -90.565924,
#               32.504152
#             ],
#             [
#               -90.564962,
#               32.50508
#             ],
#             [
#               -90.565111,
#               32.505613
#             ],
#             [
#               -90.565545,
#               32.505955
#             ],
#             [
#               -90.566328,
#               32.50581
#             ],
#             [
#               -90.567067,
#               32.505183
#             ],
#             [
#               -90.567551,
#               32.505056
#             ],
#             [
#               -90.56894,
#               32.505336
#             ],
#             [
#               -90.569642,
#               32.506242
#             ],
#             [
#               -90.571167,
#               32.50625
#             ],
#             [
#               -90.571498,
#               32.506028
#             ],
#             [
#               -90.571618,
#               32.505649
#             ],
#             [
#               -90.571611,
#               32.504092
#             ],
#             [
#               -90.571466,
#               32.503587
#             ],
#             [
#               -90.571092,
#               32.503164
#             ],
#             [
#               -90.57098,
#               32.50258
#             ],
#             [
#               -90.570189,
#               32.502148
#             ],
#             [
#               -90.569943,
#               32.501583
#             ],
#             [
#               -90.569616,
#               32.501345
#             ],
#             [
#               -90.569982,
#               32.49986
#             ],
#             [
#               -90.570093,
#               32.49956
#             ],
#             [
#               -90.570364,
#               32.499425
#             ],
#             [
#               -90.573426,
#               32.499085
#             ],
#             [
#               -90.574107,
#               32.499119
#             ],
#             [
#               -90.574837,
#               32.499773
#             ],
#             [
#               -90.574672,
#               32.500853
#             ],
#             [
#               -90.574781,
#               32.501237
#             ],
#             [
#               -90.575482,
#               32.501258
#             ],
#             [
#               -90.576317,
#               32.500972
#             ],
#             [
#               -90.576652,
#               32.501007
#             ],
#             [
#               -90.577077,
#               32.501438
#             ],
#             [
#               -90.576704,
#               32.502501
#             ],
#             [
#               -90.576898,
#               32.503415
#             ],
#             [
#               -90.57786,
#               32.503736
#             ],
#             [
#               -90.578701,
#               32.503666
#             ],
#             [
#               -90.579671,
#               32.50293
#             ],
#             [
#               -90.580596,
#               32.501785
#             ],
#             [
#               -90.580416,
#               32.50026
#             ],
#             [
#               -90.580154,
#               32.50014
#             ],
#             [
#               -90.579306,
#               32.498182
#             ],
#             [
#               -90.57972,
#               32.497482
#             ],
#             [
#               -90.581683,
#               32.495805
#             ],
#             [
#               -90.582047,
#               32.494239
#             ],
#             [
#               -90.582313,
#               32.494028
#             ],
#             [
#               -90.583594,
#               32.493825
#             ],
#             [
#               -90.584538,
#               32.493946
#             ],
#             [
#               -90.585295,
#               32.494582
#             ],
#             [
#               -90.586396,
#               32.496542
#             ],
#             [
#               -90.586916,
#               32.496979
#             ],
#             [
#               -90.58728,
#               32.496914
#             ],
#             [
#               -90.587938,
#               32.496092
#             ],
#             [
#               -90.589082,
#               32.495319
#             ],
#             [
#               -90.590216,
#               32.492773
#             ],
#             [
#               -90.589391,
#               32.491304
#             ],
#             [
#               -90.589297,
#               32.490731
#             ],
#             [
#               -90.589441,
#               32.490327
#             ],
#             [
#               -90.590317,
#               32.489585
#             ],
#             [
#               -90.590356,
#               32.48927
#             ],
#             [
#               -90.589938,
#               32.488648
#             ],
#             [
#               -90.589129,
#               32.488646
#             ],
#             [
#               -90.587287,
#               32.489103
#             ],
#             [
#               -90.586624,
#               32.48886
#             ],
#             [
#               -90.586587,
#               32.487858
#             ],
#             [
#               -90.586769,
#               32.487382
#             ],
#             [
#               -90.587274,
#               32.486865
#             ],
#             [
#               -90.587417,
#               32.486809
#             ],
#             [
#               -90.589313,
#               32.487651
#             ],
#             [
#               -90.59111,
#               32.487439
#             ],
#             [
#               -90.593929,
#               32.48531
#             ],
#             [
#               -90.597835,
#               32.482869
#             ],
#             [
#               -90.598901,
#               32.482992
#             ],
#             [
#               -90.600078,
#               32.484416
#             ],
#             [
#               -90.600277,
#               32.484433
#             ],
#             [
#               -90.600822,
#               32.484239
#             ],
#             [
#               -90.601757,
#               32.482149
#             ],
#             [
#               -90.603737,
#               32.481853
#             ],
#             [
#               -90.604071,
#               32.481297
#             ],
#             [
#               -90.604067,
#               32.479064
#             ],
#             [
#               -90.603405,
#               32.477037
#             ],
#             [
#               -90.601318,
#               32.473981
#             ],
#             [
#               -90.599709,
#               32.470409
#             ],
#             [
#               -90.599587,
#               32.469341
#             ],
#             [
#               -90.600049,
#               32.46742
#             ],
#             [
#               -90.600137,
#               32.465728
#             ],
#             [
#               -90.59993,
#               32.464461
#             ],
#             [
#               -90.600047,
#               32.463114
#             ],
#             [
#               -90.600517,
#               32.461434
#             ],
#             [
#               -90.60109,
#               32.460021
#             ],
#             [
#               -90.601586,
#               32.459311
#             ],
#             [
#               -90.601654,
#               32.458657
#             ],
#             [
#               -90.601446,
#               32.45818
#             ],
#             [
#               -90.600781,
#               32.457953
#             ],
#             [
#               -90.598574,
#               32.457957
#             ],
#             [
#               -90.598061,
#               32.457754
#             ],
#             [
#               -90.597785,
#               32.457253
#             ],
#             [
#               -90.597821,
#               32.455846
#             ],
#             [
#               -90.597211,
#               32.454594
#             ],
#             [
#               -90.597127,
#               32.454109
#             ],
#             [
#               -90.597252,
#               32.453495
#             ],
#             [
#               -90.598225,
#               32.451946
#             ],
#             [
#               -90.598293,
#               32.451405
#             ],
#             [
#               -90.597829,
#               32.450281
#             ],
#             [
#               -90.595496,
#               32.448874
#             ],
#             [
#               -90.594235,
#               32.448496
#             ],
#             [
#               -90.592649,
#               32.448446
#             ],
#             [
#               -90.591404,
#               32.448121
#             ],
#             [
#               -90.58615,
#               32.445526
#             ],
#             [
#               -90.585846,
#               32.445348
#             ],
#             [
#               -90.585761,
#               32.445097
#             ],
#             [
#               -90.585838,
#               32.444839
#             ],
#             [
#               -90.586162,
#               32.44467
#             ],
#             [
#               -90.588122,
#               32.444051
#             ],
#             [
#               -90.588637,
#               32.443648
#             ],
#             [
#               -90.589754,
#               32.44184
#             ],
#             [
#               -90.59065,
#               32.4408
#             ],
#             [
#               -90.591698,
#               32.439897
#             ],
#             [
#               -90.592592,
#               32.439713
#             ],
#             [
#               -90.593079,
#               32.439836
#             ],
#             [
#               -90.593741,
#               32.440789
#             ],
#             [
#               -90.594292,
#               32.44117
#             ],
#             [
#               -90.595366,
#               32.441204
#             ],
#             [
#               -90.595652,
#               32.440986
#             ],
#             [
#               -90.595967,
#               32.440373
#             ],
#             [
#               -90.596181,
#               32.438322
#             ],
#             [
#               -90.596362,
#               32.437878
#             ],
#             [
#               -90.597372,
#               32.437032
#             ],
#             [
#               -90.597959,
#               32.43675
#             ],
#             [
#               -90.598961,
#               32.43659
#             ],
#             [
#               -90.599419,
#               32.436308
#             ],
#             [
#               -90.59991,
#               32.435209
#             ],
#             [
#               -90.599779,
#               32.427907
#             ],
#             [
#               -90.599545,
#               32.425799
#             ],
#             [
#               -90.599985,
#               32.424627
#             ],
#             [
#               -90.602531,
#               32.42235
#             ],
#             [
#               -90.602767,
#               32.421861
#             ],
#             [
#               -90.602952,
#               32.420084
#             ],
#             [
#               -90.603295,
#               32.41964
#             ],
#             [
#               -90.604028,
#               32.419205
#             ],
#             [
#               -90.606057,
#               32.418422
#             ],
#             [
#               -90.606514,
#               32.417467
#             ],
#             [
#               -90.606078,
#               32.416114
#             ],
#             [
#               -90.606269,
#               32.4158
#             ],
#             [
#               -90.61214,
#               32.41443
#             ],
#             [
#               -90.613172,
#               32.413414
#             ],
#             [
#               -90.613081,
#               32.412356
#             ],
#             [
#               -90.6121,
#               32.409976
#             ],
#             [
#               -90.612196,
#               32.409516
#             ],
#             [
#               -90.612454,
#               32.409007
#             ],
#             [
#               -90.612825,
#               32.408822
#             ],
#             [
#               -90.613282,
#               32.408823
#             ],
#             [
#               -90.614563,
#               32.409786
#             ],
#             [
#               -90.615385,
#               32.409714
#             ],
#             [
#               -90.61549,
#               32.409438
#             ],
#             [
#               -90.614872,
#               32.40759
#             ],
#             [
#               -90.614554,
#               32.405421
#             ],
#             [
#               -90.614184,
#               32.404463
#             ],
#             [
#               -90.614309,
#               32.40372
#             ],
#             [
#               -90.614499,
#               32.40334
#             ],
#             [
#               -90.614985,
#               32.402953
#             ],
#             [
#               -90.615822,
#               32.402639
#             ],
#             [
#               -90.616974,
#               32.401712
#             ],
#             [
#               -90.616995,
#               32.400953
#             ],
#             [
#               -90.616703,
#               32.399627
#             ],
#             [
#               -90.615717,
#               32.398002
#             ],
#             [
#               -90.615756,
#               32.397687
#             ],
#             [
#               -90.616165,
#               32.397566
#             ],
#             [
#               -90.617495,
#               32.397665
#             ],
#             [
#               -90.618047,
#               32.397489
#             ],
#             [
#               -90.618247,
#               32.397247
#             ],
#             [
#               -90.618334,
#               32.396528
#             ],
#             [
#               -90.61881,
#               32.396036
#             ],
#             [
#               -90.620864,
#               32.395578
#             ],
#             [
#               -90.621159,
#               32.395401
#             ],
#             [
#               -90.621369,
#               32.394925
#             ],
#             [
#               -90.621341,
#               32.394585
#             ],
#             [
#               -90.620952,
#               32.394116
#             ],
#             [
#               -90.620335,
#               32.394018
#             ],
#             [
#               -90.61792,
#               32.39437
#             ],
#             [
#               -90.617684,
#               32.393432
#             ],
#             [
#               -90.617742,
#               32.393012
#             ],
#             [
#               -90.61856,
#               32.392464
#             ],
#             [
#               -90.622679,
#               32.390677
#             ],
#             [
#               -90.6258,
#               32.388159
#             ],
#             [
#               -90.625929,
#               32.387786
#             ],
#             [
#               -90.62593,
#               32.387118
#             ],
#             [
#               -90.625732,
#               32.386711
#             ],
#             [
#               -90.624513,
#               32.385631
#             ],
#             [
#               -90.622405,
#               32.384836
#             ],
#             [
#               -90.622273,
#               32.38406
#             ],
#             [
#               -90.622711,
#               32.38339
#             ],
#             [
#               -90.623569,
#               32.382633
#             ],
#             [
#               -90.625099,
#               32.381552
#             ],
#             [
#               -90.625893,
#               32.381215
#             ],
#             [
#               -90.62626,
#               32.380841
#             ],
#             [
#               -90.626936,
#               32.378343
#             ],
#             [
#               -90.627363,
#               32.377974
#             ],
#             [
#               -90.630798,
#               32.377081
#             ],
#             [
#               -90.633345,
#               32.377051
#             ],
#             [
#               -90.634709,
#               32.376459
#             ],
#             [
#               -90.635591,
#               32.375822
#             ],
#             [
#               -90.635979,
#               32.375145
#             ],
#             [
#               -90.636162,
#               32.374498
#             ],
#             [
#               -90.635658,
#               32.371169
#             ],
#             [
#               -90.635554,
#               32.368163
#             ],
#             [
#               -90.634852,
#               32.366296
#             ],
#             [
#               -90.631911,
#               32.361502
#             ],
#             [
#               -90.631465,
#               32.358814
#             ],
#             [
#               -90.6307,
#               32.355664
#             ],
#             [
#               -90.630411,
#               32.353428
#             ],
#             [
#               -90.63037,
#               32.34953
#             ],
#             [
#               -90.627946,
#               32.345395
#             ],
#             [
#               -90.62737,
#               32.342411
#             ],
#             [
#               -90.627673,
#               32.340187
#             ],
#             [
#               -90.627978,
#               32.339483
#             ],
#             [
#               -90.629124,
#               32.338865
#             ],
#             [
#               -90.630856,
#               32.338776
#             ],
#             [
#               -90.632512,
#               32.338972
#             ],
#             [
#               -90.634752,
#               32.339708
#             ],
#             [
#               -90.639773,
#               32.342515
#             ],
#             [
#               -90.641663,
#               32.343398
#             ],
#             [
#               -90.643615,
#               32.343693
#             ],
#             [
#               -90.651764,
#               32.344399
#             ],
#             [
#               -90.654,
#               32.344865
#             ],
#             [
#               -90.657983,
#               32.346278
#             ],
#             [
#               -90.666866,
#               32.348503
#             ],
#             [
#               -90.676741,
#               32.35125
#             ],
#             [
#               -90.681056,
#               32.352736
#             ],
#             [
#               -90.682298,
#               32.352897
#             ],
#             [
#               -90.683571,
#               32.352784
#             ],
#             [
#               -90.686087,
#               32.351848
#             ],
#             [
#               -90.687686,
#               32.351503
#             ],
#             [
#               -90.689042,
#               32.351448
#             ],
#             [
#               -90.690206,
#               32.351923
#             ],
#             [
#               -90.691715,
#               32.354092
#             ],
#             [
#               -90.692216,
#               32.354297
#             ],
#             [
#               -90.69289,
#               32.354333
#             ],
#             [
#               -90.693672,
#               32.353983
#             ],
#             [
#               -90.694517,
#               32.352996
#             ],
#             [
#               -90.695515,
#               32.351075
#             ],
#             [
#               -90.695515,
#               32.349132
#             ],
#             [
#               -90.696082,
#               32.348359
#             ],
#             [
#               -90.698267,
#               32.347383
#             ],
#             [
#               -90.699342,
#               32.347172
#             ],
#             [
#               -90.700969,
#               32.346981
#             ],
#             [
#               -90.704123,
#               32.347588
#             ],
#             [
#               -90.704743,
#               32.347309
#             ],
#             [
#               -90.705175,
#               32.346788
#             ],
#             [
#               -90.705788,
#               32.345283
#             ],
#             [
#               -90.706225,
#               32.34331
#             ],
#             [
#               -90.707605,
#               32.340004
#             ],
#             [
#               -90.707416,
#               32.339003
#             ],
#             [
#               -90.706701,
#               32.338353
#             ],
#             [
#               -90.70543,
#               32.337611
#             ],
#             [
#               -90.704136,
#               32.335531
#             ],
#             [
#               -90.703288,
#               32.334873
#             ],
#             [
#               -90.702132,
#               32.334713
#             ],
#             [
#               -90.701387,
#               32.335103
#             ],
#             [
#               -90.700118,
#               32.337781
#             ],
#             [
#               -90.699537,
#               32.337931
#             ],
#             [
#               -90.699178,
#               32.337768
#             ],
#             [
#               -90.699107,
#               32.337195
#             ],
#             [
#               -90.699764,
#               32.334094
#             ],
#             [
#               -90.699301,
#               32.332026
#             ],
#             [
#               -90.699319,
#               32.331059
#             ],
#             [
#               -90.699675,
#               32.330601
#             ],
#             [
#               -90.700927,
#               32.329746
#             ],
#             [
#               -90.701648,
#               32.328831
#             ],
#             [
#               -90.702837,
#               32.326644
#             ],
#             [
#               -90.703488,
#               32.32606
#             ],
#             [
#               -90.705128,
#               32.325303
#             ],
#             [
#               -90.705352,
#               32.324732
#             ],
#             [
#               -90.705129,
#               32.324247
#             ],
#             [
#               -90.704509,
#               32.323558
#             ],
#             [
#               -90.703633,
#               32.322891
#             ],
#             [
#               -90.703363,
#               32.321389
# ...
#               32.097367
#             ],
#             [
#               -90.988445,
#               32.096959
#             ],
#             [
#               -90.990873,
#               32.097046
#             ],
#             [
#               -90.992934,
#               32.0977
#             ],
#             [
#               -90.995796,
#               32.099501
#             ],
#             [
#               -91.001344,
#               32.100701
#             ],
#             [
#               -91.004992,
#               32.102297
#             ],
#             [
#               -91.005857,
#               32.102935
#             ],
#             [
#               -91.00818,
#               32.105206
#             ],
#             [
#               -91.009523,
#               32.106213
#             ],
#             [
#               -91.017213,
#               32.109927
#             ],
#             [
#               -91.019731,
#               32.110879
#             ],
#             [
#               -91.020719,
#               32.111072
#             ],
#             [
#               -91.024885,
#               32.111018
#             ],
#             [
#               -91.027042,
#               32.112052
#             ],
#             [
#               -91.030207,
#               32.114353
#             ],
#             [
#               -91.030507,
#               32.115453
#             ],
#             [
#               -91.03081,
#               32.12065
#             ],
#             [
#               -91.029831,
#               32.120921
#             ],
#             [
#               -91.029444,
#               32.120816
#             ],
#             [
#               -91.027007,
#               32.121053
#             ],
#             [
#               -91.020006,
#               32.123553
#             ],
#             [
#               -91.019306,
#               32.123953
#             ],
#             [
#               -91.018106,
#               32.125053
#             ],
#             [
#               -91.017606,
#               32.125152
#             ],
#             [
#               -91.014306,
#               32.128253
#             ],
#             [
#               -91.012506,
#               32.130253
#             ],
#             [
#               -91.011106,
#               32.132153
#             ],
#             [
#               -91.007206,
#               32.138452
#             ],
#             [
#               -91.005006,
#               32.142851
#             ],
#             [
#               -91.004106,
#               32.146152
#             ],
#             [
#               -91.002906,
#               32.162052
#             ],
#             [
#               -91.016606,
#               32.160852
#             ],
#             [
#               -91.025007,
#               32.162551
#             ],
#             [
#               -91.025507,
#               32.163052
#             ],
#             [
#               -91.027407,
#               32.164251
#             ],
#             [
#               -91.030807,
#               32.167051
#             ],
#             [
#               -91.036246,
#               32.170701
#             ],
#             [
#               -91.037724,
#               32.171926
#             ],
#             [
#               -91.041807,
#               32.174551
#             ],
#             [
#               -91.050207,
#               32.178451
#             ],
#             [
#               -91.058307,
#               32.180951
#             ],
#             [
#               -91.058907,
#               32.17125
#             ],
#             [
#               -91.055707,
#               32.163752
#             ],
#             [
#               -91.049707,
#               32.157352
#             ],
#             [
#               -91.048507,
#               32.150152
#             ],
#             [
#               -91.049007,
#               32.148252
#             ],
#             [
#               -91.049807,
#               32.146852
#             ],
#             [
#               -91.050207,
#               32.145252
#             ],
#             [
#               -91.050407,
#               32.144852
#             ],
#             [
#               -91.051207,
#               32.144152
#             ],
#             [
#               -91.052754,
#               32.125777
#             ],
#             [
#               -91.052966,
#               32.125192
#             ],
#             [
#               -91.053555,
#               32.124412
#             ],
#             [
#               -91.055207,
#               32.125053
#             ],
#             [
#               -91.061555,
#               32.126907
#             ],
#             [
#               -91.063829,
#               32.128298
#             ],
#             [
#               -91.067724,
#               32.130347
#             ],
#             [
#               -91.069081,
#               32.131478
#             ],
#             [
#               -91.073678,
#               32.132783
#             ],
#             [
#               -91.077043,
#               32.133493
#             ],
#             [
#               -91.08163,
#               32.133992
#             ],
#             [
#               -91.086526,
#               32.13395
#             ],
#             [
#               -91.091656,
#               32.133604
#             ],
#             [
#               -91.096342,
#               32.132556
#             ],
#             [
#               -91.101181,
#               32.131135
#             ],
#             [
#               -91.103695,
#               32.130005
#             ],
#             [
#               -91.106633,
#               32.128198
#             ],
#             [
#               -91.11099,
#               32.124644
#             ],
#             [
#               -91.111294,
#               32.125036
#             ],
#             [
#               -91.112123,
#               32.125152
#             ],
#             [
#               -91.113866,
#               32.125731
#             ],
#             [
#               -91.125109,
#               32.125774
#             ],
#             [
#               -91.131403,
#               32.126213
#             ],
#             [
#               -91.133309,
#               32.126514
#             ],
#             [
#               -91.136566,
#               32.12737
#             ],
#             [
#               -91.142158,
#               32.129736
#             ],
#             [
#               -91.1444,
#               32.13039
#             ],
#             [
#               -91.155043,
#               32.132243
#             ],
#             [
#               -91.162822,
#               32.132694
#             ],
#             [
#               -91.16445,
#               32.133505
#             ],
#             [
#               -91.165452,
#               32.13429
#             ],
#             [
#               -91.169771,
#               32.140678
#             ],
#             [
#               -91.17273,
#               32.146479
#             ],
#             [
#               -91.173495,
#               32.149009
#             ],
#             [
#               -91.173898,
#               32.151276
#             ],
#             [
#               -91.17427,
#               32.152451
#             ],
#             [
#               -91.174552,
#               32.154978
#             ],
#             [
#               -91.174577,
#               32.157311
#             ],
#             [
#               -91.174348,
#               32.159832
#             ],
#             [
#               -91.173664,
#               32.164231
#             ],
#             [
#               -91.172505,
#               32.168382
#             ],
#             [
#               -91.172211,
#               32.171058
#             ],
#             [
#               -91.171046,
#               32.176526
#             ],
#             [
#               -91.168073,
#               32.186635
#             ],
#             [
#               -91.166447,
#               32.189757
#             ],
#             [
#               -91.16586,
#               32.191643
#             ],
#             [
#               -91.165332,
#               32.194584
#             ],
#             [
#               -91.16488,
#               32.195743
#             ],
#             [
#               -91.164171,
#               32.196888
#             ],
#             [
#               -91.162062,
#               32.199035
#             ],
#             [
#               -91.158026,
#               32.201956
#             ],
#             [
#               -91.141901,
#               32.20977
#             ],
#             [
#               -91.133587,
#               32.213431
#             ],
#             [
#               -91.131771,
#               32.213744
#             ],
#             [
#               -91.130197,
#               32.213666
#             ],
#             [
#               -91.128495,
#               32.213169
#             ],
#             [
#               -91.124677,
#               32.21154
#             ],
#             [
#               -91.121823,
#               32.209708
#             ],
#             [
#               -91.118214,
#               32.207102
#             ],
#             [
#               -91.11727,
#               32.206668
#             ],
#             [
#               -91.116058,
#               32.206415
#             ],
#             [
#               -91.114084,
#               32.206697
#             ],
#             [
#               -91.113009,
#               32.20655
#             ],
#             [
#               -91.108509,
#               32.20815
#             ],
#             [
#               -91.100409,
#               32.21785
#             ],
#             [
#               -91.092108,
#               32.22385
#             ],
#             [
#               -91.083708,
#               32.22645
#             ],
#             [
#               -91.075108,
#               32.22705
#             ],
#             [
#               -91.071108,
#               32.22605
#             ],
#             [
#               -91.061408,
#               32.21865
#             ],
#             [
#               -91.055107,
#               32.22475
#             ],
#             [
#               -91.053107,
#               32.22795
#             ],
#             [
#               -91.051807,
#               32.234448
#             ],
#             [
#               -91.050307,
#               32.237949
#             ],
#             [
#               -91.046507,
#               32.241149
#             ],
#             [
#               -91.039007,
#               32.242348
#             ],
#             [
#               -91.034302,
#               32.241548
#             ],
#             [
#               -91.026607,
#               32.238749
#             ],
#             [
#               -91.021537,
#               32.236156
#             ],
#             [
#               -91.014606,
#               32.230249
#             ],
#             [
#               -91.012606,
#               32.22835
#             ],
#             [
#               -91.009606,
#               32.226149
#             ],
#             [
#               -91.008406,
#               32.22555
#             ],
#             [
#               -91.006106,
#               32.22405
#             ],
#             [
#               -91.002906,
#               32.22305
#             ],
#             [
#               -91.003906,
#               32.21905
#             ],
#             [
#               -91.005006,
#               32.21285
#             ],
#             [
#               -91.003206,
#               32.19805
#             ],
#             [
#               -90.999697,
#               32.191103
#             ],
#             [
#               -90.994944,
#               32.193141
#             ],
#             [
#               -90.994432,
#               32.193738
#             ],
#             [
#               -90.991933,
#               32.197842
#             ],
#             [
#               -90.984876,
#               32.208526
#             ],
#             [
#               -90.983381,
#               32.211767
#             ],
#             [
#               -90.982753,
#               32.215229
#             ],
#             [
#               -90.98255,
#               32.220923
#             ],
#             [
#               -90.982716,
#               32.223903
#             ],
#             [
#               -90.983263,
#               32.226201
#             ],
#             [
#               -90.983328,
#               32.228437
#             ],
#             [
#               -90.983135,
#               32.231371
#             ],
#             [
#               -90.981893,
#               32.237988
#             ],
#             [
#               -90.980754,
#               32.242485
#             ],
#             [
#               -90.98029,
#               32.243601
#             ],
#             [
#               -90.979203,
#               32.245095
#             ],
#             [
#               -90.976139,
#               32.248092
#             ],
#             [
#               -90.970016,
#               32.25168
#             ],
#             [
#               -90.969515,
#               32.252053
#             ],
#             [
#               -90.969403,
#               32.25252
#             ],
#             [
#               -90.969557,
#               32.253577
#             ],
#             [
#               -90.970099,
#               32.255074
#             ],
#             [
#               -90.971344,
#               32.257742
#             ],
#             [
#               -90.972424,
#               32.258902
#             ],
#             [
#               -90.977521,
#               32.263005
#             ],
#             [
#               -90.979662,
#               32.26525
#             ],
#             [
#               -90.981027,
#               32.266733
#             ],
#             [
#               -90.982243,
#               32.268634
#             ],
#             [
#               -90.982985,
#               32.270294
#             ],
#             [
#               -90.984071,
#               32.277493
#             ],
#             [
#               -90.984077,
#               32.279953
#             ],
#             [
#               -90.982311,
#               32.285207
#             ],
#             [
#               -90.981582,
#               32.28882
#             ],
#             [
#               -90.980747,
#               32.29141
#             ],
#             [
#               -90.979475,
#               32.293702
#             ],
#             [
#               -90.976199,
#               32.29645
#             ],
#             [
#               -90.974602,
#               32.297122
#             ],
#             [
#               -90.971643,
#               32.297497
#             ],
#             [
#               -90.968179,
#               32.297406
#             ],
#             [
#               -90.965351,
#               32.297168
#             ],
#             [
#               -90.964149,
#               32.296872
#             ],
#             [
#               -90.963079,
#               32.296284
#             ],
#             [
#               -90.96176,
#               32.294666
#             ],
#             [
#               -90.961171,
#               32.293287
#             ],
#             [
#               -90.960479,
#               32.292434
#             ],
#             [
#               -90.957361,
#               32.289858
#             ],
#             [
#               -90.957037,
#               32.288431
#             ],
#             [
#               -90.955405,
#               32.28624
#             ],
#             [
#               -90.953009,
#               32.284042
#             ],
#             [
#               -90.951352,
#               32.283199
#             ],
#             [
#               -90.949781,
#               32.283056
#             ],
#             [
#               -90.947834,
#               32.283486
#             ],
#             [
#               -90.943118,
#               32.285533
#             ],
#             [
#               -90.933991,
#               32.290343
#             ],
#             [
#               -90.922231,
#               32.298639
#             ],
#             [
#               -90.916157,
#               32.303582
#             ],
#             [
#               -90.90917,
#               32.310798
#             ],
#             [
#               -90.905173,
#               32.315497
#             ],
#             [
#               -90.902558,
#               32.319587
#             ],
#             [
#               -90.90124,
#               32.323386
#             ],
#             [
#               -90.900716,
#               32.326847
#             ],
#             [
#               -90.900722,
#               32.330379
#             ],
#             [
#               -90.893288,
#               32.341039
#             ],
#             [
#               -90.885771,
#               32.3508
#             ]
#           ]
#         ]
#       }
#     }
#   ]
# }

# %% [markdown]
# *Note:* This endpoint provides provides recommendations and details about the technique used to alter the provided geometry so that it meets Planet's validity requirements.
# Pick which geometry makes sense for you.

# %% [markdown]
# ## Using the references

# %% [markdown]
# Features references are supported in the Data API, Subscriptions API and Orders API.
# We'll walk through some examples together below.
#
# For all APIs you can replace your current geometry geojson block requests with a block like this:
# ```json
#   "geometry": {
#     "content": "pl:features/my/[collection]/[feature-id]", # your short ref
#     "type": "ref" # instead of a Polygon or Multipolygon, the type is `ref`
#   },
#
# ```

# %% [markdown]
# ### Data API
# #### Quick Searches with a Feature Reference

# %%
# Setup Item Types
item_types = ["PSScene"]


# Setup a geometry filter
geometry = {
    "type": "ref",
    "content": short_ref,
}

# Let's filter for the month of jan, and images that are not too cloudy.
filter = {
   "type":"AndFilter",
   "config":[
        {
            "type":"DateRangeFilter",
            "field_name":"acquired",
            "config":{
               "gte":"2024-01-01T00:00:00Z",
               "lte":"2024-01-15T00:00:00Z"
            },
        }, 
        {
           "type":"RangeFilter",
           "field_name":"cloud_cover",
           "config":{
              "lte":0.1
           },
        }
   ]
}


# Setup the request
request = {
    "item_types" : item_types,
    "geometry" : geometry,
    "filter": filter
    
}

# %%
# Send the POST request to the API quick search endpoint
quick_url =  "https://api.planet.com/data/v1/quick-search"
res = session.post(quick_url, json=request)


# Print the response
p(res.json())
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/2cc286e0e952450aa69069e947e8e0c7/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/2cc286e0e952450aa69069e947e8e0c7/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDI0LTAxLTAxVDIwOjU4OjI3LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjQwMTAxXzE4MjI0Ml83NV8yNGI0IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#     "_self": "https://api.planet.com/data/v1/searches/2cc286e0e952450aa69069e947e8e0c7/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191157_82_2488",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191157_82_2488/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_191157_82_2488/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.1824290366636,
#               49.480570642035765
#             ],
#             [
#               -125.24129318080176,
#               49.31647549302399
#             ],
#             [
#               -124.82241668682637,
#               49.25114716342289
#             ],
#             [
#               -124.76180073980346,
#               49.41443331535138
#             ],
#             [
#               -125.1824290366636,
#               49.480570642035765
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_191157_82_2488",
#       "properties": {
#         "acquired": "2024-01-14T19:11:57.821617Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 43,
#         "clear_percent": 0,
#         "cloud_cover": 0.02,
#         "cloud_percent": 2,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 98,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-15T00:17:02Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 103.4,
#         "satellite_id": "2488",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7040871",
#         "sun_azimuth": 161.6,
#         "sun_elevation": 17.5,
#         "updated": "2024-01-15T06:57:20Z",
#         "view_angle": 3.2,
#         "visible_confidence_percent": 61,
#         "visible_percent": 98
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191159_81_2488",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191159_81_2488/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_191159_81_2488/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.22813781807524,
#               49.35543315064544
#             ],
#             [
#               -125.28567987201173,
#               49.191086576733724
#             ],
#             [
#               -124.86797335760828,
#               49.1259428113547
#             ],
#             [
#               -124.80796766300577,
#               49.28925568831666
#             ],
#             [
#               -125.22813781807524,
#               49.35543315064544
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_191159_81_2488",
#       "properties": {
#         "acquired": "2024-01-14T19:11:59.815595Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 39,
#         "clear_percent": 0,
#         "cloud_cover": 0.05,
#         "cloud_percent": 5,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 95,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-15T00:15:37Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 103.5,
#         "satellite_id": "2488",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7040871",
#         "sun_azimuth": 161.5,
#         "sun_elevation": 17.6,
#         "updated": "2024-01-15T06:57:30Z",
#         "view_angle": 3.2,
#         "visible_confidence_percent": 56,
#         "visible_percent": 95
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182915_64_24bf",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182915_64_24bf/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_182915_64_24bf/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.66678582331713,
#               49.536862882943986
#             ],
#             [
#               -125.73183152667627,
#               49.35497739262996
#             ],
#             [
#               -125.26595552893723,
#               49.283898809789584
#             ],
#             [
#               -125.19966868836998,
#               49.46456892750318
#             ],
#             [
#               -125.66678582331713,
#               49.536862882943986
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_182915_64_24bf",
#       "properties": {
#         "acquired": "2024-01-14T18:29:15.649378Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 39,
#         "clear_percent": 0,
#         "cloud_cover": 0.07,
#         "cloud_percent": 7,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 93,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-15T00:11:46Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 103,
#         "satellite_id": "24bf",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7040876",
#         "sun_azimuth": 151.4,
#         "sun_elevation": 14.6,
#         "updated": "2024-01-15T05:00:44Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 54,
#         "visible_percent": 93
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191131_36_2495",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191131_36_2495/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_191131_36_2495/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -124.80624632672291,
#               49.09847004053555
#             ],
#             [
#               -124.8632983286616,
#               48.93357282204047
#             ],
#             [
#               -124.44495058767123,
#               48.8699616174829
#             ],
#             [
#               -124.38616618865535,
#               49.03318054388608
#             ],
#             [
#               -124.80624632672291,
#               49.09847004053555
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_191131_36_2495",
#       "properties": {
#         "acquired": "2024-01-14T19:11:31.366724Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 72,
#         "clear_percent": 0,
#         "cloud_cover": 0.01,
#         "cloud_percent": 1,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 99,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T23:01:56Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 102.9,
#         "satellite_id": "2495",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7041016",
#         "sun_azimuth": 161.9,
#         "sun_elevation": 18,
#         "updated": "2024-01-15T09:59:16Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 75,
#         "visible_percent": 99
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182939_23_2458",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182939_23_2458/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_182939_23_2458/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.80264092238482,
#               48.586605206036836
#             ],
#             [
#               -123.86105605508612,
#               48.4251683500182
#             ],
#             [
#               -123.45541494088498,
#               48.35953461102685
#             ],
#             [
#               -123.39536705664763,
#               48.52089498864311
#             ],
#             [
#               -123.80264092238482,
#               48.586605206036836
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_182939_23_2458",
#       "properties": {
#         "acquired": "2024-01-14T18:29:39.233158Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 51,
#         "clear_percent": 1,
#         "cloud_cover": 0.03,
#         "cloud_percent": 3,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 97,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T23:00:38Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 254.9,
#         "satellite_id": "2458",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7041017",
#         "sun_azimuth": 152.5,
#         "sun_elevation": 15.8,
#         "updated": "2024-01-15T09:59:27Z",
#         "view_angle": 0.5,
#         "visible_confidence_percent": 59,
#         "visible_percent": 97
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191129_37_2495",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191129_37_2495/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_191129_37_2495/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -124.76187605142599,
#               49.22382175392911
#             ],
#             [
#               -124.81971348293133,
#               49.05899641049291
#             ],
#             [
#               -124.39949771612594,
#               48.99538550600973
#             ],
#             [
#               -124.34067723091219,
#               49.158362662935176
#             ],
#             [
#               -124.76187605142599,
#               49.22382175392911
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_191129_37_2495",
#       "properties": {
#         "acquired": "2024-01-14T19:11:29.378604Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 76,
#         "clear_percent": 0,
#         "cloud_cover": 0.09,
#         "cloud_percent": 9,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 91,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T22:59:47Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 103.1,
#         "satellite_id": "2495",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7041016",
#         "sun_azimuth": 162,
#         "sun_elevation": 17.8,
#         "updated": "2024-01-15T09:59:13Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 78,
#         "visible_percent": 91
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182723_44_2439",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182723_44_2439/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_182723_44_2439/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -124.10359311282501,
#               48.763370867478166
#             ],
#             [
#               -124.16026063515237,
#               48.60011474102869
#             ],
#             [
#               -123.74806649281084,
#               48.537083627801756
#             ],
#             [
#               -123.69056645645202,
#               48.698824850209085
#             ],
#             [
#               -124.10359311282501,
#               48.763370867478166
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_182723_44_2439",
#       "properties": {
#         "acquired": "2024-01-14T18:27:23.443011Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 51,
#         "clear_percent": 1,
#         "cloud_cover": 0.05,
#         "cloud_percent": 5,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 95,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T22:17:00Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 102.5,
#         "satellite_id": "2439",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7040880",
#         "sun_azimuth": 152.2,
#         "sun_elevation": 15.6,
#         "updated": "2024-01-15T06:57:25Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 60,
#         "visible_percent": 95
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183331_81_2465",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183331_81_2465/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_183331_81_2465/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.59940539250219,
#               48.75022183319151
#             ],
#             [
#               -125.6552213389946,
#               48.587523228617265
#             ],
#             [
#               -125.2451938571015,
#               48.52314937522272
#             ],
#             [
#               -125.18825017369842,
#               48.68515722321577
#             ],
#             [
#               -125.59940539250219,
#               48.75022183319151
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_183331_81_2465",
#       "properties": {
#         "acquired": "2024-01-13T18:33:31.815879Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 67,
#         "clear_percent": 17,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": false,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 83,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T01:27:38Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 104.1,
#         "satellite_id": "2465",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7038569",
#         "sun_azimuth": 152.2,
#         "sun_elevation": 15.4,
#         "updated": "2024-01-14T04:21:27Z",
#         "view_angle": 2.3,
#         "visible_confidence_percent": 73,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183333_81_2465",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183333_81_2465/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_183333_81_2465/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.64428775856187,
#               48.62377471060667
#             ],
#             [
#               -125.6998412351654,
#               48.46106081592383
#             ],
#             [
#               -125.29083003742961,
#               48.39681864676869
#             ],
#             [
#               -125.23415893786262,
#               48.5588435138047
#             ],
#             [
#               -125.64428775856187,
#               48.62377471060667
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_183333_81_2465",
#       "properties": {
#         "acquired": "2024-01-13T18:33:33.811659Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 64,
#         "clear_percent": 21,
#         "cloud_cover": 0.01,
#         "cloud_percent": 1,
#         "ground_control": false,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 79,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T01:27:25Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 103.8,
#         "satellite_id": "2465",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7038569",
#         "sun_azimuth": 152.1,
#         "sun_elevation": 15.5,
#         "updated": "2024-01-14T04:21:12Z",
#         "view_angle": 2.3,
#         "visible_confidence_percent": 69,
#         "visible_percent": 99
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190813_55_248c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190813_55_248c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_190813_55_248c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.71201562738896,
#               48.54216939801295
#             ],
#             [
#               -123.77077139383174,
#               48.37843318039054
#             ],
#             [
#               -123.36032623279218,
#               48.31243716608241
#             ],
#             [
#               -123.29998237040745,
#               48.47560777061364
#             ],
#             [
#               -123.71201562738896,
#               48.54216939801295
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_190813_55_248c",
#       "properties": {
#         "acquired": "2024-01-13T19:08:13.557094Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 64,
#         "clear_percent": 63,
#         "cloud_cover": 0.02,
#         "cloud_percent": 2,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 29,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T00:25:01Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 137.8,
#         "satellite_id": "248c",
#         "shadow_percent": 1,
#         "snow_ice_percent": 5,
#         "strip_id": "7038702",
#         "sun_azimuth": 161.8,
#         "sun_elevation": 18.2,
#         "updated": "2024-01-14T06:57:25Z",
#         "view_angle": 0.2,
#         "visible_confidence_percent": 59,
#         "visible_percent": 98
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190811_57_248c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190811_57_248c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_190811_57_248c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.66667997811084,
#               48.66714161027277
#             ],
#             [
#               -123.72553589024774,
#               48.50339408619966
#             ],
#             [
#               -123.3142041513122,
#               48.43725093714168
#             ],
#             [
#               -123.25358097605864,
#               48.60043416529203
#             ],
#             [
#               -123.66667997811084,
#               48.66714161027277
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_190811_57_248c",
#       "properties": {
#         "acquired": "2024-01-13T19:08:11.574236Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 69,
#         "clear_percent": 72,
#         "cloud_cover": 0.03,
#         "cloud_percent": 3,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 19,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T00:24:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 139.5,
#         "satellite_id": "248c",
#         "shadow_percent": 2,
#         "snow_ice_percent": 4,
#         "strip_id": "7038702",
#         "sun_azimuth": 161.8,
#         "sun_elevation": 18.1,
#         "updated": "2024-01-14T06:57:25Z",
#         "view_angle": 0.2,
#         "visible_confidence_percent": 58,
#         "visible_percent": 97
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190807_60_248c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190807_60_248c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_190807_60_248c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.5729770378204,
#               48.91249939665438
#             ],
#             [
#               -123.6332244566768,
#               48.75265474744653
#             ],
#             [
#               -123.22123026991784,
#               48.68713134826021
#             ],
#             [
#               -123.16038460389582,
#               48.84770653556807
#             ],
#             [
#               -123.5729770378204,
#               48.91249939665438
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_190807_60_248c",
#       "properties": {
#         "acquired": "2024-01-13T19:08:07.60841Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 62,
#         "clear_percent": 40,
#         "cloud_cover": 0.04,
#         "cloud_percent": 4,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 52,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T00:24:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 141.9,
#         "satellite_id": "248c",
#         "shadow_percent": 0,
#         "snow_ice_percent": 4,
#         "strip_id": "7038702",
#         "sun_azimuth": 161.9,
#         "sun_elevation": 17.9,
#         "updated": "2024-01-14T06:57:26Z",
#         "view_angle": 0.2,
#         "visible_confidence_percent": 58,
#         "visible_percent": 96
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190809_59_248c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190809_59_248c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_190809_59_248c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.62070796757648,
#               48.79154046298508
#             ],
#             [
#               -123.68044379200309,
#               48.62797719997524
#             ],
#             [
#               -123.26819858478115,
#               48.561850406735594
#             ],
#             [
#               -123.20740267571865,
#               48.72491110677392
#             ],
#             [
#               -123.62070796757648,
#               48.79154046298508
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_190809_59_248c",
#       "properties": {
#         "acquired": "2024-01-13T19:08:09.591323Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 69,
#         "clear_percent": 63,
#         "cloud_cover": 0.05,
#         "cloud_percent": 5,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 29,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T00:24:40Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 138.8,
#         "satellite_id": "248c",
#         "shadow_percent": 1,
#         "snow_ice_percent": 2,
#         "strip_id": "7038702",
#         "sun_azimuth": 161.9,
#         "sun_elevation": 18,
#         "updated": "2024-01-14T06:57:30Z",
#         "view_angle": 0.2,
#         "visible_confidence_percent": 59,
#         "visible_percent": 95
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190805_62_248c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190805_62_248c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_190805_62_248c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.5299525269422,
#               49.04074995220022
#             ],
#             [
#               -123.5896707452987,
#               48.87708389131959
#             ],
#             [
#               -123.17508846989637,
#               48.810610163773696
#             ],
#             [
#               -123.11381051841839,
#               48.97364910396128
#             ],
#             [
#               -123.5299525269422,
#               49.04074995220022
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_190805_62_248c",
#       "properties": {
#         "acquired": "2024-01-13T19:08:05.625497Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 59,
#         "clear_percent": 26,
#         "cloud_cover": 0.03,
#         "cloud_percent": 3,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 69,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T00:24:08Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 140.3,
#         "satellite_id": "248c",
#         "shadow_percent": 0,
#         "snow_ice_percent": 1,
#         "strip_id": "7038702",
#         "sun_azimuth": 162,
#         "sun_elevation": 17.8,
#         "updated": "2024-01-16T00:57:16Z",
#         "view_angle": 0.2,
#         "visible_confidence_percent": 56,
#         "visible_percent": 97
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183327_82_2465",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183327_82_2465/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_183327_82_2465/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.5109514554945,
#               49.001742147528226
#             ],
#             [
#               -125.56979103189124,
#               48.83863672336781
#             ],
#             [
#               -125.15644793964643,
#               48.77397874851996
#             ],
#             [
#               -125.09697306777701,
#               48.93645729570047
#             ],
#             [
#               -125.5109514554945,
#               49.001742147528226
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_183327_82_2465",
#       "properties": {
#         "acquired": "2024-01-13T18:33:27.824264Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 71,
#         "clear_percent": 47,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 53,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-13T23:31:41Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 104.3,
#         "satellite_id": "2465",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7038569",
#         "sun_azimuth": 152.3,
#         "sun_elevation": 15.2,
#         "updated": "2024-01-14T04:21:12Z",
#         "view_angle": 2.2,
#         "visible_confidence_percent": 66,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183319_84_2465",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183319_84_2465/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_183319_84_2465/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
# ...
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 273.2,
#         "satellite_id": "2470",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7018140",
#         "sun_azimuth": 162.8,
#         "sun_elevation": 17,
#         "updated": "2024-01-05T03:58:39Z",
#         "view_angle": 1.1,
#         "visible_confidence_percent": 50,
#         "visible_percent": 96
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_191333_09_2470",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_191333_09_2470/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240104_191333_09_2470/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.17538822792874,
#               48.57003709677041
#             ],
#             [
#               -125.23545737760902,
#               48.404788620497456
#             ],
#             [
#               -124.8212614377309,
#               48.33840017827941
#             ],
#             [
#               -124.75974934102021,
#               48.503650126155904
#             ],
#             [
#               -125.17538822792874,
#               48.57003709677041
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240104_191333_09_2470",
#       "properties": {
#         "acquired": "2024-01-04T19:13:33.091513Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 59,
#         "clear_percent": 73,
#         "cloud_cover": 0.1,
#         "cloud_percent": 10,
#         "ground_control": false,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 16,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-04T21:27:28Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 273.7,
#         "satellite_id": "2470",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7018140",
#         "sun_azimuth": 162.7,
#         "sun_elevation": 17.1,
#         "updated": "2024-01-05T04:16:03Z",
#         "view_angle": 1.1,
#         "visible_confidence_percent": 51,
#         "visible_percent": 90
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_190841_68_24a4",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_190841_68_24a4/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240104_190841_68_24a4/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.90500597341934,
#               49.22120645086965
#             ],
#             [
#               -123.96661128602595,
#               49.0564459890931
#             ],
#             [
#               -123.54692530718552,
#               48.987600122903906
#             ],
#             [
#               -123.48358757591923,
#               49.15241396044797
#             ],
#             [
#               -123.90500597341934,
#               49.22120645086965
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240104_190841_68_24a4",
#       "properties": {
#         "acquired": "2024-01-04T19:08:41.688999Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 73,
#         "clear_percent": 79,
#         "cloud_cover": 0.1,
#         "cloud_percent": 10,
#         "ground_control": true,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 7,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-04T21:26:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 279,
#         "satellite_id": "24a4",
#         "shadow_percent": 4,
#         "snow_ice_percent": 0,
#         "strip_id": "7018115",
#         "sun_azimuth": 162.6,
#         "sun_elevation": 16.4,
#         "updated": "2024-01-05T04:21:27Z",
#         "view_angle": 3.5,
#         "visible_confidence_percent": 56,
#         "visible_percent": 90
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_183229_94_242e",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_183229_94_242e/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240104_183229_94_242e/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.47580548814507,
#               48.75287435410358
#             ],
#             [
#               -125.54278436857464,
#               48.57424186596111
#             ],
#             [
#               -125.08999399822447,
#               48.49779634675242
#             ],
#             [
#               -125.02090334028541,
#               48.6772790646505
#             ],
#             [
#               -125.47580548814507,
#               48.75287435410358
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240104_183229_94_242e",
#       "properties": {
#         "acquired": "2024-01-04T18:32:29.943959Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 57,
#         "clear_percent": 70,
#         "cloud_cover": 0.08,
#         "cloud_percent": 8,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 22,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-04T21:05:09Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 279.9,
#         "satellite_id": "242e",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7017969",
#         "sun_azimuth": 152.6,
#         "sun_elevation": 14.1,
#         "updated": "2024-01-05T04:13:18Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 51,
#         "visible_percent": 92
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240101_183250_59_241e",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240101_183250_59_241e/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240101_183250_59_241e/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.53348409191956,
#               49.18480877833996
#             ],
#             [
#               -125.59139014948393,
#               49.02225142154435
#             ],
#             [
#               -125.17814709564308,
#               48.958336893374025
#             ],
#             [
#               -125.11906325342773,
#               49.11975674557374
#             ],
#             [
#               -125.53348409191956,
#               49.18480877833996
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240101_183250_59_241e",
#       "properties": {
#         "acquired": "2024-01-01T18:32:50.596758Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 68,
#         "clear_percent": 25,
#         "cloud_cover": 0.09,
#         "cloud_percent": 9,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 58,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-01T22:16:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 103.7,
#         "satellite_id": "241e",
#         "shadow_percent": 8,
#         "snow_ice_percent": 0,
#         "strip_id": "7010903",
#         "sun_azimuth": 153.9,
#         "sun_elevation": 14,
#         "updated": "2024-01-02T09:59:22Z",
#         "view_angle": 3.5,
#         "visible_confidence_percent": 67,
#         "visible_percent": 91
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240101_182242_75_24b4",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240101_182242_75_24b4/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240101_182242_75_24b4/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -124.23737282033859,
#               48.58683396127725
#             ],
#             [
#               -124.30006361668472,
#               48.406242556854124
#             ],
#             [
#               -123.84640839469215,
#               48.33610754987424
#             ],
#             [
#               -123.7820146212451,
#               48.515121303899434
#             ],
#             [
#               -124.23737282033859,
#               48.58683396127725
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240101_182242_75_24b4",
#       "properties": {
#         "acquired": "2024-01-01T18:22:42.757397Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 76,
#         "clear_percent": 62,
#         "cloud_cover": 0.06,
#         "cloud_percent": 6,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 29,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-01T20:58:27Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 102.5,
#         "satellite_id": "24b4",
#         "shadow_percent": 4,
#         "snow_ice_percent": 0,
#         "strip_id": "7010589",
#         "sun_azimuth": 152.9,
#         "sun_elevation": 14.2,
#         "updated": "2024-01-02T03:57:44Z",
#         "view_angle": 4.5,
#         "visible_confidence_percent": 59,
#         "visible_percent": 94
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Nice! You'll notice the geometry that was used to seach becomes hydrated in the response.

# %%
# save an item ID for the orders request below.
item_id = res.json()["features"][0]["id"]

# %% [markdown]
# *Note* The geometry field in the Data API can also take an array of refs

# %%
# Setup the request
multiple_ref_geometry = {
    "type": "ref",
    "content": [short_ref, short_ref_2],
}

request = {
    "item_types" : item_types,
    "geometry" : geometry,
    "filter": filter
    
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)


# Print the response
p(res.json())
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/e05e8ba5981f4d2bb78f5d2895bb4c1f/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/e05e8ba5981f4d2bb78f5d2895bb4c1f/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDI0LTAxLTAxVDIwOjU4OjI3LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjQwMTAxXzE4MjI0Ml83NV8yNGI0IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#     "_self": "https://api.planet.com/data/v1/searches/e05e8ba5981f4d2bb78f5d2895bb4c1f/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191157_82_2488",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191157_82_2488/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_191157_82_2488/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.1824290366636,
#               49.480570642035765
#             ],
#             [
#               -125.24129318080176,
#               49.31647549302399
#             ],
#             [
#               -124.82241668682637,
#               49.25114716342289
#             ],
#             [
#               -124.76180073980346,
#               49.41443331535138
#             ],
#             [
#               -125.1824290366636,
#               49.480570642035765
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_191157_82_2488",
#       "properties": {
#         "acquired": "2024-01-14T19:11:57.821617Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 43,
#         "clear_percent": 0,
#         "cloud_cover": 0.02,
#         "cloud_percent": 2,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 98,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-15T00:17:02Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 103.4,
#         "satellite_id": "2488",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7040871",
#         "sun_azimuth": 161.6,
#         "sun_elevation": 17.5,
#         "updated": "2024-01-15T06:57:20Z",
#         "view_angle": 3.2,
#         "visible_confidence_percent": 61,
#         "visible_percent": 98
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191159_81_2488",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191159_81_2488/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_191159_81_2488/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.22813781807524,
#               49.35543315064544
#             ],
#             [
#               -125.28567987201173,
#               49.191086576733724
#             ],
#             [
#               -124.86797335760828,
#               49.1259428113547
#             ],
#             [
#               -124.80796766300577,
#               49.28925568831666
#             ],
#             [
#               -125.22813781807524,
#               49.35543315064544
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_191159_81_2488",
#       "properties": {
#         "acquired": "2024-01-14T19:11:59.815595Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 39,
#         "clear_percent": 0,
#         "cloud_cover": 0.05,
#         "cloud_percent": 5,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 95,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-15T00:15:37Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 103.5,
#         "satellite_id": "2488",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7040871",
#         "sun_azimuth": 161.5,
#         "sun_elevation": 17.6,
#         "updated": "2024-01-15T06:57:30Z",
#         "view_angle": 3.2,
#         "visible_confidence_percent": 56,
#         "visible_percent": 95
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182915_64_24bf",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182915_64_24bf/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_182915_64_24bf/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.66678582331713,
#               49.536862882943986
#             ],
#             [
#               -125.73183152667627,
#               49.35497739262996
#             ],
#             [
#               -125.26595552893723,
#               49.283898809789584
#             ],
#             [
#               -125.19966868836998,
#               49.46456892750318
#             ],
#             [
#               -125.66678582331713,
#               49.536862882943986
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_182915_64_24bf",
#       "properties": {
#         "acquired": "2024-01-14T18:29:15.649378Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 39,
#         "clear_percent": 0,
#         "cloud_cover": 0.07,
#         "cloud_percent": 7,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 93,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-15T00:11:46Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 103,
#         "satellite_id": "24bf",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7040876",
#         "sun_azimuth": 151.4,
#         "sun_elevation": 14.6,
#         "updated": "2024-01-15T05:00:44Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 54,
#         "visible_percent": 93
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191131_36_2495",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191131_36_2495/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_191131_36_2495/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -124.80624632672291,
#               49.09847004053555
#             ],
#             [
#               -124.8632983286616,
#               48.93357282204047
#             ],
#             [
#               -124.44495058767123,
#               48.8699616174829
#             ],
#             [
#               -124.38616618865535,
#               49.03318054388608
#             ],
#             [
#               -124.80624632672291,
#               49.09847004053555
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_191131_36_2495",
#       "properties": {
#         "acquired": "2024-01-14T19:11:31.366724Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 72,
#         "clear_percent": 0,
#         "cloud_cover": 0.01,
#         "cloud_percent": 1,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 99,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T23:01:56Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 102.9,
#         "satellite_id": "2495",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7041016",
#         "sun_azimuth": 161.9,
#         "sun_elevation": 18,
#         "updated": "2024-01-15T09:59:16Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 75,
#         "visible_percent": 99
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182939_23_2458",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182939_23_2458/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_182939_23_2458/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.80264092238482,
#               48.586605206036836
#             ],
#             [
#               -123.86105605508612,
#               48.4251683500182
#             ],
#             [
#               -123.45541494088498,
#               48.35953461102685
#             ],
#             [
#               -123.39536705664763,
#               48.52089498864311
#             ],
#             [
#               -123.80264092238482,
#               48.586605206036836
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_182939_23_2458",
#       "properties": {
#         "acquired": "2024-01-14T18:29:39.233158Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 51,
#         "clear_percent": 1,
#         "cloud_cover": 0.03,
#         "cloud_percent": 3,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 97,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T23:00:38Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 254.9,
#         "satellite_id": "2458",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7041017",
#         "sun_azimuth": 152.5,
#         "sun_elevation": 15.8,
#         "updated": "2024-01-15T09:59:27Z",
#         "view_angle": 0.5,
#         "visible_confidence_percent": 59,
#         "visible_percent": 97
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191129_37_2495",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_191129_37_2495/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_191129_37_2495/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -124.76187605142599,
#               49.22382175392911
#             ],
#             [
#               -124.81971348293133,
#               49.05899641049291
#             ],
#             [
#               -124.39949771612594,
#               48.99538550600973
#             ],
#             [
#               -124.34067723091219,
#               49.158362662935176
#             ],
#             [
#               -124.76187605142599,
#               49.22382175392911
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_191129_37_2495",
#       "properties": {
#         "acquired": "2024-01-14T19:11:29.378604Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 76,
#         "clear_percent": 0,
#         "cloud_cover": 0.09,
#         "cloud_percent": 9,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 91,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T22:59:47Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 103.1,
#         "satellite_id": "2495",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7041016",
#         "sun_azimuth": 162,
#         "sun_elevation": 17.8,
#         "updated": "2024-01-15T09:59:13Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 78,
#         "visible_percent": 91
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182723_44_2439",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240114_182723_44_2439/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240114_182723_44_2439/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -124.10359311282501,
#               48.763370867478166
#             ],
#             [
#               -124.16026063515237,
#               48.60011474102869
#             ],
#             [
#               -123.74806649281084,
#               48.537083627801756
#             ],
#             [
#               -123.69056645645202,
#               48.698824850209085
#             ],
#             [
#               -124.10359311282501,
#               48.763370867478166
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240114_182723_44_2439",
#       "properties": {
#         "acquired": "2024-01-14T18:27:23.443011Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 51,
#         "clear_percent": 1,
#         "cloud_cover": 0.05,
#         "cloud_percent": 5,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 95,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T22:17:00Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 102.5,
#         "satellite_id": "2439",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7040880",
#         "sun_azimuth": 152.2,
#         "sun_elevation": 15.6,
#         "updated": "2024-01-15T06:57:25Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 60,
#         "visible_percent": 95
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183331_81_2465",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183331_81_2465/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_183331_81_2465/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.59940539250219,
#               48.75022183319151
#             ],
#             [
#               -125.6552213389946,
#               48.587523228617265
#             ],
#             [
#               -125.2451938571015,
#               48.52314937522272
#             ],
#             [
#               -125.18825017369842,
#               48.68515722321577
#             ],
#             [
#               -125.59940539250219,
#               48.75022183319151
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_183331_81_2465",
#       "properties": {
#         "acquired": "2024-01-13T18:33:31.815879Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 67,
#         "clear_percent": 17,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": false,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 83,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T01:27:38Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 104.1,
#         "satellite_id": "2465",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7038569",
#         "sun_azimuth": 152.2,
#         "sun_elevation": 15.4,
#         "updated": "2024-01-14T04:21:27Z",
#         "view_angle": 2.3,
#         "visible_confidence_percent": 73,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183333_81_2465",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183333_81_2465/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_183333_81_2465/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.64428775856187,
#               48.62377471060667
#             ],
#             [
#               -125.6998412351654,
#               48.46106081592383
#             ],
#             [
#               -125.29083003742961,
#               48.39681864676869
#             ],
#             [
#               -125.23415893786262,
#               48.5588435138047
#             ],
#             [
#               -125.64428775856187,
#               48.62377471060667
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_183333_81_2465",
#       "properties": {
#         "acquired": "2024-01-13T18:33:33.811659Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 64,
#         "clear_percent": 21,
#         "cloud_cover": 0.01,
#         "cloud_percent": 1,
#         "ground_control": false,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 79,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T01:27:25Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 103.8,
#         "satellite_id": "2465",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7038569",
#         "sun_azimuth": 152.1,
#         "sun_elevation": 15.5,
#         "updated": "2024-01-14T04:21:12Z",
#         "view_angle": 2.3,
#         "visible_confidence_percent": 69,
#         "visible_percent": 99
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190813_55_248c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190813_55_248c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_190813_55_248c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.71201562738896,
#               48.54216939801295
#             ],
#             [
#               -123.77077139383174,
#               48.37843318039054
#             ],
#             [
#               -123.36032623279218,
#               48.31243716608241
#             ],
#             [
#               -123.29998237040745,
#               48.47560777061364
#             ],
#             [
#               -123.71201562738896,
#               48.54216939801295
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_190813_55_248c",
#       "properties": {
#         "acquired": "2024-01-13T19:08:13.557094Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 64,
#         "clear_percent": 63,
#         "cloud_cover": 0.02,
#         "cloud_percent": 2,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 29,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T00:25:01Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 137.8,
#         "satellite_id": "248c",
#         "shadow_percent": 1,
#         "snow_ice_percent": 5,
#         "strip_id": "7038702",
#         "sun_azimuth": 161.8,
#         "sun_elevation": 18.2,
#         "updated": "2024-01-14T06:57:25Z",
#         "view_angle": 0.2,
#         "visible_confidence_percent": 59,
#         "visible_percent": 98
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190811_57_248c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190811_57_248c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_190811_57_248c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.66667997811084,
#               48.66714161027277
#             ],
#             [
#               -123.72553589024774,
#               48.50339408619966
#             ],
#             [
#               -123.3142041513122,
#               48.43725093714168
#             ],
#             [
#               -123.25358097605864,
#               48.60043416529203
#             ],
#             [
#               -123.66667997811084,
#               48.66714161027277
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_190811_57_248c",
#       "properties": {
#         "acquired": "2024-01-13T19:08:11.574236Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 69,
#         "clear_percent": 72,
#         "cloud_cover": 0.03,
#         "cloud_percent": 3,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 19,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T00:24:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 139.5,
#         "satellite_id": "248c",
#         "shadow_percent": 2,
#         "snow_ice_percent": 4,
#         "strip_id": "7038702",
#         "sun_azimuth": 161.8,
#         "sun_elevation": 18.1,
#         "updated": "2024-01-14T06:57:25Z",
#         "view_angle": 0.2,
#         "visible_confidence_percent": 58,
#         "visible_percent": 97
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190807_60_248c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190807_60_248c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_190807_60_248c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.5729770378204,
#               48.91249939665438
#             ],
#             [
#               -123.6332244566768,
#               48.75265474744653
#             ],
#             [
#               -123.22123026991784,
#               48.68713134826021
#             ],
#             [
#               -123.16038460389582,
#               48.84770653556807
#             ],
#             [
#               -123.5729770378204,
#               48.91249939665438
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_190807_60_248c",
#       "properties": {
#         "acquired": "2024-01-13T19:08:07.60841Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 62,
#         "clear_percent": 40,
#         "cloud_cover": 0.04,
#         "cloud_percent": 4,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 52,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T00:24:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 141.9,
#         "satellite_id": "248c",
#         "shadow_percent": 0,
#         "snow_ice_percent": 4,
#         "strip_id": "7038702",
#         "sun_azimuth": 161.9,
#         "sun_elevation": 17.9,
#         "updated": "2024-01-14T06:57:26Z",
#         "view_angle": 0.2,
#         "visible_confidence_percent": 58,
#         "visible_percent": 96
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190809_59_248c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190809_59_248c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_190809_59_248c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.62070796757648,
#               48.79154046298508
#             ],
#             [
#               -123.68044379200309,
#               48.62797719997524
#             ],
#             [
#               -123.26819858478115,
#               48.561850406735594
#             ],
#             [
#               -123.20740267571865,
#               48.72491110677392
#             ],
#             [
#               -123.62070796757648,
#               48.79154046298508
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_190809_59_248c",
#       "properties": {
#         "acquired": "2024-01-13T19:08:09.591323Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 69,
#         "clear_percent": 63,
#         "cloud_cover": 0.05,
#         "cloud_percent": 5,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 29,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T00:24:40Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 138.8,
#         "satellite_id": "248c",
#         "shadow_percent": 1,
#         "snow_ice_percent": 2,
#         "strip_id": "7038702",
#         "sun_azimuth": 161.9,
#         "sun_elevation": 18,
#         "updated": "2024-01-14T06:57:30Z",
#         "view_angle": 0.2,
#         "visible_confidence_percent": 59,
#         "visible_percent": 95
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190805_62_248c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_190805_62_248c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_190805_62_248c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.5299525269422,
#               49.04074995220022
#             ],
#             [
#               -123.5896707452987,
#               48.87708389131959
#             ],
#             [
#               -123.17508846989637,
#               48.810610163773696
#             ],
#             [
#               -123.11381051841839,
#               48.97364910396128
#             ],
#             [
#               -123.5299525269422,
#               49.04074995220022
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_190805_62_248c",
#       "properties": {
#         "acquired": "2024-01-13T19:08:05.625497Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 59,
#         "clear_percent": 26,
#         "cloud_cover": 0.03,
#         "cloud_percent": 3,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 69,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-14T00:24:08Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 140.3,
#         "satellite_id": "248c",
#         "shadow_percent": 0,
#         "snow_ice_percent": 1,
#         "strip_id": "7038702",
#         "sun_azimuth": 162,
#         "sun_elevation": 17.8,
#         "updated": "2024-01-16T00:57:16Z",
#         "view_angle": 0.2,
#         "visible_confidence_percent": 56,
#         "visible_percent": 97
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183327_82_2465",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183327_82_2465/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_183327_82_2465/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.5109514554945,
#               49.001742147528226
#             ],
#             [
#               -125.56979103189124,
#               48.83863672336781
#             ],
#             [
#               -125.15644793964643,
#               48.77397874851996
#             ],
#             [
#               -125.09697306777701,
#               48.93645729570047
#             ],
#             [
#               -125.5109514554945,
#               49.001742147528226
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240113_183327_82_2465",
#       "properties": {
#         "acquired": "2024-01-13T18:33:27.824264Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 71,
#         "clear_percent": 47,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 53,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-13T23:31:41Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 104.3,
#         "satellite_id": "2465",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7038569",
#         "sun_azimuth": 152.3,
#         "sun_elevation": 15.2,
#         "updated": "2024-01-14T04:21:12Z",
#         "view_angle": 2.2,
#         "visible_confidence_percent": 66,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183319_84_2465",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240113_183319_84_2465/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240113_183319_84_2465/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
# ...
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 273.2,
#         "satellite_id": "2470",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7018140",
#         "sun_azimuth": 162.8,
#         "sun_elevation": 17,
#         "updated": "2024-01-05T03:58:39Z",
#         "view_angle": 1.1,
#         "visible_confidence_percent": 50,
#         "visible_percent": 96
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_191333_09_2470",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_191333_09_2470/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240104_191333_09_2470/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.17538822792874,
#               48.57003709677041
#             ],
#             [
#               -125.23545737760902,
#               48.404788620497456
#             ],
#             [
#               -124.8212614377309,
#               48.33840017827941
#             ],
#             [
#               -124.75974934102021,
#               48.503650126155904
#             ],
#             [
#               -125.17538822792874,
#               48.57003709677041
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240104_191333_09_2470",
#       "properties": {
#         "acquired": "2024-01-04T19:13:33.091513Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 59,
#         "clear_percent": 73,
#         "cloud_cover": 0.1,
#         "cloud_percent": 10,
#         "ground_control": false,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 16,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-04T21:27:28Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 273.7,
#         "satellite_id": "2470",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7018140",
#         "sun_azimuth": 162.7,
#         "sun_elevation": 17.1,
#         "updated": "2024-01-05T04:16:03Z",
#         "view_angle": 1.1,
#         "visible_confidence_percent": 51,
#         "visible_percent": 90
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_190841_68_24a4",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_190841_68_24a4/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240104_190841_68_24a4/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -123.90500597341934,
#               49.22120645086965
#             ],
#             [
#               -123.96661128602595,
#               49.0564459890931
#             ],
#             [
#               -123.54692530718552,
#               48.987600122903906
#             ],
#             [
#               -123.48358757591923,
#               49.15241396044797
#             ],
#             [
#               -123.90500597341934,
#               49.22120645086965
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240104_190841_68_24a4",
#       "properties": {
#         "acquired": "2024-01-04T19:08:41.688999Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 73,
#         "clear_percent": 79,
#         "cloud_cover": 0.1,
#         "cloud_percent": 10,
#         "ground_control": true,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 7,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-04T21:26:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 279,
#         "satellite_id": "24a4",
#         "shadow_percent": 4,
#         "snow_ice_percent": 0,
#         "strip_id": "7018115",
#         "sun_azimuth": 162.6,
#         "sun_elevation": 16.4,
#         "updated": "2024-01-05T04:21:27Z",
#         "view_angle": 3.5,
#         "visible_confidence_percent": 56,
#         "visible_percent": 90
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_183229_94_242e",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240104_183229_94_242e/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240104_183229_94_242e/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.47580548814507,
#               48.75287435410358
#             ],
#             [
#               -125.54278436857464,
#               48.57424186596111
#             ],
#             [
#               -125.08999399822447,
#               48.49779634675242
#             ],
#             [
#               -125.02090334028541,
#               48.6772790646505
#             ],
#             [
#               -125.47580548814507,
#               48.75287435410358
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240104_183229_94_242e",
#       "properties": {
#         "acquired": "2024-01-04T18:32:29.943959Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 57,
#         "clear_percent": 70,
#         "cloud_cover": 0.08,
#         "cloud_percent": 8,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 22,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-04T21:05:09Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 279.9,
#         "satellite_id": "242e",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7017969",
#         "sun_azimuth": 152.6,
#         "sun_elevation": 14.1,
#         "updated": "2024-01-05T04:13:18Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 51,
#         "visible_percent": 92
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240101_183250_59_241e",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240101_183250_59_241e/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240101_183250_59_241e/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.53348409191956,
#               49.18480877833996
#             ],
#             [
#               -125.59139014948393,
#               49.02225142154435
#             ],
#             [
#               -125.17814709564308,
#               48.958336893374025
#             ],
#             [
#               -125.11906325342773,
#               49.11975674557374
#             ],
#             [
#               -125.53348409191956,
#               49.18480877833996
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240101_183250_59_241e",
#       "properties": {
#         "acquired": "2024-01-01T18:32:50.596758Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 68,
#         "clear_percent": 25,
#         "cloud_cover": 0.09,
#         "cloud_percent": 9,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 58,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-01T22:16:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 103.7,
#         "satellite_id": "241e",
#         "shadow_percent": 8,
#         "snow_ice_percent": 0,
#         "strip_id": "7010903",
#         "sun_azimuth": 153.9,
#         "sun_elevation": 14,
#         "updated": "2024-01-02T09:59:22Z",
#         "view_angle": 3.5,
#         "visible_confidence_percent": 67,
#         "visible_percent": 91
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240101_182242_75_24b4",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240101_182242_75_24b4/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240101_182242_75_24b4/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -124.23737282033859,
#               48.58683396127725
#             ],
#             [
#               -124.30006361668472,
#               48.406242556854124
#             ],
#             [
#               -123.84640839469215,
#               48.33610754987424
#             ],
#             [
#               -123.7820146212451,
#               48.515121303899434
#             ],
#             [
#               -124.23737282033859,
#               48.58683396127725
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240101_182242_75_24b4",
#       "properties": {
#         "acquired": "2024-01-01T18:22:42.757397Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 76,
#         "clear_percent": 62,
#         "cloud_cover": 0.06,
#         "cloud_percent": 6,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 29,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-01-01T20:58:27Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 102.5,
#         "satellite_id": "24b4",
#         "shadow_percent": 4,
#         "snow_ice_percent": 0,
#         "strip_id": "7010589",
#         "sun_azimuth": 152.9,
#         "sun_elevation": 14.2,
#         "updated": "2024-01-02T03:57:44Z",
#         "view_angle": 4.5,
#         "visible_confidence_percent": 59,
#         "visible_percent": 94
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# #### Saved Searches with a Feature Reference
#
# ---
#
# The `/searches` endpoint lets you created saved searches that can be reused.
#
# To view your saved searches, visit the [`searches/?search_type=saved`](https://api.planet.com/data/v1/searches/?search_type=saved) endpoint.
#
# Finally, let's create a saved search using a feature reference:

# %%
# Setup the saved searches endpoint url
searches_url = "https://api.planet.com/data/v1/searches"

# %%
# Setup the request, specifying a name for the saved search, along with the usual search item_types and filter.

request = {
    "name" : "My Feature reference search",
    "item_types" : item_types,
    "filter" : filter,
    "geometry": geometry
}

# Send a POST request to the saved searches endpoint (Create the saved search)
res = session.post(searches_url, json=request)

# Print the response
p(res.json())
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/47a8c16f568e40feaf2bda41a3dee492",
#     "results": "https://api.planet.com/data/v1/searches/47a8c16f568e40feaf2bda41a3dee492/results"
#   },
#   "created": "2024-01-29T23:32:00.003470Z",
#   "filter": {
#     "config": [
#       {
#         "config": {
#           "gte": "2024-01-01T00:00:00Z",
#           "lte": "2024-01-15T00:00:00Z"
#         },
#         "field_name": "acquired",
#         "type": "DateRangeFilter"
#       },
#       {
#         "config": {
#           "lte": 0.1
#         },
#         "field_name": "cloud_cover",
#         "type": "RangeFilter"
#       }
#     ],
#     "type": "AndFilter"
#   },
#   "geometry": {
#     "content": [
#       "pl:features/my/my-title-DZ1KBq1/1231-zo1pQam#1"
#     ],
#     "type": "ref"
#   },
#   "id": "47a8c16f568e40feaf2bda41a3dee492",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": null,
#   "name": "My Feature reference search",
#   "search_type": "saved",
#   "updated": "2024-01-29T23:32:00.003470Z"
# }

# %% [markdown]
# *Note* you can see the reference returned in the search results

# %% [markdown]
# Now that we created a saved search, let's get a list of our saved searches:

# %%
# Send a GET request to the saved searches endpoint with the saved search type parameter (Get saved searches)
res = session.get(searches_url, params={"search_type" : "saved"})

p(res.json())
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogImNyZWF0ZWQiLCAic29ydF9kZXNjIjogdHJ1ZSwgInNvcnRfc3RhcnQiOiBudWxsLCAic29ydF9sYXN0X2lkIjogbnVsbCwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjogeyJzZWFyY2hfdHlwZSI6ICJzYXZlZCJ9fQ%3D%3D",
#     "_next": "https://api.planet.com/data/v1/searches/?_page=%3D%3D",
#     "_prev": "https://api.planet.com/data/v1/searches/?_page=",
#     "_self": "https://api.planet.com/data/v1/searches/?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogImNyZWF0ZWQiLCAic29ydF9kZXNjIjogdHJ1ZSwgInNvcnRfc3RhcnQiOiBudWxsLCAic29ydF9sYXN0X2lkIjogbnVsbCwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjogeyJzZWFyY2hfdHlwZSI6ICJzYXZlZCJ9fQ%3D%3D"
#   },
#   "searches": [
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/47a8c16f568e40feaf2bda41a3dee492",
#         "results": "https://api.planet.com/data/v1/searches/47a8c16f568e40feaf2bda41a3dee492/results"
#       },
#       "created": "2024-01-29T23:32:00.003470Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "gte": "2024-01-01T00:00:00Z",
#               "lte": "2024-01-15T00:00:00Z"
#             },
#             "field_name": "acquired",
#             "type": "DateRangeFilter"
#           },
#           {
#             "config": {
#               "lte": 0.1
#             },
#             "field_name": "cloud_cover",
#             "type": "RangeFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "geometry": {
#         "content": [
#           "pl:features/my/my-title-DZ1KBq1/1231-zo1pQam#1"
#         ],
#         "type": "ref"
#       },
#       "id": "47a8c16f568e40feaf2bda41a3dee492",
#       "item_types": [
#         "PSScene"
#       ],
#       "last_executed": null,
#       "name": "My Feature reference search",
#       "search_type": "saved",
#       "updated": "2024-01-29T23:32:00.003470Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/c1917cf032654c7caec8d6acbd8707dc",
#         "results": "https://api.planet.com/data/v1/searches/c1917cf032654c7caec8d6acbd8707dc/results"
#       },
#       "created": "2024-01-23T22:18:30.156638Z",
#       "filter": {
#         "config": {
#           "gte": "2024-01-01T00:00:00Z",
#           "lte": "2024-01-15T00:00:00Z"
#         },
#         "field_name": "acquired",
#         "type": "DateRangeFilter"
#       },
#       "geometry": {
#         "content": [
#           "pl:features/my/my-title-wr3PXZz/1231-eobBGno#1"
#         ],
#         "type": "ref"
#       },
#       "id": "c1917cf032654c7caec8d6acbd8707dc",
#       "item_types": [
#         "PSScene"
#       ],
#       "last_executed": "2024-01-29T17:49:49.611545Z",
#       "name": "My Feature reference search",
#       "search_type": "saved",
#       "updated": "2024-01-29T17:49:49.611945Z"
#     }
#   ]
# }

# %% [markdown]
# And you'll see the reference returned when you query your saved searches.

# %% [markdown]
# ### Orders API

# %%
orders_url = "https://api.planet.com/compute/ops/orders/v2"

# %%
request = {
    "name": "Test order with a reference",
    "source_type": "scenes",
    "products": [
        {
            "item_ids": [
                item_id # the id from the search request
            ],
            "item_type": "PSScene",
            "product_bundle": "analytic_udm2"
        }
    ],
    "tools": [
        {
            "clip": {
                "aoi": {
                    "content": short_ref,
                    "type": "ref"
                }
            }
        }
    ]

}

# Send a POST request to the orders endpoint
res = session.post(orders_url, json=request)

# Print the response
p(res.json())
# make the request
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/compute/ops/orders/v2/e9a33b9d-381a-45b1-8917-e1000cfa089a"
#   },
#   "created_on": "2024-01-29T23:32:05.108Z",
#   "error_hints": [],
#   "id": "e9a33b9d-381a-45b1-8917-e1000cfa089a",
#   "last_message": "Preparing order",
#   "last_modified": "2024-01-29T23:32:05.108Z",
#   "name": "Test order with a reference",
#   "products": [
#     {
#       "item_ids": [
#         "20240114_191157_82_2488"
#       ],
#       "item_type": "PSScene",
#       "product_bundle": "analytic_udm2"
#     }
#   ],
#   "source_type": "scenes",
#   "state": "queued",
#   "tools": [
#     {
#       "clip": {
#         "aoi": {
#           "content": "pl:features/my/my-title-DZ1KBq1/1231-zo1pQam",
#           "type": "ref"
#         }
#       }
#     }
#   ]
# }

# %% [markdown]
# **Note** Checkout that AOI reference in the response!!

# %% [markdown]
# ### Subscriptions API

# %%
# set up the subscriptions url
subs_url = "https://api.planet.com/subscriptions/v1"
    
# set up your bucket delivery
delivery_type = "your-delivery-type"
delivery_bucket = "your-bucket-name"
delivery_creds = "your-creds"

# %% [markdown]
# **Note** You can use the short_ref in the source geometry and optionally in the clip geometry
# If you choose to clip your order with a Features refence, it must be the same reference used in the source geometry.

# %%
# set up the subscription request

request = {
    "name": "Example Subscription",
    "source": {
        "type": "catalog",
        "parameters": {
            "geometry": {
                "content": short_ref,
                "type": "ref"
            },
            "time_range_type": "acquired",
            "start_time": "2024-01-01T00:00:00Z",
            "end_time": "2024-01-15T00:00:00Z",
            "item_types": [
                "PSScene"
            ],
            "asset_types": [
                "ortho_analytic_4b"
            ]
        }
    },
    "tools": [{
        "type": "clip",
        "parameters": {
            "aoi": {
                "content": short_ref,
                "type": "ref"
            }
        }
    }],
    "delivery": {
        "type": delivery_type,
        "parameters": {
            "bucket": delivery_bucket,
            "credentials": delivery_creds
        }
    }
}

# Send a POST request to the subscription endpoint
res = session.post(subs_url, json=request)

# Print the response
p(res.json())
# Out:
# {
#   "name": "Example Subscription",
#   "source": {
#     "type": "catalog",
#     "parameters": {
#       "asset_types": [
#         "ortho_analytic_4b"
#       ],
#       "item_types": [
#         "PSScene"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -125.29632568359376,
#               48.37084770238366
#             ],
#             [
#               -125.29632568359376,
#               49.335861591104106
#             ],
#             [
#               -123.2391357421875,
#               49.335861591104106
#             ],
#             [
#               -123.2391357421875,
#               48.37084770238366
#             ],
#             [
#               -125.29632568359376,
#               48.37084770238366
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "geom_ref": "pl:features/my/DZ1KBq1/zo1pQam#1",
#       "start_time": "2024-01-01T00:00:00Z",
#       "end_time": "2024-01-15T00:00:00Z",
#       "publishing_stages": [
#         "standard",
#         "finalized"
#       ],
#       "time_range_type": "acquired"
#     }
#   },
#   "tools": [
#     {
#       "type": "clip",
#       "parameters": {
#         "aoi": {
#           "coordinates": [
#             [
#               [
#                 -125.29632568359376,
#                 48.37084770238366
#               ],
#               [
#                 -125.29632568359376,
#                 49.335861591104106
#               ],
#               [
#                 -123.2391357421875,
#                 49.335861591104106
#               ],
#               [
#                 -123.2391357421875,
#                 48.37084770238366
#               ],
#               [
#                 -125.29632568359376,
#                 48.37084770238366
#               ]
#             ]
#           ],
#           "type": "Polygon"
#         }
#       }
#     }
#   ],
#   "delivery": {
#     "type": "google_cloud_storage",
#     "parameters": {
#       "bucket": "planet-manila-api-next-subscriptions",
#       "credentials": "<REDACTED>"
#     }
#   },
#   "created": "2024-01-29T23:33:10.124322Z",
#   "_links": {
#     "_self": "https://api.planet.com/subscriptions/v1/f6fe5a91-a97f-426b-a536-77f00b69c1dd"
#   },
#   "status": "preparing",
#   "id": "f6fe5a91-a97f-426b-a536-77f00b69c1dd",
#   "updated": "2024-01-29T23:33:10.124322Z"
# }

# %% [markdown]
# **Note** You'll see the Features reference and the geojson returned in the subscriptions response.

# %% [markdown]
# ## Conclusion
# **Congratulations!!**,
# You made it! That's how you can use and reuse geometry references across the Planet Platform. Go forth to use and reuse your geometry without needing to carry your geojsons around!
