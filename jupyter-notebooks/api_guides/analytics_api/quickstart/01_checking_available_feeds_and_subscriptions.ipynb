# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/planetlabs/notebooks/blob/master/jupyter-notebooks/analytics/quickstart/01_checking_available_feeds_and_subscriptions.ipynb)
#
# ###  Planet Analytics API Tutorial Part 1
#
# # Summarizing Feeds and Subscriptions
#
# Planet Analytics leverages computer vision to transform our imagery into Analytic Feeds that detect and classify objects, identify geographic features, and understand change over time across the globe.
#
# Users have subscriptions to feeds in a specific Area of Interest (AOI) and Time Interval of Interest (TOI). For example, a subscription could be Road Detection over 12 months in San Francisco, California. Users can get a list of their subscriptions from the Analytics API.
#
# This notebook demonstrates how to describe available [Analytics Feeds](https://developers.planet.com/docs/analytics/#analytic-feeds) and [Subscriptions](https://developers.planet.com/docs/analytics/#subscriptions) with the Planet Analytics API.

# %% [markdown]
# ## Setup
# To use this notebook, you need to have the following:
# - A Planet account with access to the [Analytics API](https://developers.planet.com/docs/analytics/)
# - A Planet [API Key](https://developers.planet.com/quickstart/apis/)

# %% [markdown]
# #### Import Packages

# %%
import os
import requests
from pprint import pprint
import pandas as pd
from ipyleaflet import Map, GeoJSON

# %% [markdown]
# #### Set API Key

# %%
# If your Planet API Key is not set as an environment variable, you can paste it below
API_KEY = os.environ.get('PL_API_KEY', 'PASTE_YOUR_KEY_HERE')

# Alternatively, you can just set your API key directly as a string variable:
# API_KEY = "YOUR_PLANET_API_KEY_HERE"
# Construct auth tuple for use in the requests library
BASIC_AUTH = (API_KEY, '')

# %% [markdown]
# #### Set the base url for the Planet Analytic Feeds product
# See the [Analytics API Docs](https://developers.planet.com/docs/analytics/) for more details.

# %%
BASE_URL = "https://api.planet.com/analytics/"

# %% [markdown]
# #### Test API Connection

# %%
feed_list_url = f'{BASE_URL}feeds?limit=1'
resp = requests.get(feed_list_url, auth=BASIC_AUTH)
if resp.status_code == 200:
    print('Yay, you can access the Analytics API')
else:
    print('Something is wrong:', resp.content)
# Out:
# Yay, you can access the Analytics API

# %% [markdown]
# ## Summarizing Feeds
# In this section, we will see describe the available feeds.

# %% [markdown]
# #### How many feeds are there?

# %%
limit = 1000
feed_list_url = f'{BASE_URL}feeds?limit={limit}'
pprint(f'Feeds endpoint: {feed_list_url}')

# Send a GET request to the feeds endpoint, using basic authentication
resp = requests.get(feed_list_url, auth=BASIC_AUTH)
feeds = resp.json()['data']
feed_count = len(feeds)
pprint(f'Available feeds: {feed_count}')

# Check if the available feeds count is equal to the specified limit
if feed_count >= limit:
    print('More feeds are probably available through pagination links')
    print(resp.json()['links'])
# Out:
# 'Feeds endpoint: https://api.planet.com/analytics/feeds?limit=1000'
# 'Available feeds: 158'

# %% [markdown]
# #### Inspecting feed metadata

# %%
pprint(feeds[0])
# Out:
# {'created': '2023-06-13T16:01:15.186Z',
#  'customer_contract': False,
#  'description': 'Version semantics: v{source mosaic}.{G4 process}',
#  'events': {},
#  'id': '5b73a193-484f-4aca-961b-2b1b21032a12',
#  'interval': 120,
#  'links': [{'href': 'https://api.planet.com/analytics/feeds/5b73a193-484f-4aca-961b-2b1b21032a12',
#             'rel': 'self',
#             'type': 'application/json'},
#            {'href': 'https://api.planet.com/analytics/feeds',
#             'rel': 'feeds',
#             'type': 'application/json'}],
#  'outputClasses': [],
#  'process': {'actions': [{'Fn::AddTask': ['IA_land_cover_change_v1_9_3',
#                                           {'annotations': {'results': 'object_detections_metadata:files/object_detections.geojson'},
#                                            'args': {'alpha_channel_band': 3,
#                                                     'cell_size': 8,
#                                                     'input_segmentations_from_g4_ops': False,
#                                                     'max_temporal_variability': 0.1,
#                                                     'min_detection_score': 0.4,
#                                                     'target_class_idx': 0,
#                                                     'visualize_series_id': '904f2a36-3b69-4b57-b905-df3231e501a1'},
#                                            'claims': ['{{ .Source.default | '
#                                                       'RenderSourceResources '
#                                                       '}}',
#                                                       'prn:extdata:GoogleCloudStorageObject:planet-analytics-ml-registry/models/model_01GASWPNRSNJ5TJ5Z7NMED163K/config.json']}]}],
#              'annotations': {'service': 'sif'},
#              'args': {},
#              'namespace': '{{ .Namespace }}'},
#  'source': [{'config': {'lookback_timestamp': '2023-03-20T00:00:00Z',
#                         'series_id': '1d8314e3-bb0f-476f-9821-8c5ddf883248',
#                         'visualization_series_id': '904f2a36-3b69-4b57-b905-df3231e501a1'},
#              'name': 'default',
#              'type': 'mosaic'}],
#  'status': 'active',
#  'target': {'type': 'collection'},
#  'title': 'Road change - weekly cadence - lookback 2023-03-20 - v0.25',
#  'updated': '2023-06-13T16:01:15.186Z'}

# %% [markdown]
# **Some of the fields include:**
# - id: this is a unique identifier for a feed
# - title: a human friendly name for the feed
# - description: more detail text about the feed
# - created: timestamp for when the feed was originally created
# - updated: timestamp for when the feed was last modified
# - source: a blob describing the imagery on which the feed is based
# - target: a blob describing the feed's output format
# - links: a list of blobs containing urls to related resources

# %% [markdown]
# #### Showing all available feeds in a table
# We can use a pandas DataFrame to summarize the available feeds.

# %%
# Bump this up in case there are many available feeds to display
pd.options.display.max_rows = 1000
# Make a dataframe from the feeds json data
df = pd.DataFrame(feeds)

# Instead of including the entire source and target dicts, make columns for the types
df['targetType'] = ""
df['sourceType'] = ""

for row in range(0, len(df)):
    df.loc[:, ('targetType', row)] = df['target'][row]['type']
    df.loc[:, ('sourceType', row)] = df['source'][row][0]['type']

df[['id', 'title', 'description', 'sourceType', 'targetType', 'created', 'updated']]
# Out:
#                                        id  \
# 0    5b73a193-484f-4aca-961b-2b1b21032a12
# 1    6ca29572-1f8f-4d30-8935-1ed21e088c96
# 2    c97c8c75-27c9-401d-a8b5-2bbc52612f42
# 3    4088eddd-7aa6-4766-8be1-70d1a579de20
# 4    6261fea4-dbd0-4399-b256-254c93eb2c95
# 5    842b0912-45ca-4ef0-b100-1ef1685a74ef
# 6    8573bae0-e718-42c5-af82-31bd7c3fbbc6
# 7    b644c456-a67d-4ff0-9b34-b2c073193860
# 8    fa5d9831-aa30-4507-96da-25cd6aacdf5a
# 9    a069620d-d076-4eb3-8326-0a155b510697
# 10   c0f15d04-ee29-4ef3-affc-a57c3a19fd50
# 11   e5a73e74-022e-4fc1-b47c-d0180f071f99
# 12   fa2a113d-7323-4fb3-bbc9-09cbc6469ee1
# 3    Building change - weekly cadence - lookback 20...
# 4    Road change - weekly cadence - lookback 2020-0...
# 5                            Ship Detection TOA - 50m+
# 6                            Ship Detection TOA - 25m+
# 7    Road state - weekly cadence - lookback 2021-09...
# 8                              Copy of Ship Detections
# 9    Building change - monthly cadence - lookback 2...
# 10   Road change - monthly cadence - lookback 2020-...
# 11   Road change - weekly cadence - lookback 2021-0...
# 12   Building change - weekly cadence - lookback 20...
# 13   Ship Detections on ortho_analytic_4B (DO NOT USE)
# 14                 Weekly Road Detection (independent)
# 15             Weekly Building Detection (independent)
# 16                 Ship Detections on TOA (do not use)
# 17                        Ship Detections (do not use)
# 18   Building change - weekly cadence - lookback 20...
# 19   Road change - weekly cadence - lookback 2018-0...
# 20   Road change - weekly cadence - lookback 2017-1...
# 21   Building change - weekly cadence - lookback 20...
# 22   TEST - CAMERON - Building change - weekly cade...
# 23   Building state - weekly cadence - lookback 202...
# 24   Road state - weekly cadence - lookback 2022-05...
# 25   Building change - weekly cadence - lookback 20...
# 26   Road change - weekly cadence - lookback 2021-0...
# 27   Road change - weekly cadence - lookback 2020-0...
# 28   Building change - weekly cadence - lookback 20...
# 29   Building change - weekly cadence - lookback 20...
# 30   Road change - weekly cadence - lookback 2022-0...
# 31   Building change - weekly cadence - lookback 20...
# 32   Road change - weekly cadence - lookback 2021-0...
# 33   Road change - weekly cadence - lookback 2019-0...
# 34   Road change - weekly cadence - lookback 2020-1...
# 35   Building change - weekly cadence - lookback 20...
# 36   Road change - weekly cadence - lookback 2021-1...
# 37   Building change - weekly cadence - lookback 20...
# 38   [JM] AN-5707 - Building state raster - weekly ...
# 39   [RN] Test w/ Building state raster - weekly ca...
# 40   Copy of Building state raster - weekly cadence...
# 41   Road change - weekly cadence - lookback 2017-1...
# 42   Building change - weekly cadence - lookback 20...
# 43            Monthly Building Detection (independent)
# 44   Road state raster - weekly cadence - lookback ...
# 45   Building state raster - weekly cadence - lookb...
# 46   Building State Raster - weekly cadence - lookb...
# 47                            Ship Detection v2 - 25m+
# 48                            Ship Detection v2 - 50m+
# 49   Building change - monthly cadence - lookback 2...
# 50   Road change - monthly cadence - lookback 2021-...
# 51   Building state raster - weekly cadence - lookb...
# 52   Road state raster - weekly cadence - lookback ...
# 53   Pipeline v0: Building change - weekly cadence ...
# 54   Pipeline v0: Road change - weekly cadence - lo...
# 55   Pipeline v0: Road change - weekly cadence - lo...
# 56   Pipeline v0: Building change - weekly cadence ...
# 57   Pipeline v0: Building change - weekly cadence ...
# 58   Pipeline v0: Road change - weekly cadence - lo...
# 59   Pipeline v0: Building change - weekly cadence ...
# 60   Pipeline v0: Road change - weekly cadence - lo...
# 61   Road change - weekly cadence - lookback 2019-1...
# 62   Building change - weekly cadence - lookback 20...
# 63   Road change - weekly cadence - lookback 2019-1...
# 64   Building change - weekly cadence - lookback 20...
# 65   Building change - weekly cadence - lookback 20...
# 66   Road change - weekly cadence - lookback 2019-1...
# 67   Road change - weekly cadence - lookback 2020-1...
# 68   Road change - weekly cadence - lookback 2019-0...
# 69   Building change - weekly cadence - lookback 20...
# 70   Road change - weekly cadence - lookback 2019-0...
# 71   Building change - weekly cadence - lookback 20...
# 72   Road change - weekly cadence - lookback 2020-1...
# 73   Building change - weekly cadence - lookback 20...
# 74   Building state raster - weekly cadence - lookb...
# 75   Road state raster - weekly cadence - lookback ...
# 76   Road state raster - weekly cadence - lookback ...
# 77   Building change - weekly cadence - lookback 20...
# 78   Road change - weekly cadence - lookback 2020-0...
# 79   Road change - monthly cadence - lookback 2021-...
# 80   Building state raster - weekly cadence - lookb...
# 81   Road state raster - weekly cadence - lookback ...
# 82   Road change - weekly cadence - lookback 2019-1...
# 83   Building change - weekly cadence - lookback 20...
# 84   Road change - weekly cadence - lookback 2020-0...
# 85   Building change - weekly cadence - lookback 20...
# 86   Building change - weekly cadence - lookback 20...
# 87   Road change - weekly cadence - lookback 2020-0...
# 88   [DO NOT USE] Building change - weekly cadence ...
# 89   [DO NOT USE] Road change - weekly cadence - lo...
# 90   Road change - weekly cadence - lookback 2020-0...
# 91   Building change - weekly cadence - lookback 20...
# 92   Building raster state - weekly cadence - 6/202...
# 93                  Road raster state - weekly cadence
# 94              Building raster state - weekly cadence
# 95   Road Change Detection - weekly cadence (state ...
# 96   Building Change Detection - weekly cadence (st...
# 97          Building Change Detection - weekly cadence
# 98              Road Change Detection - weekly cadence
# 99   Buildings Living Map v1:20210920 (July 2017 Lo...
# 100   Road Living Map v1:20210920 (July 2017 Lookback)
# 101                           Buildings (v9 Quarterly)
# 102                               Roads (v9 Quarterly)
# 103                                         Roads (v9)
# 104                                     Buildings (v9)
# 105   Building Change v1:20210920 (July 2017 Lookback)
# 106       Road Change v1:20210920 (July 2017 Lookback)
# 107        Road Change v1:20210921 - Northern Latitude
# 108  Building Change v1:20210920 (January 2019 Look...
# 109    Road Change v1:20210920 (January 2019 Lookback)
# 110  Binary Vegetation Classifier - TYOM - Borneo I...
# 111  TYOM - NICFI Indonesia - 15690927-2606-4a1f-a2...
# 112  TYOM - NICFI Indonesia - 15690927-2606-4a1f-a2...
# 113  TYOM - NICFI Indonesia - 15690927-2606-4a1f-a2...
# 114                            Road Change v1:20210716
# 115                        Building Change v1:20210716
# 116                   Arctic Building Change Detection
# 117  TYOM - Brazil deforestation overfit quad - fbc...
# 118  TYOM - Brazil Hummingbird Test - 30406a6f-ca80...
# 119                                Register Global Run
# 120  TYOM - Henry test - 128c07ac-41f0-4d06-8102-eb...
# 121  TYOM - RN - Testing using Label Party Dataset ...
# 122  TYOM - Humboldt County (keep me!) - 46cc313a-9...
# 123  TYOM - Mauritania Port - c66ac809-66df-4939-b4...
# 124  TYOM - Flaring in Iraq (Keep me!) - 00c44a55-2...
# 125  TYOM - Flaring in Iraq - d2b094b1-9738-4c21-90...
# 126  TYOM - Flaring in Iraq - 91b5612a-7697-41dc-93...
# 127  TYOM - Labeling Party - 2/16/21 - dcc81d7b-4f8...
# 128  TYOM - QE Test Project 2021-03-22 T21:53:29.88...
# 129                                         PS TYOM 01
# 130  TYOM - Agata Smoke Test - 9e62d9bb-6a66-44af-8...
# 131  TYOM - Agata Smoke Test - ef8f3846-d506-4b12-9...
# 132                  Monthly De-noised Road Detection
# 133              Monthly De-noised Building Detection
# 134                            Road Change v1:20201022
# 135                        Building Change v1:20201022
# 136                 [Outdated] Road Change v1:20201008
# 137             [Outdated] Building Change v1:20201008
# 138              [DEPRECATED] Building segmentation v8
# 139                                      AN-4537 Debug
# 140             [outdated] Building Change v1:20200916
# 141                 [Outdated] Road Change v1:20200916
# 142  (OBSOLETE, DO NOT USE) Roads (v7)  with Summar...
# 143   [OBSOLETE - DO NOT USE] Building Construction...
# 144          Weekly Well Pad Detection (Permian Basin)
# 145         Monthly Well Pad Detection (Permian Basin)
# 146                                 Airplane Detection
# 147  Building Construction, Global Monthly: Change ...
# 148  Building Construction, Global Monthly, without...
# 149  Building Construction, Global Monthly: Seed St...
# 150                  [DEPRECATED] Roads (v7 Quarterly)
# 151              [DEPRECATED] Buildings (v7 Quarterly)
# 152                                    Ship Detections
# 153                        [DEPRECATED] Buildings (v7)
# 154                            [DEPRECATED] Roads (v7)
# 155              (OBSOLETE, DO NOT USE) Roads (v7_1_0)
# 156        (OBSOLETE, DO NOT USE)  Buildings (v7_1_0)
# 157       Monthly Silo Bag Detections (Argentina Only)
#
#                                            description sourceType  targetType  \
# 0     Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 1     Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 2     Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 3     Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 4     Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 5                            Ship Detection TOA  -50m+     mosaic  collection
# 6                           Ship Detection TOA  - 25m+     mosaic  collection
# 7     Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 8    Ship detections from rectified PlanetScope ima...     mosaic  collection
# 9     Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 10    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 11    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 12    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 13   Ship detections from ortho_analytic_4B PlanetS...     mosaic  collection
# 14   Weekly Road Detection Based on Single Week's D...     mosaic  collection
# 15   Weekly Building Detection Based on Single Week...     mosaic  collection
# 16   Ship detections from TOA PlanetScope imagery (...     mosaic  collection
# 17   Ship detections from Visual PlanetScope imager...     mosaic  collection
# 18    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 19    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 20    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 21    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 22    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 23    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 24    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 25    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 26    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 27    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 28    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 29    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 30    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 31    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 32    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 33    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 34    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 35    Version semantics: v{source mosaic}.{G4 process}     mosaic  collection
# 36   \nE.g. AN-5696 for weekly change subscription ...     mosaic  collection
# 37   E.g. AN-5697 for weekly change subscription st...     mosaic  collection
# 38                    Blooming suppression, scores>0.4     mosaic  collection
# 39                    Blooming suppression, scores>0.4     mosaic  collection
# 40                    Blooming suppression, scores>0.4     mosaic  collection
# 41   \nE.g. for weekly change subscription starting...     mosaic  collection
# 42   E.g. for weekly change subscription starting ~...     mosaic  collection
# 43   Monthly Building Detection Based on Single Mon...     mosaic  collection
# 44                    Blooming suppression, scores>0.4     mosaic  collection
# 45                    Blooming suppression, scores>0.4     mosaic  collection
# 46                    Blooming suppression, scores>0.4     mosaic  collection
# 47                           Ship Detection v2  - 25m+     mosaic  collection
# 48                           Ship Detection  v2 - 50m+     mosaic  collection
# 49   (AN-5694) Cooper Smith Building Change Monthly v0     mosaic  collection
# 50       (AN-5694) Cooper Smith Road Change Monthly v0     mosaic  collection
# 51                    Blooming suppression, scores>0.4     mosaic  collection
# 52                    Blooming suppression, scores>0.4     mosaic  collection
# 53   E.g. for weekly change subscription starting ~...     mosaic  collection
# 54   \nE.g. for weekly change subscription starting...     mosaic  collection
# 55   \nE.g. for weekly change subscription starting...     mosaic  collection
# 56   E.g. for weekly change subscription starting ~...     mosaic  collection
# 57   E.g. for weekly change subscription starting ~...     mosaic  collection
# 58   \nE.g. for weekly change subscription starting...     mosaic  collection
# 59                    Blooming suppression, scores>0.4     mosaic  collection
# 60                    Blooming suppression, scores>0.4     mosaic  collection
# 61                                     v22, scores>0.1     mosaic  collection
# 62                                     v22, scores>0.1     mosaic  collection
# 63                    Blooming suppression, scores>0.4     mosaic  collection
# 64                    Blooming suppression, scores>0.4     mosaic  collection
# 65                                                 v23     mosaic  collection
# 66                                                 v22     mosaic  collection
# 67                                                 v23     mosaic  collection
# 68                                Blooming suppression     mosaic  collection
# 69                                Blooming suppression     mosaic  collection
# 70                                                 v22     mosaic  collection
# 71                                                 v22     mosaic  collection
# 72                                                 v22     mosaic  collection
# 73                                                 v22     mosaic  collection
# 74                                Blooming suppression     mosaic  collection
# 75                                Blooming suppression     mosaic  collection
# 76                                Blooming suppression     mosaic  collection
# 77                                Blooming suppression     mosaic  collection
# 78                                Blooming suppression     mosaic  collection
# 79                                Blooming suppression     mosaic  collection
# 80                                Blooming suppression     mosaic  collection
# 81                                Blooming suppression     mosaic  collection
# 82                               Blooming suppression      mosaic  collection
# 83                                Blooming suppression     mosaic  collection
# 84                                Blooming suppression     mosaic  collection
# 85                                Blooming suppression     mosaic  collection
# 86                Simplified change detection metadata     mosaic  collection
# 87                Simplified change detection metadata     mosaic  collection
# 88   Suppresses sudden blooming of detections. Use ...     mosaic  collection
# 89   Suppresses sudden blooming of detections. Use ...     mosaic  collection
# 90                                                 v20     mosaic  collection
# 91                                                 v20     mosaic  collection
# 92                                                 v19     mosaic  collection
# 93                                                 v19     mosaic  collection
# 94                                                 v19     mosaic  collection
# 95                                                 v19     mosaic  collection
# 96                                                 v19     mosaic  collection
# 97                                                 v19     mosaic  collection
# 98                                                 v19     mosaic  collection
# 99                     Monthly Living Map of Buildings     mosaic  collection
# 100                        Monthly Living Map of Roads     mosaic  collection
# 101                  Quarterly Building Detection (v9)     mosaic  collection
# 102                      Quarterly Road Detection (v9)     mosaic  collection
# 103                        Monthly Road Detection (v9)     mosaic  collection
# 104                    Monthly Building Detection (v9)     mosaic  collection
# 105            Monthly Building Construction Detection     mosaic  collection
# 106                Monthly Road Construction Detection     mosaic  collection
# 107                Monthly Road Construction Detection     mosaic  collection
# 108            Monthly Building Construction Detection     mosaic  collection
# 109                Monthly Road Construction Detection     mosaic  collection
# 110  Project ID: de90b6aa-6819-4ec7-9eb1-fd385d9d86...     mosaic  collection
# 111  Project ID: c73f99d9-620c-4c03-9345-3ea90fa741...     mosaic  collection
# 112  Project ID: c73f99d9-620c-4c03-9345-3ea90fa741...     mosaic  collection
# 113  Project ID: c73f99d9-620c-4c03-9345-3ea90fa741...     mosaic  collection
# 114                Monthly Road Construction Detection     mosaic  collection
# 115            Monthly Building Construction Detection     mosaic  collection
# 116   source imagery: twice-monthly visual L13 mosaics     mosaic  collection
# 117  Project ID: 669145ca-f0e1-4c2c-8603-3f30f64a74...     mosaic  collection
# 118  Project ID: b97ad82b-3b6c-4e65-ba4d-ff706b576c...     mosaic  collection
# 119  Feed to register global run. Do not use for an...     mosaic  collection
# 120  Project ID: b4dc176f-515f-470c-a45d-28ff5b85b1...     mosaic  collection
# 121  Project ID: 71059903-15ae-44ec-96ae-6630139b83...     mosaic  collection
# 122  Project ID: 053388fd-7473-4986-9ec5-6cc6d75304...     mosaic  collection
# 123  Project ID: 647aaba7-3578-458e-8a92-fb7cea375c...     mosaic  collection
# 124  Project ID: 13767713-ce5c-4cdc-aa15-f343c0801e...     mosaic  collection
# 125  Project ID: 13767713-ce5c-4cdc-aa15-f343c0801e...     mosaic  collection
# 126  Project ID: 13767713-ce5c-4cdc-aa15-f343c0801e...     mosaic  collection
# 127  Project ID: ae5cdd33-3506-40cb-b454-fd447871e9...     mosaic  collection
# 128  Project ID: 001a370c-0bf6-4dd7-b785-dc4f380e7c...     mosaic  collection
# 129  Project ID: 491b8717-94ca-464a-9061-8e74784e19...     mosaic  collection
# 130  Project ID: f142c1c9-6936-4d8f-8cdf-6a6ac224c7...     mosaic  collection
# 131  Project ID: f142c1c9-6936-4d8f-8cdf-6a6ac224c7...     mosaic  collection
# 132               De-noised Road Detection v1:20201022     mosaic  collection
# 133   Monthly De-noised Building Detection v1:20201022     mosaic  collection
# 134                 Monthly Road Development Detection     mosaic  collection
# 135            Monthly Building Construction Detection     mosaic  collection
# 136                     SD-free monthly visual mosaics     mosaic  collection
# 137                     SD-free monthly visual mosaics     mosaic  collection
# 138                     SD-free monthly visual mosaics     mosaic  collection
# 139      Clone of 827f4716-facd-4efe-9260-4f1c970080f9     mosaic  collection
# 140                                    Monthly mosaics     mosaic  collection
# 141                                    Monthly mosaics     mosaic  collection
# 142  (OBSOLETE, DO NOT USE) Roads (v7) with Summary...     mosaic  collection
# 143    Building Construction Change on Monthly Mosaics     mosaic  collection
# 144  Well Pad Detection on Weekly Permian Basin Vis...     mosaic  collection
# 145      Well Pad Detection on Monthly Visual Basemaps     mosaic  collection
# 146  Airplane detections from rectified PlanetScope...     mosaic  collection
# 147  SUBSC DATE RANGE = 2/1/2018-any. Change Detect...     mosaic  collection
# 148  SUBSC DATE RANGE = 1/1/2018-2/1/2018. Change D...     mosaic  collection
# 149  Seed State feed for Building Construction, on ...     mosaic  collection
# 150                      Quarterly Road Detection (v7)     mosaic  collection
# 151                  Quarterly Building Detection (v7)     mosaic  collection
# 152  Ship detections from rectified PlanetScope ima...     mosaic  collection
# 153                    Monthly Building Detection (v7)     mosaic  collection
# 154                        Monthly Road Detection (v7)     mosaic  collection
# 155                    Monthly Road Detection (v7_1_0)     mosaic  collection
# 156                         Monthly Building Detection     mosaic  collection
# 157  Silo bag detections from global monthly mosaic...     mosaic  collection
resp = requests.get(subscriptions_url, auth=BASIC_AUTH)
subs = resp.json()['data']
sub_count = len(subs)
print(f'Available subscriptions: {sub_count}')
if sub_count >= limit:
    print('More subscriptions are probably available through pagination links')
    print(resp.json()['links'])
# Out:
# Subscriptions endpoint: https://api.planet.com/analytics/subscriptions?limit=1000
# Available subscriptions: 562

# %% [markdown]
# #### What's in a subscription?

# %%
pprint(subs[0])
# Out:
# {'created': '2023-07-05T20:42:11.683Z',
#  'description': 'Ship Detection 50m+',
#  'endTime': '2023-06-30T00:00:00.000Z',
#  'feedID': '5b314bf0-ae01-4c98-971f-7c806f8637f0',
#  'geometry': {'coordinates': [[[-69.010057, 63.781113],
#                                [-68.127523, 63.186934],
#                                [-67.538771, 63.010675],
#                                [-66.908122, 62.647522],
#                                [-66.081585, 62.212382],
#                                [-65.813363, 62.0817],
#                                [-65.964955, 61.962506],
#                                [-66.28557, 61.827582],
#                                [-67.000334, 61.430995],
#                                [-66.307191, 60.70831],
#                                [-63.108471, 60.88852],
#                                [-61.045564, 63.079567],
#                                [-64.345754, 62.47372],
#                                [-65.252948, 62.643302],
#                                [-65.74745, 63.118],
#                                [-67.94105, 63.784663],
#                                [-69.010057, 63.781113]]],
#               'type': 'Polygon'},
#  'id': '74e7c01e-f25c-4712-9c72-f5b58afb6f53',
#  'links': [{'href': 'https://api.planet.com/analytics/subscriptions/74e7c01e-f25c-4712-9c72-f5b58afb6f53',
#             'rel': 'self',
#             'type': 'application/json'},
#            {'href': 'https://api.planet.com/analytics/collections/74e7c01e-f25c-4712-9c72-f5b58afb6f53/items',
#             'rel': 'results',
#             'type': 'application/geo+json'},
#            {'href': 'https://api.planet.com/analytics/feeds/5b314bf0-ae01-4c98-971f-7c806f8637f0',
#             'rel': 'feed',
#             'type': 'application/json'},
#            {'href': 'https://api.planet.com/analytics/subscriptions',
#             'rel': 'subscriptions',
#             'type': 'application/json'}],
#  'maxQueued': 10000,
#  'sourceUpdated': '2023-07-03T12:57:09.000Z',
#  'startTime': '2023-06-01T00:00:00.000Z',
#  'title': 'Eastern Canada ',
#  'updated': '2023-07-05T20:42:11.683Z'}

# %% [markdown]
# Subscriptions also have ID, title, description, created, and updated fields.
# Additionally, there are fields for:
# - feedID: which feed this subscription is for
# - startTime: timestamp for the subscription's beginning
# - endTime: timestamp for the subscription's ending
# - geometry: spatial area of interest to which the subscription has access
#
# **Important:**
# Subscriptions will only get results for source imagery observed between the `startTime` and `endTime` within the specified `geometry`.

# %% [markdown]
# `created` and `updated` refer to when the subscription itself was set up or modified and **do not** impact results that show up for the subscription.
#
# `startTime` and `endTime` **do** limit feed results for the subscription.

# %% [markdown]
# #### Showing all available subscriptions

# %%
df = pd.DataFrame(subs)
df[['id', 'title', 'description', 'feedID', 'startTime', 'endTime', 'created', 'updated']]
# Out:
#                                        id  \
# 0    74e7c01e-f25c-4712-9c72-f5b58afb6f53
# 1    d113c5ac-6d64-4f7b-b501-16fa45a49293
# 2    ea0b8c2b-7504-4018-bed3-2ce089dd77c5
# 549  02eb88b4-5f1f-43dd-a7ce-12a2489f2038
# 550  cda3398b-1283-4ad9-87a6-e25796b5ca80
# 551  6696da5c-88b8-49c2-a423-c936c0f386a5
# 552  76d06ec1-8507-4035-97cd-b3ea87b5b699
# 553  724e9453-3526-4b94-80c3-737b8d11c9a2
# 554  90a810ae-1252-4195-afe0-291e357e3d9e
# 555  b4656c0b-70cb-4393-876a-074f415f7159
# 556  e1d59ef3-b25d-4735-b025-43f633a7ca2e
# 557  3f598862-07e7-4d6e-a2ab-5a3d0889fb7d
# 558  360a743c-6021-40c3-a84a-d0a866239492
# 559  9db92275-1d89-4d3b-a0b6-68abd2e94142
# 560  6eff6c9e-c86a-4b89-b1e7-4f54d20075b2
# 561  63b8c2a8-1bf6-4280-9c45-29431fdb550f
#
#                                                  title  \
# 0                                      Eastern Canada
# 1                  Weekly road detections over Nairobi
# 2              Weekly building detections over Nairobi
# 3            Weekly road change detection over Nairobi
# 4        Weekly building change detection over Nairobi
# 5                                       San Diego Area
# 6                                          Spokane, WA
# 7                                          Spokane, WA
# 8                                          Spokane, WA
# 9                                          Spokane, WA
# 10                Road change detection over Zanzibar
# 11            Building change detection over Zanzibar
# 12                                      El Paso Border
# 13                Road change detection over Yumen aoi
# 14            Building change detection over Yumen aoi
# 15                                   San Diego County
# 16                                    San Diego County
# 17               Weekly road detections over Yumen aoi
# 18           Weekly building detections over Yumen aoi
# 19         Road change detection over China Taiwan aoi
# 20     Building change detection over China Taiwan aoi
# 21        Weekly road detections over China Taiwan aoi
# 22    Weekly building detections over China Taiwan aoi
# 23                                    San Diego County
# 24                                   San Diego County
# 25                                              Mandeb
# 26                                              Hormuz
# 27                                           Galveston
# 28                                      San Diego Area
# 29                                         Ho Chi Minh
# 30                                         Ho Chi Minh
# 31                                   Coastal Argentina
# 32              KGS - Weekly Building Change Detection
# 33      Sama, Canada - Road Change Detection - Monthly
# 34   Sama, Canada - Building Change Detection - Mon...
# 35   Black Sea and Sea of Azov - Back to Feb 2022 a...
# 36   Floodlight Invest Mexico - Building Detection ...
# 37                                   Port of Singapore
# 38                      Tampa Convention Center - TOA
# 39                               Port of Canaveral TOA
# 40                                 Port of Sudan - TOA
# 41        Black Sea and Sea of Azov - Back to Feb 2022
# 42                      Geoint 2023 Weekly Road Change
# 43                  Geoint 2023 Weekly Building Change
# 44   [RN] AN-5948: Test run using TOA scenes over p...
# 45                                       Port of Sudan
# 46                             Taiwanese Coastal Areas
# 47                                                 SCS
# 48                                      Rennell Island
# 49                                             Pavuvu
# 50                     Weekly Road Change Over Ukraine
# 51                 Weekly Building Change Over Ukraine
# 52                                 Port of Canaveral 2
# 53                                   Port of Canaveral
# 54                             Tampa Convention Center
# 55                                Gulf of Guinea Ships
# 56                           Argentina Fishing Vessels
# 57                      Hainan Island - Ship Detection
# 58    Kern County - Building Change Detection - Weekly
# 59   Enid, Oklahoma - Building Change Detection - W...
# 60     Enid, Oklahoma - Road Change Detection - Weekly
# 61                    Shanghai, China - Ship Detection
# 62                       Sabina Shoal - Ship Detection
# 63              Chongjin, North Korea - Ship Detection
# 64              Hamgyong, North Korea - Ship Detection
# 65             Madison - Weekly Build Change Detection
# 66                          Amphibious Ships Searching
# 67                                    New Cairo, Egypt
# 68                                    New Cairo, Egypt
# 69                                    New Cairo, Egypt
# 70                                    New Cairo, Egypt
# 71                BRA DEU KEN Ship Detection 2019-2022
# 72                     BRA DEU KEN Ship Detection Test
# 73                           Panama Canal (March 2023)
# 74                                        Panama Canal
# 75     Zanzibar - Weekly Road change Detection - v0.25
# 76   Zanzibar - Weekly Building change Detection - ...
# 77        Ghana - Weekly Road change Detection - v0.25
# 78    Ghana - Weekly Building change Detection - v0.25
# 79                      Kenya Port Ship Detection Test
# 80   Saudi Arabia - Weekly Building change Detectio...
# 81   Saudi Arabia  - Road Change Detection - Weekly...
# 82   Minnesota Department of Transportation  - Road...
# 83    Minnesota Department of Transportation  - Roa...
# 84          Tennessee - Weekly Building Change - v0.25
# 85                                             Riyadh
# 86                                             Riyadh
# 87                                        UN DPRK Demo
# 88                                            Zanzibar
# 89                                           Cape Town
# 90                                         Namora Test
# 91               UNEP - Road Change Detection - Weekly
# 92           UNEP - Building Change Detection - Weekly
# 93                                Baltic Sea Demo 50m+
# 94       Mali Airport - Road Change Detection - Weekly
# 95   Mali Airport - Building Change Detection - Weekly
# 96                                     Baltic Sea Demo
# 97               Turkey - Weekly Road Change Detection
# 98                         Earthquake-Impacted Turkey
# 99                           Black Sea and Sea of Azov
# 100                                       Gulf of Aden
# 101              Ankara - Weekly Road Change Detection
# 102          Ankara - Weekly Building Change Detection
# 103                   Building Change Detection Ankara
# 104  San Francisco-Bay area & Austin - Weekly Road ...
# 105     Persian Gulf, Spratly Islands and Kerch Strait
# 106                                       Bandar Abbas
# 107                                       Kerch Strait
# 108                                   Chongqing, China
# 109                                  Chongqing, China
# 110                                        Zibo, China
# 111                                        Zibo, China
# 112                               Nusantara, Indonesia
# 113                               Nusantara, Indonesia
# 114                                     Western Brazil
# 115                                     Eastern Brazil
# 116                                   Western Algeria
# 117                                   Western Algeria
# 118                                          Tokyo Bay
# 119                             Copy of Arequipa, Peru
# 120  Western Algeria Test Sites - Weekly Road Chang...
# 121  Western Algeria Test Sites - Weekly Road Chang...
# 122  Western Algeria Test Sites - Weekly Building C...
# 123                            Copy of NMSLO_Well_Pad_
# 124  Western Algeria - Weekly Road Change Detection...
# 125  Western Algeria - Weekly Building Change Detec...
# 126                                     Arequipa, Peru
# 127                                     Arequipa, Peru
# 128                              San Bernardino County
# 129                                        Taiwan Area
# 130  Ship Detection Latency test for ortho_analytic_4B
# 131  Ship Detection Latency test for basic_analytic_4B
# 132                                             Tehran
# 133                                             Tehran
# 134                                       Tenom, Sabah
# 135                               Kota Kinabalu, Sabah
# 136                                Prosser, Washington
# 137                                 Keppels, Australia
# 138                                        Zibo, China
# 139                                        Zibo, China
# 140                                   Chongqing, China
# 141                                   Chongqing, China
# 142                                 Keppels, Australia
# 143                                       Persian Gulf
# 144                                       Bandar Abbas
# 145                                       Bandar Abbas
# 146                                       Bandar Abbas
# 147                                    Engel's Airbase
# 148               [JM] Montana - Building construction
# 149          4M Analytics - Weekly Road Change - v0.25
# 150      4M Analytics - Weekly Building Change - v0.25
# 151          Humboldt - Weekly Building Change - v0.25
# 152       IOR_Approaches_NTRO_Ship Detection on Visual
# 153                             PF_VesselsAIO_05 on SR
# 154    Peru - Weekly Building Change Detection - v0.25
# 155                              Ukraine Area buffered
# 156                                      Ukraine Area
# 157                             Spratly Islands (25m+)
# 158                                    Spratly Islands
# 159              Panama Building Change - Weekly v0.25
# 160                               Malaysia Open Water
# 161        Tanjung Pinang Area (greater than 50m only)
# 162                                Tanjung Pinang Area
# 163        Peru - Weekly Road Change Detection - v0.25
# 164   Pyongyang - Weekly Road Change Detection - v0.25
# 165  Pyongyang - Weekly Building Change Detection -...
# 166  Spokane - Weekly Building Change Detection - v...
# 167  New Mexico - Weekly Road Change Detection - v0.25
# 168                        PL-0037518_PF_VesselsAIO_01
# 169                        PL-0037518_PF_VesselsAIO_05
# 170                        PL-0037518_PF_VesselsAIO_18
# 171                        PL-0037518_PF_VesselsAIO_04
# 172                        PL-0037518_PF_VesselsAIO_10
# 173                        PL-0037518_PF_VesselsAIO_17
# 174                        PL-0037518_PF_VesselsAIO_16
# 175                        PL-0037518_PF_VesselsAIO_15
# 176                        PL-0037518_PF_VesselsAIO_14
# 177                        PL-0037518_PF_VesselsAIO_13
# 178                        PL-0037518_PF_VesselsAIO_12
# 179                        PL-0037518_PF_VesselsAIO_11
# 180                        PL-0037518_PF_VesselsAIO_09
# 181                        PL-0037518_PF_VesselsAIO_07
# 182                        PL-0037518_PF_VesselsAIO_06
# 183  Gurugram - Weekly Building Change Detection - ...
# 184    Gurugram - Weekly Road Change Detection - v0.25
# 185   Syria - Weekly Building Change Detection - v0.25
# 186       Syria - Weekly Road Change Detection - v0.25
# 187         Mendocino - Weekly Building Change - v0.25
# 188             Mendocino - Weekly Road Change - v0.25
# 189            Ethiopia - Weekly Road Change Detection
# 190        Ethiopia - Weekly Building Change Detection
# 191                     Building State - Brazil - v0.1
# 192                         Road State - Brazil - v0.1
# 193      [DO NOT SHARE] Building State - Brazil - v0.1
# 194          [DO NOT SHARE] Road State - Brazil - v0.1
# 195          Building State - 20 AOIs in Brazil - v0.1
# 196              Road State - 20 AOIs in Brazil - v0.1
# 197                  PL-0037413_UM Lodz_bulidling_2022
# 198                  PL-0037413_UM Lodz_bulidling_2019
# 199                  PL-0037413_UM Lodz_bulidling_2020
# 200                        PL-0031008_PF_VesselsAIO_17
# 201                        PL-0031008_PF_VesselsAIO_16
# 202                        PL-0031008_PF_VesselsAIO_15
# 203                        PL-0031008_PF_VesselsAIO_14
# 204                        PL-0031008_PF_VesselsAIO_13
# 205                        PL-0031008_PF_VesselsAIO_12
# 206                        PL-0031008_PF_VesselsAIO_11
# 207                        PL-0031008_PF_VesselsAIO_10
# 208                        PL-0031008_PF_VesselsAIO_09
# 209                        PL-0031008_PF_VesselsAIO_08
# 210                        PL-0031008_PF_VesselsAIO_07
# 211  North Korea - Weekly Road Change Detection - v...
# 212  Southern Algeria - Weekly Building Change Dete...
# 213  Southern Algeria - Weekly Road Change Detectio...
# 214  Brazil 20 AOIs - weekly building change detection
# 215      Brazil 20 AOIs - weekly road change detection
# 216                             Greater Pyongyang Area
# 217                             Greater Pyongyang Area
# 218                                  Strait of Malacca
# 219  Building change in Gabon  February 2022- Augus...
# 220  Road change in Gabon February 2022 -  August 2022
# 221  West Xinjiang, China - weekly building change ...
# 222  West Xinjiang, China - weekly road change dete...
# 223  West Xinjiang, China - weekly building state r...
# 224  West Xinjiang, China - weekly road state raste...
# 225                                       scout AOI v2
# 226      Algeria - Building Change Detection - Weekly
# 227          Algeria - Road Change Detection - Weekly
# 228                Guinea - Road State Raster - Weekly
# 229            Guinea - Building State Raster - Weekly
# 230       Guinea -  Building Change Detection - Weekly
# 231            Guinea - Road Change Detection - Weekly
# 232              IOR_Approaches_NTRO_Ship Detection v2
# 233         Neighbour_Countries_NTRO_Ship Detection v2
# 234                   SCS_Ports_NTRO_Ship Detection v2
# 235              West_IOR_Coast_NTRO_Ship Detection v2
# 236        Building change Jan 2018- July 2021, Hainan
# 237           Road change Jan 2018 - July 2021, Hainan
# 238                                PL-0035770_building
# 239                      PL-0035770_buildling sep 2019
# 240                      PL-0035770_buildling sep 2020
# 241              Rwanda - Weekly Building State Raster
# 242                  Rwanda - Weekly Road State Raster
# 243                    Rwanda - Weekly Building Change
# 244                        Rwanda - Weekly Road Change
# 245                                    3 AOIs in Japan
# 246                                    3 AOIs in Japan
# 247  Test Ships - Remaining Coasts & Ports w Partia...
# 248  Building State - Moody’s pilot. Tampa, Florida...
# 249  Test Ships - Coasts & Ports w Partial UDM1 Mas...
# 250           Blantyre, Malawi PL-0037352, Road Change
# 251       Blantyre, Malawi PL-0037352, Building Change
# 252                Road change - Lium. Sample USA AOIs
# 253            Building change - Lium. Sample USA AOIs
# 254                                Road change, Hainan
# 255                            Building change, Hainan
# 256    Building change - Moody's pilot. Tampa, Florida
# 257       Building Detection - 20 AOIs in Brazil - v24
# 258                                              Nampo
# 259           Road Detection - 20 AOIs in Brazil - v24
# 260    Road Change Detection - 20 AOIs in Brazil - v24
# 261  Building Change Detection - 20 AOIs in Brazil ...
# 262         North Korea - Weekly Road Change Detection
# 263     North Korea - Weekly Building Change Detection
# 264  Iran Space Launch Facility - Weekly Road Chang...
# 265  Iran Space Launch Facility - Weekly Building C...
# 266                                     Virginia Beach
# 267     Building change - Moody's pilot - Berlin v22.1
# 268       Building change - Moody's pilot - Berlin v24
# 269   Ratio Geo Solutions - Road Change - Weekly - v24
# 270  Ratio Geo Solutions - Building Change - Weekly...
# 271                                  4 Ports Caribbean
# 272                                PL-0037412_building
# 273                Road change - Moody's pilot - v22.1
# 274            Building change - Moody's pilot - v22.1
# 275                    Building change - Moody's pilot
# 276                        Road change - Moody's pilot
# 277  Building change - Living Planet Symposium - Ma...
# 278   Road change - Living Planet Symposium - May 2022
# 279            Humboldt - weekly road change detection
# 280            Humboldt - weekly road change detection
# 281        Humboldt - weekly building change detection
# 282          Brunei - weekly building change detection
# 283              Brunei - weekly road change detection
# 284                                Ship Detection Demo
# 285  Building change - Russian Arctic Continental c...
# 286     Road change - Russian Arctic Continental coast
# 287     Road change - Russian Arctic Continental coast
# 288  Building change - Russian Arctic Continental c...
# 289      Brazil 20 AOIs - weekly road change detection
# 290  Brazil 20 AOIs - weekly building change detection
# 291                      PL-0035770_buildling sep 2019
# 292                      PL-0035770_buildling sep 2020
# 293                          Natanz, Weekly Road State
# 294                      Natanz, Weekly Building State
# 295                   Saudi Arabia, Weekly Road State
# 296             Kuala Lumpur - Building Detection 2021
# 297  Sambir Sebadi, Sarawak - Building Change Detec...
# 298  Sambir Sebadi, Sarawak - Building Change Detec...
# 299    Lusut, Sarawak - Building Change Detection 2018
# 300    Lusut, Sarawak - Building Change Detection 2021
# 301           Lusut, Sarawak - Building Detection 2021
# 302           Lusut, Sarawak - Building Detection 2018
# 303   Sambir Sebadi, Sarawak - Building Detection 2021
# 304   Sambir Sebadi, Sarawak - Building Detection 2018
# 305                     Natanz, Weekly Building Change
# 306                         Natanz, Weekly Road Change
# 307  South China Sea Islands Scene based Road Chang...
# 308  South China Sea Islands Scene based Building c...
# 309  South China Sea Islands Scene based Road State...
# 310                    New Mexico, Monthly Road Change
# 311  South China Sea Islands Scene based Building s...
# 312         South China Sea Islands Raw Road Detection
# 313  South China Sea Islands Cumulative Road Detection
# 314  South China Sea Islands Cumulative Building De...
# 315     South China Sea Islands Raw Building Detection
# 316               Kyiv Building Detection (cumulative)
# 317                      Kyiv Building Detection (raw)
# 318      Soco Gas - weekly road change detection - v23
# 319  Soco Gas - weekly building change detection - v23
# 320                 Hainan road change detection - v23
# 321        Denver - weekly road change detection - v23
# 322    Denver - weekly building change detection - v23
# 323             Hainan building change detection - v23
# 324                               Test Pooja Lithuania
# 325         HCMR Ship Detection Test - gridded polygon
# 326      Virginia - Mosaic Based Road Change Detection
# 327  Virginia - Mosaic Based Building Change Detection
# 328                          Non-Sharpened Mosaic Test
# 329                          Non-Sharpened Mosaic Test
# 330           Chemor, Perak, Building Change Detection
# 331               Chemor, Perak, Road Change Detection
# 332                  Chemor, Perak, Building Detection
# 333                      Chemor, Perak, Road Detection
# 334            Soco Gas - weekly road change detection
# 335        Soco Gas - weekly building change detection
# 336                       Kiev - Building state raster
# 337                                  20 AOIs in Brazil
# 338                                  20 AOIs in Brazil
# 339                    Virginia Road Change PL-0031681
# 340                Virginia Building Change PL-0031681
# 341                                   Nantucket Sample
# 342  West Xinjiang, China - weekly road change dete...
# 343  West Xinjiang, China - weekly building change ...
# 344             Ukraine - weekly road change detection
# 345         Ukraine - weekly building change detection
# 346       Stuttgart - weekly building change detection
# 347                         PORTO ALEGRE Denoised Test
# 348                         PORTO ALEGRE Denoised Test
# 349                       PL-0036853_building Oct 2020
# 350                       PL-0036853_buliding 2019 Oct
# 351                                PL-0036853_building
# 352                                         Sevastapol
# 540  2021-10-14T17:10:50.591Z
# 541  2021-10-14T18:28:06.692Z
# 542  2021-10-14T18:04:36.234Z
# 543  2021-10-14T18:39:08.650Z
# 544  2021-10-14T19:02:43.139Z
# 545  2021-10-14T18:16:34.000Z
# 546  2021-10-14T17:22:26.570Z
# 547  2021-10-14T19:33:51.404Z
# 548  2021-10-14T18:52:40.864Z
# 549  2021-10-14T17:47:00.286Z
# 550  2021-10-14T18:24:05.762Z
# 551  2021-10-14T16:59:46.780Z
# 552  2021-10-14T16:56:45.086Z
# 553  2021-10-14T19:10:14.662Z
# 554  2021-10-14T17:17:51.916Z
# 555  2021-10-14T17:23:53.286Z
# 556  2021-10-14T19:03:43.419Z
# 557  2021-10-14T18:22:05.549Z
# 558  2021-10-14T19:19:16.661Z
# 559  2021-10-14T17:45:58.089Z
# 560  2021-10-14T18:28:36.785Z
# 561  2021-10-14T19:24:23.821Z

# %% [markdown]
# #### Filtering subscriptions by feed

# %%
feed_id = feeds[0]['id']
feed_title = feeds[0]['title']
print(feed_title)
print('id:', feed_id)
# Out:
# Road change - weekly cadence - lookback 2023-03-20 - v0.25
# id: 5b73a193-484f-4aca-961b-2b1b21032a12

# %%
filtered_subscriptions_url = f'{BASE_URL}subscriptions?feedID={feed_id}'
print('url:', filtered_subscriptions_url)
resp = requests.get(filtered_subscriptions_url, auth=BASIC_AUTH)
filtered_subs = resp.json()['data']
filtered_sub_count = len(filtered_subs)
print(f'You have access to {filtered_sub_count} subscriptions for feed {feed_id} ({feed_title})')
# Out:
# url: https://api.planet.com/analytics/subscriptions?feedID=5b73a193-484f-4aca-961b-2b1b21032a12
# You have access to 1 subscriptions for feed 5b73a193-484f-4aca-961b-2b1b21032a12 (Road change - weekly cadence - lookback 2023-03-20 - v0.25)

# %% [markdown]
# #### Inspecting a subscription's geometry
# Subscriptions have a spatial area of interest described by a geojson geometry. We can visualize the area of interest for a subscription on a map.

# %%
# Get the latest subscription's geometry
subscription = subs[0]
geom = subscription['geometry']
pprint(geom)
# Out:
# {'coordinates': [[[-69.010057, 63.781113],
#                   [-68.127523, 63.186934],
#                   [-67.538771, 63.010675],
#                   [-66.908122, 62.647522],
#                   [-66.081585, 62.212382],
#                   [-65.813363, 62.0817],
#                   [-65.964955, 61.962506],
#                   [-66.28557, 61.827582],
#                   [-67.000334, 61.430995],
#                   [-66.307191, 60.70831],
#                   [-63.108471, 60.88852],
#                   [-61.045564, 63.079567],
#                   [-64.345754, 62.47372],
#                   [-65.252948, 62.643302],
#                   [-65.74745, 63.118],
#                   [-67.94105, 63.784663],
#                   [-69.010057, 63.781113]]],
#  'type': 'Polygon'}

# %%
# Make a map, and draw the subscription geometry
lon = geom['coordinates'][0][0][0]
lat = geom['coordinates'][0][0][0]

m = Map(center=(lat, lon), zoom=8)
geo_json = GeoJSON(data=subscription['geometry'], style = {'color': 'blue', 'opacity':1, 'weight':1.9, 'dashArray':'9', 'fillOpacity':0.1})
m.add_layer(geo_json)
m
# Out:
# Map(center=[-69.010057, -69.010057], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title…
