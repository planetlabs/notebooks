# %% [markdown]
# # Getting started with the Data API

# %% [markdown]
# ### **Let's search & download some imagery of farmland near Stockton, CA. Here are the steps we'll follow:**
#
# 1. Define an Area of Interest (AOI)
# 2. Save our AOI's coordinates to GeoJSON format
# 3. Create a few search filters
# 4. Search for imagery using those filters
# 5. Activate an image for downloading
# 6. Download an image

# %% [markdown]
# ### Requirements
# - Python 2.7 or 3+
# - requests
# - A [Planet API Key](https://www.planet.com/account/#/)

# %% [markdown]
# ## Define an Area of Interest

# %% [markdown]
# An **Area of Interest** (or *AOI*) is how we define the geographic "window" out of which we want to get data.
#
# For the Data API, this could be a simple bounding box with four corners, or a more complex shape, as long as the definition is in [GeoJSON](http://geojson.org/) format.
#
# For this example, let's just use a simple box. To make it easy, I'll use [geojson.io](http://geojson.io/) to quickly draw a shape & generate GeoJSON output for our box:

# %% [markdown]
# ![geojsonio.png](images/geojsonio.png)

# %% [markdown]
# We only need the "geometry" object for our Data API request:

# %%
# Stockton, CA bounding box (created via geojson.io) 
geojson_geometry = {
  "type": "Polygon",
  "coordinates": [
    [ 
      [-121.59290313720705, 37.93444993515032],
      [-121.27017974853516, 37.93444993515032],
      [-121.27017974853516, 38.065932950547484],
      [-121.59290313720705, 38.065932950547484],
      [-121.59290313720705, 37.93444993515032]
    ]
  ]
}

# %% [markdown]
# ## Create Filters

# %% [markdown]
# Now let's set up some **filters** to further constrain our Data API search:

# %%
# get images that overlap with our AOI 
geometry_filter = {
  "type": "GeometryFilter",
  "field_name": "geometry",
  "config": geojson_geometry
}

# get images acquired within a date range
date_range_filter = {
  "type": "DateRangeFilter",
  "field_name": "acquired",
  "config": {
    "gte": "2016-08-31T00:00:00.000Z",
    "lte": "2016-09-01T00:00:00.000Z"
  }
}

# only get images which have <50% cloud coverage
cloud_cover_filter = {
  "type": "RangeFilter",
  "field_name": "cloud_cover",
  "config": {
    "lte": 0.5
  }
}

# combine our geo, date, cloud filters
combined_filter = {
  "type": "AndFilter",
  "config": [geometry_filter, date_range_filter, cloud_cover_filter]
}

# %% [markdown]
# ## Searching: Items and Assets

# %% [markdown]
# Planet's products are categorized as **items** and **assets**: an item is a single picture taken by a satellite at a certain time. Items have multiple asset types including the image in different formats, along with supporting metadata files.
#
# For this demonstration, let's get a satellite image that is best suited for analytic applications; i.e., a 4-band image with spectral data for Red, Green, Blue and Near-infrared values. To get the image we want, we will specify an item type of `PSScene`, and asset type `ps4b_analytic` (to get a PSScene4Band Analytic asset).
#
# You can learn more about item & asset types in Planet's Data API [here](https://planet.com/docs/reference/data-api/items-assets/).
#
# Now let's search for all the items that match our filters:

# %%
import os
import json
import requests
from requests.auth import HTTPBasicAuth

# API Key stored as an env variable
PLANET_API_KEY = os.getenv('PL_API_KEY')


item_type = "PSScene"

# API request object
search_request = {
  "item_types": [item_type], 
  "filter": combined_filter
}

# fire off the POST request
search_result = \
  requests.post(
    'https://api.planet.com/data/v1/quick-search',
    auth=HTTPBasicAuth(PLANET_API_KEY, ''),
    json=search_request)

print(json.dumps(search_result.json(), indent=1))
# Out:
# {
#  "_links": {
#   "_first": "https://api.planet.com/data/v1/searches/55366b8850e0471fb3dd4e094a93e7d6/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/55366b8850e0471fb3dd4e094a93e7d6/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIxLTAxLTI3VDE3OjMxOjQ3LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTYwODMxXzE0Mzg0NV8wYzc5IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/55366b8850e0471fb3dd4e094a93e7d6/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#  },
#  "features": [
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212705_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212705_0c43/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_212705_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.25363533335903,
#        38.102991574438306
#       ],
#       [
#        -121.31213175664728,
#        38.138371663643476
#       ],
#       [
#        -121.45472224588369,
#        37.989794360274175
#       ],
#       [
#        -121.39597506862792,
#        37.954766052405795
#       ],
#       [
#        -121.25363533335903,
#        38.102991574438306
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212705_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:05.553514Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:37:59Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 168.6,
#     "satellite_id": "0c43",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232154",
#     "sun_azimuth": 217.1,
#     "sun_elevation": 55,
#     "updated": "2021-01-27T17:37:59Z",
#     "view_angle": 1.8,
#     "visible_confidence_percent": 81,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212703_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212703_0c43/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_212703_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.40113172338133,
#        38.205938534390576
#       ],
#       [
#        -121.45977255815832,
#        38.241261429813775
#       ],
#       [
#        -121.60235195993452,
#        38.092558308932425
#       ],
#       [
#        -121.5434597894109,
#        38.057581635513145
#       ],
#       [
#        -121.40113172338133,
#        38.205938534390576
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212703_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:03.039969Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:37:59Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 189.1,
#     "satellite_id": "0c43",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232154",
#     "sun_azimuth": 216.8,
#     "sun_elevation": 55,
#     "updated": "2021-01-27T17:37:59Z",
#     "view_angle": 1.7,
#     "visible_confidence_percent": 78,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212707_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212707_0c43/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_212707_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.15236482492602,
#        38.0334576476876
#       ],
#       [
#        -121.21073779048275,
#        38.06889548326457
#       ],
#       [
#        -121.3534526147278,
#        37.92047763669563
#       ],
#       [
#        -121.29480968692066,
#        37.88539024655166
#       ],
#       [
#        -121.15236482492602,
#        38.0334576476876
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212707_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:07.223909Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:37:58Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 169.4,
#     "satellite_id": "0c43",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232154",
#     "sun_azimuth": 217.4,
#     "sun_elevation": 55,
#     "updated": "2021-01-27T17:37:58Z",
#     "view_angle": 1.8,
#     "visible_confidence_percent": 79,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212706_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212706_0c43/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_212706_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.20318846502092,
#        38.06821823361878
#       ],
#       [
#        -121.26163813046634,
#        38.10361349469777
#       ],
#       [
#        -121.40424863251882,
#        37.95508581458477
#       ],
#       [
#        -121.34554477928819,
#        37.9200404578229
#       ],
#       [
#        -121.20318846502092,
#        38.06821823361878
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212706_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:06.38977Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 98,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:37:58Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 173.1,
#     "satellite_id": "0c43",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232154",
#     "sun_azimuth": 217.2,
#     "sun_elevation": 55,
#     "updated": "2021-01-27T17:37:58Z",
#     "view_angle": 1.8,
#     "visible_confidence_percent": 81,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212704_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212704_0c43/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_212704_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.30304032133586,
#        38.13769759404508
#       ],
#       [
#        -121.36156632617744,
#        38.17307306044577
#       ],
#       [
#        -121.50421120468481,
#        38.02448380428678
#       ],
#       [
#        -121.44542782166823,
#        37.98945510946883
#       ],
#       [
#        -121.30304032133586,
#        38.13769759404508
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212704_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:04.723994Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:37:57Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 180.6,
#     "satellite_id": "0c43",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232154",
#     "sun_azimuth": 217,
#     "sun_elevation": 55,
#     "updated": "2021-01-27T17:37:57Z",
#     "view_angle": 1.8,
#     "visible_confidence_percent": 100,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212703_1_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_212703_1_0c43/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_212703_1_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.3520957250651,
#        38.171871439083255
#       ],
#       [
#        -121.41068110087816,
#        38.207219145957005
#       ],
#       [
#        -121.55328979498753,
#        38.05857310929875
#       ],
#       [
#        -121.4944509881025,
#        38.02356901368412
#       ],
#       [
#        -121.3520957250651,
#        38.171871439083255
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212703_1_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:03.883939Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:37:56Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 189.1,
#     "satellite_id": "0c43",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232154",
#     "sun_azimuth": 216.9,
#     "sun_elevation": 55,
#     "updated": "2021-01-27T17:37:56Z",
#     "view_angle": 1.8,
#     "visible_confidence_percent": 79,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_180303_0e26",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_180303_0e26/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_180303_0e26/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_sr:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_sr",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.5902948623245,
#        37.99905560402393
#       ],
#       [
#        -121.61244754102333,
#        37.923102754047555
#       ],
#       [
#        -121.3136667838177,
#        37.86886056654726
#       ],
#       [
#        -121.29168693513927,
#        37.945084495160096
#       ],
#       [
#        -121.5902948623245,
#        37.99905560402393
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_180303_0e26",
#    "properties": {
#     "acquired": "2016-08-31T18:03:03.631837Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:32:35Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 276.6,
#     "satellite_id": "0e26",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "231989",
#     "sun_azimuth": 128.5,
#     "sun_elevation": 49.3,
#     "updated": "2021-01-27T17:32:35Z",
#     "view_angle": 3.1,
#     "visible_confidence_percent": 71,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_180302_0e26",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_180302_0e26/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_180302_0e26/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_sr:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_sr",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.57047017882637,
#        38.065400428517115
#       ],
#       [
#        -121.5926982278663,
#        37.9894546353282
#       ],
#       [
#        -121.2936743852695,
#        37.93509604309359
#       ],
#       [
#        -121.27162508643595,
#        38.011307968313176
#       ],
#       [
#        -121.57047017882637,
#        38.065400428517115
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_180302_0e26",
#    "properties": {
#     "acquired": "2016-08-31T18:03:02.59036Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 98,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:32:35Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 276.5,
#     "satellite_id": "0e26",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "231989",
#     "sun_azimuth": 128.6,
#     "sun_elevation": 49.3,
#     "updated": "2021-01-27T17:32:35Z",
#     "view_angle": 3.2,
#     "visible_confidence_percent": 72,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_180301_0e26",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_180301_0e26/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_180301_0e26/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_sr:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_sr",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.54994407237638,
#        38.13195941186308
#       ],
#       [
#        -121.5722432934264,
#        38.056016700591265
#       ],
#       [
#        -121.2729708226213,
#        38.00152095722934
#       ],
#       [
#        -121.25084540847627,
#        38.07772627268593
#       ],
#       [
#        -121.54994407237638,
#        38.13195941186308
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_180301_0e26",
#    "properties": {
#     "acquired": "2016-08-31T18:03:01.540205Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 98,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:32:34Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 276.3,
#     "satellite_id": "0e26",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "231989",
#     "sun_azimuth": 128.7,
#     "sun_elevation": 49.2,
#     "updated": "2021-01-27T17:32:34Z",
#     "view_angle": 3.2,
#     "visible_confidence_percent": 75,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_180235_0e0e",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_180235_0e0e/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_180235_0e0e/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_sr:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_sr",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.75811788668378,
#        38.10017255040613
#       ],
#       [
#        -121.78317725409431,
#        38.02307039859819
#       ],
#       [
#        -121.48700869861578,
#        37.963278052671654
#       ],
#       [
#        -121.46225819949156,
#        38.040431977755425
#       ],
#       [
#        -121.75811788668378,
#        38.10017255040613
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_180235_0e0e",
#    "properties": {
#     "acquired": "2016-08-31T18:02:35.82284Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 98,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:32:20Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 185.4,
#     "satellite_id": "0e0e",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232396",
#     "sun_azimuth": 128.6,
#     "sun_elevation": 49.3,
#     "updated": "2021-01-27T17:32:20Z",
#     "view_angle": 0.8,
#     "visible_confidence_percent": 72,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
# ...
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.55658609384078,
#        38.21331159716797
#       ],
#       [
#        -121.61328193852071,
#        38.1781253214791
#       ],
#       [
#        -121.46678042635311,
#        38.031641411907174
#       ],
#       [
#        -121.41037571055622,
#        38.0670420009036
#       ],
#       [
#        -121.55658609384078,
#        38.21331159716797
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_143847_0c79",
#    "properties": {
#     "acquired": "2016-08-31T14:38:47.168105Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 93,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:31:49Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 159.4,
#     "satellite_id": "0c79",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232281",
#     "sun_azimuth": 88.5,
#     "sun_elevation": 11.7,
#     "updated": "2021-01-27T17:31:49Z",
#     "view_angle": 2.9,
#     "visible_confidence_percent": 93,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_143846_0c79",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_143846_0c79/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_143846_0c79/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.60664672680858,
#        38.18007541359917
#       ],
#       [
#        -121.66325691827652,
#        38.144842540419454
#       ],
#       [
#        -121.51658240967649,
#        37.99849610843109
#       ],
#       [
#        -121.46025058083683,
#        38.033946088311524
#       ],
#       [
#        -121.60664672680858,
#        38.18007541359917
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_143846_0c79",
#    "properties": {
#     "acquired": "2016-08-31T14:38:46.333255Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 86,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:31:48Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 169.1,
#     "satellite_id": "0c79",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232281",
#     "sun_azimuth": 88.4,
#     "sun_elevation": 11.7,
#     "updated": "2021-01-27T17:31:48Z",
#     "view_angle": 2.9,
#     "visible_confidence_percent": 68,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_143843_1_0c79",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_143843_1_0c79/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_143843_1_0c79/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.70709727745536,
#        38.11242040232649
#       ],
#       [
#        -121.76359333995019,
#        38.077141139431866
#       ],
#       [
#        -121.61680096169479,
#        37.930923376234446
#       ],
#       [
#        -121.56059328522122,
#        37.96642088590375
#       ],
#       [
#        -121.70709727745536,
#        38.11242040232649
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_143843_1_0c79",
#    "properties": {
#     "acquired": "2016-08-31T14:38:43.947766Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 87,
#     "clear_percent": 98,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 2,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:31:48Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 173.8,
#     "satellite_id": "0c79",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232281",
#     "sun_azimuth": 88.3,
#     "sun_elevation": 11.5,
#     "updated": "2021-01-27T17:31:48Z",
#     "view_angle": 2.1,
#     "visible_confidence_percent": 70,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_143845_0c79",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20160831_143845_0c79/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20160831_143845_0c79/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.65636026488666,
#        38.14633266047454
#       ],
#       [
#        -121.71291737558875,
#        38.11107319958488
#       ],
#       [
#        -121.56619429031778,
#        37.96479225153997
#       ],
#       [
#        -121.50993761125943,
#        38.00026417351897
#       ],
#       [
#        -121.65636026488666,
#        38.14633266047454
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_143845_0c79",
#    "properties": {
#     "acquired": "2016-08-31T14:38:45.499088Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 86,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-01-27T17:31:47Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 175.5,
#     "satellite_id": "0c79",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "232281",
#     "sun_azimuth": 88.4,
#     "sun_elevation": 11.6,
#     "updated": "2021-01-27T17:31:47Z",
#     "view_angle": 2.8,
#     "visible_confidence_percent": 69,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   }
#  ],
#  "type": "FeatureCollection"
# }

# %% [markdown]
# Our search returns metadata for all of the images within our AOI that match our date range and cloud coverage filters. It looks like there are multiple images here; let's extract a list of just those image IDs:

# %%
# extract image IDs only
image_ids = [feature['id'] for feature in search_result.json()['features']]
print(image_ids)
# Out:
# ['20160831_212705_0c43', '20160831_212703_0c43', '20160831_212707_0c43', '20160831_212706_0c43', '20160831_212704_0c43', '20160831_212703_1_0c43', '20160831_180303_0e26', '20160831_180302_0e26', '20160831_180301_0e26', '20160831_180235_0e0e', '20160831_180236_0e0e', '20160831_180234_0e0e', '20160831_143848_0c79', '20160831_143847_0c79', '20160831_143846_0c79', '20160831_143843_1_0c79', '20160831_143845_0c79']

# %% [markdown]
# Since we just want a single image, and this is only a demonstration, for our purposes here we can arbitrarily select the first image in that list. Let's do that, and get the `asset` list available for that image:

# %%
# For demo purposes, just grab the first image ID
id0 = image_ids[0]
id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, id0)

# Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
result = \
  requests.get(
    id0_url,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# List of asset types available for this particular satellite image
print(result.json().keys())
# Out:
# dict_keys(['basic_analytic_4b', 'basic_analytic_4b_rpc', 'basic_analytic_4b_xml', 'basic_udm2', 'ortho_analytic_3b', 'ortho_analytic_3b_xml', 'ortho_analytic_4b', 'ortho_analytic_4b_xml', 'ortho_udm2', 'ortho_visual', 'ps3b_analytic', 'ps3b_analytic_dn', 'ps3b_analytic_dn_xml', 'ps3b_analytic_xml', 'ps3b_basic_analytic', 'ps3b_basic_analytic_dn', 'ps3b_basic_analytic_dn_rpc', 'ps3b_basic_analytic_dn_xml', 'ps3b_basic_analytic_rpc', 'ps3b_basic_analytic_xml', 'ps3b_basic_udm', 'ps3b_udm', 'ps3b_visual_xml', 'ps4b_analytic', 'ps4b_analytic_dn', 'ps4b_analytic_dn_xml', 'ps4b_analytic_xml', 'ps4b_basic_analytic', 'ps4b_basic_analytic_dn', 'ps4b_basic_analytic_dn_nitf', 'ps4b_basic_analytic_dn_rpc', 'ps4b_basic_analytic_dn_rpc_nitf', 'ps4b_basic_analytic_dn_xml', 'ps4b_basic_analytic_dn_xml_nitf', 'ps4b_basic_analytic_nitf', 'ps4b_basic_analytic_rpc', 'ps4b_basic_analytic_rpc_nitf', 'ps4b_basic_analytic_xml', 'ps4b_basic_analytic_xml_nitf', 'ps4b_basic_udm', 'ps4b_udm'])

# %% [markdown]
#  ## Activation and Downloading
#
# The Data API does not pre-generate assets, so they are not always immediately availiable to download. In order to download an asset, we first have to **activate** it.
#
# Remember, earlier we decided we wanted a color-corrected image best suited for *analytic* applications. We can check the status of the PSScene 4-Band analytic asset we want to download like so:

# %%
# This is "inactive" if the "analytic" asset has not yet been activated; otherwise 'active'
print(result.json()['ps4b_analytic']['status'])
# Out:
# active

# %% [markdown]
# Let's now go ahead and **activate** that asset for download:

# %%
# Parse out useful links
links = result.json()[u"ps4b_analytic"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# Request activation of the 'analytic' asset:
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# %% [markdown]
# At this point, we wait for the activation status for the asset we are requesting to change from `inactive` to `active`. We can monitor this by polling the "status" of the asset:

# %%
activation_status_result = \
  requests.get(
    self_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )
    
print(activation_status_result.json()["status"])
# Out:
# active

# %% [markdown]
# Once the asset has finished activating (status is "active"), we can download it.
#
# *Note: the download link on an active asset is temporary*

# %%
# Image can be downloaded by making a GET with your Planet API key, from here:
download_link = activation_status_result.json()["location"]
print(download_link)
# Out:
# https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..7VTxXJy4tEp3NM6gcVjVzp0YAwiOk2Dex77V3Mp2c0L1jaSY9kgjcARPdpc2d-KBviw4brwjH_hw5u2FOJaZ2A

# %% [markdown]
# ![stockton_thumb.png](images/stockton_thumb.png)
