# %% [markdown]
# # Planet API Python Client

# %% [markdown]
# This tutorial is an introduction to [Planet](https://www.planet.com)'s Data API using the official [Python client](https://github.com/planetlabs/planet-client-python), the `planet` module.
#
# ## Requirements
#
# This tutorial assumes familiarity with the [Python](https://python.org) programming language throughout. Python modules used in this tutorial are:
# * [IPython](https://ipython.org/) and [Jupyter](https://jupyter.org/)
# * [planet](https://github.com/planetlabs/planet-client-python)
# * [geojsonio](https://pypi.python.org/pypi/geojsonio)
#
# You should also have an account on the Planet Platform and retrieve your API key from your [account page](https://www.planet.com/account/).
#
# ## Useful links
# * [Documentation](https://planetlabs.github.io/planet-client-python/index.html)
# * [Planet Data API reference](https://www.planet.com/docs/reference/data-api/)

# %% [markdown]
# This tutorial will cover the basic operations possible with the Python client, particularly those that interact with the Data API.

# %% [markdown]
# The basic workflow for interacting with the Data API is:
# 1. search item types based on filters
# 1. activate assets
# 1. download assets

# %% [markdown]
# ## Set up
#
# In order to interact with the Planet API using the client, we need to import `planet.api`.

# %%
from planet import api

# %% [markdown]
# We next need to create a `ClientV1` object registered with our API key. The API key will be automatically read from the `PL_API_KEY` environment variable if it exists. If not it can be provided when creating the `api` object.

# %%
client = api.ClientV1()
# client = api.ClientV1(api_key="abcdef0123456789") <-- not a real key

# print client.auth.value

# %% [markdown]
# `ClientV1` provides basic low-level access to Planet’s API. Only one `ClientV1` should be in existence for an application. The client is thread safe and takes care to avoid API throttling and also retries any throttled requests. Any exceptional HTTP responses are handled by translation to one of the `planet.api.exceptions` classes.

# %% [markdown]
# We will also create a small helper function to print out JSON with proper indentation.

# %%
import json

def p(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# Let's also read in a GeoJSON geometry into a variable so we can use it during testing.

# %%
with open("data/san-francisco.json") as f:
    geom = json.loads(f.read())

# %% [markdown]
# ## Searching
#
# We can search for items that are interesting by using the `quick_search` member function. Searches, however, always require a proper request that includes a filter that selects the specific items to return as seach results.
#
# ### Filters
#
# The Planet Python client also includes `planet.api.filters` to assist in the creation of search filters.

# %%
from planet.api import filters

# %% [markdown]
# The possible filters include `and_filter`, `date_filter`, `range_filter` and so on, mirroring the options supported by the Planet API.

# %%
from datetime import datetime
start_date = datetime(year=2017, month=1, day=1)

date_filter = filters.date_range('acquired', gte=start_date)
cloud_filter = filters.range_filter('cloud_cover', lte=0.1)

# %%
and_filter = filters.and_filter(date_filter, cloud_filter)

# %%
p(and_filter)
# Out:
# {
#   "type": "AndFilter",
#   "config": [
#     {
#       "field_name": "acquired",
#       "type": "DateRangeFilter",
#       "config": {
#         "gte": "2017-01-01T00:00:00Z"
#       }
#     },
#     {
#       "field_name": "cloud_cover",
#       "type": "RangeFilter",
#       "config": {
#         "lte": 0.1
#       }
#     }
#   ]
# }

# %% [markdown]
# In addition to the filter, a properly-constructed request also contains the list of item types that we want to select.

# %%
item_types = ["REOrthoTile", "PSOrthoTile"]
req = filters.build_search_request(and_filter, item_types)

# %%
p(req)
# Out:
# {
#   "item_types": [
#     "PSOrthoTile",
#     "REOrthoTile"
#   ],
#   "filter": {
#     "type": "AndFilter",
#     "config": [
#       {
#         "field_name": "acquired",
#         "type": "DateRangeFilter",
#         "config": {
#           "gte": "2017-01-01T00:00:00Z"
#         }
#       },
#       {
#         "field_name": "cloud_cover",
#         "type": "RangeFilter",
#         "config": {
#           "lte": 0.1
#         }
#       }
#     ]
#   }
# }

# %%
res = client.quick_search(req)

# %% [markdown]
# The results of `quick_search` can be handled in different ways, but most commonly the user will either iterating through the list of items (`items_iter`) or writing items to a GeoJSON file (`json_encode`).
#
# In either case, the number of items must be specified.

# %%
for item in res.items_iter(4):
    print(item['id'], item['properties']['item_type'])
# Out:
# 5524910_4456218_2022-03-28_2414 PSOrthoTile
# 5524910_4452611_2022-03-28_2414 PSOrthoTile
# 5524910_4451208_2022-03-28_2414 PSOrthoTile
# 5524910_4452311_2022-03-28_2414 PSOrthoTile

# %% [markdown]
# If the number of items requested is more than 250, the client will automatically fetch more pages of results in order to get the exact number requested.

# %%
with open('output/results.json','w') as f:
    res.json_encode(f,1000)

# %% [markdown]
# This GeoJSON file can be opened and viewed in any compatible application.

# %% [markdown]
# ## Assets and downloads
#
# After a search returns results, the Python client can be used to check for assets and initiate downloads.
#
# The list of assets for an item can be retrieved with `get_assets` or `get_assets_by_id`.

# %%
print(item['id'])
# Out:
# 5524910_4452311_2022-03-28_2414

# %%
assets = client.get_assets(item).get()

# %%
assets
# Out:
# {'analytic': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/analytic'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'analytic'},
#  'analytic_5b': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljXzViIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljXzViIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/analytic_5b'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'analytic_5b'},
#  'analytic_5b_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljXzViX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljXzViX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/analytic_5b_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'analytic_5b_xml'},
#  'analytic_dn': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljX2RuIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljX2RuIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/analytic_dn'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'analytic_dn'},
#  'analytic_dn_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljX2RuX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljX2RuX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/analytic_dn_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'analytic_dn_xml'},
#  'analytic_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogImFuYWx5dGljX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/analytic_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'analytic_xml'},
#  'udm': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogInVkbSIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogInVkbSIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/udm'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'udm'},
#  'udm2': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogInVkbTIiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogInVkbTIiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/udm2'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'udm2'},
#  'visual': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogInZpc3VhbCIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogInZpc3VhbCIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/visual'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'visual'},
#  'visual_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogInZpc3VhbF94bWwiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjU1MjQ5MTBfNDQ1MjMxMV8yMDIyLTAzLTI4XzI0MTQiLCAiYyI6ICJQU09ydGhvVGlsZSIsICJ0IjogInZpc3VhbF94bWwiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/visual_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'visual_xml'}}

# %%
for asset in sorted(assets.keys()):
    print(asset)
# Out:
# analytic
# analytic_5b
# analytic_5b_xml
# analytic_dn
# analytic_dn_xml
# analytic_xml
# udm
# udm2
# visual
# visual_xml

# %%
activation = client.activate(assets['analytic'])
activation.response.status_code
# Out:
# 202

# %% [markdown]
# A response of 202 means that the request has been accepted and the activation will begin shortly. A 204 code indicates that the asset is already active and no further action is needed. A 401 code means the user does not have permissions to download this file.
#
# Below, we are polling the API until the item is done activation. This may take awhile.

# %%
import time

asset_activated = False

while asset_activated == False:
    
    # Get asset and its activation status
    assets = client.get_assets(item).get()
    asset = assets.get('analytic')
    asset_status = asset["status"]
    
    # If asset is already active, we are done
    if asset_status == 'active':
        asset_activated = True
        print("Asset is active and ready to download")
   
    # Still activating. Wait and check again.
    else:
        print("...Still waiting for asset activation...")
        time.sleep(3)
# Out:
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# ...Still waiting for asset activation...
# Asset is active and ready to download

# %%
callback = api.write_to_file(directory='output/')
body = client.download(assets['analytic_xml'], callback=callback)
body.await()
# Out:
#   File "<ipython-input-33-82ebe149417f>", line 3
#     body.await()
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Saved Searches
#
# The Python API client can also help in managing saved searches on the Planet Platform.

# %%
searches = client.get_searches()

# %%
for search in searches.items_iter(100):
    print(search['id'], search['name'])
# Out:
# 40bfde64d0534166b6f7e8c7fc8c89fd Vancouver Island
# 950f543836a2459e9c4d5848c8219304 Raj Ghat, New Delhi, Central Delhi, Delhi, India
# ae24a8d7251244b1ac283bc5b9398b78 San Francisco
# a7a648fca59245bca42d2466b289f34f San Francisco
# 6950887354d84e23889c3e308355fdcf Vancouver Island
# fe44f67590ae44d6a4e5e8030de85f90 Vancouver Island

# %%
item_types = ["PSScene"]
san_francisco_filter = filters.geom_filter(geom)
req = filters.build_search_request(san_francisco_filter, item_types, name="San Francisco")

# %%
p(req)
# Out:
# {
#   "item_types": [
#     "PSScene"
#   ],
#   "filter": {
#     "field_name": "geometry",
#     "type": "GeometryFilter",
#     "config": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -122.47455596923828,
#             37.810326435534755
#           ],
#           [
#             -122.49172210693358,
#             37.795406713958236
#           ],
#           [
#             -122.52056121826172,
#             37.784282779035216
#           ],
#           [
#             -122.51953124999999,
#             37.6971326434885
#           ],
#           [
#             -122.38941192626953,
#             37.69441603823106
#           ],
#           [
#             -122.38872528076173,
#             37.705010235842614
#           ],
#           [
#             -122.36228942871092,
#             37.70935613533687
#           ],
#           [
#             -122.34992980957031,
#             37.727280276860036
#           ],
#           [
#             -122.37773895263672,
#             37.76230130281876
#           ],
#           [
#             -122.38494873046875,
#             37.794592824285104
#           ],
#           [
#             -122.40554809570311,
#             37.813310018173155
#           ],
#           [
#             -122.46150970458983,
#             37.805715207044685
#           ],
#           [
#             -122.47455596923828,
#             37.810326435534755
#           ]
#         ]
#       ]
#     }
#   },
#   "name": "San Francisco"
# }

# %%
res = client.create_search(req)

# %%
search = res.get()
print(search["id"], search["name"])
# Out:
# 2c2d202cd5a343699e4b1f677e97ed8d San Francisco

# %%
res = client.saved_search(search["id"])

# %%
for item in res.items_iter(20):
    print(item["id"], item["properties"]["view_angle"])
# Out:
# 20220326_180313_91_241f 3
# 20220326_180311_62_241f 3
# 20220327_183227_22_2490 1
# 20220327_183229_53_2490 1
# 20220327_180339_22_2435 5
# 20220327_180341_52_2435 5
# 20220327_180456_67_106c 5
# 20220327_180455_17_106c 5
# 20220327_180453_67_106c 5
# 20220325_175739_95_2455 3.9
# 20220325_175737_65_2455 4
# 20220324_180251_82_2430 2.1
# 20220324_180249_35_2430 2.1
# 20220323_183536_13_2461 5
# 20220323_183538_46_2461 5
# 20220323_180500_58_106a 3
# 20220324_182935_1009 0.1
# 20220324_182934_1009 0.1
# 20220324_182933_1009 0.1
# 20220322_183117_0f4e 3.4

# %% [markdown]
# # Statistics
#
# The Python API client can also help report statistical summaries of the amount of data in the Planet API.

# %%
item_types = ["PSScene"]
san_francisco_filter = filters.geom_filter(geom)
req = filters.build_search_request(san_francisco_filter, item_types, interval="year")

# %%
stats = client.stats(req).get()

# %%
p(stats)
# Out:
# {
#   "buckets": [
#     {
#       "count": 3,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 60,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 200,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 1076,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 1674,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 1452,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 1514,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 1617,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 292,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %%
assets = client.get_assets(item)

# %%
assets.last_modified()

# %%
assets.get()
# Out:
# {'basic_analytic_4b': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX2FuYWx5dGljXzRiIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX2FuYWx5dGljXzRiIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/basic_analytic_4b'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.113560',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..tXn20QXUF6ybbFUxsH3JH_wz3ozuCo3RLmpwveRWafbe4uZy5F3ssfWZYZ9orgWOTKT14l1Hn3o-UmRjClnzKg',
#   'md5_digest': '63211a9a0b3027af23b6e4ae326a910b',
#   'status': 'active',
#   'type': 'basic_analytic_4b'},
#  'basic_analytic_4b_rpc': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX2FuYWx5dGljXzRiX3JwYyIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX2FuYWx5dGljXzRiX3JwYyIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/basic_analytic_4b_rpc'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.114771',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..KD0OgC-U1J8aCcA1Lrhsw_TKbft-yvBlniLm6cZ2i4szghEfAfx0cGGYLe0xP3hUeZOUF83ZfWdgYbUG2iFzSw',
#   'md5_digest': '15c1dd9e4d63386b9130c81d4e162742',
#   'status': 'active',
#   'type': 'basic_analytic_4b_rpc'},
#  'basic_analytic_4b_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX2FuYWx5dGljXzRiX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX2FuYWx5dGljXzRiX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/basic_analytic_4b_xml'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.115608',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..HVHlc0QqB7f_xTNlPkWtaHG3DOpnNAvxevdVqombIi39_vPCgUK_cynx-D7VmYNCLw-zdYraAoInopRITs9gmA',
#   'md5_digest': '7a0d51c5da6bf225cadc3ff27ddc3272',
#   'status': 'active',
#   'type': 'basic_analytic_4b_xml'},
#  'basic_udm2': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX3VkbTIiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX3VkbTIiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/basic_udm2'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.116613',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..UPwvcBuCIiEh6CBo6lEjdlyibSRwJZ2jZO849osw3LprndFGGxZ2I0EP144YE8g2ADiZn-HVsYLSri2eOOfyrw',
#   'md5_digest': '1d4a4451cadc95146ab3308583d1292a',
#   'status': 'active',
#   'type': 'basic_udm2'},
#  'ortho_analytic_3b': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX2FuYWx5dGljXzNiIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX2FuYWx5dGljXzNiIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ortho_analytic_3b'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ortho_analytic_3b'},
#  'ortho_analytic_3b_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX2FuYWx5dGljXzNiX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX2FuYWx5dGljXzNiX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ortho_analytic_3b_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ortho_analytic_3b_xml'},
#  'ortho_analytic_4b': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX2FuYWx5dGljXzRiIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX2FuYWx5dGljXzRiIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ortho_analytic_4b'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.119117',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..B_iINpL-rhjvqD89gUO8otkrxYU5-4C3tYAaw0S14F54g5ZWqc0N0RXCDQi1vuzGqkToTdqneDMX4vsip_GX9A',
#   'md5_digest': 'ec24126e7ff1bb0e5d5799628f9ce7a6',
#   'status': 'active',
#   'type': 'ortho_analytic_4b'},
#  'ortho_analytic_4b_sr': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX2FuYWx5dGljXzRiX3NyIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX2FuYWx5dGljXzRiX3NyIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ortho_analytic_4b_sr'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.119904',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..eyFo9KZ0lqS5TCTFcrH0LfuOzKIm5XU3tXinR_y5KAlewZIi_3qDsq5Qv5tJDifHwvGoWMEZnGTB4bgl3gRjQQ',
#   'md5_digest': 'da9f8b4c594830b45ab0c33feaf37948',
#   'status': 'active',
#   'type': 'ortho_analytic_4b_sr'},
#  'ortho_analytic_4b_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX2FuYWx5dGljXzRiX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX2FuYWx5dGljXzRiX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ortho_analytic_4b_xml'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.120636',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..xYUvBC36KIFHrmuTGtZJKbNgIlELXtVOQMXjJ73jAhfOshoTqE59rJzE7Fa0oKKsXsCv_BRThucofV_aczk3jg',
#   'md5_digest': 'c79fb9c7d253dc91cc1b9221331568d8',
#   'status': 'active',
#   'type': 'ortho_analytic_4b_xml'},
#  'ortho_udm2': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX3VkbTIiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX3VkbTIiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ortho_udm2'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.121399',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..B3RqFAOpIvxz3en-qy0ccIp9QVqDR1axGfsw2jgeKxFu-9WZhdFtu6L4LmDIjvtOACn1mw_ruHh6UNIcqd0NGA',
#   'md5_digest': 'd82b68be6ea21e4a5fda948aa1602230',
#   'status': 'active',
#   'type': 'ortho_udm2'},
#  'ortho_visual': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX3Zpc3VhbCIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogIm9ydGhvX3Zpc3VhbCIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ortho_visual'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ortho_visual'},
#  'ps3b_analytic': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_analytic'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.122861',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..nEtXEauTsHLT1yJrF9cZztzYu6fldP4T0RQ5Wh1slZvGgIdOOb9osIEJzBvk5bZiDEXt6fu9d0to9f6i0m0TaA',
#   'md5_digest': '14b10ece5674c70a743b285c035b335f',
#   'status': 'active',
#   'type': 'ps3b_analytic'},
#  'ps3b_analytic_dn': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_analytic_dn'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps3b_analytic_dn'},
#  'ps3b_analytic_dn_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_analytic_dn_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps3b_analytic_dn_xml'},
#  'ps3b_analytic_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_analytic_xml'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.125111',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..DZWOO4VWHS-1l1Qf99RhHnt50BS9w6rznP4QnQcfcbkeC3zvLhmNfMQlsqvtK59ZyZgA74-pnP2nYyfOxDq6Tw',
#   'md5_digest': '7a85ddf7ec3d576b4d6089b410729615',
#   'status': 'active',
#   'type': 'ps3b_analytic_xml'},
#  'ps3b_basic_analytic': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_basic_analytic'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps3b_basic_analytic'},
#  'ps3b_basic_analytic_dn': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_basic_analytic_dn'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps3b_basic_analytic_dn'},
#  'ps3b_basic_analytic_dn_rpc': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWNfZG5fcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWNfZG5fcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_basic_analytic_dn_rpc'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps3b_basic_analytic_dn_rpc'},
#  'ps3b_basic_analytic_dn_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_basic_analytic_dn_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps3b_basic_analytic_dn_xml'},
#  'ps3b_basic_analytic_rpc': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWNfcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWNfcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_basic_analytic_rpc'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps3b_basic_analytic_rpc'},
#  'ps3b_basic_analytic_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_basic_analytic_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps3b_basic_analytic_xml'},
#  'ps3b_basic_udm': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfdWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYmFzaWNfdWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_basic_udm'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps3b_basic_udm'},
#  'ps3b_udm': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfdWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfdWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_udm'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps3b_udm'},
#  'ps3b_visual_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfdmlzdWFsX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfdmlzdWFsX3htbCIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps3b_visual_xml'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.131998',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..nJqlVDcnKSfTyHTgdW4OaejHcAFM6b6kqgeqfDsvN7eU1bOx7-v57jmlChdVPC3U49_q1EOYF4fxtxeZCiJgsw',
#   'md5_digest': '7008f4399a612dd10e62801c41763f3b',
#   'status': 'active',
#   'type': 'ps3b_visual_xml'},
#  'ps4b_analytic': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_analytic'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_analytic'},
#  'ps4b_analytic_dn': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_analytic_dn'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_analytic_dn'},
#  'ps4b_analytic_dn_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_analytic_dn_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_analytic_dn_xml'},
#  'ps4b_analytic_sr': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYW5hbHl0aWNfc3IiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYW5hbHl0aWNfc3IiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_analytic_sr'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.135038',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..Ys73LkqZxHX6-imLLesi6Ni2pwY71Quh5mNkR1hLSA4g0r00uSeEmApxjKvOpTVLNHrcq8crapKNNfcmFgTyOQ',
#   'md5_digest': 'c81ffa1a2cc1776d6b3956af9dc142d9',
#   'status': 'active',
#   'type': 'ps4b_analytic_sr'},
#  'ps4b_analytic_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_analytic_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_analytic_xml'},
#  'ps4b_basic_analytic': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic'},
#  'ps4b_basic_analytic_dn': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_dn'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_dn'},
#  'ps4b_basic_analytic_dn_nitf': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG5fbml0ZiIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG5fbml0ZiIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_dn_nitf'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_dn_nitf'},
#  'ps4b_basic_analytic_dn_rpc': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG5fcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG5fcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_dn_rpc'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_dn_rpc'},
#  'ps4b_basic_analytic_dn_rpc_nitf': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG5fcnBjX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG5fcnBjX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_dn_rpc_nitf'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_dn_rpc_nitf'},
#  'ps4b_basic_analytic_dn_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_dn_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_dn_xml'},
#  'ps4b_basic_analytic_dn_xml_nitf': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG5feG1sX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfZG5feG1sX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_dn_xml_nitf'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_dn_xml_nitf'},
#  'ps4b_basic_analytic_nitf': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfbml0ZiIsICJjdCI6ICJpdGVtLXR5cGUifQ',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfbml0ZiIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_nitf'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_nitf'},
#  'ps4b_basic_analytic_rpc': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_rpc'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_rpc'},
#  'ps4b_basic_analytic_rpc_nitf': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfcnBjX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfcnBjX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_rpc_nitf'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_rpc_nitf'},
#  'ps4b_basic_analytic_xml': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_xml'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_xml'},
#  'ps4b_basic_analytic_xml_nitf': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfeG1sX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfYW5hbHl0aWNfeG1sX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_analytic_xml_nitf'},
#   '_permissions': ['download'],
#   'md5_digest': None,
#   'status': 'inactive',
#   'type': 'ps4b_basic_analytic_xml_nitf'},
#  'ps4b_basic_udm': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfdWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfYmFzaWNfdWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_basic_udm'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.145827',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..OWPlVrIiaPXRNImbj4NAXNOycBRb1WSyZvyFh7qTKXKcKTrlVSg2IjiDVpBfqH8bvidcetoQ5M8R1U2vCAFWcA',
#   'md5_digest': '985eabcb85d1d790e4a6e7b3da0fd165',
#   'status': 'active',
#   'type': 'ps4b_basic_udm'},
#  'ps4b_udm': {'_links': {'_self': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfdWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9',
#    'activate': 'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMzIyXzE4MzExN18wZjRlIiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzNGJfdWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate',
#    'type': 'https://api.planet.com/data/v1/asset-types/ps4b_udm'},
#   '_permissions': ['download'],
#   'expires_at': '2022-03-28T15:34:16.146568',
#   'location': 'https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..Zp7B95qnOcPomRiRcXTUwsxubKMB_KtLyIC2MiZfq_-QdXWLuueG6-ORsrYo30zU9dn1GlI1o_HxedNPSylNlQ',
#   'md5_digest': 'af83b663f001910ce9fbd0cf9aedcca5',
#   'status': 'active',
#   'type': 'ps4b_udm'}}
