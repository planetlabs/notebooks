# %% [markdown]
# # Planet Data API Introduction using Python
#
# ---

# %% [markdown]
# ## Introduction
#
# ---
#
# This tutorial is an introduction to [Planet](https://www.planet.com)'s Data API. It provides code samples on how to write simple Python code to access data.
#
# [`https://api.planet.com/data/v1`](https://api.planet.com/data/v1)
#
# The focus of this tutorial will be the search portion of the Planet Data API. We will find and download imagery data using complex searches and save them for later use, as well as learn how to get stats on search results. After completing this tutorial, you should feel comfortable interacting with the Data API, and have a good foundation for leveraging the Planet Data API for your own applications.

# %% [markdown]
# ## Table of Contents
#
# ---
#
# * **Introduction**
#     * Requirements
#        * Software & Modules
#        * Planet API Key
#     * Useful Links
#
#
# * **Overview**
#      * The Basic Workflow
#       * Data API Endpoints
#       * Planet Explorer
#
#
# * **Basic Setup**
#     * Authentication
#     * Helper Modules and Functions
#     * Our First Request
#
#
# * **Search Mechanics & Filters**
#     * Statistics
#     * Using a Search Filter
#     * Filter types
#         * Field Filters
#         * Logical Filters
#         * (Field) Filter Type examples
#     * Complex Queries using Logical Filters
#
#
# * **Searching for Items**
#     * Quick Search
#         * Mapping Footprints Example
#
#
# * **Assets & Permissions**
#     * Activating Assets
#     * Downloading Assets
#     * Rate Limits
#
#
# * **Saved Searches**
#
#
# * **Conclusion**

# %% [markdown]
# ### Requirements
#
# ---
#
# #### Software & Modules
#
# This tutorial assumes familiarity with the [Python](https://python.org) programming language throughout. Familiarity with basic REST API concepts and usage is also assumed.
#
# We'll be using a **"Jupyter Notebook"** (aka Python Notebook) to run through the examples.
# To learn more about and get started with using Jupyter, visit: [Jupyter](https://jupyter.org/) and [IPython](https://ipython.org/).
#
# For the best experience, download this notebook and run it on your system, and make sure to install the modules listed below first. You can also copy the examples' code to a separate Python files an run them directly with Python on your system if you prefer.
#
#
# Python modules used in this tutorial are:
# * [requests](http://docs.python-requests.org/)
# * [geojsonio](https://pypi.python.org/pypi/geojsonio)
#
#
# #### Planet API Key
#
# You should have an account on the Planet Platform to access the Data API. You may retrieve your API key from your [account page](https://www.planet.com/account/), or from the "API Tab" in [Planet Explorer](https://www.planet.com/explorer).

# %% [markdown]
# ### Useful links
#
# ---
#
# * [Planet Data API Reference & Documentation](https://www.planet.com/docs/reference/data-api/)
# * [Planet Explorer](https://www.planet.com/explorer)
#
# * Planet Data API explorer - Coming Soon!

# %% [markdown]
# ## Overview
#
# ---
#
# ### The Basic Workflow:
#
# 1. Search item types based on filters
# 1. Activate assets
# 1. Download assets

# %% [markdown]
# ### API Endpoints
#
# This tutorial will cover the following API ***endpoints***:
#
# * [`/item-types`](https://api.planet.com/data/v1/item-types/)
# * [`/asset-types`](https://api.planet.com/data/v1/asset-types/)
# * `/quick-search`
# * `/searches`
# * `/stats`
#
# There is an additional [`/spec`](https://api.planet.com/data/v1/spec) endpoint that publishes a [Swagger](http://swagger.io/) specification for the Data API.
#
# ### Exploring Endpoints
#
# We can start by exploring two endpoints using our browser.
#
# ##### What item types are available?
#
# https://api.planet.com/data/v1/item-types/
#
# ##### What assets are available?
#
# https://api.planet.com/data/v1/asset-types/

# %% [markdown]
# ***Note:*** *You may choose to install a helpful browser plugin called **JSONView** that formats JSON and makes it easier to read:*
#
# * [Chrome Extension](https://chrome.google.com/webstore/detail/jsonview/chklaanhfefbnpoihckbnefhakgolnmc)
# * [Firefox Plugin](https://addons.mozilla.org/en-us/firefox/addon/jsonview/)

# %% [markdown]
# ### Planet Explorer
# We can also use Planet Explorer to expose relevant API information for search results.
#
# In Planet Explorer, while in *Daily Imagery Mode* click on the *"Api"* button in the bottom left corner of the results panel.
#
# ![Planet Explorer Screenshot](images/planet-explorer.png)
#
# Here, you may access your API Key, selected item id's, and `cURL` request information containing filters and options.

# %% [markdown]
# ## Basic Setup
#
# ---
#
# Before interacting with the Planet Data API using Python, we will set up our environment with some useful modules and helper functions.
#
# * We'll configure *authentication* to the Planet Data API
# * We'll use the `requests` Python module to make HTTP communication easier.
# * We'll use the `json` Python module to help us work with JSON responses from the API.
# * We'll create a function called `p` that will print Python dictionaries nicely.
#
# Then we'll be ready to make our first call to the Planet API by hitting the base endpoint at `https://api.planet.com/data/v1`.
#
# Let's start by configuring authentication:

# %% [markdown]
# ### Authentication
#
# Authentication with the Planet Data API be achieved using a valid Planet **API key**.

# %% [markdown]
# You can *export* your API Key as an environment variable on your system:
#
# `export PL_API_KEY="YOUR API KEY HERE"`
#
# Or add the variable to your path, etc. If you are using our Docker environement, it will already be set.
#
# To start our Python code, we'll setup an API Key variable from an environment variable to use with our requests:

# %%
# Import the os module in order to access environment variables
import os

# If you're following along with this notebook, you can enter your API Key on the following line, and uncomment it:
#os.environ['PL_API_KEY']='YOUR API KEY HERE'

# Setup the API Key from the `PL_API_KEY` environment variable
PLANET_API_KEY = os.getenv('PL_API_KEY')

# %% [markdown]
# ### Helper Modules and Functions

# %%
# Import helper modules
import json
import requests

# %%
# Helper function to printformatted JSON using the json module
def p(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# ### Our First Request

# %%
# Setup Planet Data API base URL
URL = "https://api.planet.com/data/v1"

# Setup the session
session = requests.Session()

# Authenticate
session.auth = (PLANET_API_KEY, "")

# %%
# Make a GET request to the Planet Data API
res = session.get(URL)

# %% [markdown]
# Now we should get a response, hopefully it's a `200` code, saying everything is OK!

# %%
# Response status code
res.status_code
# Out:
# 200

# %%
# Response Body
res.text
# Out:
# u'{"_links": {"_self": "https://api.planet.com/data/v1/", "asset-types": "https://api.planet.com/data/v1/asset-types/", "item-types": "https://api.planet.com/data/v1/item-types/", "spec": "https://api.planet.com/data/v1/spec"}}'

# %%
# Print formatted JSON response
p(res.json())
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/",
#     "item-types": "https://api.planet.com/data/v1/item-types/",
#     "spec": "https://api.planet.com/data/v1/spec",
#     "asset-types": "https://api.planet.com/data/v1/asset-types/"
#   }
# }

# %%
# Print the value of the item-types key from _links
print(res.json()["_links"]["item-types"])
# Out:
# https://api.planet.com/data/v1/item-types/

# %% [markdown]
# **Congratulations!** You just made your first request to the Planet Data API using Python!
#
# Now, let's take a look at how to access all that high cadence satellite imagery!

# %% [markdown]
# ## Search Mechanics & Filters
#
# ---
#
# There's a lot of data available on the Planet Data API and in order to find what we're looking for, we'll have to perform various types of searches.
#
# To construct a search, we use **filters** that let us limit results based on date, geography or other metadata properties.
#
# Using these filters, we are able to **search** for items or get **statistics** for search results.
#
# Let's first make a request to the `/stats` endpoint to understand how the filters work:

# %% [markdown]
# ### Statistics `/stats`
#
# ---
#
# The `/stats` endpoint provides a summary of the available data based on some search criteria.
#
# `https://api.planet.com/data/v1/stats`
#
# We'll need to send a ***`POST`*** request to `/stats`, let's start by setting up the request url:

# %%
# Setup the stats URL
stats_url = "{}/stats".format(URL)

# Print the stats URL
print(stats_url)
# Out:
# https://api.planet.com/data/v1/stats

# %% [markdown]
# ### Using a Search Filter
#
# Search filters should have the following properties:
#
# * **Type** (`type`) - The type of filter being used
# * **Configuration** (`config`) - The configuration for this filter
# * **Field Name** (`field_name`) - The field on which to filter
#
# For this example, let's use a filter to get some stats on what data is available for *Planet Scope (3 Band)* and *Rapid Eye (Ortho Tile)* products taken from 2013 until now:

# %%
# Specify the sensors/satellites or "item types" to include in our results
item_types = ["PSScene3Band", "REOrthoTile"]

# %%
# Create filter object for all imagery captured between 2013-01-01 and present.
date_filter = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "gte": "2013-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

# %% [markdown]
# Depending on the filter type, some requests may need an `interval` field:
#
# The following intervals are possible:
# * `year`
# * `month`
# * `week`
# * `day`
# * `hour`
#
# An `interval` must be provided with the request so that the number of matching items can be aggregated. We'll use an interval with our date filter.

# %% [markdown]
# Now let's perform our request using the `date_filter` filter we created above:

# %%
# Construct the request.
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 3095020,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3602185,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8501990,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 36831501,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 175002840,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 44414627,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# ***Good Job!*** You've received a response from the API that contains some statistics like item counts for the search criteria!

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new date filter to find data from before 2013.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 
date_filter2 = {
}

request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

res = session.post(stats_url, json=request)
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 3095020,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3602185,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8501990,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 36831501,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 175002840,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 44414627,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# ---
#
# Next, let's take a closer look at some of the available filters:

# %% [markdown]
# ### Filter types
#
# The Planet Data API supports several filter types. The most common are the following:
#
# ### Field Filters
#
# * `DateRangeFilter`
# * `RangeFilter`
# * `StringInFilter`
# * `PermissionFilter`
# * `GeometryFilter`
#
# ### Logical Filters
#
# * `NotFilter`
# * `AndFilter`
# * `OrFilter`
#
# More information and examples on filter types can be found at the [API Docs](https://www.planet.com/docs/reference/data-api/search-api/).
#
# ---
#
# ### (Field) Filter Type examples:

# %% [markdown]
# #### `DateRangeFilter`
#
# Find imagery that was `acquired` or `published` before, after or between certain dates.
#
# ```
# {
#   "type": "DateRangeFilter",
#   "field_name": "acquired",
#   "config": {
#     "gt": "2016-01-01T00:00:00Z",
#     "lte": "2016-03-01T00:00:00Z"
#   }
# }
# ```
#
# The upper or lower bound may be omitted.

# %% [markdown]
# #### `RangeFilter`
#
# Find imagery that has a metadata that matches a number within a range of numbers.
#
# ```
# {
#   "type": "RangeFilter",
#   "field_name": "cloud_cover",
#   "config": {
#     "lt": 0.2,
#     "gt": 0.1
#   }
# }
# ```

# %% [markdown]
# The following **operators** are supported by the Data API's `DateRangeFilter` and `RangeFilter`:
# * `gt`: Greater Than
# * `gte`: Greater Than or Equal To
# * `lt`: Less Than
# * `lte`: Less Than or Equal To

# %% [markdown]
# #### `StringInFilter`
#
# Find imagery that has a metadata that matches a string within the array of provided strings.
#
#
# ```
# {
#   "type": "StringInFilter",
#   "field_name": "instrument",
#   "config": ["PS2"]
# }
# ```

# %% [markdown]
# #### `PermissionFilter`
#
# Find data which has assets that are accessible by the user.
#
# ```
# {
#   "type": "PermissionFilter",
#   "config": ["assets.analytic:download"]
# }
# ```
#
# ***Note:*** `assets:download` means *any* downloadable asset.

# %% [markdown]
# #### `GeometryFilter`
#
# Find data contained within a given geometry. The filter's config value may be any valid GeoJSON object.
#
# ```
# {
#   "type": "GeometryFilter",
#   "field_name": "geometry",
#   "config": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ]
#       ]
#     ]
#   }
# }
# ```
#
# A few quick ways to get a GeoJSON geometry to use in your search:
#
# * Draw an Area of Interst (AOI) in [Planet Explorer](http://planet.com/explorer), and use the API button to see the geometry filter config.
# * Use your favorite GIS tools like [Quantum GIS (QGIS)](http://www.qgis.org) and export GeoJSON.
# * Draw a polygon in [GeoJSON.io](http://geojson.io).
#
# Make sure the `config` property in the geometry filter is in the right format, which should be similar to a `feature` property in a GeoJSON object.

# %% [markdown]
# ---
#
# Let's try a few more requests and get some more stats, this time using different filters:

# %%
# Search for imagery only from PlanetScope satellites that have a PS2 telescope

# Setup item types
item_types = ["PSScene3Band"]

# Setup a filter for instrument type
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 1524094,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 29356498,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 170905430,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 43876768,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new filter that finds all data from PS0 or PS1 telescopes.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 

instrument_filter2 = {
}
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter2
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "field": {
#     "filter.type": [
#       {
#         "message": "'type' is a required property"
#       }
#     ]
#   },
#   "general": []
# }

# %% [markdown]
# Find a GeoJSON geometry from http://geojson.io and copy one `feature`.

# %%
# Search for imagery that only intersects with 40N, 90W

# Setup GeoJSON 
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup Geometry Filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": "POINT(-90 40)"
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "field": {
#     "filter.config": [
#       {
#         "message": "u'POINT(-90 40)' is not of type 'object'"
#       }
#     ],
#     "interval": [
#       {
#         "message": "'interval' is a required property"
#       }
#     ]
#   },
#   "general": []
# }

# %% [markdown]
# ### Complex Queries using Logical Filters
#
# Complex queries may require combining field filters using **logical filters** (see Filter Types above).
#
# Let's try a complex stats search:

# %%
# PS2 imagery; over 40N, 90W; captured between 2013 and present

# Setup an "AND" logical filter
and_filter = {
    "type": "AndFilter",
    "config": [instrument_filter, geometry_filter, date_filter]
}

# Print the logical filter
p(and_filter)
# Out:
# {
#   "config": [
#     {
#       "field_name": "instrument",
#       "config": [
#         "PS2"
#       ],
#       "type": "StringInFilter"
#     },
#     {
#       "field_name": "geometry",
#       "config": "POINT(-90 40)",
#       "type": "GeometryFilter"
#     },
#     {
#       "field_name": "acquired",
#       "config": {
#         "gte": "2013-01-01T00:00:00.000Z"
#       },
#       "type": "DateRangeFilter"
#     }
#   ],
#   "type": "AndFilter"
# }

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : and_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "field": {
#     "filter.config.1.config": [
#       {
#         "message": "u'POINT(-90 40)' is not of type 'object'"
#       }
#     ]
#   },
#   "general": []
# }

# %% [markdown]
# Here's another complex search query example using a "Not" logical filter and "string in" field filter. Can you tell what it's requesting?

# %%
# Setup Item Types
item_types = ["PSScene4Band"]

# Setup Instrument Filter
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# Setup "not" Logical Filter
not_filter = {
    "type": "NotFilter",
    "config": instrument_filter
}

# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : not_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": []
# }

# %% [markdown]
# Now that you're comfortable working with **filters**, let's take a look at how to perform searches!

# %% [markdown]
# ## Searching for Items
#
# ---
#
# There are two types of searches:
# * **"Quick Search"** `/quick-search`
# * **"Saved Searches"** `/searches`
#
# Saved searches are retained on the Planet Platform and may be performed again at any time in the future. You can use these to setup efficient workflows for repetitive tasks, for example, querying an area that is of interest to you, or getting data for specific sensors.
#
# Quick searches are meant to be more fleeting, and are not guaranteed to be available on the API after they are executed.
#
# Searches use the same request format as the `/stats` endpoint except without the `interval` field.

# %% [markdown]
# ### Quick Search
#
# Let's dive right in and create our first `quick search`:

# %%
# Setup the quick search endpoint url
quick_url = "{}/quick-search".format(URL)

# %%
# Setup Item Types
item_types = ["PSScene4Band"]

# Setup GeoJSON for only imagery that intersects with 40N, 90W
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup a geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": "POINT(40 -90)"
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "field": {
#     "filter.config": [
#       {
#         "message": "u'POINT(40 -90)' is not of type 'object'"
#       }
#     ]
#   },
#   "general": []
# }

# %% [markdown]
# Nice! The response gives us search results for Planet Scope (4 Band) for a specific area.
#
# Let's do another search, this time using the "not" filter we setup earlier:

# %%
# Setup Item Types
item_types = ["PSScene3Band"]

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : not_filter
}

# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "type": "FeatureCollection",
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/9e1072d20825405f89bee6828c3f3f6d/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#     "_first": "https://api.planet.com/data/v1/searches/9e1072d20825405f89bee6828c3f3f6d/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/9e1072d20825405f89bee6828c3f3f6d/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE3LTEwLTI0VDA0OjM4OjA3LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTYwMzMwXzA5MDg0MV8wYjA3IiwgInNvcnRfZGVzYyI6IHRydWV9"
#   },
#   "features": [
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               116.78651205147732,
#               38.95910810588407
#             ],
#             [
#               116.48582643713424,
#               38.95799224360764
#             ],
#             [
#               116.22482734145359,
#               38.634134715592324
#             ],
#             [
#               116.50853319395833,
#               38.62956689642292
#             ],
#             [
#               116.78651205147732,
#               38.95910810588407
#             ]
#           ]
#         ]
#       },
#       "id": "20160926_034414_0906",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160926_034414_0906",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160926_034414_0906/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160926_034414_0906/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-09-26T03:44:14.174921Z",
#         "satellite_id": "0906",
#         "sun_elevation": 52.1,
#         "pixel_resolution": 3,
#         "rows": 12160,
#         "epsg_code": 32650,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS0",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0.02,
#         "columns": 16325,
#         "updated": "2017-10-24T08:27:22Z",
#         "quality_category": "test",
#         "sun_azimuth": 159.6,
#         "origin_y": 4312263,
#         "origin_x": 432531,
#         "view_angle": 52.3,
#         "strip_id": "666205",
#         "cloud_cover": 0.17,
#         "gsd": 10.9,
#         "published": "2017-10-24T08:27:22Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               110.37910991206076,
#               12.775556280122105
#             ],
#             [
#               110.40893976893645,
#               12.734376102932556
#             ],
#             [
#               110.47238915770404,
#               12.778578086029677
#             ],
#             [
#               110.44256520784639,
#               12.819766800208976
#             ],
#             [
#               110.37910991206076,
#               12.775556280122105
#             ]
#           ]
#         ]
#       },
#       "id": "20160514_013208_0b0d",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013208_0b0d",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013208_0b0d/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013208_0b0d/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-05-14T01:32:08.381344Z",
#         "satellite_id": "0b0d",
#         "sun_elevation": 45.9,
#         "pixel_resolution": 3,
#         "rows": 3146,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3377,
#         "updated": "2017-10-24T04:52:40Z",
#         "quality_category": "test",
#         "sun_azimuth": 76.2,
#         "origin_y": 1417272,
#         "origin_x": 432606,
#         "view_angle": 0.1,
#         "strip_id": "182740",
#         "cloud_cover": 0.01,
#         "gsd": 2.1,
#         "published": "2017-10-24T04:52:40Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               110.25125357148934,
#               12.939390458981396
#             ],
#             [
#               110.28115390878003,
#               12.898246376898774
#             ],
#             [
#               110.34458886598465,
#               12.942524346999551
#             ],
#             [
#               110.31469357727727,
#               12.983674857044647
#             ],
#             [
#               110.25125357148934,
#               12.939390458981396
#             ]
#           ]
#         ]
#       },
#       "id": "20160514_013205_0b0d",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013205_0b0d",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013205_0b0d/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013205_0b0d/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-05-14T01:32:05.117317Z",
#         "satellite_id": "0b0d",
#         "sun_elevation": 45.8,
#         "pixel_resolution": 3,
#         "rows": 3147,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3376,
#         "updated": "2017-10-24T04:52:40Z",
#         "quality_category": "test",
#         "sun_azimuth": 76.4,
#         "origin_y": 1435431,
#         "origin_x": 418782,
#         "view_angle": 0,
#         "strip_id": "182740",
#         "cloud_cover": 0,
#         "gsd": 2.1,
#         "published": "2017-10-24T04:52:40Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               110.09029077972178,
#               13.158440172458286
#             ],
#             [
#               110.12017284005853,
#               13.117264879454165
#             ],
#             [
#               110.1837170998908,
#               13.16147162380001
#             ],
#             [
#               110.1538401455747,
#               13.202658636015364
#             ],
#             [
#               110.09029077972178,
#               13.158440172458286
#             ]
#           ]
#         ]
#       },
#       "id": "20160514_013201_0b0d",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013201_0b0d",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013201_0b0d/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013201_0b0d/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-05-14T01:32:01.037284Z",
#         "satellite_id": "0b0d",
#         "sun_elevation": 45.7,
#         "pixel_resolution": 3,
#         "rows": 3145,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3376,
#         "updated": "2017-10-24T04:52:40Z",
#         "quality_category": "test",
#         "sun_azimuth": 76.6,
#         "origin_y": 1459704,
#         "origin_x": 401409,
#         "view_angle": 0.2,
#         "strip_id": "182740",
#         "cloud_cover": 0,
#         "gsd": 2.1,
#         "published": "2017-10-24T04:52:40Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               109.96075321686405,
#               13.32139408664316
#             ],
#             [
#               109.9907169293351,
#               13.280261706493933
#             ],
#             [
#               110.0542350631164,
#               13.324558963439152
#             ],
#             [
#               110.02427784293886,
#               13.365699485648555
#             ],
#             [
#               109.96075321686405,
#               13.32139408664316
#             ]
#           ]
#         ]
#       },
#       "id": "20160514_013157_0b0d",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013157_0b0d",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013157_0b0d/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013157_0b0d/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-05-14T01:31:57.773258Z",
#         "satellite_id": "0b0d",
#         "sun_elevation": 45.6,
#         "pixel_resolution": 3,
#         "rows": 3146,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3377,
#         "updated": "2017-10-24T04:52:40Z",
#         "quality_category": "test",
#         "sun_azimuth": 76.7,
#         "origin_y": 1477788,
#         "origin_x": 387441,
#         "view_angle": 0.1,
#         "strip_id": "182740",
#         "cloud_cover": 0.05,
#         "gsd": 2.1,
#         "published": "2017-10-24T04:52:40Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               107.62944184538148,
#               2.1054006643090126
#             ],
#             [
#               107.6624189646118,
#               2.151016408818824
#             ],
#             [
#               107.59368279029755,
#               2.20104143460078
#             ],
#             [
#               107.56070836906291,
#               2.1554208299942212
#             ],
#             [
#               107.62944184538148,
#               2.1054006643090126
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090851_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090851_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090851_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090851_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:08:51.791097Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 26.4,
#         "pixel_resolution": 3,
#         "rows": 3526,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3775,
#         "updated": "2017-10-24T04:52:05Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.4,
#         "origin_y": 243534,
#         "origin_x": 784836,
#         "view_angle": 0.1,
#         "strip_id": "168204",
#         "cloud_cover": 0,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:52:05Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               107.41911883462107,
#               1.8010279799727786
#             ],
#             [
#               107.45199931230961,
#               1.846722063424921
#             ],
#             [
#               107.38317081084112,
#               1.8966199131223653
#             ],
#             [
#               107.35029078993647,
#               1.8509264069785032
#             ],
#             [
#               107.41911883462107,
#               1.8010279799727786
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090846_1_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090846_1_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090846_1_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090846_1_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:08:46.079055Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 26.6,
#         "pixel_resolution": 3,
#         "rows": 3524,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3775,
#         "updated": "2017-10-24T04:52:05Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.6,
#         "origin_y": 209817,
#         "origin_x": 761466,
#         "view_angle": 0.1,
#         "strip_id": "168204",
#         "cloud_cover": 0,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:52:05Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               106.60679302262389,
#               0.6576551974170693
#             ],
#             [
#               106.63968511490981,
#               0.7033755752025365
#             ],
#             [
#               106.57087647230766,
#               0.7533613658800293
#             ],
#             [
#               106.53798441919389,
#               0.707639552280841
#             ],
#             [
#               106.60679302262389,
#               0.6576551974170693
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090824_1_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090824_1_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090824_1_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090824_1_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:08:24.046897Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 27.4,
#         "pixel_resolution": 3,
#         "rows": 3528,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3775,
#         "updated": "2017-10-24T04:52:05Z",
#         "quality_category": "test",
#         "sun_azimuth": 274.1,
#         "origin_y": 83301,
#         "origin_x": 671145,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.87,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:52:05Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               106.33586663763558,
#               0.2713489336964869
#             ],
#             [
#               106.36874844377928,
#               0.3170918068538271
#             ],
#             [
#               106.29992215574546,
#               0.3670802543064762
#             ],
#             [
#               106.26703937209236,
#               0.32133789241551636
#             ],
#             [
#               106.33586663763558,
#               0.2713489336964869
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090816_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090816_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090816_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090816_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:08:16.702845Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 27.7,
#         "pixel_resolution": 3,
#         "rows": 3528,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3774,
#         "updated": "2017-10-24T04:52:05Z",
#         "quality_category": "test",
#         "sun_azimuth": 274.4,
#         "origin_y": 40584,
#         "origin_x": 640998,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.24,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:52:05Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               107.32205382678711,
#               1.6710571513650982
#             ],
#             [
#               107.35495739942587,
#               1.7167401163153584
#             ],
#             [
#               107.28615246946381,
#               1.7666832978635707
#             ],
#             [
#               107.2532488146493,
#               1.720998803215815
#             ],
#             [
#               107.32205382678711,
#               1.6710571513650982
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090843_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090843_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090843_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090843_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:08:43.631037Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 26.7,
#         "pixel_resolution": 3,
#         "rows": 3525,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3775,
#         "updated": "2017-10-24T04:52:04Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.6,
#         "origin_y": 195429,
#         "origin_x": 750681,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:52:04Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               108.10491120164073,
#               2.7778093508554442
#             ],
#             [
#               108.13786585525537,
#               2.8234298229279577
#             ],
#             [
#               108.06907014277778,
#               2.8733685203326798
#             ],
#             [
#               108.03611714512355,
#               2.8277431208726855
#             ],
#             [
#               108.10491120164073,
#               2.7778093508554442
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090904_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:04.847195Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 25.9,
#         "pixel_resolution": 3,
#         "rows": 3529,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3775,
#         "updated": "2017-10-24T04:42:39Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.1,
#         "origin_y": 318015,
#         "origin_x": 170445,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.71,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:39Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               108.04933719337288,
#               2.697102022237935
#             ],
#             [
#               108.08228182388744,
#               2.742729173615761
#             ],
#             [
#               108.01348588908726,
#               2.7926589640692967
#             ],
#             [
#               107.98054171072253,
#               2.7470298279861134
#             ],
#             [
#               108.04933719337288,
#               2.697102022237935
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090903_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090903_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090903_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090903_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:03.215183Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 25.9,
#         "pixel_resolution": 3,
#         "rows": 3530,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3775,
#         "updated": "2017-10-24T04:42:39Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.1,
#         "origin_y": 309099,
#         "origin_x": 164235,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.16,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:39Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               109.64437495113722,
#               4.941548751977338
#             ],
#             [
#               109.67758145013565,
#               4.9869724529478345
#             ],
#             [
#               109.60885186509731,
#               5.037079757003216
#             ],
#             [
#               109.57564698054087,
#               4.9916530613172325
#             ],
#             [
#               109.64437495113722,
#               4.941548751977338
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090946_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090946_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090946_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090946_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:46.463525Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 24.3,
#         "pixel_resolution": 3,
#         "rows": 3525,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3769,
#         "updated": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "sun_azimuth": 272.2,
#         "origin_y": 556929,
#         "origin_x": 342084,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:38Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               109.5557378034488,
#               4.814681527841784
#             ],
#             [
#               109.58894658146761,
#               4.8601040907011726
#             ],
#             [
#               109.52023481854914,
#               4.910228599287142
#             ],
#             [
#               109.48702861212978,
#               4.864803305822242
#             ],
#             [
#               109.5557378034488,
#               4.814681527841784
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090944_1_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_1_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_1_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_1_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:44.015505Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 24.4,
#         "pixel_resolution": 3,
#         "rows": 3526,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3769,
#         "updated": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "sun_azimuth": 272.2,
#         "origin_y": 542925,
#         "origin_x": 332226,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:38Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               109.58556091686181,
#               4.857494250179219
#             ],
#             [
#               109.61874577632146,
#               4.902933685155448
#             ],
#             [
#               109.55000272233023,
#               4.953017207681689
#             ],
#             [
#               109.51682028536761,
#               4.907574594477407
#             ],
#             [
#               109.58556091686181,
#               4.857494250179219
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090944_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:44.831512Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 24.3,
#         "pixel_resolution": 3,
#         "rows": 3524,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3768,
#         "updated": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "sun_azimuth": 272.2,
#         "origin_y": 547647,
#         "origin_x": 335541,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:38Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               109.52687647654382,
#               4.7746250861406345
#             ],
#             [
#               109.56008604156833,
#               4.8200491258702005
#             ],
#             [
#               109.49137721740148,
#               4.8701796923473095
#             ],
#             [
#               109.45816986268419,
#               4.824752799868769
#             ],
#             [
#               109.52687647654382,
#               4.7746250861406345
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090943_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090943_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090943_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090943_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:43.199499Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 24.4,
#         "pixel_resolution": 3,
#         "rows": 3526,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3768,
#         "updated": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "sun_azimuth": 272.2,
#         "origin_y": 538503,
#         "origin_x": 329016,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:38Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               108.98558714941588,
#               4.0150321871642936
#             ],
#             [
#               109.01874618356368,
#               4.060489514094876
#             ],
#             [
#               108.95007711065412,
#               4.110624515471389
#             ],
#             [
#               108.9169204108934,
#               4.065164309581307
#             ],
#             [
#               108.98558714941588,
#               4.0150321871642936
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090928_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090928_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090928_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090928_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:28.51138Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 25,
#         "pixel_resolution": 3,
#         "rows": 3529,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3771,
#         "updated": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "sun_azimuth": 272.5,
#         "origin_y": 454650,
#         "origin_x": 268731,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:38Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               108.079092304241,
#               2.7432279317162336
#             ],
#             [
#               108.11203173819564,
#               2.788856880871918
#             ],
#             [
#               108.04322615069405,
#               2.838776103032485
#             ],
#             [
#               108.01028842534024,
#               2.7931416851678805
#             ],
#             [
#               108.079092304241,
#               2.7432279317162336
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090904_1_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_1_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_1_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_1_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:04.031189Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 25.9,
#         "pixel_resolution": 3,
#         "rows": 3530,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3775,
#         "updated": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.1,
#         "origin_y": 314196,
#         "origin_x": 167559,
#         "view_angle": 0.1,
#         "strip_id": "168204",
#         "cloud_cover": 0.47,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:38Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               108.01414899126641,
#               2.647626050066925
#             ],
#             [
#               108.04711957859456,
#               2.6932387565630074
#             ],
#             [
#               107.97835007141582,
#               2.743211968967204
#             ],
#             [
#               107.9453795710229,
#               2.6975978579623985
#             ],
#             [
#               108.01414899126641,
#               2.647626050066925
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090902_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090902_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090902_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090902_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:02.399176Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 26,
#         "pixel_resolution": 3,
#         "rows": 3525,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3776,
#         "updated": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.1,
#         "origin_y": 303624,
#         "origin_x": 827529,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.18,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:38Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               107.98790291550307,
#               2.6117552459387103
#             ],
#             [
#               108.02090597832992,
#               2.6573420324477817
#             ],
#             [
#               107.95217792448064,
#               2.707368082034234
#             ],
#             [
#               107.91917496469101,
#               2.661779158882702
#             ],
#             [
#               107.98790291550307,
#               2.6117552459387103
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090901_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090901_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090901_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090901_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:01.583171Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 26,
#         "pixel_resolution": 3,
#         "rows": 3525,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3776,
#         "updated": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.2,
#         "origin_y": 299649,
#         "origin_x": 824622,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.12,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:38Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               107.96054029043839,
#               2.571164414889842
#             ],
#             [
#               107.99351363987765,
#               2.616773635437032
#             ],
#             [
#               107.92475448732854,
#               2.6667570324668413
#             ],
#             [
#               107.89178256621025,
#               2.621145490048836
#             ],
#             [
#               107.96054029043839,
#               2.571164414889842
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090900_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090900_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090900_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090900_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:00.767164Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 26,
#         "pixel_resolution": 3,
#         "rows": 3524,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3776,
#         "updated": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.2,
#         "origin_y": 295146,
#         "origin_x": 821583,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.02,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:42:38Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               107.92993848186248,
#               2.5293781348139683
#             ],
#             [
#               107.96293197696286,
#               2.5749729557770045
#             ],
#             [
#               107.89419533495969,
#               2.624990780233284
#             ],
#             [
#               107.86120434250019,
# ...
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3767,
#         "updated": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "sun_azimuth": 271.9,
#         "origin_y": 641100,
#         "origin_x": 402939,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:38:07Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               110.1358134188282,
#               5.627688099243179
#             ],
#             [
#               110.16908950975026,
#               5.673060651237806
#             ],
#             [
#               110.1003398911481,
#               5.72319221464695
#             ],
#             [
#               110.06706702965096,
#               5.6778130701710365
#             ],
#             [
#               110.1358134188282,
#               5.627688099243179
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090959_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090959_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090959_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090959_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:59.519634Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 23.7,
#         "pixel_resolution": 3,
#         "rows": 3522,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3767,
#         "updated": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "sun_azimuth": 271.9,
#         "origin_y": 632685,
#         "origin_x": 396687,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.07,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:38:07Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               110.07567375820832,
#               5.543919523227931
#             ],
#             [
#               110.10895500699439,
#               5.589287980702038
#             ],
#             [
#               110.04022336556038,
#               5.639437676045841
#             ],
#             [
#               110.00694550136234,
#               5.594062500069902
#             ],
#             [
#               110.07567375820832,
#               5.543919523227931
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090957_1_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090957_1_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090957_1_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090957_1_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:57.887621Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 23.8,
#         "pixel_resolution": 3,
#         "rows": 3523,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3767,
#         "updated": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "sun_azimuth": 271.9,
#         "origin_y": 623436,
#         "origin_x": 390015,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:38:07Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               108.92581776717816,
#               3.9315948282251836
#             ],
#             [
#               108.95888829542089,
#               3.9771165820965506
#             ],
#             [
#               108.89012750952,
#               4.027123502825285
#             ],
#             [
#               108.85706311979872,
#               3.9815965870842436
#             ],
#             [
#               108.92581776717816,
#               3.9315948282251836
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090926_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090926_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090926_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090926_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:26.879367Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 25,
#         "pixel_resolution": 3,
#         "rows": 3527,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3771,
#         "updated": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "sun_azimuth": 272.6,
#         "origin_y": 445431,
#         "origin_x": 262059,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.03,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:38:07Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               108.28780166713707,
#               3.030407129800798
#             ],
#             [
#               108.32076319053408,
#               3.076021329654138
#             ],
#             [
#               108.25195624212486,
#               3.1259450419906782
#             ],
#             [
#               108.21899927788613,
#               3.0803297039090936
#             ],
#             [
#               108.28780166713707,
#               3.030407129800798
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090909_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090909_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090909_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090909_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:09:09.743233Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 25.7,
#         "pixel_resolution": 3,
#         "rows": 3528,
#         "epsg_code": 32649,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3774,
#         "updated": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "sun_azimuth": 273,
#         "origin_y": 345915,
#         "origin_x": 190866,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.05,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:38:07Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               107.50816949296826,
#               1.9293592386756075
#             ],
#             [
#               107.54111479677192,
#               1.9750032781142908
#             ],
#             [
#               107.47235297739768,
#               2.0249917421504495
#             ],
#             [
#               107.43940772252175,
#               1.9793476548307714
#             ],
#             [
#               107.50816949296826,
#               1.9293592386756075
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090848_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090848_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090848_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090848_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:08:48.527073Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 26.5,
#         "pixel_resolution": 3,
#         "rows": 3526,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3775,
#         "updated": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.5,
#         "origin_y": 224034,
#         "origin_x": 771366,
#         "view_angle": 0.1,
#         "strip_id": "168204",
#         "cloud_cover": 0.01,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:38:07Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               107.29883561439362,
#               1.6366980681546246
#             ],
#             [
#               107.3317628859731,
#               1.6823621678358331
#             ],
#             [
#               107.2629876316373,
#               1.7323434476056252
#             ],
#             [
#               107.23006160854055,
#               1.686677199542447
#             ],
#             [
#               107.29883561439362,
#               1.6366980681546246
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090842_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090842_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090842_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090842_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:08:42.815031Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 26.7,
#         "pixel_resolution": 3,
#         "rows": 3526,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3775,
#         "updated": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.6,
#         "origin_y": 191628,
#         "origin_x": 748104,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.01,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:38:07Z"
#       }
#     },
#     {
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               107.23912083157167,
#               1.5488001315535453
#             ],
#             [
#               107.27192738251976,
#               1.5945534225499283
#             ],
#             [
#               107.20302409165686,
#               1.644355513400082
#             ],
#             [
#               107.17021862847123,
#               1.5986014823127632
#             ],
#             [
#               107.23912083157167,
#               1.5488001315535453
#             ]
#           ]
#         ]
#       },
#       "id": "20160330_090841_0b07",
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090841_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090841_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090841_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "type": "Feature",
#       "properties": {
#         "acquired": "2016-03-30T09:08:41.183019Z",
#         "satellite_id": "0b07",
#         "sun_elevation": 26.7,
#         "pixel_resolution": 3,
#         "rows": 3523,
#         "epsg_code": 32648,
#         "item_type": "PSScene3Band",
#         "usable_data": 0,
#         "instrument": "PS1",
#         "ground_control": false,
#         "provider": "planetscope",
#         "anomalous_pixels": 0,
#         "columns": 3775,
#         "updated": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "sun_azimuth": 273.7,
#         "origin_y": 181887,
#         "origin_x": 741453,
#         "view_angle": 0,
#         "strip_id": "168204",
#         "cloud_cover": 0.02,
#         "gsd": 2.3,
#         "published": "2017-10-24T04:38:07Z"
#       }
#     }
#   ]
# }

# %% [markdown]
# Let's take a closer look at our response data:

# %%
# Assign a features variable 
features = geojson["features"]

# Get the number of features present in the response
len(features)
# Out:
# 250

# %%
# Loop over all the features from the response
for f in features:
    # Print the ID for each feature
    p(f["id"])
# Out:
# "20160926_034414_0906"
# "20160514_013208_0b0d"
# "20160514_013205_0b0d"
# "20160514_013201_0b0d"
# "20160514_013157_0b0d"
# "20160330_090851_0b07"
# "20160330_090846_1_0b07"
# "20160330_090824_1_0b07"
# "20160330_090816_0b07"
# "20160330_090843_0b07"
# "20160330_090904_0b07"
# "20160330_090903_0b07"
# "20160330_090946_0b07"
# "20160330_090944_1_0b07"
# "20160330_090944_0b07"
# "20160330_090943_0b07"
# "20160330_090928_0b07"
# "20160330_090904_1_0b07"
# "20160330_090902_0b07"
# "20160330_090901_0b07"
# "20160330_090900_0b07"
# "20160330_090859_0b07"
# "20160330_090945_0b07"
# "20160330_090942_0b07"
# "20160330_090927_0b07"
# "20160330_090906_0b07"
# "20160330_090905_0b07"
# "20160330_090647_0b09"
# "20160330_090625_0b09"
# "20160330_090616_0b09"
# "20160330_090545_0b09"
# "20160330_090638_0b09"
# "20160330_090636_0b09"
# "20160330_090635_0b09"
# "20160330_090631_0b09"
# "20160330_090630_0b09"
# "20160330_090619_0b09"
# "20160330_090554_0b09"
# "20160330_090540_0b09"
# "20160330_090534_0b09"
# "20160330_090645_0b09"
# "20160330_090623_0b09"
# "20160330_090616_1_0b09"
# "20160330_090615_0b09"
# "20160330_090602_0b09"
# "20160330_090554_1_0b09"
# "20160330_090536_0b09"
# "20160330_090533_0b09"
# "20160330_090532_0b09"
# "20160330_090634_0b09"
# "20160330_090643_0b09"
# "20160330_090624_0b09"
# "20160330_090606_0b09"
# "20160330_090604_0b09"
# "20160330_090549_0b09"
# "20160330_090546_0b09"
# "20160330_090542_0b09"
# "20160330_090531_0b09"
# "20160330_090530_0b09"
# "20160330_090639_0b09"
# "20160330_090629_0b09"
# "20160330_090621_0b09"
# "20160330_090617_0b09"
# "20160330_090612_0b09"
# "20160330_090607_0b09"
# "20160330_090600_0b09"
# "20160330_090553_0b09"
# "20160330_090539_0b09"
# "20160330_090921_0b07"
# "20160330_090913_0b07"
# "20160330_090646_0b09"
# "20160330_090643_1_0b09"
# "20160330_090633_0b09"
# "20160330_090620_0b09"
# "20160330_090614_0b09"
# "20160330_090559_0b09"
# "20160330_090550_0b09"
# "20160330_090644_0b09"
# "20160330_090641_0b09"
# "20160330_090637_0b09"
# "20160330_090628_0b09"
# "20160330_090626_0b09"
# "20160330_090611_0b09"
# "20160330_090610_0b09"
# "20160330_090545_1_0b09"
# "20160330_090541_0b09"
# "20160330_090917_0b07"
# "20160330_090907_0b07"
# "20160330_090630_1_0b09"
# "20160330_090613_0b09"
# "20160330_090612_1_0b09"
# "20160330_090608_0b09"
# "20160330_090557_0b09"
# "20160330_090550_1_0b09"
# "20160330_090544_0b09"
# "20160330_090951_0b07"
# "20160330_090908_0b07"
# "20160330_090803_0b07"
# "20160330_090632_0b09"
# "20160330_090608_1_0b09"
# "20160330_090603_1_0b09"
# "20160330_090603_0b09"
# "20160330_090552_0b09"
# "20160330_090948_0b07"
# "20160330_090941_0b07"
# "20160330_090921_1_0b07"
# "20160330_090920_0b07"
# "20160330_090757_0b07"
# "20160330_090627_0b09"
# "20160330_090605_0b09"
# "20160330_090558_0b09"
# "20160330_090541_1_0b09"
# "20160330_090936_0b07"
# "20160330_090916_0b07"
# "20160330_090914_0b07"
# "20160330_090857_0b07"
# "20160330_090756_0b07"
# "20160330_090634_1_0b09"
# "20160330_090622_0b09"
# "20160330_090621_1_0b09"
# "20160330_090609_0b09"
# "20160330_090950_0b07"
# "20160330_090919_0b07"
# "20160330_090918_0b07"
# "20160330_090915_0b07"
# "20160330_090739_0b07"
# "20160330_090642_0b09"
# "20160330_090625_1_0b09"
# "20160330_090601_0b09"
# "20160330_090556_0b09"
# "20160330_090940_0b07"
# "20160330_090908_1_0b07"
# "20160330_090809_0b07"
# "20160330_090806_0b07"
# "20160330_090805_0b07"
# "20160330_090755_0b07"
# "20160330_090723_0b07"
# "20160330_090640_0b09"
# "20160330_090618_0b09"
# "20160330_090949_0b07"
# "20160330_090939_0b07"
# "20160330_090910_0b07"
# "20160330_090802_0b07"
# "20160330_090801_0b07"
# "20160330_090743_0b07"
# "20160330_090740_0b07"
# "20160330_090735_0b07"
# "20160330_090639_1_0b09"
# "20160330_090559_1_0b09"
# "20160330_090924_0b07"
# "20160330_090855_0b07"
# "20160330_090808_0b07"
# "20160330_090739_1_0b07"
# "20160330_090957_0b07"
# "20160330_090935_1_0b07"
# "20160330_090926_1_0b07"
# "20160330_090752_0b07"
# "20160330_090749_0b07"
# "20160330_090748_0b07"
# "20160330_090728_0b07"
# "20160330_090537_1_0b09"
# "20160330_090954_0b07"
# "20160330_090953_0b07"
# "20160330_090929_0b07"
# "20160330_090854_0b07"
# "20160330_090810_1_0b07"
# "20160330_090748_1_0b07"
# "20160330_090725_0b07"
# "20160330_090548_0b09"
# "20160330_090538_0b09"
# "20160330_090955_0b07"
# "20160330_090932_0b07"
# "20160330_090855_1_0b07"
# "20160330_090757_1_0b07"
# "20160330_090754_0b07"
# "20160330_090751_0b07"
# "20160330_090731_1_0b07"
# "20160330_090729_0b07"
# "20160330_090532_1_0b09"
# "20160330_090934_0b07"
# "20160330_090933_0b07"
# "20160330_090930_0b07"
# "20160330_090922_0b07"
# "20160330_090745_0b07"
# "20160330_090742_0b07"
# "20160330_090734_0b07"
# "20160330_090732_0b07"
# "20160330_090956_0b07"
# "20160330_090952_1_0b07"
# "20160330_090930_1_0b07"
# "20160330_090856_0b07"
# "20160330_090852_0b07"
# "20160330_090828_0b07"
# "20160330_090827_0b07"
# "20160330_090746_0b07"
# "20160330_090726_1_0b07"
# "20160330_090931_0b07"
# "20160330_090853_0b07"
# "20160330_090830_0b07"
# "20160330_090923_0b07"
# "20160330_090912_0b07"
# "20160330_090859_1_0b07"
# "20160330_090759_0b07"
# "20160330_090750_0b07"
# "20160330_090947_0b07"
# "20160330_090917_1_0b07"
# "20160330_090858_0b07"
# "20160330_090810_0b07"
# "20160330_090735_1_0b07"
# "20160330_090730_0b07"
# "20160330_090724_0b07"
# "20160330_090543_0b09"
# "20160330_090535_0b09"
# "20160330_090948_1_0b07"
# "20160330_090939_1_0b07"
# "20160330_090925_0b07"
# "20160330_090913_1_0b07"
# "20160330_090829_0b07"
# "20160330_090744_0b07"
# "20160330_090737_0b07"
# "20160330_090736_0b07"
# "20160330_090537_0b09"
# "20160330_090952_0b07"
# "20160330_090935_0b07"
# "20160330_090911_0b07"
# "20160330_090837_0b07"
# "20160330_090836_0b07"
# "20160330_090835_0b07"
# "20160330_090834_0b07"
# "20160330_090833_1_0b07"
# "20160330_090833_0b07"
# "20160330_090832_0b07"
# "20160330_090831_0b07"
# "20160330_090828_1_0b07"
# "20160330_090806_1_0b07"
# "20160330_090753_0b07"
# "20160330_090744_1_0b07"
# "20160330_090741_0b07"
# "20160330_090726_0b07"
# "20160330_090547_0b09"
# "20160330_091002_0b07"
# "20160330_091001_1_0b07"
# "20160330_091001_0b07"
# "20160330_090959_0b07"
# "20160330_090957_1_0b07"
# "20160330_090926_0b07"
# "20160330_090909_0b07"
# "20160330_090848_0b07"
# "20160330_090842_0b07"
# "20160330_090841_0b07"

# %%
# Print the first feature
p(features[0])
# Out:
# {
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           116.78651205147732,
#           38.95910810588407
#         ],
#         [
#           116.48582643713424,
#           38.95799224360764
#         ],
#         [
#           116.22482734145359,
#           38.634134715592324
#         ],
#         [
#           116.50853319395833,
#           38.62956689642292
#         ],
#         [
#           116.78651205147732,
#           38.95910810588407
#         ]
#       ]
#     ]
#   },
#   "id": "20160926_034414_0906",
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160926_034414_0906",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160926_034414_0906/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160926_034414_0906/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#   ],
#   "type": "Feature",
#   "properties": {
#     "acquired": "2016-09-26T03:44:14.174921Z",
#     "satellite_id": "0906",
#     "sun_elevation": 52.1,
#     "pixel_resolution": 3,
#     "rows": 12160,
#     "epsg_code": 32650,
#     "item_type": "PSScene3Band",
#     "usable_data": 0,
#     "instrument": "PS0",
#     "ground_control": false,
#     "provider": "planetscope",
#     "anomalous_pixels": 0.02,
#     "columns": 16325,
#     "updated": "2017-10-24T08:27:22Z",
#     "quality_category": "test",
#     "sun_azimuth": 159.6,
#     "origin_y": 4312263,
#     "origin_x": 432531,
#     "view_angle": 52.3,
#     "strip_id": "666205",
#     "cloud_cover": 0.17,
#     "gsd": 10.9,
#     "published": "2017-10-24T08:27:22Z"
#   }
# }

# %% [markdown]
# What happens when there are A LOT of results?
#
# When the number of matching items exceeds 250, the results are delivered in pages. Let's perform a search query that should return a large number of results:

# %%
# Setup a GeoJSON polygon for our geometry filter
geom = {
    "type": "Polygon",
    "coordinates": [
      [
        [
          -125.29632568359376,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          48.37084770238366
        ]
      ]
    ]
  }

# Setup the geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# %%
# Print the response "_links" property
p(geojson["_links"])
# Out:
# {
#   "_self": "https://api.planet.com/data/v1/searches/80414f2765b4453ca59b347e0d2127fe/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#   "_first": "https://api.planet.com/data/v1/searches/80414f2765b4453ca59b347e0d2127fe/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/80414f2765b4453ca59b347e0d2127fe/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE4LTAzLTEwVDIzOjQ3OjA0LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTgwMzEwXzE4MzgwOV8xMDJmIiwgInNvcnRfZGVzYyI6IHRydWV9"
# }

# %%
# Assign the "_links" -> "_next" property (link to next page of results) to a variable 
next_url = geojson["_links"]["_next"]

# Print the link to the next page of results
print(next_url)
# Out:
# https://api.planet.com/data/v1/searches/80414f2765b4453ca59b347e0d2127fe/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE4LTAzLTEwVDIzOjQ3OjA0LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTgwMzEwXzE4MzgwOV8xMDJmIiwgInNvcnRfZGVzYyI6IHRydWV9

# %% [markdown]
# The page size can be set with a `_page_size` parameter in the request:

# %%
# Send the POST request to the API quick search endpoint with a page size of 9
res = session.post(quick_url, json=request, params={"_page_size" : 9})

# Assign the response to a variable
geojson = res.json()

# Get the number of features present in the response
len(geojson["features"])
# Out:
# 9

# %% [markdown]
# ### Mapping Footprints Example
#
# The [`geojsonio`](https://pypi.python.org/pypi/geojsonio/) module can be used to map GeoJSON files and is therefore compatible with the output from Planet Data API searches.
#
# Make sure you've got the module installed and then let's use it to show our resuls on a map:

# %%
# Import the geojsonio python module
# You may need to install this on your system first
import geojsonio

# Assign the url variable to display the geojsonio map
url = geojsonio.display(res.text)

# %% [markdown]
# We can now iterate through the pages of results.

# %%
# Assign the next_url variable to the next page of results from the response (Setup the next page of results)
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %%
# Setup the next page of results
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %% [markdown]
# Cool huh? Now that we know how to search and find items we are interested in, let's try activating and downloading some assets.

# %% [markdown]
# ## Assets & Permissions
#
# Assets may be imagery files, image masks, metadata files or some other file type that might be associated with the item.
#
# The `_permissions` element in each feature contains a list of assets that the user has access to.

# %% [markdown]
# Let's pick the first item out of our search result to work with, and then see what the permissions are for that item:

# %%
# Assign a variable to the search result features (items)
features = geojson["features"]

# Get the first result's feature
feature = features[0]

# Print the ID
p(feature["id"])

# Print the permissions
p(feature["_permissions"])
# Out:
# "20180312_183901_1050"
# [
#   "assets.analytic_xml:download",
#   "assets.basic_analytic_dn:download",
#   "assets.basic_analytic_dn_xml:download",
#   "assets.basic_analytic_xml:download",
#   "assets.analytic_dn:download",
#   "assets.basic_udm:download",
#   "assets.analytic:download",
#   "assets.visual:download",
#   "assets.analytic_dn_xml:download",
#   "assets.basic_analytic_rpc:download",
#   "assets.basic_analytic_dn_rpc:download",
#   "assets.visual_xml:download",
#   "assets.basic_analytic:download",
#   "assets.udm:download"
# ]

# %% [markdown]
# Each item has an `assets` endpoint in the API that lists all of its assets. Let's get a list of available assets for our item:

# %%
# Get the assets link for the item
assets_url = feature["_links"]["assets"]

# Print the assets link
print(assets_url)
# Out:
# https://api.planet.com/data/v1/item-types/PSScene3Band/items/20180312_183901_1050/assets/

# %%
# Send a GET request to the assets url for the item (Get the list of available assets for the item)
res = session.get(assets_url)

# Assign a variable to the response
assets = res.json()

# Print the asset types that are available
p(assets.keys())
# Out:
# [
#   "analytic_xml",
#   "basic_analytic_dn",
#   "basic_analytic_rpc",
#   "basic_analytic_xml",
#   "analytic_dn",
#   "basic_udm",
#   "analytic",
#   "visual",
#   "analytic_dn_xml",
#   "basic_analytic_dn_xml",
#   "basic_analytic_dn_rpc",
#   "visual_xml",
#   "basic_analytic",
#   "udm"
# ]

# %% [markdown]
# We can see that most items have several assets available. Let's check out the "visual" asset for this item:

# %%
# Assign a variable to the visual asset from the item's assets
visual = assets["visual"]

# Print the visual asset data
p(visual)
# Out:
# {
#   "status": "inactive",
#   "md5_digest": null,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMzEyXzE4MzkwMV8xMDUwIiwgImMiOiAiUFNTY2VuZTNCYW5kIiwgInQiOiAidmlzdWFsIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#     "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMzEyXzE4MzkwMV8xMDUwIiwgImMiOiAiUFNTY2VuZTNCYW5kIiwgInQiOiAidmlzdWFsIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#     "type": "https://api.planet.com/data/v1/asset-types/visual"
#   },
#   "_permissions": [
#     "download"
#   ],
#   "type": "visual"
# }

# %% [markdown]
# ### Activating Assets
#
# Before an asset is available for download, it must be **activated**.
#
# You can activate an asset by sending a *POST* or *GET* request to the asset's **"activation link"**.
#
# The activation usually takes a little bit of time, but hey, I'm sure by now you have some ideas on how to automate your workflow. Go robots!

# %%
# Setup the activation url for a particular asset (in this case the visual asset)
activation_url = visual["_links"]["activate"]

# Send a request to the activation url to activate the item
res = session.get(activation_url)

# Print the response from the activation request
p(res.status_code)
# Out:
# 204

# %% [markdown]
# #### Activation Response Codes
#
# After hitting an activation url, you should get a response code back from the API:
#
# * **`202`** - The request has been accepted and the activation will begin shortly.
# * **`204`** - The asset is already active and no further action is needed.
# * **`401`** - The user does not have permissions to download this file.

# %% [markdown]
# After requesting to actiate an asset, let's do another request to see if the assset's status has changed:

# %%
import time

asset_activated = False

while asset_activated == False:
    # Send a request to the item's assets url
    res = session.get(assets_url)

    # Assign a variable to the item's assets url response
    assets = res.json()

    # Assign a variable to the visual asset from the response
    visual = assets["visual"]

    asset_status = visual["status"]
    
    # If asset is already active, we are done
    if asset_status == 'active':
        asset_activated = True
        print("Asset is active and ready to download")

# Print the visual asset data    
print(visual)
# Out:
# Asset is active and ready to download
# {u'status': u'active', u'md5_digest': u'2144cf0f0d723b74a0d5a7a581239059', u'expires_at': u'2018-03-14T00:45:04.167503', u'_links': {u'_self': u'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMzEyXzE4MzkwMV8xMDUwIiwgImMiOiAiUFNTY2VuZTNCYW5kIiwgInQiOiAidmlzdWFsIiwgImN0IjogIml0ZW0tdHlwZSJ9', u'activate': u'https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMzEyXzE4MzkwMV8xMDUwIiwgImMiOiAiUFNTY2VuZTNCYW5kIiwgInQiOiAidmlzdWFsIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate', u'type': u'https://api.planet.com/data/v1/asset-types/visual'}, u'_permissions': [u'download'], u'type': u'visual', u'location': u'https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..XVeFLEOCN6J2sxJ73KHj6e3fe8d9gqBhOUf6YNbu0uSkY8adYeCcViDy5yDD58X3WxQL91eRfkDcKohb5ZtXLw'}

# %% [markdown]
# #### Activation Status
#
# An asset may have a `status` of `inactive`, `activating` or `active`.
#
# Once an asset is active, the response will contain a `location`. We'll use the `location` to download the asset!
#
# Below, we are polling the API until the item is activated. This may take awhile.

# %% [markdown]
# ### Downloading Assets
#
# The asset's `location` property points asset file for use to download. Are you ready to download the asset? Let's do it!

# %%
# Assign a variable to the visual asset's location endpoint
location_url = visual["location"]

# Print the location endpoint
print(location_url)
# Out:
# https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..XVeFLEOCN6J2sxJ73KHj6e3fe8d9gqBhOUf6YNbu0uSkY8adYeCcViDy5yDD58X3WxQL91eRfkDcKohb5ZtXLw

# %% [markdown]
# There's the location url! You could click on it to open it in a browser and download the file... but why not let your code do it?
#
# Let's write a small helper function to download asset files:

# %%
# Create a function to download asset files
# Parameters: 
# - url (the location url)
# - filename (the filename to save it as. defaults to whatever the file is called originally)

def pl_download(url, filename=None):
    
    # Send a GET request to the provided location url, using your API Key for authentication
    res = requests.get(url, stream=True, auth=(PLANET_API_KEY, ""))
    # If no filename argument is given
    if not filename:
        # Construct a filename from the API response
        if "content-disposition" in res.headers:
            filename = res.headers["content-disposition"].split("filename=")[-1].strip("'\"")
        # Construct a filename from the location url
        else:
            filename = url.split("=")[1][:10]
    # Save the file
    with open('output/' + filename, "wb") as f:
        for chunk in res.iter_content(chunk_size=1024):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                f.flush()

    return filename

# %%
# Download the file from an activated asset's location url
pl_download(location_url)
# Out:
# '20180312_183901_1050_3B_Visual.tif'

# %% [markdown]
# **High Five!** You should now be downloading your very own GeoTIFF! We can't wait to see what you'll do with it!

# %% [markdown]
# ### Rate Limits
#
# ---
#
# Now that you know how to download assets, you should probably keep some of the API **rate limits** in mind:
#
# * For most endpoints, the rate limit is 10 requests per second, per API key.
# * For activation endpoints, the rate limit is 5 requests per second, per API key.
# * For download endpoints, the rate limit is 15 requests per second, per API key.
#
# If you're writing to code to automate accessing the API, you should account for `429` responses and handle retries after a *backoff period*.

# %% [markdown]
# ## Saved Searches
#
# ---
#
# The `/searches` endpoint lets you created saved searches that can be reused.
#
# To view your saved searches, visit the [`searches/?search_type=saved`](https://api.planet.com/data/v1/searches/?search_type=saved) endpoint.
#
# Finally, let's create a saved search:

# %%
# Setup the saved searches endpoint url
searches_url = "{}/searches".format(URL)

# %%
# Setup the request, specifying a name for the saved search, along with the usual search item_types and filter.
request = {
    "name" : "Vancouver Island",
    "item_types" : item_types,
    "filter" : geometry_filter
}

# Send a POST request to the saved searches endpoint (Create the saved search)
res = session.post(searches_url, json=request)

# Print the response
p(res.json())
# Out:
# {
#   "searches": [
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:22:46.863581Z",
#       "name": "bbb53500955d406490497c5b16211798",
#       "created": "2018-03-13T23:22:46.168165Z",
#       "last_executed": "2018-03-13T23:22:46.863329Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "id",
#             "config": [
#               "20170623_180038_0f34"
#             ],
#             "type": "StringInFilter"
#           },
#           {
#             "type": "PermissionFilter",
#             "config": [
#               "assets.analytic:download",
#               "assets.analytic_xml:download"
#             ]
#           }
#         ]
#       },
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/bbb53500955d406490497c5b16211798",
#         "results": "https://api.planet.com/data/v1/searches/bbb53500955d406490497c5b16211798/results"
#       },
#       "id": "bbb53500955d406490497c5b16211798"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:22:30.950873Z",
#       "name": "088d92e68d5a4ea9acf65f88e4ac2dfe",
#       "created": "2018-03-13T23:22:30.431385Z",
#       "last_executed": "2018-03-13T23:22:30.950647Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "id",
#             "config": [
#               "20170623_180038_0f34"
#             ],
#             "type": "StringInFilter"
#           },
#           {
#             "type": "PermissionFilter",
#             "config": [
#               "assets.analytic:download",
#               "assets.analytic_xml:download"
#             ]
#           }
#         ]
#       },
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/088d92e68d5a4ea9acf65f88e4ac2dfe",
#         "results": "https://api.planet.com/data/v1/searches/088d92e68d5a4ea9acf65f88e4ac2dfe/results"
#       },
#       "id": "088d92e68d5a4ea9acf65f88e4ac2dfe"
#     },
#     {
#       "search_type": "saved",
#       "updated": "2018-03-13T23:19:35.933421Z",
#       "name": "San Francisco",
#       "created": "2018-03-13T23:19:35.320001Z",
#       "last_executed": "2018-03-13T23:19:35.933161Z",
#       "filter": {
#         "field_name": "geometry",
#         "config": {
#           "type": "Polygon",
#           "coordinates": [
#             [
#               [
#                 -122.47455596923828,
#                 37.810326435534755
#               ],
#               [
#                 -122.49172210693358,
#                 37.795406713958236
#               ],
#               [
#                 -122.52056121826172,
#                 37.784282779035216
#               ],
#               [
#                 -122.51953124999999,
#                 37.6971326434885
#               ],
#               [
#                 -122.38941192626953,
#                 37.69441603823106
#               ],
#               [
#                 -122.38872528076173,
#                 37.705010235842614
#               ],
#               [
#                 -122.36228942871092,
#                 37.70935613533687
#               ],
#               [
#                 -122.34992980957031,
#                 37.727280276860036
#               ],
#               [
#                 -122.37773895263672,
#                 37.76230130281876
#               ],
#               [
#                 -122.38494873046875,
#                 37.794592824285104
#               ],
#               [
#                 -122.40554809570311,
#                 37.813310018173155
#               ],
#               [
#                 -122.46150970458983,
#                 37.805715207044685
#               ],
#               [
#                 -122.47455596923828,
#                 37.810326435534755
#               ]
#             ]
#           ]
#         },
#         "type": "GeometryFilter"
#       },
#       "item_types": [
#         "PSScene3Band"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/3cde2de9cc4b471b85164d578a23b833",
#         "results": "https://api.planet.com/data/v1/searches/3cde2de9cc4b471b85164d578a23b833/results"
#       },
#       "id": "3cde2de9cc4b471b85164d578a23b833"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:18:38.533083Z",
#       "name": "5945e184982941b780ce2c6fdf7f1167",
#       "created": "2018-03-13T23:18:38.074124Z",
#       "last_executed": "2018-03-13T23:18:38.532887Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "id",
#             "config": [
#               "20160831_180302_0e26"
#             ],
#             "type": "StringInFilter"
#           },
#           {
#             "type": "PermissionFilter",
#             "config": [
#               "assets.analytic_sr:download"
#             ]
#           }
#         ]
#       },
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/5945e184982941b780ce2c6fdf7f1167",
#         "results": "https://api.planet.com/data/v1/searches/5945e184982941b780ce2c6fdf7f1167/results"
#       },
#       "id": "5945e184982941b780ce2c6fdf7f1167"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:18:27.430523Z",
#       "name": "ab050030a5b149778930e832727ce0fb",
#       "created": "2018-03-13T23:18:26.820688Z",
#       "last_executed": "2018-03-13T23:18:27.430325Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "id",
#             "config": [
#               "20160831_180302_0e26"
#             ],
#             "type": "StringInFilter"
#           },
#           {
#             "type": "PermissionFilter",
#             "config": [
#               "assets.analytic:download",
#               "assets.analytic_xml:download"
#             ]
#           }
#         ]
#       },
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/ab050030a5b149778930e832727ce0fb",
#         "results": "https://api.planet.com/data/v1/searches/ab050030a5b149778930e832727ce0fb/results"
#       },
#       "id": "ab050030a5b149778930e832727ce0fb"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:16:37.443041Z",
#       "name": "3452648a4f9c491aa87a72b987555e20",
#       "created": "2018-03-13T23:16:33.486413Z",
#       "last_executed": "2018-03-13T23:16:37.442847Z",
#       "filter": {
#         "field_name": "geometry",
#         "config": {
#           "type": "Polygon",
#           "coordinates": [
#             [
#               [
#                 -125.29632568359376,
#                 48.37084770238366
#               ],
#               [
#                 -125.29632568359376,
#                 49.335861591104106
#               ],
#               [
#                 -123.2391357421875,
#                 49.335861591104106
#               ],
#               [
#                 -123.2391357421875,
#                 48.37084770238366
#               ],
#               [
#                 -125.29632568359376,
#                 48.37084770238366
#               ]
#             ]
#           ]
#         },
#         "type": "GeometryFilter"
#       },
#       "item_types": [
#         "PSScene3Band"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/3452648a4f9c491aa87a72b987555e20",
#         "results": "https://api.planet.com/data/v1/searches/3452648a4f9c491aa87a72b987555e20/results"
#       },
#       "id": "3452648a4f9c491aa87a72b987555e20"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:16:30.174538Z",
#       "name": "80414f2765b4453ca59b347e0d2127fe",
#       "created": "2018-03-13T23:16:30.164078Z",
#       "last_executed": "2018-03-13T23:16:30.174372Z",
#       "filter": {
#         "field_name": "geometry",
#         "config": {
#           "type": "Polygon",
#           "coordinates": [
#             [
#               [
#                 -125.29632568359376,
#                 48.37084770238366
#               ],
#               [
#                 -125.29632568359376,
#                 49.335861591104106
#               ],
#               [
#                 -123.2391357421875,
#                 49.335861591104106
#               ],
#               [
#                 -123.2391357421875,
#                 48.37084770238366
#               ],
#               [
#                 -125.29632568359376,
#                 48.37084770238366
#               ]
#             ]
#           ]
#         },
#         "type": "GeometryFilter"
#       },
#       "item_types": [
#         "PSScene3Band"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/80414f2765b4453ca59b347e0d2127fe",
#         "results": "https://api.planet.com/data/v1/searches/80414f2765b4453ca59b347e0d2127fe/results"
#       },
#       "id": "80414f2765b4453ca59b347e0d2127fe"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:16:27.268374Z",
#       "name": "9e1072d20825405f89bee6828c3f3f6d",
#       "created": "2018-03-13T23:16:27.235778Z",
#       "last_executed": "2018-03-13T23:16:27.268230Z",
#       "filter": {
#         "type": "NotFilter",
#         "config": {
#           "field_name": "instrument",
#           "config": [
#             "PS2"
#           ],
#           "type": "StringInFilter"
#         }
#       },
#       "item_types": [
#         "PSScene3Band"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/9e1072d20825405f89bee6828c3f3f6d",
#         "results": "https://api.planet.com/data/v1/searches/9e1072d20825405f89bee6828c3f3f6d/results"
#       },
#       "id": "9e1072d20825405f89bee6828c3f3f6d"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:16:25.914701Z",
#       "name": "3936447001b9429ba6160b9a46bbc21a",
#       "created": "2018-03-13T23:16:25.858375Z",
#       "last_executed": "2018-03-13T23:16:25.914451Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.59290313720705,
#                     37.93444993515032
#                   ],
#                   [
#                     -121.27017974853516,
#                     37.93444993515032
#                   ],
#                   [
#                     -121.27017974853516,
#                     38.065932950547484
#                   ],
#                   [
#                     -121.59290313720705,
#                     38.065932950547484
#                   ],
#                   [
#                     -121.59290313720705,
#                     37.93444993515032
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gte": "2016-08-31T00:00:00Z",
#               "lte": "2016-09-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lte": 0.5
#             },
#             "type": "RangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "PSScene3Band"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/3936447001b9429ba6160b9a46bbc21a",
#         "results": "https://api.planet.com/data/v1/searches/3936447001b9429ba6160b9a46bbc21a/results"
#       },
#       "id": "3936447001b9429ba6160b9a46bbc21a"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:16:23.699177Z",
#       "name": "45a88cd383bd458991ec02eec7963423",
#       "created": "2018-03-13T23:16:15.240921Z",
#       "last_executed": "2018-03-13T23:16:23.698978Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "acquired",
#             "config": {
#               "gte": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lte": 0.1
#             },
#             "type": "RangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile",
#         "REOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/45a88cd383bd458991ec02eec7963423",
#         "results": "https://api.planet.com/data/v1/searches/45a88cd383bd458991ec02eec7963423/results"
#       },
#       "id": "45a88cd383bd458991ec02eec7963423"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:05:53.712524Z",
#       "name": "629e07f99ea046dcaa757827ce1e4c9f",
#       "created": "2018-03-13T23:05:52.713840Z",
#       "last_executed": "2018-03-13T23:05:53.712327Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 0.05
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/629e07f99ea046dcaa757827ce1e4c9f",
#         "results": "https://api.planet.com/data/v1/searches/629e07f99ea046dcaa757827ce1e4c9f/results"
#       },
#       "id": "629e07f99ea046dcaa757827ce1e4c9f"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:05:51.433668Z",
#       "name": "83566cedd8304f54a48788eb014e4783",
#       "created": "2018-03-13T23:05:50.503636Z",
#       "last_executed": "2018-03-13T23:05:51.433443Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 0.05
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/83566cedd8304f54a48788eb014e4783",
#         "results": "https://api.planet.com/data/v1/searches/83566cedd8304f54a48788eb014e4783/results"
#       },
#       "id": "83566cedd8304f54a48788eb014e4783"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:05:49.554413Z",
#       "name": "29cb618f80fe48b1adb5e626d71ee4cf",
#       "created": "2018-03-13T23:05:48.802530Z",
#       "last_executed": "2018-03-13T23:05:49.554207Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 5.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "sun_elevation",
#             "config": {
#               "gt": 0.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "Landsat8L1G"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/29cb618f80fe48b1adb5e626d71ee4cf",
#         "results": "https://api.planet.com/data/v1/searches/29cb618f80fe48b1adb5e626d71ee4cf/results"
#       },
#       "id": "29cb618f80fe48b1adb5e626d71ee4cf"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:05:48.313716Z",
#       "name": "6c87a47fa35c412c9b17daaf6eaf3cdc",
#       "created": "2018-03-13T23:05:46.222510Z",
#       "last_executed": "2018-03-13T23:05:48.313494Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 5.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "sun_elevation",
#             "config": {
#               "gt": 0.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "Landsat8L1G"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/6c87a47fa35c412c9b17daaf6eaf3cdc",
#         "results": "https://api.planet.com/data/v1/searches/6c87a47fa35c412c9b17daaf6eaf3cdc/results"
#       },
#       "id": "6c87a47fa35c412c9b17daaf6eaf3cdc"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:05:44.629942Z",
#       "name": "decce040899747ea9ee2e03f76b6f4b3",
#       "created": "2018-03-13T23:05:42.775518Z",
#       "last_executed": "2018-03-13T23:05:44.629738Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 5.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "sun_elevation",
#             "config": {
#               "gt": 0.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "Landsat8L1G"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/decce040899747ea9ee2e03f76b6f4b3",
#         "results": "https://api.planet.com/data/v1/searches/decce040899747ea9ee2e03f76b6f4b3/results"
#       },
#       "id": "decce040899747ea9ee2e03f76b6f4b3"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:05:39.671970Z",
#       "name": "5a1a007f71e9459aae2b7b9715214c34",
#       "created": "2018-03-13T23:05:37.426259Z",
#       "last_executed": "2018-03-13T23:05:39.671771Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 0.05
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/5a1a007f71e9459aae2b7b9715214c34",
#         "results": "https://api.planet.com/data/v1/searches/5a1a007f71e9459aae2b7b9715214c34/results"
#       },
#       "id": "5a1a007f71e9459aae2b7b9715214c34"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T23:01:33.152589Z",
#       "name": "0fcfa366e5644451862c5b2cd17ad75d",
#       "created": "2018-03-13T23:01:31.070811Z",
#       "last_executed": "2018-03-13T23:01:33.152390Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 0.05
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/0fcfa366e5644451862c5b2cd17ad75d",
#         "results": "https://api.planet.com/data/v1/searches/0fcfa366e5644451862c5b2cd17ad75d/results"
#       },
#       "id": "0fcfa366e5644451862c5b2cd17ad75d"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T17:03:04.865510Z",
#       "name": "258d347aa4b94317977672bf9e844744",
#       "created": "2018-03-13T17:03:03.811085Z",
#       "last_executed": "2018-03-13T17:03:04.865312Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 0.05
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/258d347aa4b94317977672bf9e844744",
#         "results": "https://api.planet.com/data/v1/searches/258d347aa4b94317977672bf9e844744/results"
#       },
#       "id": "258d347aa4b94317977672bf9e844744"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T17:03:02.751826Z",
#       "name": "2beb53bd4b95412c8548147b600e32da",
#       "created": "2018-03-13T17:03:01.509165Z",
#       "last_executed": "2018-03-13T17:03:02.751621Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 5.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "sun_elevation",
#             "config": {
#               "gt": 0.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "Landsat8L1G"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/2beb53bd4b95412c8548147b600e32da",
#         "results": "https://api.planet.com/data/v1/searches/2beb53bd4b95412c8548147b600e32da/results"
#       },
#       "id": "2beb53bd4b95412c8548147b600e32da"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T17:03:00.300954Z",
#       "name": "207a7925fc0e4653b7d2d7db6ad1f5ec",
#       "created": "2018-03-13T17:02:58.908302Z",
#       "last_executed": "2018-03-13T17:03:00.300738Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 5.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "sun_elevation",
#             "config": {
#               "gt": 0.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "Landsat8L1G"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/207a7925fc0e4653b7d2d7db6ad1f5ec",
#         "results": "https://api.planet.com/data/v1/searches/207a7925fc0e4653b7d2d7db6ad1f5ec/results"
#       },
#       "id": "207a7925fc0e4653b7d2d7db6ad1f5ec"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T17:02:57.337674Z",
#       "name": "83382b08983544b4ac9947ac41a5fac9",
#       "created": "2018-03-13T17:02:55.959315Z",
#       "last_executed": "2018-03-13T17:02:57.337494Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 5.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "sun_elevation",
#             "config": {
#               "gt": 0.0
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "Landsat8L1G"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/83382b08983544b4ac9947ac41a5fac9",
#         "results": "https://api.planet.com/data/v1/searches/83382b08983544b4ac9947ac41a5fac9/results"
#       },
#       "id": "83382b08983544b4ac9947ac41a5fac9"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T17:02:54.610204Z",
#       "name": "fa0ab5efbb1041c0acff06924a950382",
#       "created": "2018-03-13T17:02:53.183298Z",
#       "last_executed": "2018-03-13T17:02:54.609986Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.34622533958
#                   ],
#                   [
#                     -121.2344205379486,
#                     38.28911976564886
#                   ],
#                   [
#                     -121.3113248348236,
#                     38.28911976564886
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 0.05
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-08-23T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/fa0ab5efbb1041c0acff06924a950382",
#         "results": "https://api.planet.com/data/v1/searches/fa0ab5efbb1041c0acff06924a950382/results"
#       },
#       "id": "fa0ab5efbb1041c0acff06924a950382"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-03-13T16:58:05.450116Z",
#       "name": "f79bf70cfa2e4fafb6f1a974a7475b74",
#       "created": "2018-03-13T16:53:30.855205Z",
#       "last_executed": "2018-03-13T16:58:05.449890Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -91.163064,
#                     42.986781
#                   ],
#                   [
#                     -91.14556,
#                     42.90798
#                   ],
#                   [
#                     -91.143375,
#                     42.90467
#                   ],
#                   [
#                     -91.117411,
#                     42.895837
#                   ],
#                   [
#                     -91.100565,
#                     42.883078
#                   ],
#                   [
#                     -91.077643,
#                     42.803798
#                   ],
#                   [
#                     -91.069549,
#                     42.769628
#                   ],
#                   [
#                     -91.064896,
#                     42.757272
#                   ],
#                   [
#                     -91.053733,
#                     42.738238
#                   ],
#                   [
#                     -90.976314,
#                     42.695996
#                   ],
#                   [
#                     -90.949213,
#                     42.685573
#                   ],
#                   [
#                     -90.896961,
#                     42.674407
#                   ],
#                   [
#                     -90.84391,
#                     42.663071
#                   ],
#                   [
#                     -90.769495,
#                     42.651443
#                   ],
#                   [
#                     -90.720209,
#                     42.640758
#                   ],
#                   [
#                     -90.709204,
#                     42.636078
#                   ],
#                   [
#                     -90.702671,
#                     42.630756
#                   ],
#                   [
#                     -90.645627,
#                     42.5441
#                   ],
#                   [
#                     -90.636727,
#                     42.518702
#                   ],
#                   [
#                     -90.636927,
#                     42.513202
#                   ],
#                   [
#                     -90.640927,
#                     42.508302
#                   ],
#                   [
#                     -90.655927,
#                     42.491703
#                   ],
#                   [
#                     -90.656527,
#                     42.489203
#                   ],
#                   [
#                     -90.656327,
#                     42.483603
#                   ],
#                   [
#                     -90.654027,
#                     42.478503
#                   ],
#                   [
#                     -90.646727,
#                     42.471904
#                   ],
#                   [
#                     -90.624328,
#                     42.458904
#                   ],
#                   [
#                     -90.559451,
#                     42.430695
#                   ],
#                   [
#                     -90.477279,
#                     42.383794
#                   ],
#                   [
#                     -90.474834,
#                     42.381473
#                   ],
#                   [
#                     -90.419027,
#                     42.328505
#                   ],
#                   [
#                     -90.416535,
#                     42.325109
#                   ],
#                   [
#                     -90.4162,
#                     42.321314
#                   ],
#                   [
#                     -90.424326,
#                     42.293326
#                   ],
#                   [
#                     -90.430735,
#                     42.284211
#                   ],
#                   [
#                     -90.430884,
#                     42.27823
#                   ],
#                   [
#                     -90.419326,
#                     42.254467
#                   ],
#                   [
#                     -90.391108,
#                     42.225473
#                   ],
#                   [
#                     -90.375129,
#                     42.214811
#                   ],
#                   [
#                     -90.356964,
#                     42.205445
#                   ],
#                   [
#                     -90.349162,
#                     42.204277
#                   ],
#                   [
#                     -90.316269,
#                     42.1936
#                   ],
#                   [
#                     -90.306531,
#                     42.190439
#                   ],
#                   [
#                     -90.234919,
#                     42.165431
#                   ],
#                   [
#                     -90.211328,
#                     42.15401
#                   ],
#                   [
#                     -90.167533,
#                     42.122475
#                   ],
#                   [
#                     -90.162225,
#                     42.11488
#                   ],
#                   [
#                     -90.161119,
#                     42.104404
#                   ],
#                   [
#                     -90.163405,
#                     42.087613
#                   ],
#                   [
#                     -90.168358,
#                     42.075779
#                   ],
#                   [
#                     -90.166495,
#                     42.054543
#                   ],
#                   [
#                     -90.164537,
#                     42.045007
#                   ],
#                   [
#                     -90.154221,
#                     42.033073
#                   ],
#                   [
#                     -90.150916,
#                     42.02944
#                   ],
#                   [
#                     -90.141167,
#                     42.008931
#                   ],
#                   [
#                     -90.140613,
#                     41.995999
#                   ],
#                   [
#                     -90.1516,
#                     41.931002
#                   ],
#                   [
#                     -90.152104,
#                     41.928947
#                   ],
#                   [
#                     -90.181973,
#                     41.80707
#                   ],
#                   [
#                     -90.187969,
#                     41.803163
#                   ],
#                   [
#                     -90.20844,
#                     41.797176
#                   ],
#                   [
#                     -90.222263,
#                     41.793133
#                   ],
#                   [
#                     -90.242747,
#                     41.783767
#                   ],
#                   [
#                     -90.278633,
#                     41.767358
#                   ],
#                   [
#                     -90.302782,
#                     41.750031
#                   ],
#                   [
#                     -90.309826,
#                     41.743321
#                   ],
#                   [
#                     -90.31522,
#                     41.734264
#                   ],
#                   [
#                     -90.317041,
#                     41.729104
#                   ],
#                   [
#                     -90.334525,
#                     41.679559
#                   ],
#                   [
#                     -90.343162,
#                     41.648141
#                   ],
#                   [
#                     -90.34165,
#                     41.621484
#                   ],
#                   [
#                     -90.39793,
#                     41.572233
#                   ],
#                   [
#                     -90.461432,
#                     41.523533
#                   ],
#                   [
#                     -90.474332,
#                     41.519733
#                   ],
#                   [
#                     -90.499475,
#                     41.518055
#                   ],
#                   [
#                     -90.605937,
#                     41.494232
#                   ],
#                   [
#                     -90.655839,
#                     41.462132
#                   ],
#                   [
#                     -90.737537,
#                     41.450127
#                   ],
#                   [
#                     -90.771672,
#                     41.450761
#                   ],
#                   [
#                     -90.786282,
# ...
#               "coordinates": [
#                 [
#                   [
#                     -123.07643830776215,
#                     49.312673429931955
#                   ],
#                   [
#                     -123.07617545127869,
#                     49.31256851295718
#                   ],
#                   [
#                     -123.07596892118453,
#                     49.31275386612794
#                   ],
#                   [
#                     -123.07622641324997,
#                     49.31287102296105
#                   ],
#                   [
#                     -123.07643830776215,
#                     49.312673429931955
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "field_name": "cloud_cover",
#             "config": {
#               "lt": 0.1
#             },
#             "type": "RangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "gt": "2017-01-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           },
#           {
#             "field_name": "acquired",
#             "config": {
#               "lt": "2017-06-01T00:00:00Z"
#             },
#             "type": "DateRangeFilter"
#           }
#         ]
#       },
#       "item_types": [
#         "Sentinel2L1C",
#         "PSScene4Band",
#         "PSScene3Band",
#         "Landsat8L1G",
#         "SkySatScene",
#         "REOrthoTile",
#         "PSOrthoTile",
#         "REScene"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/a7e8daca94764b4db9157ac7cff58d36",
#         "results": "https://api.planet.com/data/v1/searches/a7e8daca94764b4db9157ac7cff58d36/results"
#       },
#       "id": "a7e8daca94764b4db9157ac7cff58d36"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-01-25T17:57:14.113121Z",
#       "name": "b677d206dd484abfbe8455082fcc1f4a",
#       "created": "2018-01-25T17:57:11.495392Z",
#       "last_executed": "2018-01-25T17:57:14.112860Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -66.98300436421299,
#                     18.348086637611146
#                   ],
#                   [
#                     -66.90486333567492,
#                     18.348086637611146
#                   ],
#                   [
#                     -66.90486333567492,
#                     18.506121736521962
#                   ],
#                   [
#                     -66.98300436421299,
#                     18.506121736521962
#                   ],
#                   [
#                     -66.98300436421299,
#                     18.348086637611146
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "type": "OrFilter",
#             "config": [
#               {
#                 "type": "AndFilter",
#                 "config": [
#                   {
#                     "field_name": "item_type",
#                     "config": [
#                       "PSOrthoTile"
#                     ],
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "field_name": "sun_elevation",
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "type": "RangeFilter"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "OrFilter",
#             "config": [
#               {
#                 "field_name": "acquired",
#                 "config": {
#                   "gte": "2017-08-01T19:00:00Z",
#                   "lte": "2017-10-30T23:59:59Z"
#                 },
#                 "type": "DateRangeFilter"
#               }
#             ]
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/b677d206dd484abfbe8455082fcc1f4a",
#         "results": "https://api.planet.com/data/v1/searches/b677d206dd484abfbe8455082fcc1f4a/results"
#       },
#       "id": "b677d206dd484abfbe8455082fcc1f4a"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-01-25T17:55:11.354935Z",
#       "name": "a1fb11c6b7b3475ea2c03db612d5db1d",
#       "created": "2018-01-25T17:55:09.745531Z",
#       "last_executed": "2018-01-25T17:55:11.354717Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -66.98300436421299,
#                     18.348086637611146
#                   ],
#                   [
#                     -66.90486333567492,
#                     18.348086637611146
#                   ],
#                   [
#                     -66.90486333567492,
#                     18.506121736521962
#                   ],
#                   [
#                     -66.98300436421299,
#                     18.506121736521962
#                   ],
#                   [
#                     -66.98300436421299,
#                     18.348086637611146
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "type": "OrFilter",
#             "config": [
#               {
#                 "type": "AndFilter",
#                 "config": [
#                   {
#                     "field_name": "item_type",
#                     "config": [
#                       "PSOrthoTile"
#                     ],
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "field_name": "sun_elevation",
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "type": "RangeFilter"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "OrFilter",
#             "config": [
#               {
#                 "field_name": "acquired",
#                 "config": {
#                   "gte": "2017-08-01T19:00:00Z",
#                   "lte": "2017-09-30T23:59:59Z"
#                 },
#                 "type": "DateRangeFilter"
#               }
#             ]
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/a1fb11c6b7b3475ea2c03db612d5db1d",
#         "results": "https://api.planet.com/data/v1/searches/a1fb11c6b7b3475ea2c03db612d5db1d/results"
#       },
#       "id": "a1fb11c6b7b3475ea2c03db612d5db1d"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-01-25T17:52:40.644311Z",
#       "name": "3ae0fdc0b9224622b44eabd07631adba",
#       "created": "2018-01-25T17:52:38.525726Z",
#       "last_executed": "2018-01-25T17:52:40.644110Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -67.1145857109125,
#                     18.33897017788017
#                   ],
#                   [
#                     -66.87567506457181,
#                     18.33897017788017
#                   ],
#                   [
#                     -66.87567506457181,
#                     18.547295460861292
#                   ],
#                   [
#                     -67.1145857109125,
#                     18.547295460861292
#                   ],
#                   [
#                     -67.1145857109125,
#                     18.33897017788017
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "type": "OrFilter",
#             "config": [
#               {
#                 "type": "AndFilter",
#                 "config": [
#                   {
#                     "field_name": "item_type",
#                     "config": [
#                       "PSOrthoTile"
#                     ],
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "field_name": "sun_elevation",
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "type": "RangeFilter"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "OrFilter",
#             "config": [
#               {
#                 "field_name": "acquired",
#                 "config": {
#                   "gte": "2017-08-01T19:00:00Z",
#                   "lte": "2017-09-30T23:59:59Z"
#                 },
#                 "type": "DateRangeFilter"
#               }
#             ]
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/3ae0fdc0b9224622b44eabd07631adba",
#         "results": "https://api.planet.com/data/v1/searches/3ae0fdc0b9224622b44eabd07631adba/results"
#       },
#       "id": "3ae0fdc0b9224622b44eabd07631adba"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-01-25T17:52:05.020366Z",
#       "name": "0662ffaa18e54a7e8f01fe85551d25ce",
#       "created": "2018-01-25T17:52:03.447164Z",
#       "last_executed": "2018-01-25T17:52:05.020170Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -66.1192,
#                     18.4636
#                   ],
#                   [
#                     -66.1134,
#                     18.4636
#                   ],
#                   [
#                     -66.1134,
#                     18.468
#                   ],
#                   [
#                     -66.1192,
#                     18.468
#                   ],
#                   [
#                     -66.1192,
#                     18.4636
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "type": "OrFilter",
#             "config": [
#               {
#                 "type": "AndFilter",
#                 "config": [
#                   {
#                     "field_name": "item_type",
#                     "config": [
#                       "PSOrthoTile"
#                     ],
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "field_name": "sun_elevation",
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "type": "RangeFilter"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "OrFilter",
#             "config": [
#               {
#                 "field_name": "acquired",
#                 "config": {
#                   "gte": "2017-08-01T19:00:00Z",
#                   "lte": "2017-09-30T23:59:59Z"
#                 },
#                 "type": "DateRangeFilter"
#               }
#             ]
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/0662ffaa18e54a7e8f01fe85551d25ce",
#         "results": "https://api.planet.com/data/v1/searches/0662ffaa18e54a7e8f01fe85551d25ce/results"
#       },
#       "id": "0662ffaa18e54a7e8f01fe85551d25ce"
#     },
#     {
#       "search_type": "quick",
#       "updated": "2018-01-24T00:09:04.214981Z",
#       "name": "90f470e14ae0448f95568ee995e5df52",
#       "created": "2018-01-24T00:09:03.173690Z",
#       "last_executed": "2018-01-24T00:09:04.214762Z",
#       "filter": {
#         "type": "AndFilter",
#         "config": [
#           {
#             "field_name": "geometry",
#             "config": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -66.1192,
#                     18.4636
#                   ],
#                   [
#                     -66.1134,
#                     18.4636
#                   ],
#                   [
#                     -66.1134,
#                     18.468
#                   ],
#                   [
#                     -66.1192,
#                     18.468
#                   ],
#                   [
#                     -66.1192,
#                     18.4636
#                   ]
#                 ]
#               ]
#             },
#             "type": "GeometryFilter"
#           },
#           {
#             "type": "OrFilter",
#             "config": [
#               {
#                 "type": "AndFilter",
#                 "config": [
#                   {
#                     "field_name": "item_type",
#                     "config": [
#                       "PSOrthoTile"
#                     ],
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "field_name": "sun_elevation",
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "type": "RangeFilter"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "OrFilter",
#             "config": [
#               {
#                 "field_name": "acquired",
#                 "config": {
#                   "gte": "2017-08-01T19:00:00Z",
#                   "lte": "2017-09-30T23:59:59Z"
#                 },
#                 "type": "DateRangeFilter"
#               }
#             ]
#           }
#         ]
#       },
#       "item_types": [
#         "PSOrthoTile"
#       ],
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/90f470e14ae0448f95568ee995e5df52",
#         "results": "https://api.planet.com/data/v1/searches/90f470e14ae0448f95568ee995e5df52/results"
#       },
#       "id": "90f470e14ae0448f95568ee995e5df52"
#     }
#   ],
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/?_page=eyJxdWVyeV9wYXJhbXMiOiB7InNlYXJjaF90eXBlIjogImFueSJ9LCAic29ydF9wcmV2IjogZmFsc2UsICJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogImNyZWF0ZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#     "_first": "https://api.planet.com/data/v1/searches/?_page=eyJxdWVyeV9wYXJhbXMiOiB7InNlYXJjaF90eXBlIjogImFueSJ9LCAic29ydF9wcmV2IjogZmFsc2UsICJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogImNyZWF0ZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#     "_prev": "https://api.planet.com/data/v1/searches/?_page=",
#     "_next": "https://api.planet.com/data/v1/searches/?_page=%3D%3D"
#   }
# }

# %% [markdown]
# Now that we created a saved search, let's get a list of our saved searches:

# %%
# Send a GET request to the saved searches endpoint with the saved search type parameter (Get saved searches)
res = session.get(searches_url, params={"search_type" : "saved"})

# Assign a variable to the searches property in the saved searches response
searches = res.json()["searches"]
print(searches[2])#['name'])
print(len(searches))

# Loop through the searches
for search in searches:
    # Print the ID, Created Time, and Name for each saved search
    print("id: {} created: {} name: {}".format(search["id"], search["created"], search['name']))
# Out:
# {u'search_type': u'saved', u'updated': u'2018-01-23T22:46:51.997115Z', u'name': u'Median\xeda Alta', u'created': u'2018-01-23T22:46:51.997098Z', u'last_executed': None, u'filter': {u'type': u'AndFilter', u'config': [{u'field_name': u'geometry', u'config': {u'type': u'Polygon', u'coordinates': [[[-65.93333152841195, 18.339142007654047], [-65.93333152841195, 18.509595760282522], [-65.75366847158806, 18.509595760282522], [-65.75366847158806, 18.339142007654047], [-65.93333152841195, 18.339142007654047]]]}, u'type': u'GeometryFilter'}, {u'type': u'OrFilter', u'config': [{u'type': u'AndFilter', u'config': [{u'field_name': u'item_type', u'config': [u'PSScene4Band'], u'type': u'StringInFilter'}, {u'field_name': u'sun_elevation', u'config': {u'gte': 0.0, u'lte': 90.0}, u'type': u'RangeFilter'}]}]}, {u'type': u'OrFilter', u'config': [{u'field_name': u'acquired', u'config': {u'gte': u'2017-09-17T19:00:00Z', u'lte': u'2017-09-30T23:59:59Z'}, u'type': u'DateRangeFilter'}]}]}, u'item_types': [u'PSScene4Band'], u'__daily_email_enabled': False, u'_links': {u'_self': u'https://api.planet.com/data/v1/searches/7d793c34ee074cdebdb4c85b56b65e18', u'results': u'https://api.planet.com/data/v1/searches/7d793c34ee074cdebdb4c85b56b65e18/results'}, u'id': u'7d793c34ee074cdebdb4c85b56b65e18'}
# 5
# id: 3cde2de9cc4b471b85164d578a23b833 created: 2018-03-13T23:19:35.320001Z name: San Francisco
# id: 378c4e84629a48688fac99c917214c76 created: 2018-03-03T02:46:41.798342Z name: San Francisco
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-71-9a64e43cd6a1> in <module>()
#      10 for search in searches:
#      11     # Print the ID, Created Time, and Name for each saved search
# ---> 12     print("id: {} created: {} name: {}".format(search["id"], search["created"], search['name']))
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xed' in position 6: ordinal not in range(128)

# %% [markdown]
# Ok, now let's check out the results from a particular saved search:

# %%
# Setup the saved search url, using the first saved search in the list
saved_url = "{}/{}".format(searches_url, searches[0]["id"])

# Print the saved search url
p(saved_url)

# Setup the saved search's results url
results_url = "{}/results".format(saved_url)

# Print the saved search's results url
p(results_url)

# %%
# Send a GET request to the saved search url (Get the saved search data)
res = session.get(saved_url)

# Print the response
p(res.json())

# Print the number of features in the saved search
p(len(res["features"]))

# Print the first feature in the saved search
p(res["features"][0])

# %% [markdown]
# A saved search can also be updated by senidng a **`PUT`** request with a changed search definition back to the API.
#
# Did you know that saved searches can also send you a daily email to alert you to when new items are added to the search resutlts? Oh yeah!

# %%
# Assign a variable to the saved search response
search = res.json();

# Print the saved search
p(search)

# %%
# Change the saved search name to "South Vancouver Island"
search["name"] = "South Vancouver Island"

# Set the daily email enabled to true (Get email alerts when new items show up in this search)
search["__daily_email_enabled"] = True

# Send a PUT request to the saved search endpoint (Update the saved search)
res = session.put(saved_url, json=search)

# The response status code
res.status_code

# %% [markdown]
# ## Conclusion
#
# You made it! You should now be able to use the Planet API to find items and assets by searching, get stats and save searches, and activate and download assets using Python code!
#
# Don't forget to visit the [Planet API Reference Docs](https://www.planet.com/docs/reference/).
