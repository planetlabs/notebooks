# %% [markdown]
# # Planet Data API Introduction using Python
#
# ---

# %% [markdown]
# ## Introduction
#
# ---
#
# This tutorial is an introduction to [Planet](https://www.planet.com)'s Data API. It provides code samples on how to write simple Python code to access data.
#
# [`https://api.planet.com/data/v1`](https://api.planet.com/data/v1)
#
# The focus of this tutorial will be the search portion of the Planet Data API. We will find and download imagery data using complex searches and save them for later use, as well as learn how to get stats on search results. After completing this tutorial, you should feel comfortable interacting with the Data API, and have a good foundation for leveraging the Planet Data API for your own applications.

# %% [markdown]
# ## Table of Contents
#
# ---
#
# * **Introduction**
#     * Requirements
#        * Software & Modules
#        * Planet API Key
#     * Useful Links
#
#
# * **Overview**
#      * The Basic Workflow
#       * Data API Endpoints
#       * Planet Explorer
#
#
# * **Basic Setup**
#     * Authentication
#     * Helper Modules and Functions
#     * Our First Request
#
#
# * **Search Mechanics & Filters**
#     * Statistics
#     * Using a Search Filter
#     * Filter types
#         * Field Filters
#         * Logical Filters
#         * (Field) Filter Type examples
#     * Complex Queries using Logical Filters
#
#
# * **Searching for Items**
#     * Quick Search
#         * Mapping Footprints Example
#
#
# * **Assets & Permissions**
#     * Activating Assets
#     * Downloading Assets
#     * Rate Limits
#
#
# * **Saved Searches**
#
#
# * **Conclusion**

# %% [markdown]
# ### Requirements
#
# ---
#
# #### Software & Modules
#
# This tutorial assumes familiarity with the [Python](https://python.org) programming language throughout. Familiarity with basic REST API concepts and usage is also assumed.
#
# We'll be using a **"Jupyter Notebook"** (aka Python Notebook) to run through the examples.
# To learn more about and get started with using Jupyter, visit: [Jupyter](https://jupyter.org/) and [IPython](https://ipython.org/).
#
# For the best experience, download this notebook and run it on your system, and make sure to install the modules listed below first. You can also copy the examples' code to a separate Python files an run them directly with Python on your system if you prefer.
#
#
# Python modules used in this tutorial are:
# * [requests](http://docs.python-requests.org/)
# * [geojsonio](https://pypi.python.org/pypi/geojsonio)
#
#
# #### Planet API Key
#
# You should have an account on the Planet Platform to access the Data API. You may retrieve your API key from your [account page](https://www.planet.com/account/), or from the "API Tab" in [Planet Explorer](https://www.planet.com/explorer).

# %% [markdown]
# ### Useful links
#
# ---
#
# * [Planet Data API Reference & Documentation](https://www.planet.com/docs/reference/data-api/)
# * [Planet Explorer](https://www.planet.com/explorer)

# %% [markdown]
# ## Overview
#
# ---
#
# ### The Basic Workflow:
#
# 1. Search item types based on filters
# 1. Activate assets
# 1. Download assets

# %% [markdown]
# ### API Endpoints
#
# This tutorial will cover the following API ***endpoints***:
#
# * [`/item-types`](https://api.planet.com/data/v1/item-types/)
# * [`/asset-types`](https://api.planet.com/data/v1/asset-types/)
# * `/quick-search`
# * `/searches`
# * `/stats`
#
# There is an additional [`/spec`](https://api.planet.com/data/v1/spec) endpoint that publishes a [Swagger](http://swagger.io/) specification for the Data API.
#
# ### Exploring Endpoints
#
# We can start by exploring two endpoints using our browser.
#
# ##### What item types are available?
#
# https://api.planet.com/data/v1/item-types/
#
# ##### What assets are available?
#
# https://api.planet.com/data/v1/asset-types/

# %% [markdown]
# ***Note:*** *You may choose to install a helpful browser plugin called **JSONView** that formats JSON and makes it easier to read:*
#
# * [Chrome Extension](https://chrome.google.com/webstore/detail/jsonview/chklaanhfefbnpoihckbnefhakgolnmc)
# * [Firefox Plugin](https://addons.mozilla.org/en-us/firefox/addon/jsonview/)

# %% [markdown]
# ### Planet Explorer
# We can also use Planet Explorer to expose relevant API information for search results.
#
# In Planet Explorer, while in *Daily Imagery Mode* click on the *"Api"* button in the bottom left corner of the results panel.
#
# ![Planet Explorer Screenshot](images/planet-explorer.png)
#
# Here, you may access your API Key, selected item id's, and `cURL` request information containing filters and options.

# %% [markdown]
# ## Basic Setup
#
# ---
#
# Before interacting with the Planet Data API using Python, we will set up our environment with some useful modules and helper functions.
#
# * We'll configure *authentication* to the Planet Data API
# * We'll use the `requests` Python module to make HTTP communication easier.
# * We'll use the `json` Python module to help us work with JSON responses from the API.
# * We'll create a function called `p` that will print Python dictionaries nicely.
#
# Then we'll be ready to make our first call to the Planet API by hitting the base endpoint at `https://api.planet.com/data/v1`.
#
# Let's start by configuring authentication:

# %% [markdown]
# ### Authentication
#
# Authentication with the Planet Data API be achieved using a valid Planet **API key**.

# %% [markdown]
# You can *export* your API Key as an environment variable on your system:
#
# `export PL_API_KEY="YOUR API KEY HERE"`
#
# Or add the variable to your path, etc. If you are using our Docker environement, it will already be set.
#
# To start our Python code, we'll setup an API Key variable from an environment variable to use with our requests:

# %%
# Import the os module in order to access environment variables
import os

# If you're following along with this notebook, you can enter your API Key on the following line, and uncomment it:
#os.environ['PL_API_KEY']='YOUR API KEY HERE'

# Setup the API Key from the `PL_API_KEY` environment variable
PLANET_API_KEY = os.getenv('PL_API_KEY')

# %% [markdown]
# ### Helper Modules and Functions

# %%
# Import helper modules
import json
import requests

# %%
# Helper function to printformatted JSON using the json module
def p(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# ### Our First Request

# %%
# Setup Planet Data API base URL
URL = "https://api.planet.com/data/v1"

# Setup the session
session = requests.Session()

# Authenticate
session.auth = (PLANET_API_KEY, "")

# %%
# Make a GET request to the Planet Data API
res = session.get(URL)

# %% [markdown]
# Now we should get a response, hopefully it's a `200` code, saying everything is OK!

# %%
# Response status code
res.status_code
# Out:
# 200

# %%
# Response Body
res.text
# Out:
# '{"_links": {"_self": "https://api.planet.com/data/v1/", "asset-types": "https://api.planet.com/data/v1/asset-types/", "item-types": "https://api.planet.com/data/v1/item-types/", "spec": "https://api.planet.com/data/v1/spec"}}'

# %%
# Print formatted JSON response
p(res.json())
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/",
#     "asset-types": "https://api.planet.com/data/v1/asset-types/",
#     "item-types": "https://api.planet.com/data/v1/item-types/",
#     "spec": "https://api.planet.com/data/v1/spec"
#   }
# }

# %%
# Print the value of the item-types key from _links
print(res.json()["_links"]["item-types"])
# Out:
# https://api.planet.com/data/v1/item-types/

# %% [markdown]
# **Congratulations!** You just made your first request to the Planet Data API using Python!
#
# Now, let's take a look at how to access all that high cadence satellite imagery!

# %% [markdown]
# ## Search Mechanics & Filters
#
# ---
#
# There's a lot of data available on the Planet Data API and in order to find what we're looking for, we'll have to perform various types of searches.
#
# To construct a search, we use **filters** that let us limit results based on date, geography or other metadata properties.
#
# Using these filters, we are able to **search** for items or get **statistics** for search results.
#
# Let's first make a request to the `/stats` endpoint to understand how the filters work:

# %% [markdown]
# ### Statistics `/stats`
#
# ---
#
# The `/stats` endpoint provides a summary of the available data based on some search criteria.
#
# `https://api.planet.com/data/v1/stats`
#
# We'll need to send a ***`POST`*** request to `/stats`, let's start by setting up the request url:

# %%
# Setup the stats URL
stats_url = "{}/stats".format(URL)

# Print the stats URL
print(stats_url)
# Out:
# https://api.planet.com/data/v1/stats

# %% [markdown]
# ### Using a Search Filter
#
# Search filters should have the following properties:
#
# * **Type** (`type`) - The type of filter being used
# * **Configuration** (`config`) - The configuration for this filter
# * **Field Name** (`field_name`) - The field on which to filter
#
# For this example, let's use a filter to get some stats on what data is available for *Planet Scope (3 Band)* and *Rapid Eye (Ortho Tile)* products taken from 2013 until now:

# %%
# Specify the sensors/satellites or "item types" to include in our results
item_types = ["PSScene", "REOrthoTile"]

# %%
# Create filter object for all imagery captured between 2013-01-01 and present.
date_filter = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "gte": "2013-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

# %% [markdown]
# Depending on the filter type, some requests may need an `interval` field:
#
# The following intervals are possible:
# * `year`
# * `month`
# * `week`
# * `day`
# * `hour`
#
# An `interval` must be provided with the request so that the number of matching items can be aggregated. We'll use an interval with our date filter.

# %% [markdown]
# Now let's perform our request using the `date_filter` filter we created above:

# %%
# Construct the request.
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 3113815,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3608106,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8574067,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 41937290,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 216992475,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 289237977,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 229636054,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 226642335,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 211954906,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 37481995,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# ***Good Job!*** You've received a response from the API that contains some statistics like item counts for the search criteria!

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new date filter to find data from before 2013.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 
date_filter2 = {
}

request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter2
}

res = session.post(stats_url, json=request)
p(res.json())
# Out:
# {
#   "field": {
#     "filter.type": [
#       {
#         "message": "'type' is a required property"
#       }
#     ]
#   },
#   "general": []
# }

# %% [markdown]
# ---
#
# Next, let's take a closer look at some of the available filters:

# %% [markdown]
# ### Filter types
#
# The Planet Data API supports several filter types. The most common are the following:
#
# ### Field Filters
#
# * `DateRangeFilter`
# * `RangeFilter`
# * `StringInFilter`
# * `PermissionFilter`
# * `GeometryFilter`
#
# ### Logical Filters
#
# * `NotFilter`
# * `AndFilter`
# * `OrFilter`
#
# More information and examples on filter types can be found at the [API Docs](https://www.planet.com/docs/reference/data-api/search-api/).
#
# ---
#
# ### (Field) Filter Type examples:

# %% [markdown]
# #### `DateRangeFilter`
#
# Find imagery that was `acquired` or `published` before, after or between certain dates.
#
# ```
# {
#   "type": "DateRangeFilter",
#   "field_name": "acquired",
#   "config": {
#     "gt": "2016-01-01T00:00:00Z",
#     "lte": "2016-03-01T00:00:00Z"
#   }
# }
# ```
#
# The upper or lower bound may be omitted.

# %% [markdown]
# #### `RangeFilter`
#
# Find imagery that has a metadata that matches a number within a range of numbers.
#
# ```
# {
#   "type": "RangeFilter",
#   "field_name": "cloud_cover",
#   "config": {
#     "lt": 0.2,
#     "gt": 0.1
#   }
# }
# ```

# %% [markdown]
# The following **operators** are supported by the Data API's `DateRangeFilter` and `RangeFilter`:
# * `gt`: Greater Than
# * `gte`: Greater Than or Equal To
# * `lt`: Less Than
# * `lte`: Less Than or Equal To

# %% [markdown]
# #### `StringInFilter`
#
# Find imagery that has a metadata that matches a string within the array of provided strings.
#
#
# ```
# {
#   "type": "StringInFilter",
#   "field_name": "instrument",
#   "config": ["PS2"]
# }
# ```

# %% [markdown]
# #### `PermissionFilter`
#
# Find data which has assets that are accessible by the user.
#
# ```
# {
#   "type": "PermissionFilter",
#   "config": ["assets.analytic:download"]
# }
# ```
#
# ***Note:*** `assets:download` means *any* downloadable asset.

# %% [markdown]
# #### `GeometryFilter`
#
# Find data contained within a given geometry. The filter's config value may be any valid GeoJSON object.
#
# ```
# {
#   "type": "GeometryFilter",
#   "field_name": "geometry",
#   "config": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ]
#       ]
#     ]
#   }
# }
# ```
#
# A few quick ways to get a GeoJSON geometry to use in your search:
#
# * Draw an Area of Interst (AOI) in [Planet Explorer](http://planet.com/explorer), and use the API button to see the geometry filter config.
# * Use your favorite GIS tools like [Quantum GIS (QGIS)](http://www.qgis.org) and export GeoJSON.
# * Draw a polygon in [GeoJSON.io](http://geojson.io).
#
# Make sure the `config` property in the geometry filter is in the right format, which should be similar to a `feature` property in a GeoJSON object.

# %% [markdown]
# ---
#
# Let's try a few more requests and get some more stats, this time using different filters:

# %%
# Search for imagery only from PlanetScope satellites that have a PS2 telescope

# Setup item types
item_types = ["PSScene"]

# Setup a filter for instrument type
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 1547749,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 34319610,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 212862822,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 286265252,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 212734523,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 192168135,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 137402181,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 19088864,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new filter that finds all data from PS0 or PS1 telescopes.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 

instrument_filter2 = {
}
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter2
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "field": {
#     "filter.type": [
#       {
#         "message": "'type' is a required property"
#       }
#     ]
#   },
#   "general": []
# }

# %% [markdown]
# Find a GeoJSON geometry from http://geojson.io and copy one `feature`.

# %%
# Search for imagery that only intersects with 40N, 90W

# Setup GeoJSON 
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup Geometry Filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : geometry_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 6,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 4,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 46,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 176,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 302,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 305,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 349,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 484,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 87,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# ### Complex Queries using Logical Filters
#
# Complex queries may require combining field filters using **logical filters** (see Filter Types above).
#
# Let's try a complex stats search:

# %%
# PS2 imagery; over 40N, 90W; captured between 2013 and present

# Setup an "AND" logical filter
and_filter = {
    "type": "AndFilter",
    "config": [instrument_filter, geometry_filter, date_filter]
}

# Print the logical filter
p(and_filter)
# Out:
# {
#   "type": "AndFilter",
#   "config": [
#     {
#       "type": "StringInFilter",
#       "field_name": "instrument",
#       "config": [
#         "PS2"
#       ]
#     },
#     {
#       "type": "GeometryFilter",
#       "field_name": "geometry",
#       "config": {
#         "type": "Point",
#         "coordinates": [
#           -90,
#           40
#         ]
#       }
#     },
#     {
#       "type": "DateRangeFilter",
#       "field_name": "acquired",
#       "config": {
#         "gte": "2013-01-01T00:00:00.000Z"
#       }
#     }
#   ]
# }

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : and_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 1,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 45,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 176,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 302,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 253,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 204,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 147,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 23,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# Here's another complex search query example using a "Not" logical filter and "string in" field filter. Can you tell what it's requesting?

# %%
# Setup Item Types
item_types = ["PSScene"]

# Setup Instrument Filter
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# Setup "not" Logical Filter
not_filter = {
    "type": "NotFilter",
    "config": instrument_filter
}

# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : not_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 465217,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3574799,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3836405,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 833,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 0,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 14224704,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 34126430,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 74552725,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 18394850,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# Now that you're comfortable working with **filters**, let's take a look at how to perform searches!

# %% [markdown]
# ## Searching for Items
#
# ---
#
# There are two types of searches:
# * **"Quick Search"** `/quick-search`
# * **"Saved Searches"** `/searches`
#
# Saved searches are retained on the Planet Platform and may be performed again at any time in the future. You can use these to setup efficient workflows for repetitive tasks, for example, querying an area that is of interest to you, or getting data for specific sensors.
#
# Quick searches are meant to be more fleeting, and are not guaranteed to be available on the API after they are executed.
#
# Searches use the same request format as the `/stats` endpoint except without the `interval` field.

# %% [markdown]
# ### Quick Search
#
# Let's dive right in and create our first `quick search`:

# %%
# Setup the quick search endpoint url
quick_url = "{}/quick-search".format(URL)

# %%
# Setup Item Types
item_types = ["PSScene"]

# Setup GeoJSON for only imagery that intersects with 40N, 90W
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup a geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/c89a4da50b5a4fcc81ed7960564d2949/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/c89a4da50b5a4fcc81ed7960564d2949/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIxLTA4LTI2VDIzOjQ0OjM4LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjEwODI2XzE2MjYzMl8xMDAzIiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#     "_self": "https://api.planet.com/data/v1/searches/c89a4da50b5a4fcc81ed7960564d2949/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220321_172556_67_1064",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220321_172556_67_1064/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220321_172556_67_1064/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.2128978861248,
#               40.06927378363654
#             ],
#             [
#               -90.25222261906615,
#               39.92771486131101
#             ],
#             [
#               -89.97658725109696,
#               39.88222239963637
#             ],
#             [
#               -89.93681775400017,
#               40.02325956199968
#             ],
#             [
#               -90.2128978861248,
#               40.06927378363654
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220321_172556_67_1064",
#       "properties": {
#         "acquired": "2022-03-21T17:25:56.671881Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 99,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-22T02:57:13Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 102.9,
#         "satellite_id": "1064",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5507142",
#         "sun_azimuth": 164.3,
#         "sun_elevation": 49.5,
#         "updated": "2022-03-23T08:50:09Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 99,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220321_172555_17_1064",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220321_172555_17_1064/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220321_172555_17_1064/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.18685801451109,
#               40.163447100961726
#             ],
#             [
#               -90.2262444114857,
#               40.021896549552444
#             ],
#             [
#               -89.9501984712591,
#               39.976408394126075
#             ],
#             [
#               -89.91040300995991,
#               40.117446873306726
#             ],
#             [
#               -90.18685801451109,
#               40.163447100961726
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220321_172555_17_1064",
#       "properties": {
#         "acquired": "2022-03-21T17:25:55.171893Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 100,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-22T02:57:13Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 102.6,
#         "satellite_id": "1064",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5507142",
#         "sun_azimuth": 164.4,
#         "sun_elevation": 49.4,
#         "updated": "2022-03-23T08:50:09Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 100,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220212_162353_03_24a5",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220212_162353_03_24a5/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220212_162353_03_24a5/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.04165829302251,
#               40.08752587158529
#             ],
#             [
#               -90.09539499372633,
#               39.89893416176037
#             ],
#             [
#               -89.6862225461983,
#               39.82939894923311
#             ],
#             [
#               -89.63203082314824,
#               40.01692517036894
#             ],
#             [
#               -90.04165829302251,
#               40.08752587158529
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220212_162353_03_24a5",
#       "properties": {
#         "acquired": "2022-02-12T16:23:53.032369Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 53,
#         "clear_percent": 3,
#         "cloud_cover": 0.96,
#         "cloud_percent": 96,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-21T17:09:14Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 103,
#         "satellite_id": "24a5",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "5387070",
#         "sun_azimuth": 148.9,
#         "sun_elevation": 30.9,
#         "updated": "2022-03-21T17:09:14Z",
#         "view_angle": 3,
#         "visible_confidence_percent": 54,
#         "visible_percent": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220317_155301_05_2449",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220317_155301_05_2449/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220317_155301_05_2449/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.31503434982447,
#               40.10133201728915
#             ],
#             [
#               -90.3697127908707,
#               39.91112242037044
#             ],
#             [
#               -89.95714814484852,
#               39.84041403985713
#             ],
#             [
#               -89.90146824790686,
#               40.02980297076697
#             ],
#             [
#               -90.31503434982447,
#               40.10133201728915
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220317_155301_05_2449",
#       "properties": {
#         "acquired": "2022-03-17T15:53:01.05381Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 71,
#         "clear_percent": 18,
#         "cloud_cover": 0.38,
#         "cloud_percent": 10,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 29,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 43,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-19T00:27:27Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 105.7,
#         "satellite_id": "2449",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5495794",
#         "sun_azimuth": 134.6,
#         "sun_elevation": 38.6,
#         "updated": "2022-03-19T05:45:07Z",
#         "view_angle": 1.2,
#         "visible_confidence_percent": 61,
#         "visible_percent": 62
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220317_155258_75_2449",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220317_155258_75_2449/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220317_155258_75_2449/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.27479688858895,
#               40.24487651184861
#             ],
#             [
#               -90.32972163591562,
#               40.05471846782168
#             ],
#             [
#               -89.91629280644841,
#               39.983912278959515
#             ],
#             [
#               -89.86031833764036,
#               40.1732320986506
#             ],
#             [
#               -90.27479688858895,
#               40.24487651184861
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220317_155258_75_2449",
#       "properties": {
#         "acquired": "2022-03-17T15:52:58.755411Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 73,
#         "clear_percent": 56,
#         "cloud_cover": 0.05,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 5,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 39,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-19T00:27:20Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 106.1,
#         "satellite_id": "2449",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5495794",
#         "sun_azimuth": 134.7,
#         "sun_elevation": 38.5,
#         "updated": "2022-03-19T05:45:08Z",
#         "view_angle": 1.1,
#         "visible_confidence_percent": 61,
#         "visible_percent": 95
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220316_161925_1025",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220316_161925_1025/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220316_161925_1025/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_3b:download",
#         "assets.ortho_analytic_3b_xml:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_udm2",
#         "ortho_analytic_3b",
#         "ortho_analytic_3b_xml",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.07197295206214,
#               40.05773108986116
#             ],
#             [
#               -90.0914475665363,
#               39.98723990167564
#             ],
#             [
#               -89.8079092163807,
#               39.94154557877202
#             ],
#             [
#               -89.78874557255295,
#               40.01195271136214
#             ],
#             [
#               -90.07197295206214,
#               40.05773108986116
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220316_161925_1025",
#       "properties": {
#         "acquired": "2022-03-16T16:19:25.479545Z",
#         "anomalous_pixels": 0.08,
#         "clear_confidence_percent": 79,
#         "clear_percent": 11,
#         "cloud_cover": 0.86,
#         "cloud_percent": 86,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-18T01:32:45Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 101.5,
#         "satellite_id": "1025",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "5492299",
#         "sun_azimuth": 142.7,
#         "sun_elevation": 41.8,
#         "updated": "2022-03-18T09:58:03Z",
#         "view_angle": 3.9,
#         "visible_confidence_percent": 74,
#         "visible_percent": 14
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220317_162239_1035",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220317_162239_1035/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220317_162239_1035/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_3b:download",
#         "assets.ortho_analytic_3b_xml:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_udm2",
#         "ortho_analytic_3b",
#         "ortho_analytic_3b_xml",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.04220900231397,
#               40.07275203686929
#             ],
#             [
#               -90.06221415154036,
#               40.003049910732315
#             ],
#             [
#               -89.77960901226298,
#               39.955495466833646
#             ],
#             [
#               -89.75984711882599,
#               40.02538563331459
#             ],
#             [
#               -90.04220900231397,
#               40.07275203686929
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220317_162239_1035",
#       "properties": {
#         "acquired": "2022-03-17T16:22:39.524019Z",
#         "anomalous_pixels": 0.09,
#         "clear_confidence_percent": 60,
#         "clear_percent": 18,
#         "cloud_cover": 0.28,
#         "cloud_percent": 13,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 16,
#         "instrument": "PS2",
#         "item_type": "PSScene",
#         "light_haze_percent": 54,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-18T00:22:23Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 275,
#         "satellite_id": "1035",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5495170",
#         "sun_azimuth": 142.9,
#         "sun_elevation": 42.3,
#         "updated": "2022-03-18T06:54:22Z",
#         "view_angle": 2,
#         "visible_confidence_percent": 54,
#         "visible_percent": 72
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220317_162240_1035",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220317_162240_1035/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220317_162240_1035/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_3b:download",
#         "assets.ortho_analytic_3b_xml:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_udm2",
#         "ortho_analytic_3b",
#         "ortho_analytic_3b_xml",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.05999173093919,
#               40.01058394873063
#             ],
#             [
#               -90.0799387065315,
#               39.94087178967972
#             ],
#             [
#               -89.7976327987168,
#               39.89334082872165
#             ],
#             [
#               -89.77785481071115,
#               39.96323176286259
#             ],
#             [
#               -90.05999173093919,
#               40.01058394873063
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220317_162240_1035",
#       "properties": {
#         "acquired": "2022-03-17T16:22:40.507584Z",
#         "anomalous_pixels": 0.09,
#         "clear_confidence_percent": 56,
#         "clear_percent": 22,
#         "cloud_cover": 0.42,
#         "cloud_percent": 16,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 26,
#         "instrument": "PS2",
#         "item_type": "PSScene",
#         "light_haze_percent": 35,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-17T23:53:33Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 274.7,
#         "satellite_id": "1035",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5495170",
#         "sun_azimuth": 142.9,
#         "sun_elevation": 42.3,
#         "updated": "2022-03-18T06:54:22Z",
#         "view_angle": 2,
#         "visible_confidence_percent": 51,
#         "visible_percent": 58
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220315_162247_80_247f",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220315_162247_80_247f/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220315_162247_80_247f/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
# ...
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210827_162741_1038/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_3b:download",
#         "assets.ortho_analytic_3b_xml:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_udm2",
#         "ortho_analytic_3b",
#         "ortho_analytic_3b_xml",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.09293676343404,
#               40.03598699805142
#             ],
#             [
#               -90.11371564398621,
#               39.9643063540531
#             ],
#             [
#               -89.8244691175807,
#               39.915115965782554
#             ],
#             [
#               -89.8038643153091,
#               39.98712993227014
#             ],
#             [
#               -90.09293676343404,
#               40.03598699805142
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20210827_162741_1038",
#       "properties": {
#         "acquired": "2021-08-27T16:27:41.962674Z",
#         "anomalous_pixels": 0.09,
#         "clear_confidence_percent": 99,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-08-27T22:35:56Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.4,
#         "satellite_id": "1038",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "4840419",
#         "sun_azimuth": 138.5,
#         "sun_elevation": 53.2,
#         "updated": "2021-08-28T04:51:16Z",
#         "view_angle": 4.1,
#         "visible_confidence_percent": 99,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210826_160155_83_106c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210826_160155_83_106c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210826_160155_83_106c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.27130504846141,
#               40.021471299553575
#             ],
#             [
#               -90.22931255186745,
#               39.87808809101259
#             ],
#             [
#               -89.94954637384369,
#               39.926363133718056
#             ],
#             [
#               -89.99069633047768,
#               40.069156890170646
#             ],
#             [
#               -90.27130504846141,
#               40.021471299553575
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20210826_160155_83_106c",
#       "properties": {
#         "acquired": "2021-08-26T16:01:55.839771Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 100,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-08-27T04:52:36Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 82.4,
#         "satellite_id": "106c",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "4838201",
#         "sun_azimuth": 130.5,
#         "sun_elevation": 50.3,
#         "updated": "2021-11-10T06:13:04Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 100,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210826_162632_1003",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210826_162632_1003/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210826_162632_1003/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_3b:download",
#         "assets.ortho_analytic_3b_xml:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_udm2",
#         "ortho_analytic_3b",
#         "ortho_analytic_3b_xml",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.19157835986583,
#               40.06558554724621
#             ],
#             [
#               -90.21238130188439,
#               39.99444951970508
#             ],
#             [
#               -89.92471766252825,
#               39.94525210404674
#             ],
#             [
#               -89.90405008237975,
#               40.01677839401488
#             ],
#             [
#               -90.19157835986583,
#               40.06558554724621
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20210826_162632_1003",
#       "properties": {
#         "acquired": "2021-08-26T16:26:32.15786Z",
#         "anomalous_pixels": 0.08,
#         "clear_confidence_percent": 99,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PS2",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-08-26T23:44:38Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.8,
#         "satellite_id": "1003",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "4837548",
#         "sun_azimuth": 137.4,
#         "sun_elevation": 53.2,
#         "updated": "2021-08-27T07:31:13Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 84,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Nice! The response gives us search results for Planet Scope (4 Band) for a specific area.
#
# Let's do another search, this time using the "not" filter we setup earlier:

# %%
# Setup Item Types
item_types = ["PSScene"]

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : not_filter
}

# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/9a0ae3f06a214037a15290f604d1ad7c/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/9a0ae3f06a214037a15290f604d1ad7c/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIyLTAzLTI1VDIxOjAxOjEzLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjIwMzI1XzA5MTMwMV84Nl8yNDQ3IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#     "_self": "https://api.planet.com/data/v1/searches/9a0ae3f06a214037a15290f604d1ad7c/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220311_142917_63_247b",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220311_142917_63_247b/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220311_142917_63_247b/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -70.69791668546402,
#               -26.978725182710438
#             ],
#             [
#               -70.74272045849698,
#               -27.174471016638787
#             ],
#             [
#               -70.37407556631322,
#               -27.24245365811799
#             ],
#             [
#               -70.33031065627358,
#               -27.045698650556712
#             ],
#             [
#               -70.69791668546402,
#               -26.978725182710438
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220311_142917_63_247b",
#       "properties": {
#         "acquired": "2022-03-11T14:29:17.630123Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 97,
#         "clear_percent": 68,
#         "cloud_cover": 0.32,
#         "cloud_percent": 32,
#         "ground_control": true,
#         "gsd": 4.2,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:03:52Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 0,
#         "satellite_id": "247b",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "5498153",
#         "sun_azimuth": 62.2,
#         "sun_elevation": 48.2,
#         "updated": "2022-03-25T21:03:52Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 74,
#         "visible_percent": 68
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_080816_65_2484",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_080816_65_2484/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220325_080816_65_2484/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               29.00561233173192,
#               5.508193827635261
#             ],
#             [
#               28.966852366826416,
#               5.3155963743444055
#             ],
#             [
#               29.290626744837454,
#               5.249220955132553
#             ],
#             [
#               29.330335130631266,
#               5.443066315283854
#             ],
#             [
#               29.00561233173192,
#               5.508193827635261
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220325_080816_65_2484",
#       "properties": {
#         "acquired": "2022-03-25T08:08:16.656492Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 60,
#         "clear_percent": 56,
#         "cloud_cover": 0.32,
#         "cloud_percent": 26,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 6,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 11,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:03:51Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "satellite_azimuth": 277.6,
#         "satellite_id": "2484",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "5515986",
#         "sun_azimuth": 95.5,
#         "sun_elevation": 59.2,
#         "updated": "2022-03-25T21:03:51Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 57,
#         "visible_percent": 68
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_080821_27_2484",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_080821_27_2484/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220325_080821_27_2484/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               28.947751545236688,
#               5.218109044912568
#             ],
#             [
#               28.90894190955855,
#               5.025862348895485
#             ],
#             [
#               29.23302656365324,
#               4.957572005376174
#             ],
#             [
#               29.27210667558867,
#               5.150993199817096
#             ],
#             [
#               28.947751545236688,
#               5.218109044912568
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220325_080821_27_2484",
#       "properties": {
#         "acquired": "2022-03-25T08:08:21.275656Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 45,
#         "clear_percent": 11,
#         "cloud_cover": 0.67,
#         "cloud_percent": 48,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 19,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 21,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:03:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.5,
#         "satellite_id": "2484",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "5515986",
#         "sun_azimuth": 95,
#         "sun_elevation": 59.2,
#         "updated": "2022-03-25T21:03:50Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 54,
#         "visible_percent": 33
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220323_175058_75_2484",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220323_175058_75_2484/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220323_175058_75_2484/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -108.03500228843055,
#               51.94907171124168
#             ],
#             [
#               -108.11493001800461,
#               51.75882443189843
#             ],
#             [
#               -107.60292286511253,
#               51.67522236869578
#             ],
#             [
#               -107.52130088180152,
#               51.86562581094926
#             ],
#             [
#               -108.03500228843055,
#               51.94907171124168
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220323_175058_75_2484",
#       "properties": {
#         "acquired": "2022-03-23T17:50:58.752283Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 61,
#         "clear_percent": 41,
#         "cloud_cover": 0.01,
#         "cloud_percent": 1,
#         "ground_control": false,
#         "gsd": 4.1,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 8,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:03:46Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "satellite_azimuth": 277.3,
#         "satellite_id": "2484",
#         "shadow_percent": 0,
#         "snow_ice_percent": 50,
#         "strip_id": "5516408",
#         "sun_azimuth": 152.4,
#         "sun_elevation": 36.2,
#         "updated": "2022-03-25T21:03:46Z",
#         "view_angle": 2,
#         "visible_confidence_percent": 55,
#         "visible_percent": 99
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220323_175103_37_2484",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220323_175103_37_2484/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220323_175103_37_2484/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_sr",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -108.15318927430626,
#               51.66508735803024
#             ],
#             [
#               -108.2321673007848,
#               51.47518777752146
#             ],
#             [
#               -107.72267340583605,
#               51.3919796089251
#             ],
#             [
#               -107.64119564357284,
#               51.581885029052884
#             ],
#             [
#               -108.15318927430626,
#               51.66508735803024
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220323_175103_37_2484",
#       "properties": {
#         "acquired": "2022-03-23T17:51:03.375165Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 49,
#         "clear_percent": 12,
#         "cloud_cover": 0.12,
#         "cloud_percent": 12,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 12,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:03:40Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.5,
#         "satellite_id": "2484",
#         "shadow_percent": 0,
#         "snow_ice_percent": 64,
#         "strip_id": "5516408",
#         "sun_azimuth": 152.2,
#         "sun_elevation": 36.4,
#         "updated": "2022-03-25T21:03:40Z",
#         "view_angle": 2,
#         "visible_confidence_percent": 57,
#         "visible_percent": 88
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_031524_18_247f",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_031524_18_247f/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220325_031524_18_247f/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               110.63803719014689,
#               50.888716995710425
#             ],
#             [
#               110.5620095971825,
#               50.69935056266204
#             ],
#             [
#               111.06160631771225,
#               50.617177447372455
#             ],
#             [
#               111.13989970114324,
#               50.80669321860169
#             ],
#             [
#               110.63803719014689,
#               50.888716995710425
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220325_031524_18_247f",
#       "properties": {
#         "acquired": "2022-03-25T03:15:24.180878Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 30,
#         "clear_percent": 8,
#         "cloud_cover": 0.82,
#         "cloud_percent": 82,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 2,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:03:35Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.5,
#         "satellite_id": "247f",
#         "shadow_percent": 0,
#         "snow_ice_percent": 8,
#         "strip_id": "5516397",
#         "sun_azimuth": 151.5,
#         "sun_elevation": 37.5,
#         "updated": "2022-03-25T21:03:35Z",
#         "view_angle": 3.1,
#         "visible_confidence_percent": 43,
#         "visible_percent": 18
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_031519_54_247f",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_031519_54_247f/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220325_031519_54_247f/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               110.7537438303508,
#               51.17451792624546
#             ],
#             [
#               110.67675941297057,
#               50.98507089639247
#             ],
#             [
#               111.17918531110205,
#               50.90260994319337
#             ],
#             [
#               111.25837029557661,
#               51.092089631278206
#             ],
#             [
#               110.7537438303508,
#               51.17451792624546
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220325_031519_54_247f",
#       "properties": {
#         "acquired": "2022-03-25T03:15:19.54825Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 47,
#         "clear_percent": 6,
#         "cloud_cover": 0.14,
#         "cloud_percent": 14,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:03:35Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.6,
#         "satellite_id": "247f",
#         "shadow_percent": 3,
#         "snow_ice_percent": 77,
#         "strip_id": "5516397",
#         "sun_azimuth": 151.8,
#         "sun_elevation": 37.3,
#         "updated": "2022-03-25T21:03:35Z",
#         "view_angle": 3.1,
#         "visible_confidence_percent": 55,
#         "visible_percent": 86
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_031528_81_247f",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_031528_81_247f/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220325_031528_81_247f/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               110.52330796605341,
#               50.60348114520896
#             ],
#             [
#               110.44794078911877,
#               50.41401981396378
#             ],
#             [
#               110.94459054842943,
#               50.33215123240843
#             ],
#             [
#               111.022394037614,
#               50.521743719781405
#             ],
#             [
#               110.52330796605341,
#               50.60348114520896
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220325_031528_81_247f",
#       "properties": {
#         "acquired": "2022-03-25T03:15:28.813506Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 32,
#         "clear_percent": 7,
#         "cloud_cover": 0.71,
#         "cloud_percent": 71,
#         "ground_control": true,
#         "gsd": 4.1,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:03:34Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.9,
#         "satellite_id": "247f",
#         "shadow_percent": 1,
#         "snow_ice_percent": 20,
#         "strip_id": "5516397",
#         "sun_azimuth": 151.3,
#         "sun_elevation": 37.8,
#         "updated": "2022-03-25T21:03:34Z",
#         "view_angle": 3.1,
#         "visible_confidence_percent": 45,
#         "visible_percent": 29
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220324_092146_33_2407",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220324_092146_33_2407/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220324_092146_33_2407/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_sr:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
# ...
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               5.025467188077381,
#               13.682202177777606
#             ],
#             [
#               4.987118619856014,
#               13.49415724563327
#             ],
#             [
#               5.308239351836664,
#               13.431554618955904
#             ],
#             [
#               5.3467173345289725,
#               13.618645238450224
#             ],
#             [
#               5.025467188077381,
#               13.682202177777606
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220325_091327_13_2447",
#       "properties": {
#         "acquired": "2022-03-25T09:13:27.133303Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 44,
#         "clear_percent": 19,
#         "cloud_cover": 0.41,
#         "cloud_percent": 40,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 2,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 38,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:01:13Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "satellite_azimuth": 99.1,
#         "satellite_id": "2447",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "5517083",
#         "sun_azimuth": 104,
#         "sun_elevation": 50.9,
#         "updated": "2022-03-25T21:01:13Z",
#         "view_angle": 2,
#         "visible_confidence_percent": 50,
#         "visible_percent": 59
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_091304_15_2447",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_091304_15_2447/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220325_091304_15_2447/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               5.3188209835230635,
#               15.130449001632906
#             ],
#             [
#               5.28012008564597,
#               14.942456305946003
#             ],
#             [
#               5.603158555461185,
#               14.87966643434195
#             ],
#             [
#               5.642206585293283,
#               15.066598166591511
#             ],
#             [
#               5.3188209835230635,
#               15.130449001632906
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220325_091304_15_2447",
#       "properties": {
#         "acquired": "2022-03-25T09:13:04.159716Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 34,
#         "clear_percent": 0,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 98,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:01:13Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "satellite_azimuth": 99.7,
#         "satellite_id": "2447",
#         "shadow_percent": 0,
#         "snow_ice_percent": 1,
#         "strip_id": "5517083",
#         "sun_azimuth": 105.8,
#         "sun_elevation": 50.7,
#         "updated": "2022-03-25T21:01:13Z",
#         "view_angle": 2,
#         "visible_confidence_percent": 47,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_091301_86_2447",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220325_091301_86_2447/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220325_091301_86_2447/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download",
#         "assets.ps3b_analytic:download",
#         "assets.ps3b_analytic_dn:download",
#         "assets.ps3b_analytic_dn_xml:download",
#         "assets.ps3b_analytic_xml:download",
#         "assets.ps3b_basic_analytic:download",
#         "assets.ps3b_basic_analytic_dn:download",
#         "assets.ps3b_basic_analytic_dn_rpc:download",
#         "assets.ps3b_basic_analytic_dn_xml:download",
#         "assets.ps3b_basic_analytic_rpc:download",
#         "assets.ps3b_basic_analytic_xml:download",
#         "assets.ps3b_basic_udm:download",
#         "assets.ps3b_udm:download",
#         "assets.ps3b_visual_xml:download",
#         "assets.ps4b_analytic:download",
#         "assets.ps4b_analytic_dn:download",
#         "assets.ps4b_analytic_dn_xml:download",
#         "assets.ps4b_analytic_xml:download",
#         "assets.ps4b_basic_analytic:download",
#         "assets.ps4b_basic_analytic_dn:download",
#         "assets.ps4b_basic_analytic_dn_nitf:download",
#         "assets.ps4b_basic_analytic_dn_rpc:download",
#         "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_dn_xml:download",
#         "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#         "assets.ps4b_basic_analytic_nitf:download",
#         "assets.ps4b_basic_analytic_rpc:download",
#         "assets.ps4b_basic_analytic_rpc_nitf:download",
#         "assets.ps4b_basic_analytic_xml:download",
#         "assets.ps4b_basic_analytic_xml_nitf:download",
#         "assets.ps4b_basic_udm:download",
#         "assets.ps4b_udm:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual",
#         "ps3b_analytic",
#         "ps3b_analytic_dn",
#         "ps3b_analytic_dn_xml",
#         "ps3b_analytic_xml",
#         "ps3b_basic_analytic",
#         "ps3b_basic_analytic_dn",
#         "ps3b_basic_analytic_dn_rpc",
#         "ps3b_basic_analytic_dn_xml",
#         "ps3b_basic_analytic_rpc",
#         "ps3b_basic_analytic_xml",
#         "ps3b_basic_udm",
#         "ps3b_udm",
#         "ps3b_visual_xml",
#         "ps4b_analytic",
#         "ps4b_analytic_dn",
#         "ps4b_analytic_dn_xml",
#         "ps4b_analytic_xml",
#         "ps4b_basic_analytic",
#         "ps4b_basic_analytic_dn",
#         "ps4b_basic_analytic_dn_nitf",
#         "ps4b_basic_analytic_dn_rpc",
#         "ps4b_basic_analytic_dn_rpc_nitf",
#         "ps4b_basic_analytic_dn_xml",
#         "ps4b_basic_analytic_dn_xml_nitf",
#         "ps4b_basic_analytic_nitf",
#         "ps4b_basic_analytic_rpc",
#         "ps4b_basic_analytic_rpc_nitf",
#         "ps4b_basic_analytic_xml",
#         "ps4b_basic_analytic_xml_nitf",
#         "ps4b_basic_udm",
#         "ps4b_udm"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               5.348175271485409,
#               15.275470577374733
#             ],
#             [
#               5.309421369443316,
#               15.08744952633488
#             ],
#             [
#               5.6327075527361306,
#               15.024647786423072
#             ],
#             [
#               5.67174107360963,
#               15.211632214766004
#             ],
#             [
#               5.348175271485409,
#               15.275470577374733
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20220325_091301_86_2447",
#       "properties": {
#         "acquired": "2022-03-25T09:13:01.862357Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 38,
#         "clear_percent": 0,
#         "cloud_cover": 0.03,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 4,
#         "heavy_haze_percent": 3,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 94,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2022-03-25T21:01:13Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "satellite_azimuth": 99.9,
#         "satellite_id": "2447",
#         "shadow_percent": 0,
#         "snow_ice_percent": 2,
#         "strip_id": "5517083",
#         "sun_azimuth": 106,
#         "sun_elevation": 50.6,
#         "updated": "2022-03-25T21:01:13Z",
#         "view_angle": 2,
#         "visible_confidence_percent": 47,
#         "visible_percent": 97
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Let's take a closer look at our response data:

# %%
# Assign a features variable 
features = geojson["features"]

# Get the number of features present in the response
len(features)
# Out:
# 250

# %%
# Loop over all the features from the response
for f in features:
    # Print the ID for each feature
    p(f["id"])
# Out:
# "20220311_142917_63_247b"
# "20220325_080816_65_2484"
# "20220325_080821_27_2484"
# "20220323_175058_75_2484"
# "20220323_175103_37_2484"
# "20220325_031524_18_247f"
# "20220325_031519_54_247f"
# "20220325_031528_81_247f"
# "20220324_092146_33_2407"
# "20220325_031521_86_247f"
# "20220324_090756_38_2407"
# "20220324_091912_72_2407"
# "20220324_090036_19_2407"
# "20220324_092148_62_2407"
# "20220325_052751_48_2424"
# "20220325_052746_88_2424"
# "20220325_053954_49_2424"
# "20220325_052723_85_2424"
# "20220325_052705_43_2424"
# "20220324_091917_31_2407"
# "20220324_090839_94_2407"
# "20220324_090800_97_2407"
# "20220325_053738_63_2424"
# "20220325_053436_73_2424"
# "20220325_052749_18_2424"
# "20220325_052739_97_2424"
# "20220325_052733_06_2424"
# "20220325_052716_94_2424"
# "20220325_102631_27_2485"
# "20220325_102419_04_2485"
# "20220325_052756_09_2424"
# "20220325_052742_27_2424"
# "20220325_052735_36_2424"
# "20220325_052700_83_2424"
# "20220325_052656_22_2424"
# "20220323_144138_10_2484"
# "20220323_144135_79_2484"
# "20220323_144133_48_2484"
# "20220325_053959_09_2424"
# "20220325_053734_03_2424"
# "20220325_052728_46_2424"
# "20220325_052710_04_2424"
# "20220325_052703_13_2424"
# "20220325_053956_79_2424"
# "20220325_053439_03_2424"
# "20220325_052800_69_2424"
# "20220325_052744_57_2424"
# "20220325_052721_55_2424"
# "20220325_052719_25_2424"
# "20220324_233705_72_249b"
# "20220325_054006_00_2424"
# "20220325_054003_70_2424"
# "20220325_054001_39_2424"
# "20220325_052802_99_2424"
# "20220325_052753_78_2424"
# "20220325_052737_67_2424"
# "20220325_052707_73_2424"
# "20220325_053740_94_2424"
# "20220325_053736_33_2424"
# "20220325_052730_76_2424"
# "20220324_095449_96_2484"
# "20220324_095452_27_2484"
# "20220324_095445_34_2484"
# "20220324_095443_03_2484"
# "20220324_095456_89_2484"
# "20220325_094227_99_2473"
# "20220325_094223_35_2473"
# "20220325_094221_04_2473"
# "20220323_081317_91_2440"
# "20220323_080932_82_2440"
# "20220323_080930_52_2440"
# "20220325_094300_40_2473"
# "20220325_094225_67_2473"
# "20220323_081315_61_2440"
# "20220323_080928_23_2440"
# "20220324_142709_34_2457"
# "20220324_142711_64_2457"
# "20220324_142704_75_2457"
# "20220324_142707_05_2457"
# "20220324_152001_55_2478"
# "20220324_151938_35_2478"
# "20220324_151936_03_2478"
# "20220324_151728_41_2478"
# "20220324_151714_49_2478"
# "20220324_151635_05_2478"
# "20220324_151541_68_2478"
# "20220324_151539_36_2478"
# "20220324_151537_04_2478"
# "20220324_150830_10_2478"
# "20220324_151721_45_2478"
# "20220324_151716_81_2478"
# "20220324_151655_93_2478"
# "20220324_151653_61_2478"
# "20220324_151651_29_2478"
# "20220324_151642_01_2478"
# "20220324_151553_28_2478"
# "20220324_151550_96_2478"
# "20220324_150834_74_2478"
# "20220324_151959_23_2478"
# "20220324_151956_91_2478"
# "20220324_151954_59_2478"
# "20220324_151933_71_2478"
# "20220324_151931_39_2478"
# "20220324_151929_07_2478"
# "20220324_151723_77_2478"
# "20220324_151646_65_2478"
# "20220324_151544_00_2478"
# "20220324_151726_09_2478"
# "20220325_101721_06_2489"
# "20220325_021445_52_2451"
# "20220325_022136_75_2451"
# "20220325_022134_45_2451"
# "20220325_021443_22_2451"
# "20220325_003157_91_2455"
# "20220325_003055_88_2455"
# "20220325_003039_80_2455"
# "20220325_003028_31_2455"
# "20220325_002801_28_2455"
# "20220325_002736_01_2455"
# "20220325_003241_56_2455"
# "20220325_003239_26_2455"
# "20220325_003137_23_2455"
# "20220325_003128_05_2455"
# "20220325_003102_77_2455"
# "20220325_003035_21_2455"
# "20220325_003019_12_2455"
# "20220325_002833_45_2455"
# "20220325_002831_15_2455"
# "20220325_002808_17_2455"
# "20220325_002805_88_2455"
# "20220325_002745_20_2455"
# "20220325_002740_61_2455"
# "20220325_002729_12_2455"
# "20220325_021529_17_2451"
# "20220325_021526_87_2451"
# "20220325_003202_51_2455"
# "20220325_003155_61_2455"
# "20220325_003151_02_2455"
# "20220325_003148_72_2455"
# "20220325_003130_34_2455"
# "20220325_003105_07_2455"
# "20220325_003026_02_2455"
# "20220325_003023_72_2455"
# "20220325_003007_64_2455"
# "20220325_002821_96_2455"
# "20220325_022633_11_2451"
# "20220325_003207_10_2455"
# "20220325_003153_32_2455"
# "20220325_003044_40_2455"
# "20220325_003032_91_2455"
# "20220325_003030_61_2455"
# "20220325_003016_83_2455"
# "20220325_002826_55_2455"
# "20220325_002824_26_2455"
# "20220325_002819_66_2455"
# "20220325_002812_77_2455"
# "20220325_002754_39_2455"
# "20220325_002752_09_2455"
# "20220325_002731_42_2455"
# "20220325_022635_40_2451"
# "20220325_003220_88_2455"
# "20220325_003209_40_2455"
# "20220325_003204_80_2455"
# "20220325_003146_42_2455"
# "20220325_003132_64_2455"
# "20220325_003123_45_2455"
# "20220325_003121_15_2455"
# "20220325_003116_56_2455"
# "20220325_003042_10_2455"
# "20220325_002810_47_2455"
# "20220325_002803_58_2455"
# "20220325_002756_69_2455"
# "20220325_002742_90_2455"
# "20220325_002733_71_2455"
# "20220325_003037_50_2455"
# "20220325_002758_99_2455"
# "20220325_022132_15_2451"
# "20220325_021832_96_2451"
# "20220323_071156_97_2416"
# "20220323_071234_15_2416"
# "20220323_071149_53_2416"
# "20220324_101335_68_2416"
# "20220324_100423_07_2416"
# "20220324_154318_44_2464"
# "20220324_154336_82_2464"
# "20220324_154325_34_2464"
# "20220324_154007_72_2464"
# "20220324_154003_12_2464"
# "20220324_153956_23_2464"
# "20220324_153953_93_2464"
# "20220324_153951_63_2464"
# "20220324_153912_57_2464"
# "20220324_153910_27_2464"
# "20220324_153851_89_2464"
# "20220324_153828_91_2464"
# "20220324_154323_04_2464"
# "20220324_154309_25_2464"
# "20220324_154250_87_2464"
# "20220324_154151_12_2464"
# "20220324_154021_50_2464"
# "20220324_154016_91_2464"
# "20220324_154014_61_2464"
# "20220324_153935_55_2464"
# "20220324_153933_25_2464"
# "20220324_153930_95_2464"
# "20220324_153856_48_2464"
# "20220324_153035_55_2464"
# "20220324_153026_35_2464"
# "20220325_091519_70_2447"
# "20220325_091512_81_2447"
# "20220325_091505_91_2447"
# "20220325_091449_83_2447"
# "20220325_091433_75_2447"
# "20220325_091345_51_2447"
# "20220325_091340_91_2447"
# "20220325_091322_53_2447"
# "20220325_091317_94_2447"
# "20220325_091315_64_2447"
# "20220325_091308_75_2447"
# "20220325_091306_45_2447"
# "20220325_091254_97_2447"
# "20220325_091248_07_2447"
# "20220325_091243_48_2447"
# "20220325_091238_88_2447"
# "20220324_154334_53_2464"
# "20220324_154218_70_2464"
# "20220324_154148_82_2464"
# "20220324_154026_10_2464"
# "20220324_154000_82_2464"
# "20220324_153944_74_2464"
# "20220324_153940_14_2464"
# "20220324_153917_16_2464"
# "20220324_153907_97_2464"
# "20220324_153903_38_2464"
# "20220325_091517_40_2447"
# "20220325_091510_51_2447"
# "20220325_091508_21_2447"
# "20220325_091501_32_2447"
# "20220325_091452_13_2447"
# "20220325_091447_54_2447"
# "20220325_091438_35_2447"
# "20220325_091436_05_2447"
# "20220325_091429_16_2447"
# "20220325_091406_18_2447"
# "20220325_091352_40_2447"
# "20220325_091350_10_2447"
# "20220325_091338_62_2447"
# "20220325_091327_13_2447"
# "20220325_091304_15_2447"
# "20220325_091301_86_2447"

# %%
# Print the first feature
p(features[0])
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20220311_142917_63_247b",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20220311_142917_63_247b/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20220311_142917_63_247b/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download",
#     "assets.ps3b_analytic:download",
#     "assets.ps3b_analytic_dn:download",
#     "assets.ps3b_analytic_dn_xml:download",
#     "assets.ps3b_analytic_xml:download",
#     "assets.ps3b_basic_analytic:download",
#     "assets.ps3b_basic_analytic_dn:download",
#     "assets.ps3b_basic_analytic_dn_rpc:download",
#     "assets.ps3b_basic_analytic_dn_xml:download",
#     "assets.ps3b_basic_analytic_rpc:download",
#     "assets.ps3b_basic_analytic_xml:download",
#     "assets.ps3b_basic_udm:download",
#     "assets.ps3b_udm:download",
#     "assets.ps3b_visual_xml:download",
#     "assets.ps4b_analytic:download",
#     "assets.ps4b_analytic_dn:download",
#     "assets.ps4b_analytic_dn_xml:download",
#     "assets.ps4b_analytic_sr:download",
#     "assets.ps4b_analytic_xml:download",
#     "assets.ps4b_basic_analytic:download",
#     "assets.ps4b_basic_analytic_dn:download",
#     "assets.ps4b_basic_analytic_dn_nitf:download",
#     "assets.ps4b_basic_analytic_dn_rpc:download",
#     "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_dn_xml:download",
#     "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#     "assets.ps4b_basic_analytic_nitf:download",
#     "assets.ps4b_basic_analytic_rpc:download",
#     "assets.ps4b_basic_analytic_rpc_nitf:download",
#     "assets.ps4b_basic_analytic_xml:download",
#     "assets.ps4b_basic_analytic_xml_nitf:download",
#     "assets.ps4b_basic_udm:download",
#     "assets.ps4b_udm:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual",
#     "ps3b_analytic",
#     "ps3b_analytic_dn",
#     "ps3b_analytic_dn_xml",
#     "ps3b_analytic_xml",
#     "ps3b_basic_analytic",
#     "ps3b_basic_analytic_dn",
#     "ps3b_basic_analytic_dn_rpc",
#     "ps3b_basic_analytic_dn_xml",
#     "ps3b_basic_analytic_rpc",
#     "ps3b_basic_analytic_xml",
#     "ps3b_basic_udm",
#     "ps3b_udm",
#     "ps3b_visual_xml",
#     "ps4b_analytic",
#     "ps4b_analytic_dn",
#     "ps4b_analytic_dn_xml",
#     "ps4b_analytic_sr",
#     "ps4b_analytic_xml",
#     "ps4b_basic_analytic",
#     "ps4b_basic_analytic_dn",
#     "ps4b_basic_analytic_dn_nitf",
#     "ps4b_basic_analytic_dn_rpc",
#     "ps4b_basic_analytic_dn_rpc_nitf",
#     "ps4b_basic_analytic_dn_xml",
#     "ps4b_basic_analytic_dn_xml_nitf",
#     "ps4b_basic_analytic_nitf",
#     "ps4b_basic_analytic_rpc",
#     "ps4b_basic_analytic_rpc_nitf",
#     "ps4b_basic_analytic_xml",
#     "ps4b_basic_analytic_xml_nitf",
#     "ps4b_basic_udm",
#     "ps4b_udm"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -70.69791668546402,
#           -26.978725182710438
#         ],
#         [
#           -70.74272045849698,
#           -27.174471016638787
#         ],
#         [
#           -70.37407556631322,
#           -27.24245365811799
#         ],
#         [
#           -70.33031065627358,
#           -27.045698650556712
#         ],
#         [
#           -70.69791668546402,
#           -26.978725182710438
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20220311_142917_63_247b",
#   "properties": {
#     "acquired": "2022-03-11T14:29:17.630123Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 97,
#     "clear_percent": 68,
#     "cloud_cover": 0.32,
#     "cloud_percent": 32,
#     "ground_control": true,
#     "gsd": 4.2,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2022-03-25T21:03:52Z",
#     "publishing_stage": "finalized",
#     "quality_category": "test",
#     "satellite_azimuth": 0,
#     "satellite_id": "247b",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "5498153",
#     "sun_azimuth": 62.2,
#     "sun_elevation": 48.2,
#     "updated": "2022-03-25T21:03:52Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 74,
#     "visible_percent": 68
#   },
#   "type": "Feature"
# }

# %% [markdown]
# What happens when there are A LOT of results?
#
# When the number of matching items exceeds 250, the results are delivered in pages. Let's perform a search query that should return a large number of results:

# %%
# Setup a GeoJSON polygon for our geometry filter
geom = {
    "type": "Polygon",
    "coordinates": [
      [
        [
          -125.29632568359376,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          48.37084770238366
        ]
      ]
    ]
  }

# Setup the geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# %%
# Print the response "_links" property
p(geojson["_links"])
# Out:
# {
#   "_first": "https://api.planet.com/data/v1/searches/c06bddaafd76435599fd676e0b53c35d/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/c06bddaafd76435599fd676e0b53c35d/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIyLTAzLTA5VDA5OjE3OjQ0LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjIwMzA4XzE4MTYyNF80M18yNDYzIiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/c06bddaafd76435599fd676e0b53c35d/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
# }

# %%
# Assign the "_links" -> "_next" property (link to next page of results) to a variable 
next_url = geojson["_links"]["_next"]

# Print the link to the next page of results
print(next_url)
# Out:
# https://api.planet.com/data/v1/searches/c06bddaafd76435599fd676e0b53c35d/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIyLTAzLTA5VDA5OjE3OjQ0LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjIwMzA4XzE4MTYyNF80M18yNDYzIiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319

# %% [markdown]
# The page size can be set with a `_page_size` parameter in the request:

# %%
# Send the POST request to the API quick search endpoint with a page size of 9
res = session.post(quick_url, json=request, params={"_page_size" : 9})

# Assign the response to a variable
geojson = res.json()

# Get the number of features present in the response
len(geojson["features"])
# Out:
# 9

# %% [markdown]
# ### Mapping Footprints Example
#
# The [`geojsonio`](https://pypi.python.org/pypi/geojsonio/) module can be used to map GeoJSON files and is therefore compatible with the output from Planet Data API searches.
#
# Make sure you've got the module installed and then let's use it to show our resuls on a map:

# %%
# Import the geojsonio python module
# You may need to install this on your system first
import geojsonio

# Assign the url variable to display the geojsonio map
url = geojsonio.display(res.text)

# %% [markdown]
# We can now iterate through the pages of results.

# %%
# Assign the next_url variable to the next page of results from the response (Setup the next page of results)
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %%
# Setup the next page of results
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %% [markdown]
# Cool huh? Now that we know how to search and find items we are interested in, let's try activating and downloading some assets.

# %% [markdown]
# ## Assets & Permissions
#
# Assets may be imagery files, image masks, metadata files or some other file type that might be associated with the item.
#
# The `_permissions` element in each feature contains a list of assets that the user has access to.

# %% [markdown]
# Let's pick the first item out of our search result to work with, and then see what the permissions are for that item:

# %%
# Assign a variable to the search result features (items)
features = geojson["features"]

# Get the first result's feature
feature = features[0]

# Print the ID
p(feature["id"])

# Print the permissions
p(feature["_permissions"])
# Out:
# "20220207_185113_68_24a5"
# [
#   "assets.basic_analytic_4b:download",
#   "assets.basic_analytic_4b_rpc:download",
#   "assets.basic_analytic_4b_xml:download",
#   "assets.basic_analytic_8b:download",
#   "assets.basic_analytic_8b_xml:download",
#   "assets.basic_udm2:download",
#   "assets.ortho_analytic_4b:download",
#   "assets.ortho_analytic_4b_sr:download",
#   "assets.ortho_analytic_4b_xml:download",
#   "assets.ortho_analytic_8b:download",
#   "assets.ortho_analytic_8b_sr:download",
#   "assets.ortho_analytic_8b_xml:download",
#   "assets.ortho_udm2:download",
#   "assets.ortho_visual:download",
#   "assets.ps3b_analytic:download",
#   "assets.ps3b_analytic_dn:download",
#   "assets.ps3b_analytic_dn_xml:download",
#   "assets.ps3b_analytic_xml:download",
#   "assets.ps3b_basic_analytic:download",
#   "assets.ps3b_basic_analytic_dn:download",
#   "assets.ps3b_basic_analytic_dn_rpc:download",
#   "assets.ps3b_basic_analytic_dn_xml:download",
#   "assets.ps3b_basic_analytic_rpc:download",
#   "assets.ps3b_basic_analytic_xml:download",
#   "assets.ps3b_basic_udm:download",
#   "assets.ps3b_udm:download",
#   "assets.ps3b_visual_xml:download",
#   "assets.ps4b_analytic:download",
#   "assets.ps4b_analytic_dn:download",
#   "assets.ps4b_analytic_dn_xml:download",
#   "assets.ps4b_analytic_sr:download",
#   "assets.ps4b_analytic_xml:download",
#   "assets.ps4b_basic_analytic:download",
#   "assets.ps4b_basic_analytic_dn:download",
#   "assets.ps4b_basic_analytic_dn_nitf:download",
#   "assets.ps4b_basic_analytic_dn_rpc:download",
#   "assets.ps4b_basic_analytic_dn_rpc_nitf:download",
#   "assets.ps4b_basic_analytic_dn_xml:download",
#   "assets.ps4b_basic_analytic_dn_xml_nitf:download",
#   "assets.ps4b_basic_analytic_nitf:download",
#   "assets.ps4b_basic_analytic_rpc:download",
#   "assets.ps4b_basic_analytic_rpc_nitf:download",
#   "assets.ps4b_basic_analytic_xml:download",
#   "assets.ps4b_basic_analytic_xml_nitf:download",
#   "assets.ps4b_basic_udm:download",
#   "assets.ps4b_udm:download"
# ]

# %% [markdown]
# Each item has an `assets` endpoint in the API that lists all of its assets. Let's get a list of available assets for our item:

# %%
# Get the assets link for the item
assets_url = feature["_links"]["assets"]

# Print the assets link
print(assets_url)
# Out:
# https://api.planet.com/data/v1/item-types/PSScene/items/20220207_185113_68_24a5/assets/

# %%
# Send a GET request to the assets url for the item (Get the list of available assets for the item)
res = session.get(assets_url)

# Assign a variable to the response
assets = res.json()

# %%
# Print the asset types that are available
print(assets.keys())
# Out:
# dict_keys(['basic_analytic_4b', 'basic_analytic_4b_rpc', 'basic_analytic_4b_xml', 'basic_analytic_8b', 'basic_analytic_8b_xml', 'basic_udm2', 'ortho_analytic_4b', 'ortho_analytic_4b_sr', 'ortho_analytic_4b_xml', 'ortho_analytic_8b', 'ortho_analytic_8b_sr', 'ortho_analytic_8b_xml', 'ortho_udm2', 'ortho_visual', 'ps3b_analytic', 'ps3b_analytic_dn', 'ps3b_analytic_dn_xml', 'ps3b_analytic_xml', 'ps3b_basic_analytic', 'ps3b_basic_analytic_dn', 'ps3b_basic_analytic_dn_rpc', 'ps3b_basic_analytic_dn_xml', 'ps3b_basic_analytic_rpc', 'ps3b_basic_analytic_xml', 'ps3b_basic_udm', 'ps3b_udm', 'ps3b_visual_xml', 'ps4b_analytic', 'ps4b_analytic_dn', 'ps4b_analytic_dn_xml', 'ps4b_analytic_sr', 'ps4b_analytic_xml', 'ps4b_basic_analytic', 'ps4b_basic_analytic_dn', 'ps4b_basic_analytic_dn_nitf', 'ps4b_basic_analytic_dn_rpc', 'ps4b_basic_analytic_dn_rpc_nitf', 'ps4b_basic_analytic_dn_xml', 'ps4b_basic_analytic_dn_xml_nitf', 'ps4b_basic_analytic_nitf', 'ps4b_basic_analytic_rpc', 'ps4b_basic_analytic_rpc_nitf', 'ps4b_basic_analytic_xml', 'ps4b_basic_analytic_xml_nitf', 'ps4b_basic_udm', 'ps4b_udm'])

# %% [markdown]
# We can see that most items have several assets available. Let's check out the "ps3b_analytic" asset for this item. This is the 3-band analytic asset for the PSScene item.

# %%
# Assign a variable to the visual asset from the item's assets
ps3b_analytic = assets["ps3b_analytic"]

# Print the visual asset data
p(ps3b_analytic)
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMjA3XzE4NTExM182OF8yNGE1IiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0",
#     "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjIwMjA3XzE4NTExM182OF8yNGE1IiwgImMiOiAiUFNTY2VuZSIsICJ0IjogInBzM2JfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#     "type": "https://api.planet.com/data/v1/asset-types/ps3b_analytic"
#   },
#   "_permissions": [
#     "download"
#   ],
#   "expires_at": "2022-03-25T22:28:12.625075",
#   "location": "https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..d4rz-w9NrMEXF6NvsaSigd_cxBlgGiqp49tmCa-t5mEQvPYkQ2Xicbf-GnmcvzJyEd3QqJJabA7oPspiSa-LEw",
#   "md5_digest": "fa8447f828d53e1f3788629d21c37104",
#   "status": "active",
#   "type": "ps3b_analytic"
# }

# %% [markdown]
# ### Activating Assets
#
# Before an asset is available for download, it must be **activated**.
#
# You can activate an asset by sending a *POST* or *GET* request to the asset's **"activation link"**.
#
# The activation usually takes a little bit of time, but hey, I'm sure by now you have some ideas on how to automate your workflow. Go robots!

# %%
# Setup the activation url for a particular asset (in this case the ps3b_analytic asset)
activation_url = ps3b_analytic["_links"]["activate"]

# Send a request to the activation url to activate the item
res = session.get(activation_url)

# Print the response from the activation request
p(res.status_code)
# Out:
# 204

# %% [markdown]
# #### Activation Response Codes
#
# After hitting an activation url, you should get a response code back from the API:
#
# * **`202`** - The request has been accepted and the activation will begin shortly.
# * **`204`** - The asset is already active and no further action is needed.
# * **`401`** - The user does not have permissions to download this file.

# %% [markdown]
# After requesting to actiate an asset, let's do another request to see if the assset's status has changed. This may take some time.

# %%
import time

asset_activated = False

while asset_activated == False:
    # Send a request to the item's assets url
    res = session.get(assets_url)

    # Assign a variable to the item's assets url response
    assets = res.json()

    # Assign a variable to the ps3b_analytic asset from the response
    visual = assets["ps3b_analytic"]

    asset_status = ps3b_analytic["status"]
    print(asset_status)
    
    # If asset is already active, we are done
    if asset_status == 'active':
        asset_activated = True
        print("Asset is active and ready to download")

# Print the ps3b_analytic asset data    
p(ps3b_analytic)
# Out:
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# activating
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-3cc5fe93fff1> in <module>
#       5 while asset_activated == False:
#       6     # Send a request to the item's assets url
# ----> 7     res = session.get(assets_url)
#       8
#       9     # Assign a variable to the item's assets url response
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /opt/conda/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/conda/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# /opt/conda/lib/python3.7/http/client.py in getresponse(self)
#    1352         try:
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#    1356                 self.close()
#
# /opt/conda/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /opt/conda/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /opt/conda/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/conda/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /opt/conda/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Activation Status
#
# An asset may have a `status` of `inactive`, `activating` or `active`.
#
# Once an asset is active, the response will contain a `location`. We'll use the `location` to download the asset!
#
# Below, we are polling the API until the item is activated. This may take awhile.

# %% [markdown]
# ### Downloading Assets
#
# The asset's `location` property points asset file for use to download. Are you ready to download the asset? Let's do it!

# %%
# Assign a variable to the visual asset's location endpoint
location_url = ps3b_analytic["location"]

# Print the location endpoint
print(location_url)
# Out:
# https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..d4rz-w9NrMEXF6NvsaSigd_cxBlgGiqp49tmCa-t5mEQvPYkQ2Xicbf-GnmcvzJyEd3QqJJabA7oPspiSa-LEw

# %% [markdown]
# There's the location url! You could click on it to open it in a browser and download the file... but why not let your code do it?
#
# Let's write a small helper function to download asset files:

# %%
# Create a function to download asset files
# Parameters: 
# - url (the location url)
# - filename (the filename to save it as. defaults to whatever the file is called originally)

def pl_download(url, filename=None):
    
    # Send a GET request to the provided location url, using your API Key for authentication
    res = requests.get(url, stream=True, auth=(PLANET_API_KEY, ""))
    # If no filename argument is given
    if not filename:
        # Construct a filename from the API response
        if "content-disposition" in res.headers:
            filename = res.headers["content-disposition"].split("filename=")[-1].strip("'\"")
        # Construct a filename from the location url
        else:
            filename = url.split("=")[1][:10]
    # Save the file
    with open('output/' + filename, "wb") as f:
        for chunk in res.iter_content(chunk_size=1024):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                f.flush()

    return filename

# %%
# Download the file from an activated asset's location url
pl_download(location_url)
# Out:
# '20220207_185113_68_24a5_3B_Analytic.tif'

# %% [markdown]
# **High Five!** You should now be downloading your very own GeoTIFF! We can't wait to see what you'll do with it!

# %% [markdown]
# ### Rate Limits
#
# ---
#
# Now that you know how to download assets, you should probably keep some of the API **rate limits** in mind:
#
# * For most endpoints, the rate limit is 10 requests per second, per API key.
# * For activation endpoints, the rate limit is 5 requests per second, per API key.
# * For download endpoints, the rate limit is 15 requests per second, per API key.
#
# If you're writing to code to automate accessing the API, you should account for `429` responses and handle retries after a *backoff period*.

# %% [markdown]
# ## Saved Searches
#
# ---
#
# The `/searches` endpoint lets you created saved searches that can be reused.
#
# To view your saved searches, visit the [`searches/?search_type=saved`](https://api.planet.com/data/v1/searches/?search_type=saved) endpoint.
#
# Finally, let's create a saved search:

# %%
# Setup the saved searches endpoint url
searches_url = "{}/searches".format(URL)

# %%
# Setup the request, specifying a name for the saved search, along with the usual search item_types and filter.
request = {
    "name" : "Vancouver Island",
    "item_types" : item_types,
    "filter" : geometry_filter
}

# Send a POST request to the saved searches endpoint (Create the saved search)
res = session.post(searches_url, json=request)

# Print the response
p(res.json())
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/40bfde64d0534166b6f7e8c7fc8c89fd",
#     "results": "https://api.planet.com/data/v1/searches/40bfde64d0534166b6f7e8c7fc8c89fd/results"
#   },
#   "created": "2022-03-25T21:40:22.598539Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "type": "GeometryFilter"
#   },
#   "id": "40bfde64d0534166b6f7e8c7fc8c89fd",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": null,
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2022-03-25T21:40:22.598539Z"
# }

# %% [markdown]
# Now that we created a saved search, let's get a list of our saved searches:

# %%
# Send a GET request to the saved searches endpoint with the saved search type parameter (Get saved searches)
res = session.get(searches_url, params={"search_type" : "saved"})

# Assign a variable to the searches property in the saved searches response
searches = res.json()["searches"]
print(searches[2])#['name'])
print(len(searches))

# Loop through the searches
for search in searches:
    # Print the ID, Created Time, and Name for each saved search
    print("id: {} created: {} name: {}".format(search["id"], search["created"], search['name']))
# Out:
# {'__daily_email_enabled': False, '_links': {'_self': 'https://api.planet.com/data/v1/searches/ae24a8d7251244b1ac283bc5b9398b78', 'results': 'https://api.planet.com/data/v1/searches/ae24a8d7251244b1ac283bc5b9398b78/results'}, 'created': '2021-10-19T15:09:57.147222Z', 'filter': {'config': {'coordinates': [[[-122.47455596923828, 37.810326435534755], [-122.49172210693358, 37.795406713958236], [-122.52056121826172, 37.784282779035216], [-122.51953124999999, 37.6971326434885], [-122.38941192626953, 37.69441603823106], [-122.38872528076173, 37.705010235842614], [-122.36228942871092, 37.70935613533687], [-122.34992980957031, 37.727280276860036], [-122.37773895263672, 37.76230130281876], [-122.38494873046875, 37.794592824285104], [-122.40554809570311, 37.813310018173155], [-122.46150970458983, 37.805715207044685], [-122.47455596923828, 37.810326435534755]]], 'type': 'Polygon'}, 'field_name': 'geometry', 'type': 'GeometryFilter'}, 'id': 'ae24a8d7251244b1ac283bc5b9398b78', 'item_types': ['PSScene3Band'], 'last_executed': '2021-10-19T15:10:02.928479Z', 'name': 'San Francisco', 'search_type': 'saved', 'updated': '2021-10-19T15:10:02.928773Z'}
# 6
# id: 40bfde64d0534166b6f7e8c7fc8c89fd created: 2022-03-25T21:40:22.598539Z name: Vancouver Island
# id: 950f543836a2459e9c4d5848c8219304 created: 2021-10-28T18:03:05.752256Z name: Raj Ghat, New Delhi, Central Delhi, Delhi, India
# id: ae24a8d7251244b1ac283bc5b9398b78 created: 2021-10-19T15:09:57.147222Z name: San Francisco
# id: a7a648fca59245bca42d2466b289f34f created: 2021-10-18T18:12:06.881703Z name: San Francisco
# id: 6950887354d84e23889c3e308355fdcf created: 2021-10-08T18:31:51.983485Z name: Vancouver Island
# id: fe44f67590ae44d6a4e5e8030de85f90 created: 2021-10-08T18:29:03.053168Z name: Vancouver Island

# %% [markdown]
# Ok, now let's check out the results from a particular saved search:

# %%
# Setup the saved search url, using the first saved search in the list
saved_url = "{}/{}".format(searches_url, searches[0]["id"])

# Print the saved search url
p(saved_url)

# Setup the saved search's results url
results_url = "{}/results".format(saved_url)

# Print the saved search's results url
p(results_url)
# Out:
# "https://api.planet.com/data/v1/searches/40bfde64d0534166b6f7e8c7fc8c89fd"
# "https://api.planet.com/data/v1/searches/40bfde64d0534166b6f7e8c7fc8c89fd/results"

# %%
# Send a GET request to the saved search url (Get the saved search data)
res = session.get(saved_url)

# Print the response
p(res.json())
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/40bfde64d0534166b6f7e8c7fc8c89fd",
#     "results": "https://api.planet.com/data/v1/searches/40bfde64d0534166b6f7e8c7fc8c89fd/results"
#   },
#   "created": "2022-03-25T21:40:22.598539Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "type": "GeometryFilter"
#   },
#   "id": "40bfde64d0534166b6f7e8c7fc8c89fd",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": null,
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2022-03-25T21:40:22.598539Z"
# }

# %%
# Send a GET request to the saved search results url (Get the saved search results)
results = session.get(results_url).json()

# Print the number of features in the saved search
print(len(results["features"]))

# Print the first feature in the saved search
print(results["features"][0])
# Out:
# 250
# {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20220324_182552_75_241f', 'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20220324_182552_75_241f/assets/', 'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20220324_182552_75_241f/thumb'}, '_permissions': ['assets.basic_analytic_4b:download', 'assets.basic_analytic_4b_rpc:download', 'assets.basic_analytic_4b_xml:download', 'assets.basic_analytic_8b:download', 'assets.basic_analytic_8b_xml:download', 'assets.basic_udm2:download', 'assets.ortho_analytic_4b:download', 'assets.ortho_analytic_4b_sr:download', 'assets.ortho_analytic_4b_xml:download', 'assets.ortho_analytic_8b:download', 'assets.ortho_analytic_8b_sr:download', 'assets.ortho_analytic_8b_xml:download', 'assets.ortho_udm2:download', 'assets.ortho_visual:download', 'assets.ps3b_analytic:download', 'assets.ps3b_analytic_dn:download', 'assets.ps3b_analytic_dn_xml:download', 'assets.ps3b_analytic_xml:download', 'assets.ps3b_basic_analytic:download', 'assets.ps3b_basic_analytic_dn:download', 'assets.ps3b_basic_analytic_dn_rpc:download', 'assets.ps3b_basic_analytic_dn_xml:download', 'assets.ps3b_basic_analytic_rpc:download', 'assets.ps3b_basic_analytic_xml:download', 'assets.ps3b_basic_udm:download', 'assets.ps3b_udm:download', 'assets.ps3b_visual_xml:download', 'assets.ps4b_analytic:download', 'assets.ps4b_analytic_dn:download', 'assets.ps4b_analytic_dn_xml:download', 'assets.ps4b_analytic_sr:download', 'assets.ps4b_analytic_xml:download', 'assets.ps4b_basic_analytic:download', 'assets.ps4b_basic_analytic_dn:download', 'assets.ps4b_basic_analytic_dn_nitf:download', 'assets.ps4b_basic_analytic_dn_rpc:download', 'assets.ps4b_basic_analytic_dn_rpc_nitf:download', 'assets.ps4b_basic_analytic_dn_xml:download', 'assets.ps4b_basic_analytic_dn_xml_nitf:download', 'assets.ps4b_basic_analytic_nitf:download', 'assets.ps4b_basic_analytic_rpc:download', 'assets.ps4b_basic_analytic_rpc_nitf:download', 'assets.ps4b_basic_analytic_xml:download', 'assets.ps4b_basic_analytic_xml_nitf:download', 'assets.ps4b_basic_udm:download', 'assets.ps4b_udm:download'], 'assets': ['basic_analytic_4b', 'basic_analytic_4b_rpc', 'basic_analytic_4b_xml', 'basic_analytic_8b', 'basic_analytic_8b_xml', 'basic_udm2', 'ortho_analytic_4b', 'ortho_analytic_4b_sr', 'ortho_analytic_4b_xml', 'ortho_analytic_8b', 'ortho_analytic_8b_sr', 'ortho_analytic_8b_xml', 'ortho_udm2', 'ortho_visual', 'ps3b_analytic', 'ps3b_analytic_dn', 'ps3b_analytic_dn_xml', 'ps3b_analytic_xml', 'ps3b_basic_analytic', 'ps3b_basic_analytic_dn', 'ps3b_basic_analytic_dn_rpc', 'ps3b_basic_analytic_dn_xml', 'ps3b_basic_analytic_rpc', 'ps3b_basic_analytic_xml', 'ps3b_basic_udm', 'ps3b_udm', 'ps3b_visual_xml', 'ps4b_analytic', 'ps4b_analytic_dn', 'ps4b_analytic_dn_xml', 'ps4b_analytic_sr', 'ps4b_analytic_xml', 'ps4b_basic_analytic', 'ps4b_basic_analytic_dn', 'ps4b_basic_analytic_dn_nitf', 'ps4b_basic_analytic_dn_rpc', 'ps4b_basic_analytic_dn_rpc_nitf', 'ps4b_basic_analytic_dn_xml', 'ps4b_basic_analytic_dn_xml_nitf', 'ps4b_basic_analytic_nitf', 'ps4b_basic_analytic_rpc', 'ps4b_basic_analytic_rpc_nitf', 'ps4b_basic_analytic_xml', 'ps4b_basic_analytic_xml_nitf', 'ps4b_basic_udm', 'ps4b_udm'], 'geometry': {'coordinates': [[[-125.21211791049433, 49.011137305252234], [-125.28321160852991, 48.823509405047396], [-124.80583524935713, 48.74331667992123], [-124.73369875737615, 48.9310065338029], [-125.21211791049433, 49.011137305252234]]], 'type': 'Polygon'}, 'id': '20220324_182552_75_241f', 'properties': {'acquired': '2022-03-24T18:25:52.752223Z', 'anomalous_pixels': 0, 'clear_confidence_percent': 34, 'clear_percent': 0, 'cloud_cover': 1, 'cloud_percent': 2, 'ground_control': True, 'gsd': 4.1, 'heavy_haze_percent': 98, 'instrument': 'PSB.SD', 'item_type': 'PSScene', 'light_haze_percent': 0, 'pixel_resolution': 3, 'provider': 'planetscope', 'published': '2022-03-25T17:30:55Z', 'publishing_stage': 'standard', 'quality_category': 'test', 'satelli ...

# %% [markdown]
# A saved search can also be updated by senidng a **`PUT`** request with a changed search definition back to the API.
#
# Did you know that saved searches can also send you a daily email to alert you to when new items are added to the search resutlts? Oh yeah!

# %%
# Assign a variable to the saved search response
search = res.json()

# Print the saved search
p(search)
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/40bfde64d0534166b6f7e8c7fc8c89fd",
#     "results": "https://api.planet.com/data/v1/searches/40bfde64d0534166b6f7e8c7fc8c89fd/results"
#   },
#   "created": "2022-03-25T21:40:22.598539Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "type": "GeometryFilter"
#   },
#   "id": "40bfde64d0534166b6f7e8c7fc8c89fd",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": null,
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2022-03-25T21:40:22.598539Z"
# }

# %%
# Change the saved search name to "South Vancouver Island"
search["name"] = "South Vancouver Island"

# Set the daily email enabled to true (Get email alerts when new items show up in this search)
search["__daily_email_enabled"] = True

# Send a PUT request to the saved search endpoint (Update the saved search)
res = session.put(saved_url, json=search)

# The response status code
res.status_code
# Out:
# 400

# %% [markdown]
# ## Conclusion
#
# You made it! You should now be able to use the Planet API to find items and assets by searching, get stats and save searches, and activate and download assets using Python code!
#
# Don't forget to visit the [Planet API Reference Docs](https://www.planet.com/docs/reference/).
