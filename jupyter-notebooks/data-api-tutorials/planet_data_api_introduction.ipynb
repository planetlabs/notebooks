# %% [markdown]
# # Planet Data API Introduction using Python
#
# ---

# %% [markdown]
# ## Introduction
#
# ---
#
# This tutorial is an introduction to [Planet](https://www.planet.com)'s Data API. It provides code samples on how to write simple Python code to access data.
#
# [`https://api.planet.com/data/v1`](https://api.planet.com/data/v1)
#
# The focus of this tutorial will be the search portion of the Planet Data API. We will find and download imagery data using complex searches and save them for later use, as well as learn how to get stats on search results. After completing this tutorial, you should feel comfortable interacting with the Data API, and have a good foundation for leveraging the Planet Data API for your own applications.

# %% [markdown]
# ## Table of Contents
#
# ---
#
# * **Introduction**
#     * Requirements
#        * Software & Modules
#        * Planet API Key
#     * Useful Links
#
#
# * **Overview**
#      * The Basic Workflow
#       * Data API Endpoints
#       * Planet Explorer
#
#
# * **Basic Setup**
#     * Authentication
#     * Helper Modules and Functions
#     * Our First Request
#
#
# * **Search Mechanics & Filters**
#     * Statistics
#     * Using a Search Filter
#     * Filter types
#         * Field Filters
#         * Logical Filters
#         * (Field) Filter Type examples
#     * Complex Queries using Logical Filters
#
#
# * **Searching for Items**
#     * Quick Search
#         * Mapping Footprints Example
#
#
# * **Assets & Permissions**
#     * Activating Assets
#     * Downloading Assets
#     * Rate Limits
#
#
# * **Saved Searches**
#
#
# * **Conclusion**

# %% [markdown]
# ### Requirements
#
# ---
#
# #### Software & Modules
#
# This tutorial assumes familiarity with the [Python](https://python.org) programming language throughout. Familiarity with basic REST API concepts and usage is also assumed.
#
# We'll be using a **"Jupyter Notebook"** (aka Python Notebook) to run through the examples.
# To learn more about and get started with using Jupyter, visit: [Jupyter](https://jupyter.org/) and [IPython](https://ipython.org/).
#
# For the best experience, download this notebook and run it on your system, and make sure to install the modules listed below first. You can also copy the examples' code to a separate Python files an run them directly with Python on your system if you prefer.
#
#
# Python modules used in this tutorial are:
# * [requests](http://docs.python-requests.org/)
# * [geojsonio](https://pypi.python.org/pypi/geojsonio)
#
#
# #### Planet API Key
#
# You should have an account on the Planet Platform to access the Data API. You may retrieve your API key from your [account page](https://www.planet.com/account/), or from the "API Tab" in [Planet Explorer](https://www.planet.com/explorer).

# %% [markdown]
# ### Useful links
#
# ---
#
# * [Planet Data API Reference & Documentation](https://www.planet.com/docs/reference/data-api/)
# * [Planet Explorer](https://www.planet.com/explorer)

# %% [markdown]
# ## Overview
#
# ---
#
# ### The Basic Workflow:
#
# 1. Search item types based on filters
# 1. Activate assets
# 1. Download assets

# %% [markdown]
# ### API Endpoints
#
# This tutorial will cover the following API ***endpoints***:
#
# * [`/item-types`](https://api.planet.com/data/v1/item-types/)
# * [`/asset-types`](https://api.planet.com/data/v1/asset-types/)
# * `/quick-search`
# * `/searches`
# * `/stats`
#
# There is an additional [`/spec`](https://api.planet.com/data/v1/spec) endpoint that publishes a [Swagger](http://swagger.io/) specification for the Data API.
#
# ### Exploring Endpoints
#
# We can start by exploring two endpoints using our browser.
#
# ##### What item types are available?
#
# https://api.planet.com/data/v1/item-types/
#
# ##### What assets are available?
#
# https://api.planet.com/data/v1/asset-types/

# %% [markdown]
# ***Note:*** *You may choose to install a helpful browser plugin called **JSONView** that formats JSON and makes it easier to read:*
#
# * [Chrome Extension](https://chrome.google.com/webstore/detail/jsonview/chklaanhfefbnpoihckbnefhakgolnmc)
# * [Firefox Plugin](https://addons.mozilla.org/en-us/firefox/addon/jsonview/)

# %% [markdown]
# ### Planet Explorer
# We can also use Planet Explorer to expose relevant API information for search results.
#
# In Planet Explorer, while in *Daily Imagery Mode* click on the *"Api"* button in the bottom left corner of the results panel.
#
# ![Planet Explorer Screenshot](images/planet-explorer.png)
#
# Here, you may access your API Key, selected item id's, and `cURL` request information containing filters and options.

# %% [markdown]
# ## Basic Setup
#
# ---
#
# Before interacting with the Planet Data API using Python, we will set up our environment with some useful modules and helper functions.
#
# * We'll configure *authentication* to the Planet Data API
# * We'll use the `requests` Python module to make HTTP communication easier.
# * We'll use the `json` Python module to help us work with JSON responses from the API.
# * We'll create a function called `p` that will print Python dictionaries nicely.
#
# Then we'll be ready to make our first call to the Planet API by hitting the base endpoint at `https://api.planet.com/data/v1`.
#
# Let's start by configuring authentication:

# %% [markdown]
# ### Authentication
#
# Authentication with the Planet Data API be achieved using a valid Planet **API key**.

# %% [markdown]
# You can *export* your API Key as an environment variable on your system:
#
# `export PL_API_KEY="YOUR API KEY HERE"`
#
# Or add the variable to your path, etc. If you are using our Docker environement, it will already be set.
#
# To start our Python code, we'll setup an API Key variable from an environment variable to use with our requests:

# %%
# Import the os module in order to access environment variables
import os

# If you're following along with this notebook, you can enter your API Key on the following line, and uncomment it:
#os.environ['PL_API_KEY']='YOUR API KEY HERE'

# Setup the API Key from the `PL_API_KEY` environment variable
PLANET_API_KEY = os.getenv('PL_API_KEY')

# %% [markdown]
# ### Helper Modules and Functions

# %%
# Import helper modules
import json
import requests

# %%
# Helper function to printformatted JSON using the json module
def p(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# ### Our First Request

# %%
# Setup Planet Data API base URL
URL = "https://api.planet.com/data/v1"

# Setup the session
session = requests.Session()

# Authenticate
session.auth = (PLANET_API_KEY, "")

# %%
# Make a GET request to the Planet Data API
res = session.get(URL)

# %% [markdown]
# Now we should get a response, hopefully it's a `200` code, saying everything is OK!

# %%
# Response status code
res.status_code
# Out:
# 200

# %%
# Response Body
res.text
# Out:
# '{"_links": {"_self": "https://api.planet.com/data/v1/", "asset-types": "https://api.planet.com/data/v1/asset-types/", "item-types": "https://api.planet.com/data/v1/item-types/", "spec": "https://api.planet.com/data/v1/spec"}}'

# %%
# Print formatted JSON response
p(res.json())
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/",
#     "asset-types": "https://api.planet.com/data/v1/asset-types/",
#     "item-types": "https://api.planet.com/data/v1/item-types/",
#     "spec": "https://api.planet.com/data/v1/spec"
#   }
# }

# %%
# Print the value of the item-types key from _links
print(res.json()["_links"]["item-types"])
# Out:
# https://api.planet.com/data/v1/item-types/

# %% [markdown]
# **Congratulations!** You just made your first request to the Planet Data API using Python!
#
# Now, let's take a look at how to access all that high cadence satellite imagery!

# %% [markdown]
# ## Search Mechanics & Filters
#
# ---
#
# There's a lot of data available on the Planet Data API and in order to find what we're looking for, we'll have to perform various types of searches.
#
# To construct a search, we use **filters** that let us limit results based on date, geography or other metadata properties.
#
# Using these filters, we are able to **search** for items or get **statistics** for search results.
#
# Let's first make a request to the `/stats` endpoint to understand how the filters work:

# %% [markdown]
# ### Statistics `/stats`
#
# ---
#
# The `/stats` endpoint provides a summary of the available data based on some search criteria.
#
# `https://api.planet.com/data/v1/stats`
#
# We'll need to send a ***`POST`*** request to `/stats`, let's start by setting up the request url:

# %%
# Setup the stats URL
stats_url = "{}/stats".format(URL)

# Print the stats URL
print(stats_url)
# Out:
# https://api.planet.com/data/v1/stats

# %% [markdown]
# ### Using a Search Filter
#
# Search filters should have the following properties:
#
# * **Type** (`type`) - The type of filter being used
# * **Configuration** (`config`) - The configuration for this filter
# * **Field Name** (`field_name`) - The field on which to filter
#
# For this example, let's use a filter to get some stats on what data is available for *Planet Scope (3 Band)* and *Rapid Eye (Ortho Tile)* products taken from 2013 until now:

# %%
# Specify the sensors/satellites or "item types" to include in our results
item_types = ["PSScene3Band", "REOrthoTile"]

# %%
# Create filter object for all imagery captured between 2013-01-01 and present.
date_filter = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "gte": "2013-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

# %% [markdown]
# Depending on the filter type, some requests may need an `interval` field:
#
# The following intervals are possible:
# * `year`
# * `month`
# * `week`
# * `day`
# * `hour`
#
# An `interval` must be provided with the request so that the number of matching items can be aggregated. We'll use an interval with our date filter.

# %% [markdown]
# Now let's perform our request using the `date_filter` filter we created above:

# %%
# Construct the request.
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 3095020,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3596278,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8491790,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 37679317,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 174722989,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 186371062,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# ***Good Job!*** You've received a response from the API that contains some statistics like item counts for the search criteria!

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new date filter to find data from before 2013.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 
date_filter2 = {
}

request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter2
}

res = session.post(stats_url, json=request)
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 3095020,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3596278,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8491790,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 37679317,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 174722989,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 186371062,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# ---
#
# Next, let's take a closer look at some of the available filters:

# %% [markdown]
# ### Filter types
#
# The Planet Data API supports several filter types. The most common are the following:
#
# ### Field Filters
#
# * `DateRangeFilter`
# * `RangeFilter`
# * `StringInFilter`
# * `PermissionFilter`
# * `GeometryFilter`
#
# ### Logical Filters
#
# * `NotFilter`
# * `AndFilter`
# * `OrFilter`
#
# More information and examples on filter types can be found at the [API Docs](https://www.planet.com/docs/reference/data-api/search-api/).
#
# ---
#
# ### (Field) Filter Type examples:

# %% [markdown]
# #### `DateRangeFilter`
#
# Find imagery that was `acquired` or `published` before, after or between certain dates.
#
# ```
# {
#   "type": "DateRangeFilter",
#   "field_name": "acquired",
#   "config": {
#     "gt": "2016-01-01T00:00:00Z",
#     "lte": "2016-03-01T00:00:00Z"
#   }
# }
# ```
#
# The upper or lower bound may be omitted.

# %% [markdown]
# #### `RangeFilter`
#
# Find imagery that has a metadata that matches a number within a range of numbers.
#
# ```
# {
#   "type": "RangeFilter",
#   "field_name": "cloud_cover",
#   "config": {
#     "lt": 0.2,
#     "gt": 0.1
#   }
# }
# ```

# %% [markdown]
# The following **operators** are supported by the Data API's `DateRangeFilter` and `RangeFilter`:
# * `gt`: Greater Than
# * `gte`: Greater Than or Equal To
# * `lt`: Less Than
# * `lte`: Less Than or Equal To

# %% [markdown]
# #### `StringInFilter`
#
# Find imagery that has a metadata that matches a string within the array of provided strings.
#
#
# ```
# {
#   "type": "StringInFilter",
#   "field_name": "instrument",
#   "config": ["PS2"]
# }
# ```

# %% [markdown]
# #### `PermissionFilter`
#
# Find data which has assets that are accessible by the user.
#
# ```
# {
#   "type": "PermissionFilter",
#   "config": ["assets.analytic:download"]
# }
# ```
#
# ***Note:*** `assets:download` means *any* downloadable asset.

# %% [markdown]
# #### `GeometryFilter`
#
# Find data contained within a given geometry. The filter's config value may be any valid GeoJSON object.
#
# ```
# {
#   "type": "GeometryFilter",
#   "field_name": "geometry",
#   "config": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ]
#       ]
#     ]
#   }
# }
# ```
#
# A few quick ways to get a GeoJSON geometry to use in your search:
#
# * Draw an Area of Interst (AOI) in [Planet Explorer](http://planet.com/explorer), and use the API button to see the geometry filter config.
# * Use your favorite GIS tools like [Quantum GIS (QGIS)](http://www.qgis.org) and export GeoJSON.
# * Draw a polygon in [GeoJSON.io](http://geojson.io).
#
# Make sure the `config` property in the geometry filter is in the right format, which should be similar to a `feature` property in a GeoJSON object.

# %% [markdown]
# Let's try a few more exercises to practice using different types of filters:
#
# ---
#
# <div class="alert alert-info">
#
# **Exercise:** Search for imagery only from PlanetScope satellites that have a PS2 telescope
#
# </div>

# %%
# Setup item types
item_types = ["PSScene3Band"]

# Setup a filter for instrument type
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 1539543,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 30243181,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 170625428,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 184139032,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new filter that finds all data from PS0 or PS1 telescopes.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 

instrument_filter2 = {
}
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter2
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "field": {
#     "filter.type": [
#       {
#         "message": "'type' is a required property"
#       }
#     ]
#   },
#   "general": []
# }

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Search for imagery that intersects with 40N, 90W.
#
# </div>

# %%
# Setup GeoJSON by filling in the coordinates!
geom = {
    "type": "Point",
    "coordinates": [
        
    ]
}

# Setup Geometry Filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : geometry_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 6,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 4,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 46,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 176,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 307,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 304,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 334,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 399,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# ### Complex Queries using Logical Filters
#
# Complex queries may require combining field filters using **logical filters** (see Filter Types above).
#
# Let's try a complex stats search:

# %%
# PS2 imagery; over 40N, 90W; captured between 2013 and present

# Setup an "AND" logical filter to combine multiple filters
and_filter = {
    "type": "AndFilter",
    "config": [instrument_filter, geometry_filter, date_filter]
}

# Print the logical filter
p(and_filter)
# Out:
# {
#   "type": "AndFilter",
#   "config": [
#     {
#       "type": "StringInFilter",
#       "field_name": "instrument",
#       "config": [
#         "PS2"
#       ]
#     },
#     {
#       "type": "GeometryFilter",
#       "field_name": "geometry",
#       "config": {
#         "type": "Point",
#         "coordinates": [
#           -90,
#           40
#         ]
#       }
#     },
#     {
#       "type": "DateRangeFilter",
#       "field_name": "acquired",
#       "config": {
#         "gte": "2013-01-01T00:00:00.000Z"
#       }
#     }
#   ]
# }

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : and_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 1,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 45,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 176,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 307,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 253,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 204,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 127,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# Here's another complex search query example using a "Not" logical filter and "string in" field filter. Can you tell what it's requesting?

# %%
# Setup Item Types
item_types = ["PSScene4Band"]

# Setup Instrument Filter
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# Setup "not" Logical Filter
not_filter = {
    "type": "NotFilter",
    "config": instrument_filter
}

# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : not_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 13978790,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 29179078,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 51062369,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# Now that you're comfortable working with **filters**, let's take a look at how to perform searches!

# %% [markdown]
# ## Searching for Items
#
# ---
#
# There are two types of searches:
# * **"Quick Search"** `/quick-search`
# * **"Saved Searches"** `/searches`
#
# Saved searches are retained on the Planet Platform and may be performed again at any time in the future. You can use these to setup efficient workflows for repetitive tasks, for example, querying an area that is of interest to you, or getting data for specific sensors.
#
# Quick searches are meant to be more fleeting, and are not guaranteed to be available on the API after they are executed.
#
# Searches use the same request format as the `/stats` endpoint except without the `interval` field.

# %% [markdown]
# ### Quick Search
#
# Let's dive right in and create our first `quick search`:

# %%
# Setup the quick search endpoint url
quick_url = "{}/quick-search".format(URL)

# %%
# Setup Item Types
item_types = ["PSScene4Band"]

# Setup GeoJSON for only imagery that intersects with 40N, 90W
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup a geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": "POINT(40 -90)"
}

# Setup the request
# Note: there is no interval field here!
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "field": {
#     "filter.config": [
#       {
#         "message": "'POINT(40 -90)' is not of type 'object'"
#       }
#     ]
#   },
#   "general": []
# }

# %% [markdown]
# Nice! The response gives us search results for Planet Scope (4 Band) for a specific area.
#
# Let's do another search, this time using the "not" filter we setup earlier:

# %%
# Setup Item Types
item_types = ["PSScene3Band"]

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : not_filter
}

# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/3e48602b72d6415ab24894e042b8e90e/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/3e48602b72d6415ab24894e042b8e90e/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIxLTEwLTA4VDE3OjM2OjUzLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjExMDA4XzEwMjA1MV8wNF8yNDU1IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#     "_self": "https://api.planet.com/data/v1/searches/3e48602b72d6415ab24894e042b8e90e/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_041000_72_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_041000_72_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_041000_72_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.10378112122012,
#               15.717864515117691
#             ],
#             [
#               94.06309071128737,
#               15.519001025453896
#             ],
#             [
#               94.4066067839349,
#               15.453356426465788
#             ],
#             [
#               94.44735896425018,
#               15.65111387316564
#             ],
#             [
#               94.10378112122012,
#               15.717864515117691
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_041000_72_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:10:00.729929Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.24,
#         "columns": 13708,
#         "epsg_code": 32646,
#         "ground_control": false,
#         "gsd": 4.2,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 614013,
#         "origin_y": 1738038,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:39:00Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "rows": 9692,
#         "satellite_azimuth": 99,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 136.1,
#         "sun_elevation": 60.9,
#         "updated": "2021-10-08T17:39:00Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040958_42_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040958_42_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040958_42_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.13310049221884,
#               15.861722502800356
#             ],
#             [
#               94.0923027614715,
#               15.662876819981616
#             ],
#             [
#               94.43603468799203,
#               15.597111416366511
#             ],
#             [
#               94.4768934069585,
#               15.79485053910902
#             ],
#             [
#               94.13310049221884,
#               15.861722502800356
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040958_42_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:58.423729Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.19,
#         "columns": 13708,
#         "epsg_code": 32646,
#         "ground_control": false,
#         "gsd": 4.2,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 617067,
#         "origin_y": 1753968,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:39:00Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "rows": 9693,
#         "satellite_azimuth": 98.8,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 136.4,
#         "sun_elevation": 60.8,
#         "updated": "2021-10-08T17:39:00Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040956_11_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040956_11_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040956_11_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.16733615172471,
#               16.01086432369141
#             ],
#             [
#               94.1266548639722,
#               15.816957264267508
#             ],
#             [
#               94.46272174839237,
#               15.754484823338583
#             ],
#             [
#               94.50197984134704,
#               15.946621772824368
#             ],
#             [
#               94.16733615172471,
#               16.01086432369141
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040956_11_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:56.117529Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.24,
#         "columns": 13367,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 620658,
#         "origin_y": 1770489,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:39:00Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9390,
#         "satellite_azimuth": 98.8,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 136.6,
#         "sun_elevation": 60.7,
#         "updated": "2021-10-08T17:39:00Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040953_81_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040953_81_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040953_81_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.19688244804277,
#               16.15655871215518
#             ],
#             [
#               94.15701478066829,
#               15.962870187173278
#             ],
#             [
#               94.49230729914099,
#               15.89889272090282
#             ],
#             [
#               94.53203765991842,
#               16.091382833664323
#             ],
#             [
#               94.19688244804277,
#               16.15655871215518
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040953_81_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:53.811329Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.43,
#         "columns": 13346,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 623820,
#         "origin_y": 1786626,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9435,
#         "satellite_azimuth": 99,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 136.8,
#         "sun_elevation": 60.7,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040951_50_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040951_50_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040951_50_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.22638658639852,
#               16.3010746064261
#             ],
#             [
#               94.18651322749007,
#               16.107430374260982
#             ],
#             [
#               94.52212445701554,
#               16.04358101493448
#             ],
#             [
#               94.56190915490461,
#               16.23604599545432
#             ],
#             [
#               94.22638658639852,
#               16.3010746064261
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040951_50_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:51.505129Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.46,
#         "columns": 13349,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 626886,
#         "origin_y": 1802634,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9427,
#         "satellite_azimuth": 98.9,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 137,
#         "sun_elevation": 60.6,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040949_19_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040949_19_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040949_19_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.25633363114353,
#               16.4457355862721
#             ],
#             [
#               94.21657060860592,
#               16.25190415698976
#             ],
#             [
#               94.55241177518425,
#               16.18815035951345
#             ],
#             [
#               94.59216485836839,
#               16.380673385409654
#             ],
#             [
#               94.25633363114353,
#               16.4457355862721
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040949_19_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:49.198929Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.47,
#         "columns": 13345,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 630006,
#         "origin_y": 1818660,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9429,
#         "satellite_azimuth": 98.9,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 137.2,
#         "sun_elevation": 60.5,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040946_89_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040946_89_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040946_89_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.28572603413298,
#               16.590427208851747
#             ],
#             [
#               94.24584437178504,
#               16.39670974189167
#             ],
#             [
#               94.58187860849876,
#               16.33291717880633
#             ],
#             [
#               94.62173320317486,
#               16.52520970778998
#             ],
#             [
#               94.28572603413298,
#               16.590427208851747
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040946_89_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:46.892729Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.5,
#         "columns": 13345,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 633036,
#         "origin_y": 1834689,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9424,
#         "satellite_azimuth": 99,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 137.4,
#         "sun_elevation": 60.4,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040944_58_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040944_58_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040944_58_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.31530274642105,
#               16.735219465886335
#             ],
#             [
#               94.27524027978919,
#               16.541617350285843
#             ],
#             [
#               94.6116036382958,
#               16.477627782176395
#             ],
#             [
#               94.65152649305224,
#               16.669961915305006
#             ],
#             [
#               94.31530274642105,
#               16.735219465886335
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040944_58_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:44.586529Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.46,
#         "columns": 13349,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 636075,
#         "origin_y": 1850730,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9425,
#         "satellite_azimuth": 98.9,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 137.6,
#         "sun_elevation": 60.3,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040942_28_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040942_28_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040942_28_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.34568414142183,
#               16.88004990095956
#             ],
#             [
#               94.3056497596252,
#               16.686351642083956
#             ],
#             [
#               94.64241223282637,
#               16.622448052762387
#             ],
#             [
#               94.68220547840501,
#               16.81470162663012
#             ],
#             [
#               94.34568414142183,
#               16.88004990095956
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040942_28_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:42.280329Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.54,
#         "columns": 13347,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 639216,
#         "origin_y": 1866777,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9424,
#         "satellite_azimuth": 98.9,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 137.8,
#         "sun_elevation": 60.2,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040939_97_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040939_97_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040939_97_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.37560678914306,
#               17.024428456772462
#             ],
#             [
#               94.33549239867155,
#               16.830395263598195
#             ],
#             [
#               94.67255564725643,
#               16.76664823279506
#             ],
#             [
#               94.71226512325144,
#               16.959070421360064
#             ],
#             [
#               94.37560678914306,
#               17.024428456772462
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040939_97_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:39.974129Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.57,
#         "columns": 13344,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 642291,
#         "origin_y": 1882773,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9428,
#         "satellite_azimuth": 98.9,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 138,
#         "sun_elevation": 60.1,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040937_66_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040937_66_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040937_66_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.40567812175856,
#               17.168364837240638
#             ],
#             [
#               94.36592772884043,
#               16.975042048703468
#             ],
#             [
#               94.70266658761985,
#               16.91092850712445
#             ],
#             [
#               94.74276908747844,
#               17.10291155799214
#             ],
#             [
#               94.40567812175856,
#               17.168364837240638
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040937_66_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:37.667929Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.52,
#         "columns": 13336,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 645423,
#         "origin_y": 1898724,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9413,
#         "satellite_azimuth": 98.8,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 138.2,
#         "sun_elevation": 60,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040935_36_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040935_36_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040935_36_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.43562802810459,
#               17.31274853909724
#             ],
#             [
#               94.39547177119857,
#               17.11909491164234
#             ],
#             [
#               94.73290714732188,
#               17.054999927569007
#             ],
#             [
#               94.77288650294605,
#               17.24748119074125
#             ],
#             [
#               94.43562802810459,
#               17.31274853909724
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040935_36_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:35.361729Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.5,
#         "columns": 13344,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 648456,
#         "origin_y": 1914723,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9422,
#         "satellite_azimuth": 98.9,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 138.4,
#         "sun_elevation": 59.9,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040933_05_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040933_05_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040933_05_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.46466847887021,
#               17.456829245621474
#             ],
#             [
#               94.42453312395071,
#               17.263274630760776
#             ],
#             [
#               94.76222953723551,
#               17.19939222014051
#             ],
#             [
#               94.80222992914022,
#               17.391630165565893
#             ],
#             [
#               94.46466847887021,
#               17.456829245621474
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040933_05_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:33.055529Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.3,
#         "columns": 13344,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 651429,
#         "origin_y": 1930692,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9409,
#         "satellite_azimuth": 98.5,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 138.6,
#         "sun_elevation": 59.8,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040930_74_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040930_74_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040930_74_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.4943710381379,
#               17.601880425533874
#             ],
#             [
#               94.45420213113277,
#               17.40802017871814
#             ],
#             [
#               94.79209817478606,
#               17.344347114006478
#             ],
#             [
#               94.83226765570953,
#               17.536668578865445
#             ],
#             [
#               94.4943710381379,
#               17.601880425533874
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040930_74_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:30.749329Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.16,
#         "columns": 13345,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 654462,
#         "origin_y": 1946766,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:59Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9410,
#         "satellite_azimuth": 98.8,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 138.8,
#         "sun_elevation": 59.7,
#         "updated": "2021-10-08T17:38:59Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040928_44_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040928_44_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040928_44_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.52525317178488,
#               17.747294777995258
#             ],
#             [
#               94.48507814551787,
#               17.553515255726698
#             ],
#             [
#               94.82326462794168,
#               17.4897062336477
#             ],
#             [
#               94.86341691089521,
#               17.682046817506695
#             ],
#             [
#               94.52525317178488,
#               17.747294777995258
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040928_44_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:28.443129Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.09,
#         "columns": 13343,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 657618,
#         "origin_y": 1962885,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:58Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "rows": 9410,
#         "satellite_azimuth": 99,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 139,
#         "sun_elevation": 59.6,
#         "updated": "2021-10-08T17:38:58Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040926_13_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040926_13_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040926_13_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.55583024296139,
#               17.892497664469442
#             ],
#             [
#               94.51545210637663,
#               17.698832746282548
#             ],
#             [
#               94.85394191540996,
#               17.634904315139437
#             ],
#             [
#               94.89418220640245,
#               17.82719560106316
#             ],
#             [
#               94.55583024296139,
#               17.892497664469442
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040926_13_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:26.136929Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.14,
#         "columns": 13345,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 660714,
#         "origin_y": 1978980,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:58Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "rows": 9408,
#         "satellite_azimuth": 99.1,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 139.2,
#         "sun_elevation": 59.5,
#         "updated": "2021-10-08T17:38:58Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040923_83_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040923_83_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040923_83_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.58521245925361,
#               18.0375402280413
#             ],
#             [
#               94.54496056951727,
#               17.843926527601358
#             ],
#             [
#               94.88343289343877,
#               17.77994608444975
#             ],
#             [
#               94.9237115642602,
#               17.972219640430303
#             ],
#             [
#               94.58521245925361,
#               18.0375402280413
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040923_83_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:23.830729Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.32,
#         "columns": 13334,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 663711,
#         "origin_y": 1995060,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:58Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9406,
#         "satellite_azimuth": 99.1,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 139.4,
#         "sun_elevation": 59.4,
#         "updated": "2021-10-08T17:38:58Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040921_52_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040921_52_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040921_52_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.61519606006989,
#               18.182208648110894
#             ],
#             [
#               94.57483417722649,
#               17.988548176730536
#             ],
#             [
#               94.91372433946314,
#               17.92461166130254
#             ],
#             [
#               94.9539199202326,
#               18.116882082600583
#             ],
#             [
#               94.61519606006989,
#               18.182208648110894
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040921_52_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:21.524529Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.36,
#         "columns": 13334,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 666741,
#         "origin_y": 2011098,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:58Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9404,
#         "satellite_azimuth": 99,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 139.6,
#         "sun_elevation": 59.3,
#         "updated": "2021-10-08T17:38:58Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040919_21_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040919_21_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040919_21_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               94.64605807010116,
#               18.32650035485575
#             ],
#             [
#               94.60557279956494,
#               18.13279659083722
#             ],
#             [
#               94.9448348343033,
#               18.068943744285697
#             ],
#             [
#               94.98504182171226,
#               18.26109297373838
#             ],
#             [
#               94.64605807010116,
#               18.32650035485575
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_040919_21_227a",
#       "properties": {
#         "acquired": "2021-10-08T04:09:19.218329Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.36,
#         "columns": 13336,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 669858,
#         "origin_y": 2027097,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:38:58Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9400,
#         "satellite_azimuth": 99.1,
#         "satellite_id": "227a",
#         "strip_id": "4978635",
#         "sun_azimuth": 139.7,
#         "sun_elevation": 59.2,
#         "updated": "2021-10-08T17:38:58Z",
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040916_91_227a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040916_91_227a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_040916_91_227a/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
# ...
#             [
#               65.37847772804295,
#               34.105214940228414
#             ],
#             [
#               65.76072421225021,
#               34.03942460384423
#             ],
#             [
#               65.8088273781612,
#               34.2277818225855
#             ],
#             [
#               65.42587282965445,
#               34.29522707748242
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_052909_46_2434",
#       "properties": {
#         "acquired": "2021-10-08T05:29:09.466936Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 13113,
#         "epsg_code": 32641,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 719397,
#         "origin_y": 3797556,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:36:54Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9197,
#         "satellite_azimuth": 100.7,
#         "satellite_id": "2434",
#         "strip_id": "4978576",
#         "sun_azimuth": 140.5,
#         "sun_elevation": 41.7,
#         "updated": "2021-10-08T17:36:54Z",
#         "view_angle": 5
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_052907_16_2434",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_052907_16_2434/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_052907_16_2434/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               65.46212804662035,
#               34.43953384159728
#             ],
#             [
#               65.41501653465482,
#               34.249411359228
#             ],
#             [
#               65.7979794699386,
#               34.18358016866858
#             ],
#             [
#               65.84641797960295,
#               34.37173584056571
#             ],
#             [
#               65.46212804662035,
#               34.43953384159728
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_052907_16_2434",
#       "properties": {
#         "acquired": "2021-10-08T05:29:07.163336Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 13120,
#         "epsg_code": 32641,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 722391,
#         "origin_y": 3813645,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:36:54Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9199,
#         "satellite_azimuth": 100.6,
#         "satellite_id": "2434",
#         "strip_id": "4978576",
#         "sun_azimuth": 140.6,
#         "sun_elevation": 41.6,
#         "updated": "2021-10-08T17:36:54Z",
#         "view_angle": 5
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_052904_85_2434",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_052904_85_2434/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_052904_85_2434/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               65.4987007248913,
#               34.58390144745536
#             ],
#             [
#               65.45112656334705,
#               34.39392762207567
#             ],
#             [
#               65.83505697511028,
#               34.32810984419312
#             ],
#             [
#               65.88306363182977,
#               34.516344712852934
#             ],
#             [
#               65.4987007248913,
#               34.58390144745536
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_052904_85_2434",
#       "properties": {
#         "acquired": "2021-10-08T05:29:04.859736Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 13111,
#         "epsg_code": 32641,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 725331,
#         "origin_y": 3829740,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:36:54Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9188,
#         "satellite_azimuth": 100.7,
#         "satellite_id": "2434",
#         "strip_id": "4978576",
#         "sun_azimuth": 140.7,
#         "sun_elevation": 41.6,
#         "updated": "2021-10-08T17:36:54Z",
#         "view_angle": 5
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_052902_55_2434",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_052902_55_2434/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_052902_55_2434/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               65.53537934916554,
#               34.72828423117118
#             ],
#             [
#               65.48665288972882,
#               34.53847358984188
#             ],
#             [
#               65.87151206593406,
#               34.47254458378393
#             ],
#             [
#               65.91980355253534,
#               34.66082832941436
#             ],
#             [
#               65.53537934916554,
#               34.72828423117118
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_052902_55_2434",
#       "properties": {
#         "acquired": "2021-10-08T05:29:02.556136Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 13124,
#         "epsg_code": 32641,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 728202,
#         "origin_y": 3845841,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:36:54Z",
#         "publishing_stage": "standard",
#         "quality_category": "test",
#         "rows": 9182,
#         "satellite_azimuth": 100.7,
#         "satellite_id": "2434",
#         "strip_id": "4978576",
#         "sun_azimuth": 140.8,
#         "sun_elevation": 41.5,
#         "updated": "2021-10-08T17:36:54Z",
#         "view_angle": 5
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_102100_25_2455",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_102100_25_2455/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_102100_25_2455/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -8.704160219869571,
#               29.768319371558174
#             ],
#             [
#               -8.749569677949882,
#               29.577887516566328
#             ],
#             [
#               -8.384710629435068,
#               29.512282822984197
#             ],
#             [
#               -8.338958792046606,
#               29.701365190898287
#             ],
#             [
#               -8.704160219869571,
#               29.768319371558174
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_102100_25_2455",
#       "properties": {
#         "acquired": "2021-10-08T10:21:00.258029Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 13232,
#         "epsg_code": 32629,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 524253,
#         "origin_y": 3293151,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:36:53Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "rows": 9417,
#         "satellite_azimuth": 99.6,
#         "satellite_id": "2455",
#         "strip_id": "4978993",
#         "sun_azimuth": 136.5,
#         "sun_elevation": 44.4,
#         "updated": "2021-10-08T17:36:53Z",
#         "view_angle": 5.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_102055_64_2455",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_102055_64_2455/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_102055_64_2455/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -8.637108095197519,
#               30.05718476379332
#             ],
#             [
#               -8.68219765403231,
#               29.866699430346316
#             ],
#             [
#               -8.316335290660433,
#               29.801140741709
#             ],
#             [
#               -8.270912589538122,
#               29.990238174246777
#             ],
#             [
#               -8.637108095197519,
#               30.05718476379332
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_102055_64_2455",
#       "properties": {
#         "acquired": "2021-10-08T10:20:55.649791Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 13212,
#         "epsg_code": 32629,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 530691,
#         "origin_y": 3325179,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:36:53Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "rows": 9411,
#         "satellite_azimuth": 99.7,
#         "satellite_id": "2455",
#         "strip_id": "4978993",
#         "sun_azimuth": 136.7,
#         "sun_elevation": 44.2,
#         "updated": "2021-10-08T17:36:53Z",
#         "view_angle": 5.2
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_102051_04_2455",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_102051_04_2455/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_102051_04_2455/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -8.569714223636208,
#               30.346770692226684
#             ],
#             [
#               -8.61425050506754,
#               30.155987877349997
#             ],
#             [
#               -8.246779729578092,
#               30.090426154570306
#             ],
#             [
#               -8.201432546837884,
#               30.279463251476734
#             ],
#             [
#               -8.569714223636208,
#               30.346770692226684
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20211008_102051_04_2455",
#       "properties": {
#         "acquired": "2021-10-08T10:20:51.041554Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 13221,
#         "epsg_code": 32629,
#         "ground_control": true,
#         "gsd": 4.1,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 537144,
#         "origin_y": 3357291,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2021-10-08T17:36:53Z",
#         "publishing_stage": "standard",
#         "quality_category": "standard",
#         "rows": 9416,
#         "satellite_azimuth": 99.8,
#         "satellite_id": "2455",
#         "strip_id": "4978993",
#         "sun_azimuth": 137,
#         "sun_elevation": 44,
#         "updated": "2021-10-08T17:36:53Z",
#         "view_angle": 5.2
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Let's take a closer look at our response data:

# %%
# Assign a features variable 
features = geojson["features"]

# Get the number of features present in the response
len(features)
# Out:
# 250

# %%
# Loop over all the features from the response
for f in features:
    # Print the ID for each feature
    p(f["id"])
# Out:
# "20211008_041000_72_227a"
# "20211008_040958_42_227a"
# "20211008_040956_11_227a"
# "20211008_040953_81_227a"
# "20211008_040951_50_227a"
# "20211008_040949_19_227a"
# "20211008_040946_89_227a"
# "20211008_040944_58_227a"
# "20211008_040942_28_227a"
# "20211008_040939_97_227a"
# "20211008_040937_66_227a"
# "20211008_040935_36_227a"
# "20211008_040933_05_227a"
# "20211008_040930_74_227a"
# "20211008_040928_44_227a"
# "20211008_040926_13_227a"
# "20211008_040923_83_227a"
# "20211008_040921_52_227a"
# "20211008_040919_21_227a"
# "20211008_040916_91_227a"
# "20211008_040914_60_227a"
# "20211008_040912_29_227a"
# "20211008_040909_99_227a"
# "20211008_040907_68_227a"
# "20211008_040905_38_227a"
# "20211008_040903_07_227a"
# "20211008_040900_76_227a"
# "20211008_040858_46_227a"
# "20211008_040856_15_227a"
# "20211008_040853_85_227a"
# "20211008_040851_54_227a"
# "20211008_040849_23_227a"
# "20211008_040846_93_227a"
# "20211008_040844_62_227a"
# "20211008_040842_31_227a"
# "20211008_040840_01_227a"
# "20211008_040837_70_227a"
# "20211008_040835_40_227a"
# "20211008_040833_09_227a"
# "20211008_040830_78_227a"
# "20211008_040828_48_227a"
# "20211008_040826_17_227a"
# "20211008_040823_86_227a"
# "20211008_040821_56_227a"
# "20211008_040819_25_227a"
# "20211008_040816_95_227a"
# "20211008_040814_64_227a"
# "20211008_040812_33_227a"
# "20211008_040810_03_227a"
# "20211008_040807_72_227a"
# "20211008_040805_41_227a"
# "20211008_040803_11_227a"
# "20211008_040800_80_227a"
# "20211008_040758_50_227a"
# "20211008_040756_19_227a"
# "20211008_040753_88_227a"
# "20211008_040751_58_227a"
# "20211008_040749_27_227a"
# "20211008_040746_97_227a"
# "20211008_040744_66_227a"
# "20211008_040742_35_227a"
# "20211008_040740_05_227a"
# "20211008_040737_74_227a"
# "20211008_040735_43_227a"
# "20211008_040733_13_227a"
# "20211008_040730_82_227a"
# "20211008_040728_52_227a"
# "20211008_040726_21_227a"
# "20211008_040723_90_227a"
# "20211008_040721_60_227a"
# "20211008_040719_29_227a"
# "20211008_040716_98_227a"
# "20211008_040714_68_227a"
# "20211008_040712_37_227a"
# "20211008_040710_07_227a"
# "20211008_040707_76_227a"
# "20211008_040705_45_227a"
# "20211008_040703_15_227a"
# "20211008_040700_84_227a"
# "20211008_040658_54_227a"
# "20211008_040656_23_227a"
# "20211008_040653_92_227a"
# "20211008_040651_62_227a"
# "20211008_040649_31_227a"
# "20211008_040647_00_227a"
# "20211008_040644_70_227a"
# "20211008_040642_39_227a"
# "20211008_040640_09_227a"
# "20211008_040637_78_227a"
# "20211008_040633_17_227a"
# "20211008_040628_55_227a"
# "20211008_040623_94_227a"
# "20211008_040619_33_227a"
# "20211008_040614_72_227a"
# "20211008_040610_10_227a"
# "20211008_040605_49_227a"
# "20211008_040600_88_227a"
# "20211008_040556_27_227a"
# "20211008_040551_66_227a"
# "20211008_040547_04_227a"
# "20211008_040540_12_227a"
# "20211008_040537_82_227a"
# "20211008_040533_21_227a"
# "20211008_040517_06_227a"
# "20211008_040510_14_227a"
# "20211008_040440_16_227a"
# "20211008_040435_55_227a"
# "20211008_040430_94_227a"
# "20211008_040424_02_227a"
# "20211008_040417_10_227a"
# "20211008_040412_49_227a"
# "20211008_040407_88_227a"
# "20211008_040403_26_227a"
# "20211008_040358_65_227a"
# "20211008_040354_04_227a"
# "20211008_040349_43_227a"
# "20211008_040344_81_227a"
# "20211008_040340_20_227a"
# "20211008_040335_59_227a"
# "20211008_040330_98_227a"
# "20211008_040326_36_227a"
# "20211008_040312_53_227a"
# "20211008_135248_61_106a"
# "20211008_135246_60_106a"
# "20211008_135244_58_106a"
# "20211008_135242_57_106a"
# "20211008_135240_55_106a"
# "20211008_135238_53_106a"
# "20211008_135232_49_106a"
# "20211008_135228_45_106a"
# "20211008_135224_42_106a"
# "20211008_135212_33_106a"
# "20211008_135146_12_106a"
# "20211008_135144_11_106a"
# "20211008_135142_09_106a"
# "20211008_135140_07_106a"
# "20211008_135136_04_106a"
# "20211008_135132_01_106a"
# "20211008_135127_98_106a"
# "20211008_135117_90_106a"
# "20211008_135115_88_106a"
# "20211008_135113_87_106a"
# "20211008_135101_77_106a"
# "20211008_135059_76_106a"
# "20211008_135055_72_106a"
# "20211008_135037_58_106a"
# "20211008_135035_57_106a"
# "20211008_135033_55_106a"
# "20211008_135031_53_106a"
# "20211008_135003_31_106a"
# "20211008_134953_23_106a"
# "20211008_134949_20_106a"
# "20211008_134937_10_106a"
# "20211008_134633_66_106a"
# "20211008_134601_40_106a"
# "20211008_134537_21_106a"
# "20211008_071111_63_2403"
# "20211008_071109_34_2403"
# "20211008_053129_98_2434"
# "20211008_053127_68_2434"
# "20211008_053125_37_2434"
# "20211008_053123_07_2434"
# "20211008_053120_77_2434"
# "20211008_053118_46_2434"
# "20211008_053116_16_2434"
# "20211008_053113_86_2434"
# "20211008_053111_55_2434"
# "20211008_053109_25_2434"
# "20211008_053106_95_2434"
# "20211008_053104_64_2434"
# "20211008_053102_34_2434"
# "20211008_053100_03_2434"
# "20211008_053057_73_2434"
# "20211008_053055_43_2434"
# "20211008_053053_12_2434"
# "20211008_053050_82_2434"
# "20211008_053048_52_2434"
# "20211008_053046_21_2434"
# "20211008_061013_47_106a"
# "20211008_053043_91_2434"
# "20211008_053041_61_2434"
# "20211008_053039_30_2434"
# "20211008_053037_00_2434"
# "20211008_053034_70_2434"
# "20211008_053032_39_2434"
# "20211008_053030_09_2434"
# "20211008_053027_78_2434"
# "20211008_053025_48_2434"
# "20211008_053023_18_2434"
# "20211008_053020_87_2434"
# "20211008_053018_57_2434"
# "20211008_053016_27_2434"
# "20211008_053013_96_2434"
# "20211008_053011_66_2434"
# "20211008_053009_36_2434"
# "20211008_102330_02_2455"
# "20211008_102300_07_2455"
# "20211008_102239_33_2455"
# "20211008_102234_72_2455"
# "20211008_102230_11_2455"
# "20211008_102223_20_2455"
# "20211008_102216_29_2455"
# "20211008_102211_68_2455"
# "20211008_102207_07_2455"
# "20211008_053007_05_2434"
# "20211008_053004_75_2434"
# "20211008_053002_44_2434"
# "20211008_053000_14_2434"
# "20211008_052957_84_2434"
# "20211008_052955_53_2434"
# "20211008_052953_23_2434"
# "20211008_052950_93_2434"
# "20211008_052948_62_2434"
# "20211008_052946_32_2434"
# "20211008_052944_02_2434"
# "20211008_052941_71_2434"
# "20211008_052939_41_2434"
# "20211008_052937_11_2434"
# "20211008_102200_16_2455"
# "20211008_102157_86_2455"
# "20211008_102153_25_2455"
# "20211008_102148_64_2455"
# "20211008_102144_03_2455"
# "20211008_102137_12_2455"
# "20211008_102132_51_2455"
# "20211008_102130_21_2455"
# "20211008_102127_90_2455"
# "20211008_102123_29_2455"
# "20211008_102118_69_2455"
# "20211008_102114_08_2455"
# "20211008_102109_47_2455"
# "20211008_102104_86_2455"
# "20211008_052934_80_2434"
# "20211008_052932_50_2434"
# "20211008_052930_19_2434"
# "20211008_052927_89_2434"
# "20211008_052925_59_2434"
# "20211008_052923_28_2434"
# "20211008_052920_98_2434"
# "20211008_052918_68_2434"
# "20211008_052916_37_2434"
# "20211008_052914_07_2434"
# "20211008_052911_77_2434"
# "20211008_052909_46_2434"
# "20211008_052907_16_2434"
# "20211008_052904_85_2434"
# "20211008_052902_55_2434"
# "20211008_102100_25_2455"
# "20211008_102055_64_2455"
# "20211008_102051_04_2455"

# %%
# Print the first feature
p(features[0])
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_041000_72_227a",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211008_041000_72_227a/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211008_041000_72_227a/thumb"
#   },
#   "_permissions": [
#     "assets.analytic:download",
#     "assets.analytic_dn:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_udm:download",
#     "assets.udm:download",
#     "assets.visual:download",
#     "assets.visual_xml:download"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           94.10378112122012,
#           15.717864515117691
#         ],
#         [
#           94.06309071128737,
#           15.519001025453896
#         ],
#         [
#           94.4066067839349,
#           15.453356426465788
#         ],
#         [
#           94.44735896425018,
#           15.65111387316564
#         ],
#         [
#           94.10378112122012,
#           15.717864515117691
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20211008_041000_72_227a",
#   "properties": {
#     "acquired": "2021-10-08T04:10:00.729929Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.24,
#     "columns": 13708,
#     "epsg_code": 32646,
#     "ground_control": false,
#     "gsd": 4.2,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene3Band",
#     "origin_x": 614013,
#     "origin_y": 1738038,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-10-08T17:39:00Z",
#     "publishing_stage": "preview",
#     "quality_category": "test",
#     "rows": 9692,
#     "satellite_azimuth": 99,
#     "satellite_id": "227a",
#     "strip_id": "4978635",
#     "sun_azimuth": 136.1,
#     "sun_elevation": 60.9,
#     "updated": "2021-10-08T17:39:00Z",
#     "view_angle": 4
#   },
#   "type": "Feature"
# }

# %% [markdown]
# What happens when there are A LOT of results?
#
# When the number of matching items exceeds 250, the results are delivered in pages. Let's perform a search query that should return a large number of results:

# %%
# Setup a GeoJSON polygon for our geometry filter
geom = {
    "type": "Polygon",
    "coordinates": [
      [
        [
          -125.29632568359376,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          48.37084770238366
        ]
      ]
    ]
  }

# Setup the geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# %%
# Print the response "_links" property
p(geojson["_links"])
# Out:
# {
#   "_first": "https://api.planet.com/data/v1/searches/710464ff3bc84659a23525dd3c5db3c5/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/710464ff3bc84659a23525dd3c5db3c5/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIxLTEwLTAzVDA0OjQwOjE1LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjExMDAyXzE5MTAwMF8zNl8yNDA4IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/710464ff3bc84659a23525dd3c5db3c5/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
# }

# %%
# Assign the "_links" -> "_next" property (link to next page of results) to a variable 
next_url = geojson["_links"]["_next"]

# Print the link to the next page of results
print(next_url)
# Out:
# https://api.planet.com/data/v1/searches/710464ff3bc84659a23525dd3c5db3c5/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIxLTEwLTAzVDA0OjQwOjE1LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjExMDAyXzE5MTAwMF8zNl8yNDA4IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319

# %% [markdown]
# The page size can be set with a `_page_size` parameter in the request:

# %%
# Send the POST request to the API quick search endpoint with a page size of 9
res = session.post(quick_url, json=request, params={"_page_size" : 9})

# Assign the response to a variable
geojson = res.json()

# Get the number of features present in the response
len(geojson["features"])
# Out:
# 9

# %% [markdown]
# ### Mapping Footprints Example
#
# The [`geojsonio`](https://pypi.python.org/pypi/geojsonio/) module can be used to map GeoJSON files and is therefore compatible with the output from Planet Data API searches.
#
# Make sure you've got the module installed and then let's use it to show our resuls on a map:

# %%
# Import the geojsonio python module
# You may need to install this on your system first
import geojsonio

# Assign the url variable to display the geojsonio map, and print to display the link.
url = geojsonio.display(res.text)
print(url)
# Out:
# http://geojson.io/#data=data:application/json,%7B%22_links%22%3A%20%7B%22_first%22%3A%20%22https%3A//api.planet.com/data/v1/searches/dcd12c9104ad44f6bb42a56880c1fc01/results%3F_page%3DeyJwYWdlX3NpemUiOiA5LCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9kZXNjIjogdHJ1ZSwgInNvcnRfc3RhcnQiOiBudWxsLCAic29ydF9sYXN0X2lkIjogbnVsbCwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjogeyJfcGFnZV9zaXplIjogIjkifX0%253D%22%2C%20%22_next%22%3A%20%22https%3A//api.planet.com/data/v1/searches/dcd12c9104ad44f6bb42a56880c1fc01/results%3F_page%%22%2C%20%22_self%22%3A%20%22https%3A//api.planet.com/data/v1/searches/dcd12c9104ad44f6bb42a56880c1fc01/results%3F_page%%22%7D%2C%20%22features%22%3A%20%5B%7B%22_links%22%3A%20%7B%22_self%22%3A%20%22https%3A//api.planet.com/data/v1/item-types/PSScene3Band/items/20211007_181834_67_2434%22%2C%20%22assets%22%3A%20%22https%3A//api.planet.com/data/v1/item-types/PSScene3Band/items/20211007_181834_67_2434/assets/%22%2C%20%22thumbnail%22%3A%20%22https%3A//tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211007_181834_67_2434/thumb%22%7D%2C%20%22_permissions%22%3A%20%5B%22assets.analytic%3Adownload%22%2C%20%22assets.analytic_dn%3Adownload%22%2C%20%22assets.analytic_dn_xml%3Adownload%22%2C%20%22assets.analytic_xml%3Adownload%22%2C%20%22assets.basic_analytic%3Adownload%22%2C%20%22assets.basic_analytic_dn%3Adownload%22%2C%20%22assets.basic_analytic_dn_rpc%3Adownload%22%2C%20%22assets.basic_analytic_dn_xml%3Adownload%22%2C%20%22assets.basic_analytic_rpc%3Adownload%22%2C%20%22assets.basic_analytic_xml%3Adownload%22%2C%20%22assets.basic_udm%3Adownload%22%2C%20%22assets.udm%3Adownload%22%2C%20%22assets.visual%3Adownload%22%2C%20%22assets.visual_xml%3Adownload%22%5D%2C%20%22geometry%22%3A%20%7B%22coordinates%22%3A%20%5B%5B%5B-123.38798909937168%2C%2048.80571191006027%5D%2C%20%5B-123.45454140009068%2C%2048.61626027844213%5D%2C%20%5B-122.97834779385612%2C%2048.541611233693224%5D%2C%20%5B-122.90949475783441%2C%2048.729578158739386%5D%2C%20%5B-123.38798909937168%2C%2048.80571191006027%5D%5D%5D%2C%20%22type%22%3A%20%22Polygon%22%7D%2C%20%22id%22%3A%20%2220211007_181834_67_2434%22%2C%20%22properties%22%3A%20%7B%22acquired%22%3A%20%222021-10-07T18%3A18%3A34.678663Z%22%2C%20%22anomalous_pixels%22%3A%200%2C%20%22cloud_cover%22%3A%200.15%2C%20%22columns%22%3A%2013387%2C%20%22epsg_code%22%3A%2032610%2C%20%22ground_control%22%3A%20true%2C%20%22gsd%22%3A%204.1%2C%20%22instrument%22%3A%20%22PSB.SD%22%2C%20%22item_type%22%3A%20%22PSScene3Band%22%2C%20%22origin_x%22%3A%20466497%2C%20%22origin_y%22%3A%205405931%2C%20%22pixel_resolution%22%3A%203%2C%20%22provider%22%3A%20%22planetscope%22%2C%20%22published%22%3A%20%222021-10-08T02%3A48%3A31Z%22%2C%20%22publishing_stage%22%3A%20%22finalized%22%2C%20%22quality_category%22%3A%20%22test%22%2C%20%22rows%22%3A%209810%2C%20%22satellite_azimuth%22%3A%20104.8%2C%20%22satellite_id%22%3A%20%222434%22%2C%20%22strip_id%22%3A%20%224976769%22%2C%20%22sun_azimuth%22%3A%20150.4%2C%20%22sun_elevation%22%3A%2031.4%2C%20%22updated%22%3A%20%222021-10-08T06%3A28%3A33Z%22%2C%20%22view_angle%22%3A%203%7D%2C%20%22type%22%3A%20%22Feature%22%7D%2C%20%7B%22_links%22%3A%20%7B%22_self%22%3A%20%22https%3A//api.planet.com/data/v1/item-types/PSScene3Band/items/20211007_181832_37_2434%22%2C%20%22assets%22%3A%20%22https%3A//api.planet.com/data/v1/item-types/PSScene3Band/items/20211007_181832_37_2434/assets/%22%2C%20%22thumbnail%22%3A%20%22https%3A//tiles.planet.com/data/v1/item-types/PSScene3Ba ...

# %% [markdown]
# We can now iterate through the pages of results.

# %%
# Assign the next_url variable to the next page of results from the response (Setup the next page of results)
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %%
# Setup the next page of results
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %% [markdown]
# Cool huh? Now that we know how to search and find items we are interested in, let's try activating and downloading some assets.

# %% [markdown]
# ## Assets & Permissions
#
# Assets may be imagery files, image masks, metadata files or some other file type that might be associated with the item. You can find more information about assets v.s. items here : https://developers.planet.com/docs/apis/data/items-assets/
#
# The `_permissions` element in each feature contains a list of assets that the user has access to.

# %% [markdown]
# Let's pick the first item out of our search result to work with, and then see what the permissions are for that item:

# %%
# Assign a variable to the search result features (items)
features = geojson["features"]

# Get the first result's feature
feature = features[0]

# Print the ID
p(feature["id"])

# Print the permissions
p(feature["_permissions"])
# Out:
# "20211007_180600_72_106c"
# [
#   "assets.analytic:download",
#   "assets.analytic_dn:download",
#   "assets.analytic_dn_xml:download",
#   "assets.analytic_xml:download",
#   "assets.basic_analytic:download",
#   "assets.basic_analytic_dn:download",
#   "assets.basic_analytic_dn_rpc:download",
#   "assets.basic_analytic_dn_xml:download",
#   "assets.basic_analytic_rpc:download",
#   "assets.basic_analytic_xml:download",
#   "assets.basic_udm:download",
#   "assets.udm:download",
#   "assets.visual:download",
#   "assets.visual_xml:download"
# ]

# %% [markdown]
# Each item has an `assets` endpoint in the API that lists all of its assets. Let's get a list of available assets for our item:

# %%
# Get the assets link for the item
assets_url = feature["_links"]["assets"]

# Print the assets link
print(assets_url)
# Out:
# https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211007_180600_72_106c/assets/

# %%
# Send a GET request to the assets url for the item (Get the list of available assets for the item)
res = session.get(assets_url)

# Assign a variable to the response
assets = res.json()

# %%
# Print the asset types that are available
print(assets.keys())
# Out:
# dict_keys(['analytic', 'analytic_dn', 'analytic_dn_xml', 'analytic_xml', 'basic_analytic', 'basic_analytic_dn', 'basic_analytic_dn_rpc', 'basic_analytic_dn_xml', 'basic_analytic_rpc', 'basic_analytic_xml', 'basic_udm', 'udm', 'visual', 'visual_xml'])

# %% [markdown]
# We can see that most items have several assets available. Let's check out the "visual" asset for this item:

# %%
# Assign a variable to the visual asset from the item's assets
visual = assets["visual"]

# Print the visual asset data
p(visual)
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjExMDA3XzE4MDYwMF83Ml8xMDZjIiwgImMiOiAiUFNTY2VuZTNCYW5kIiwgInQiOiAidmlzdWFsIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#     "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjExMDA3XzE4MDYwMF83Ml8xMDZjIiwgImMiOiAiUFNTY2VuZTNCYW5kIiwgInQiOiAidmlzdWFsIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#     "type": "https://api.planet.com/data/v1/asset-types/visual"
#   },
#   "_permissions": [
#     "download"
#   ],
#   "md5_digest": null,
#   "status": "inactive",
#   "type": "visual"
# }

# %% [markdown]
# ### Activating Assets
#
# Before an asset is available for download, it must be **activated**.
#
# You can activate an asset by sending a *POST* or *GET* request to the asset's **"activation link"**.
#
# The activation usually takes a little bit of time, but hey, I'm sure by now you have some ideas on how to automate your workflow. Go robots!

# %%
# Setup the activation url for a particular asset (in this case the visual asset)
activation_url = visual["_links"]["activate"]

# Send a request to the activation url to activate the item
res = session.get(activation_url)

# Print the response from the activation request
p(res.status_code)
# Out:
# 202

# %% [markdown]
# #### Activation Response Codes
#
# After hitting an activation url, you should get a response code back from the API:
#
# * **`202`** - The request has been accepted and the activation will begin shortly.
# * **`204`** - The asset is already active and no further action is needed.
# * **`401`** - The user does not have permissions to download this file.

# %% [markdown]
# After requesting to activate an asset, let's do another request to see if the assset's status has changed:

# %%
import time

asset_activated = False

while asset_activated == False:
    # Send a request to the item's assets url
    res = session.get(assets_url)

    # Assign a variable to the item's assets url response
    assets = res.json()

    # Assign a variable to the visual asset from the response
    visual = assets["visual"]

    asset_status = visual["status"]
    
    # If asset is already active, we are done
    if asset_status == 'active':
        asset_activated = True
        print("Asset is active and ready to download")

# Print the visual asset data    
p(visual)
# Out:
# Asset is active and ready to download
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjExMDA3XzE4MDYwMF83Ml8xMDZjIiwgImMiOiAiUFNTY2VuZTNCYW5kIiwgInQiOiAidmlzdWFsIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#     "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjExMDA3XzE4MDYwMF83Ml8xMDZjIiwgImMiOiAiUFNTY2VuZTNCYW5kIiwgInQiOiAidmlzdWFsIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#     "type": "https://api.planet.com/data/v1/asset-types/visual"
#   },
#   "_permissions": [
#     "download"
#   ],
#   "expires_at": "2021-10-08T19:11:17.541696",
#   "location": "https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..odxOn02FhRVqJMuPJNljRbvXWVEu_qHlu6Ui0S3Ued1EOXAr_vrHSE0uTo5R4jRVXTx27vY2WU9HNQIw7Ci6TA",
#   "md5_digest": "bae637a235a5e4b4b2808cb9f32fb35e",
#   "status": "active",
#   "type": "visual"
# }

# %% [markdown]
# #### Activation Status
#
# An asset may have a `status` of `inactive`, `activating` or `active`.
#
# Once an asset is active, the response will contain a `location`. We'll use the `location` to download the asset!
#
# Below, we are polling the API until the item is activated. This may take awhile.

# %% [markdown]
# ### Downloading Assets
#
# The asset's `location` property points asset file for use to download. Are you ready to download the asset? Let's do it!

# %%
# Assign a variable to the visual asset's location endpoint
location_url = visual["location"]

# Print the location endpoint
print(location_url)
# Out:
# https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..odxOn02FhRVqJMuPJNljRbvXWVEu_qHlu6Ui0S3Ued1EOXAr_vrHSE0uTo5R4jRVXTx27vY2WU9HNQIw7Ci6TA

# %% [markdown]
# There's the location url! You could click on it to open it in a browser and download the file... but why not let your code do it?
#
# Let's write a small helper function to download asset files:

# %%
# Create a function to download asset files
# Parameters: 
# - url (the location url)
# - filename (the filename to save it as. defaults to whatever the file is called originally)

def pl_download(url, filename=None):
    
    # Send a GET request to the provided location url, using your API Key for authentication
    res = requests.get(url, stream=True, auth=(PLANET_API_KEY, ""))
    # If no filename argument is given
    if not filename:
        # Construct a filename from the API response
        if "content-disposition" in res.headers:
            filename = res.headers["content-disposition"].split("filename=")[-1].strip("'\"")
        # Construct a filename from the location url
        else:
            filename = url.split("=")[1][:10]
    # Save the file
    with open('output/' + filename, "wb") as f:
        for chunk in res.iter_content(chunk_size=1024):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                f.flush()

    return filename

# %%
# Download the file from an activated asset's location url
pl_download(location_url)
# Out:
# '20211007_180600_72_106c_3B_Visual.tif'

# %% [markdown]
# **High Five!** You should now be downloading your very own GeoTIFF! We can't wait to see what you'll do with it!

# %% [markdown]
# ### Rate Limits
#
# ---
#
# Now that you know how to download assets, you should probably keep some of the API **rate limits** in mind:
#
# * For most endpoints, the rate limit is 10 requests per second, per API key.
# * For activation endpoints, the rate limit is 5 requests per second, per API key.
# * For download endpoints, the rate limit is 15 requests per second, per API key.
#
# If you're writing to code to automate accessing the API, you should account for `429` responses and handle retries after a *backoff period*.

# %% [markdown]
# ## Saved Searches
#
# ---
#
# The `/searches` endpoint lets you created saved searches that can be reused.
#
# To view your saved searches, visit the [`searches/?search_type=saved`](https://api.planet.com/data/v1/searches/?search_type=saved) endpoint.
#
# Finally, let's create a saved search:

# %%
# Setup the saved searches endpoint url
searches_url = "{}/searches".format(URL)

# %%
# Setup the request, specifying a name for the saved search, along with the usual search item_types and filter.
request = {
    "name" : "Vancouver Island",
    "item_types" : item_types,
    "filter" : geometry_filter
}

# Send a POST request to the saved searches endpoint (Create the saved search)
res = session.post(searches_url, json=request)

# Print the response
p(res.json())
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/6950887354d84e23889c3e308355fdcf",
#     "results": "https://api.planet.com/data/v1/searches/6950887354d84e23889c3e308355fdcf/results"
#   },
#   "created": "2021-10-08T18:31:51.983485Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "type": "GeometryFilter"
#   },
#   "id": "6950887354d84e23889c3e308355fdcf",
#   "item_types": [
#     "PSScene3Band"
#   ],
#   "last_executed": null,
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2021-10-08T18:31:51.983485Z"
# }

# %% [markdown]
# Now that we created a saved search, let's get a list of our saved searches:

# %%
# Send a GET request to the saved searches endpoint with the saved search type parameter (Get saved searches)
res = session.get(searches_url, params={"search_type" : "saved"})

# Assign a variable to the searches property in the saved searches response
searches = res.json()["searches"]
print(searches[1]['name'])
print(len(searches))

# Loop through the searches
for search in searches:
    # Print the ID, Created Time, and Name for each saved search
    print("id: {} created: {} name: {}".format(search["id"], search["created"], search['name']))
# Out:
# Vancouver Island
# 2
# id: 6950887354d84e23889c3e308355fdcf created: 2021-10-08T18:31:51.983485Z name: Vancouver Island
# id: fe44f67590ae44d6a4e5e8030de85f90 created: 2021-10-08T18:29:03.053168Z name: Vancouver Island

# %% [markdown]
# Ok, now let's check out the results from a particular saved search:

# %%
# Setup the saved search url, using the first saved search in the list
saved_url = "{}/{}".format(searches_url, searches[0]["id"])

# Print the saved search url
p(saved_url)

# Setup the saved search's results url
results_url = "{}/results".format(saved_url)

# Print the saved search's results url
p(results_url)
# Out:
# "https://api.planet.com/data/v1/searches/6950887354d84e23889c3e308355fdcf"
# "https://api.planet.com/data/v1/searches/6950887354d84e23889c3e308355fdcf/results"

# %%
# Send a GET request to the saved search url (Get the saved search data)
res = session.get(saved_url)

# Print the response
p(res.json())
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/6950887354d84e23889c3e308355fdcf",
#     "results": "https://api.planet.com/data/v1/searches/6950887354d84e23889c3e308355fdcf/results"
#   },
#   "created": "2021-10-08T18:31:51.983485Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "type": "GeometryFilter"
#   },
#   "id": "6950887354d84e23889c3e308355fdcf",
#   "item_types": [
#     "PSScene3Band"
#   ],
#   "last_executed": "2021-10-08T18:33:01.563942Z",
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2021-10-08T18:33:01.564187Z"
# }

# %%
# Send a GET request to the saved search results url (Get the saved search results)
results = session.get(results_url).json()

# Print the number of features in the saved search
print(len(results["features"]))

# Print the first feature in the saved search
print(results["features"][0])
# Out:
# 250
# {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211007_182737_88_2235', 'assets': 'https://api.planet.com/data/v1/item-types/PSScene3Band/items/20211007_182737_88_2235/assets/', 'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20211007_182737_88_2235/thumb'}, '_permissions': ['assets.analytic:download', 'assets.analytic_dn:download', 'assets.analytic_dn_xml:download', 'assets.analytic_xml:download', 'assets.basic_analytic:download', 'assets.basic_analytic_dn:download', 'assets.basic_analytic_dn_rpc:download', 'assets.basic_analytic_dn_xml:download', 'assets.basic_analytic_rpc:download', 'assets.basic_analytic_xml:download', 'assets.basic_udm:download', 'assets.udm:download', 'assets.visual:download', 'assets.visual_xml:download'], 'geometry': {'coordinates': [[[-125.56641403394262, 49.168884422632615], [-125.62991731055041, 48.98804871303205], [-125.17022259214622, 48.918075938634594], [-125.1050566301443, 49.096916264250765], [-125.56641403394262, 49.168884422632615]]], 'type': 'Polygon'}, 'id': '20211007_182737_88_2235', 'properties': {'acquired': '2021-10-07T18:27:37.886863Z', 'anomalous_pixels': 0, 'cloud_cover': 0.16, 'columns': 12911, 'epsg_code': 32610, 'ground_control': True, 'gsd': 3.9, 'instrument': 'PSB.SD', 'item_type': 'PSScene3Band', 'origin_x': 307602, 'origin_y': 5449404, 'pixel_resolution': 3, 'provider': 'planetscope', 'published': '2021-10-08T10:33:42Z', 'publishing_stage': 'finalized', 'quality_category': 'standard', 'rows': 9596, 'satellite_azimuth': 102.8, 'satellite_id': '2235', 'strip_id': '4977993', 'sun_azimuth': 150.8, 'sun_elevation': 31.2, 'updated': '2021-10-08T16:04:28Z', 'view_angle': 4.9}, 'type': 'Feature'}

# %% [markdown]
# A saved search can also be updated by senidng a **`PUT`** request with a changed search definition back to the API.
#
# Did you know that saved searches can also send you a daily email to alert you to when new items are added to the search resutlts? Oh yeah!

# %%
# Assign a variable to the saved search response
search = res.json()

# Print the saved search
p(search)
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/6950887354d84e23889c3e308355fdcf",
#     "results": "https://api.planet.com/data/v1/searches/6950887354d84e23889c3e308355fdcf/results"
#   },
#   "created": "2021-10-08T18:31:51.983485Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "type": "GeometryFilter"
#   },
#   "id": "6950887354d84e23889c3e308355fdcf",
#   "item_types": [
#     "PSScene3Band"
#   ],
#   "last_executed": "2021-10-08T18:33:01.563942Z",
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2021-10-08T18:33:01.564187Z"
# }

# %%
# Change the saved search name to "South Vancouver Island"
search["name"] = "South Vancouver Island"

# Set the daily email enabled to true (Get email alerts when new items show up in this search)
search["__daily_email_enabled"] = True

# Send a PUT request to the saved search endpoint (Update the saved search)
res = session.put(saved_url, json=search)

# The response status code
res.status_code
# Out:
# 400

# %% [markdown]
# ## Conclusion
#
# You made it! You should now be able to use the Planet API to find items and assets by searching, get stats and save searches, and activate and download assets using Python code!
#
# Don't forget to visit the [Planet API Reference Docs](https://www.planet.com/docs/reference/).
